# %%
import pytesseract as pyt
import funclib.iolib as iolib
import cv2

# %%
img=cv2.imread('C:/temp/sa/441/SA_441_001.jpg')

# %%
res = pyt.image_to_data(img)

# %%
txt = pyt.image_to_string(img)

# %%
# Out:
# 'NAM 4 tO\n@ www.seangler.com\n\nIssue 441 £3.25 On sale June 11 - July 8 bles mLU ee\n\n \n   \n  \n   \n  \n\n    \n\n    \n\nAGAZINE\n\n \n\nne sy ee\n| fe oe\ned\n\nBi\n\nPE INA\nFoor Te 4\n\n‘THE MARK : MAS ee) Ps\n_EVERY CAST a ee\n\n \n\n \n\n  \n  \n \n  \n\n    \n    \n \n\n \n \n\n= i “s é\na sf a Po\nHE AAAS He F — .\nPeCrE TY al 4 f\nHTN ;\ntires Uae - %\nui -\n\nee eae\n\n      \n     \n\nMID-PRICED SECTION) _~ \\\nBOAT REELS St Pat = :\nREVIEWED AND RATED ee AM'

# %%
bb = pyt.image_to_boxes(img)

# %%
bb
# Out:
# 'N 664 3274 1600 3474 0\nA 1596 3276 1691 3472 0\nM 1697 3379 1790 3472 0\n4 2032 3186 2111 3488 0\nt 2146 3174 2333 3474 0\nO 2224 3169 2404 3469 0\n@ 1134 3162 1180 3208 0\nw 1191 3172 1238 3201 0\nw 1211 3161 1270 3211 0\nw 1239 3172 1286 3201 0\n. 1288 3172 1334 3201 0\ns 1335 3172 1346 3181 0\ne 1349 3171 1375 3202 0\na 1377 3171 1407 3202 0\nn 1409 3171 1437 3202 0\ng 1442 3172 1471 3202 0\nl 1475 3161 1505 3202 0\ne 1510 3172 1521 3211 0\nr 1525 3171 1554 3202 0\n. 1558 3172 1588 3201 0\nc 1592 3171 1616 3202 0\no 1618 3171 1647 3202 0\nm 1651 3172 1696 3202 0\nI 1144 3120 1150 3146 0\ns 1153 3120 1165 3139 0\ns 1168 3120 1181 3139 0\nu 1183 3120 1201 3139 0\ne 1203 3120 1218 3139 0\n4 1228 3120 1247 3146 0\n4 1249 3120 1268 3146 0\n1 1270 3120 1283 3146 0\n£ 1302 3120 1318 3146 0\n3 1304 3120 1333 3146 0\n. 1322 3120 1344 3146 0\n2 1348 3120 1363 3146 0\n5 1366 3120 1382 3146 0\nO 1393 3120 1410 3146 0\nn 1393 3120 1432 3146 0\ns 1442 3120 1448 3147 0\na 1442 3120 1455 3139 0
# ...

# %%
def a(**args):
    print(**args)
    
    
a(a=2, b=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-c2c22d0ac253> in <module>
#       3
#       4
# ----> 5 a(a=2, b=3)
#
# <ipython-input-25-c2c22d0ac253> in a(**args)
#       1 def a(**args):
# ----> 2     print(**args)
#       3
#       4
#       5 a(a=2, b=3)
#
# TypeError: 'b' is an invalid keyword argument for this function

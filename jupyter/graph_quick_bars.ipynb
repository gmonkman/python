# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="ticks")

#grey = ["#FFFFFF", "#999999", "#666666", "#333333", "#000000"]
#grey = ["#FFFFFF", "#AAAAAA"]
#sns.set(font='Times New Roman', font_scale=1.4)
#sns.set_palette(grey)

print('done')

# %%
D = [645.170264777472, 185244.832186043, 317014.231087451, 189869.407528425, 7727.23206442239, 157.053434368276, 497.477938313114, 94670.8383501009, 120283.63783788, 13681.3753904675, 12929.2201683051, 587.827601893559, 276.029224493318, 41630.7907453785, 40939.0139319577, 27043.3178229638, 29542.1949442316, 53726.1454595751, 53627.5930386766, 59251.9316723664, 165.105593485501, 163.148000537549, 18984.1563142351, 9238.80632375936, 6885.7911767738, 13213.2118038646, 1489.62586146814, 26793.5347603036, 7106.27431670089, 2097.682220922, 12487.3443239224, 257600.610583363, 259600.044576803, 1296.89338122162, 2646.25341391727, 4650.47961250753, 398.206028873267, 100.68216531975, 40378.9713946759, 32723.5887265723, 99139.8875552758, 25234.8867958724, 1231.16655235924, 22813.2525009147, 40474.8597658331, 1856.15162274216, 738.812688293131, 22.1762494917516, 127852.828632961, 29775.202420328, 30251.7982683868, 28960.9638178327, 1231.16655235924, 3223.90239894862, 1247.76308500795, 7905.89997576522, 4001.95870596901, 4357.62032237333, 1471.64685222137, 3771.11814194175, 14356.175242238, 39097.3620723117, 16172.7656895537, 16075.2328033676, 15734.3657944494, 20809.905997148, 106220.065253578, 117486.092983822, 118154.548926402, 1661.37903405997, 1502.58971185598, 15390.4918482643, 2926.75909982747, 4936.85306638324, 352.942099977819, 120.942485019968, 3024.46870296087, 4392.26253711614, 301095.873999799, 220302.758074452, 25084.7320010508, 29683.9009883408, 16075.2328033676, 23046.6385072794, 19014.9399931232, 18607.8321494227, 3419.78018687112, 23103.4588896023, 9369.40891720328, 16075.2328033676, 105.827683924079, 152.881080705095, 130432.774697115, 19337.8582553017, 6481.90629500063, 23288.8096362723, 36982.9849286861, 37270.8763732936, 53662.1644816389, 107932.630858376, 75114.1336336564, 38914.1648793721, 33203.0075608925, 7992.39518920819, 2679.67033795209, 9564.6532235752, 20441.0616566539, 8003.17824091975, 8639.28723860162, 7831.29866292032, 13875.1699076068, 13061.2412962193, 12968.2448764889, 58999.9631732753, 24001.3307618713, 53909.823051173, 62853.7747765658, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 16243.8524543047, 6674.97302012422, 24336.5802850426, 285.14825973706, 64.5414530290441, 217875.207060492, 201816.029722476, 248773.961023538, 149957.096355532, 93823.9796754645, 3323.63770717019, 2113.0509598654, 59205.7372533991, 49844.8380732542, 38352.2843003789, 13783.1238813133, 106642.666903495, 20136.3256375156, 39279.9867060061, 49689.5483780383, 115626.203614991, 1231.16655235924, 31083.2818765417, 39121.5320908468, 77678.564325246, 380.817770655907, 14562.5868921673, 11993.1440623566, 55.8837027444483, 38395.5162652675, 29022.0149688602, 6420.04136945592, 6378.26505696896, 1138.45999053649, 38708.9004276412, 36345.1773306461, 59699.3500091682, 41807.3980454959, 34550.4475929599, 42564.7746867847, 16.3228423493427, 133323.159293456, 667.663331675873, 566.070592134515, 455.694465281122, 63022.9310985036, 61675.5672358642, 62963.9191277031, 1047.13566240669, 1726.78747627392, 833.754596971846, 732.161857430488, 318.876640848771, 503.803818518197, 75119.3607257243, 76906.5894884502, 106262.899226039, 99873.2748641811, 120155.203014464, 120161.274140481, 1636.3387577496, 2555.65784578012, 14698.7196074896, 6067.67516071741, 6659.72073745366, 116.113033013679, 56.4271046072093, 36982.9849286861, 37270.8763732936, 84742.2583124658, 318787.158881648, 79193.6212417645, 59525.5285814222, 38866.3590823727, 56527.9663472911, 398.206028873267, 100.68216531975, 50160.0019535822, 234590.014936767, 7207.9970968208, 70248.3287512563, 71878.0095908231, 83235.1096507397, 29956.0676611137, 31467.8950165582, 55906.1796423999, 31376.1177507954, 33082.6821194926, 15930.0072802454, 49816.5963875827, 50495.2170310016, 6575.0201531482, 44736.7683990614, 9363.31485657881, 8588.56313603438, 8478.29437244718, 8424.53992549178, 6986.92025529698, 106534.658847529, 105164.083375368, 98154.2063421278, 265881.406942199, 98577.4713523465, 76250.6345613541, 64627.7391468771, 64915.171832041, 67741.0649378462, 69259.5676108839, 71140.6085347772, 64838.3209392977, 62229.8932347855, 10191.1149934228, 4609.9497339827, 82212.9587570128, 71696.7257012923, 27029.5600822834, 82531.4380148114, 1566.43504916357, 1740.19297824683, 3157.42592751229, 5066.94277545488, 2678.84357044532, 776.458767526788, 99863.4268788019, 91442.5278966552, 94156.427348632, 6824.90737549132, 9338.0036826125, 2926.75909982747, 4936.85306638324, 29754.4711835021, 33885.6833851376, 78748.5386595732, 2367.48284749759, 85306.609714591, 269635.641958756, 200.880466402473, 2748.90367264954, 3146.1869277557, 667.663331675873, 566.070592134515, 16047.9197541244, 398.206028873267, 100.68216531975, 58.7388248369891, 7459.97312429195, 61189.3805516982, 61138.8834667541, 24421.6014659106, 28739.0719837288, 36982.9849286861, 37270.8763732936, 939.647131209686, 765.476897764711, 28502.9484160247, 27538.760045669, 36982.9849286861, 37270.8763732936, 55.8837027444483, 2503.22465938129, 19337.8582553017, 74.3657790574448, 47394.5693211796, 48777.3119871082, 49275.87054464, 490.175644231983, 97252.109611701, 128472.334862071, 41962.6523769007, 42717.7109154456, 41753.5225450899, 83972.1491771803, 72916.0079924524, 47394.3221433593, 2926.75909982747, 4936.85306638324, 172.584973036458, 87.6629534755182, 7050.0901392691, 16178.8870682882, 15686.3969583108, 4828.12111498445, 6547.27767107307, 3932.49989460599, 37309.1458147217, 36020.7844884336, 5464.37139355726, 4837.72180647165, 5214.81215779854, 24407.2529326777, 42068.8601975961, 4001.95870596901, 4357.62032237333, 2488.91064827619, 58304.6277967036, 7865.32144566663, 2963.0341471296, 6629.21128288077, 89.9569446043147, 46380.9466329274, 29985.98634893, 74468.5859618556, 6174.87505432243, 6202.81004403112, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 53245.5428776038, 47843.8069577467, 28502.9484160247, 27538.760045669, 844.798579275008, 21239.5085097229, 74468.5859618555, 27742.4362139144, 26589.3618023656, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 3313.85856569276, 1912.26404284212, 2309.15705582493, 4001.95870596901, 4357.62032237333, 51941.9656989116, 15960.0069247879, 16203.080886329, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 16075.2328033676, 10462.4053117686, 2649.48106975283, 2303.94096584347, 978.210874007546, 1200.01359268611, 874.058492322683, 28502.9484160247, 27538.760045669, 6896.21895765393, 6957.26595603622, 2874.98772369872, 8241.64417111204, 1590.62962703208, 8525.11892901175, 12848.1705650344, 10870.9598630101, 398.206028873267, 100.68216531975, 658.254210804327, 58023.8142959694, 56816.7399974924, 65275.1644014031, 66273.7225362944, 54789.6454481294, 15089.1442964011, 28990.8983180029, 51231.6252950158, 16075.2328033676, 552.411858399765, 60183.5061423319, 46668.6333132622, 339.827732395811, 4543.005008474, 14568.9882459507, 18229.5014058069, 3263.63297233387, 5040.54247213971, 34611.5517309391, 2003.4634332603, 2929.73425000019, 74952.8962537709, 73816.1464338528, 4778.87249697422, 12432.5515288051, 29151.1674739006, 1010.20469158349, 1533.65712371744, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 12484.373274721, 9737.01364015589, 490.963527188231, 10186.8548760226, 14356.175242238, 939.647131209686, 765.476897764711, 9459.55834462236, 9090.63054171216, 1012.70680144016, 175.594808747193, 84706.4905000096, 73650.3493152817, 48128.6634661886, 71560.7670427717, 10115.1414311492, 14640.2917620512, 83046.2819805495, 129357.862729424, 126592.918362475, 583.163675813022, 3717.78716509019, 4063.05589236591, 2442.57894508746, 78964.5330365169, 16075.2328033676, 8888.55156116432, 13126.1079786317, 340.396859535075, 2146.15677478869, 10866.8240402462, 11750.254004767, 9724.70541100056, 37304.5884083199, 16075.2328033676, 8100.65293700648, 22813.2525009148, 40474.8597658331, 255.167752297303, 303.185109429245, 279480.211873755, 324021.23527511, 292491.38484444, 342681.360935878, 341953.310039447, 272823.292184098, 324009.175469596, 346889.653593849, 330269.235803238, 344026.21315091, 342121.81215428, 347437.576400163, 14356.175242238, 3210.22461028652, 48883.1161968722, 5364.6373587917, 5122.79347148782, 190550.453244645, 183041.425770549, 166700.091595302, 228319.792361715, 206229.670988471, 212260.6150237, 259218.546324761, 160401.681656756, 2911.83232932982, 561.127273411792, 380.817770655907, 10199.8134264271, 10775.7313088592, 10953.2065447233, 39152.5350651669, 100892.040899703, 86078.686640521, 93618.6830399937, 13344.8335501362, 102.369921957763, 1542.34645833776, 1746.13633341972, 16075.2328033676, 1919.65615760217, 2300.76513012454, 11891.8101323552, 23345.4130563754, 16327.9586412978, 29683.9009883408, 44359.7426141151, 1864.15501149668, 1023.3122550351, 25858.2380340544, 90336.8654554026, 153175.665720884, 152120.572302137, 164604.694454292, 75181.7586486951, 380.817770655907, 19337.8582553017, 24663.8843108134, 24333.6971420371, 16075.2328033676, 30392.1036495274, 3937.85967839162, 5022.27902985833, 3258.09478190648, 3892.96057067616, 71868.8837917406, 44785.4418942574, 54335.2186310429, 1231.16655235924, 136.012689198563, 8449.04613060234, 35166.3767057038, 37464.6869431648, 47077.3759909243, 9179.4351480092, 9744.47568862683, 1342.24089681159, 16016.9853780818, 2140.88523286617, 97846.0685297032, 83334.7513584655, 57114.6273256259, 78177.9758693609, 6858.72940185392, 398.206028873267, 100.68216531975, 217979.170162831, 230583.606720964, 229552.734577958, 230167.485050007, 38102.3727928803, 9420.404946814, 9712.48764411936, 55.8837027444483, 4001.95870596901, 4357.62032237333, 140.706246505873, 211.60387541609, 36982.9849286861, 37270.8763732936, 11235.8851670407, 29680.0672361943, 37323.261964084, 36412.8273770491, 2926.75909982747, 4936.85306638324, 7277.08714193597, 6559.11677966549, 716.656480374193, 47866.6305604207, 48154.5220050282, 37309.1458147217, 36020.7844884336, 4001.95870596901, 4357.62032237333, 550.696375876155, 94216.1806078267, 95194.2004036776, 94967.0488846865, 1459.96585583202, 786.203510370341, 44148.5181528298, 60101.1148757128, 59793.6230436501, 3226.89675550796, 1099.00964046036, 380.817770655907, 16075.2328033676, 844.798579275008, 16562.5015385432, 17321.0487098954, 14356.175242238, 358415.519046812, 132863.320753378, 17371.6711978961, 38453.0937798998, 13137.5455802551, 57179.2516879579, 121093.186968869, 10899.9084998347, 3118.82804160328, 4341.38652612177, 67506.9746874263, 67593.1238565141, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529483, 25460.6460476849, 29956.0676611137, 107761.13571061, 87343.7261574945, 104343.188067858, 55858.9712807683, 105279.057493626, 108080.217412432, 88136.19712613, 55904.6634132464, 50619.8917984435, 116.113033013679, 56.4271046072093, 2926.75909982747, 4936.85306638324, 3198.12022203508, 24951.7336656281, 26920.2978981647, 27933.8353640163, 36982.9849286861, 37270.8763732936, 4.43587975574906, 16.5322001370311, 3458.38954358547, 2846.04664650645, 1725.25063823698, 2532.9436458643, 44610.9729374625, 26395.0142745991, 45538.6753430896, 100998.484325828, 3419.44985664345, 90238.9738802455, 3799.37210766113, 8324.55592938742, 55474.5300094339, 60808.7570070567, 55762.4214540415, 11128.8747920339, 1976.96749552712, 4410.00906559182, 29390.4928785669, 79400.9615099252, 97197.213520732, 134460.902553787, 130173.146680095, 108609.34109722, 171007.339604957, 99451.2902740251, 126372.457024038, 69637.372653854, 129281.893430623, 398.206028873267, 100.68216531975, 21026.3467770811, 30400.6503084859, 535.778320926114, 35.9876265013509, 430.335507715417, 3907.49810066986, 6557.97275492812, 3064.59097399396, 82.0380194876043, 9696.51006616501, 4001.95870596901, 4357.62032237333, 2154.10060268908, 3472.39278598836, 3339.45079263317, 54918.4673368106, 45063.4841038352, 38038.15458219, 43169.7573307585, 11422.2436922383, 10890.2359298531, 10850.0311574498, 10467.6238342472, 1012.56210112466, 1658.13449840418, 398.206028873267, 100.68216531975, 217875.207060492, 201816.029722476, 248773.961023538, 149957.096355532, 5497.07375038258, 5784.9651949901, 48.8008458005068, 4928.47611226194, 1231.16655235924, 94802.5742757517, 16075.2328033676, 885.387831514171, 1063.60090266067, 14714.3393577939, 12982.9861593943, 214953.793914793, 25708.8643510101, 27559.7427108821, 32580.05900252, 31015.8100724706, 28842.5627324724, 24999.2736803868, 27139.0603903356, 29035.5536688263, 24782.9421171501, 24709.3226178318, 26962.7310796978, 10570.6395529076, 11889.4584045209, 25858.2380340544, 90336.8654554026, 1690.37945033393, 1999.32864516351, 1798.70980355616, 28502.9484160247, 27538.760045669, 1864.15501149668, 46680.1420720144, 6026.12025333998, 5479.17348804746, 380.817770655907, 16075.2328033676, 3798.41797398889, 3801.93366105333, 9845.52894200794, 16075.2328033676, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 36378.500257182, 129741.446714219, 123351.822352361, 143343.877908028, 141715.483093503, 143633.750502644, 133479.083334697, 143639.821628661, 124262.288358417, 134573.650190483, 134618.202145567, 130900.108996249, 26124.3244076893, 2109.53252126097, 2143.42195024829, 55643.3918320751, 56029.639847205, 55662.5590095013, 3666.08320161095, 31461.5587619452, 31289.8742605205, 3618.70767474765, 72123.7895365963, 130221.750728759, 95235.9902468732, 66803.602210216, 52084.2851064684, 32939.1179965398, 43.0151553656216, 47125.7363399674, 4229.2575585769, 1274.55381234526, 19337.8582553017, 9544.0079955959, 118156.097363299, 28324.3980824335, 10147.9908617658, 12949.4237811007, 859.482646123311, 963.17025169054, 956.399771826697, 16075.2328033676, 164731.013592411, 142618.836086752, 14078.7204502843, 2169.48833135398, 841.3868698417, 297.314519904182, 713.779297157666, 24.099113824523, 4859.77655505076, 2680.03167849163, 8942.06191125956, 935.357683121805, 93970.774067387, 6781.44329206734, 58999.9631732753, 102887.844044544, 112321.582851818, 92653.4901914753, 102654.212374968, 6231.71786296769, 6928.32294973735, 255.167752297303, 303.185109429245, 200.880466402474, 9050.30260064635, 16458.5311383836, 339.942759730869, 15416.2388111479, 398.206028873267, 100.68216531975, 16075.2328033676, 1260.7749038034, 1196.12277662171, 658.254210804327, 5896.45348112171, 35762.7574246921, 35402.9427583481, 165.105593485501, 163.148000537549, 93823.9796754645, 33848.6065348556, 51510.213799774, 49861.1835933649, 36982.9849286861, 37270.8763732936, 38914.1648793721, 939.647131209686, 765.476897764711, 25811.0732482626, 10313.7477821363, 29956.0676611137, 89988.1933233015, 7187.06057206227, 46680.1420720144, 398.206028873267, 100.68216531975, 52925.0539860187, 53926.1569011661, 16075.2328033676, 29956.0676611137, 136.012689198563, 192.824626395379, 1856.15162274216, 6206.78361507429, 5637.69785234136, 15191.45633912, 1186.44330849647, 32939.1179965398, 5811.28951558421, 2989.49900525221, 32939.1179965398, 1175.84411873711, 22141.7466835399, 29840.290833318, 98285.6142032768, 133851.513033321, 131768.930917344, 135319.44510056, 4834.11438490712, 5387.83038017881, 1029.77306266525, 30050.8749118687, 28514.4830375177, 14561.9991018998, 4456.94251146803, 31789.1416899254, 1599.91328556599, 1484.50152993265, 903.242528483442, 1992.81415180144, 3694.34542580678, 2479.06519138115, 20973.4078963525, 20946.0521746564, 1412.22009106794, 1241.1340850347, 86.7113720302211, 60270.9455996538, 143.650275992601, 46737.8010136089, 217875.207060492, 201816.029722476, 248773.961023538, 149957.096355532, 153175.665720884, 63571.5935003966, 55150.6945182499, 59383.2623424327, 12585.4245354073, 12603.1462169386, 60256.3454301609, 16362.2934401697, 18718.7848973496, 21559.383336955, 18854.1216781865, 38914.1648793721, 1023.3122550351, 2938.68960930383, 3017.93001228411, 117728.043977566, 102589.272151334, 34758.8279893827, 210230.485689291, 216363.944030199, 209307.279298118, 20422.9995753521, 20524.9315493816, 32786.6468915872, 14665.247977956, 28182.9745341029, 45121.6600310956, 28066.8761189716, 412.617984159691, 221.343795961572, 2161.37474954919, 33482.090172389, 27683.6967859526, 380.817770655907, 11370.7101112596, 19676.6431090546, 34806.7113946924, 68626.3369318041, 6073.87127164214, 27799.0180940323, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 837.531698829998, 837.531698829998, 195.013030138647, 20238.7591713545, 17143.4868081474, 3717.78716509019, 22813.2525009147, 40474.8597658331, 59447.9554611138, 51894.0758877476, 65470.7689980335, 59917.7630912783, 67615.0010442909, 46603.2360352084, 25586.7928825069, 118969.682038897, 34426.3466428419, 3880.83690843246, 17140.7643310436, 885.387831514171, 1063.60090266067, 25409.6463701444, 15761.8257439804, 18571.1358579689, 5653.61700601806, 4954.59974633103, 7430.5265058239, 21965.4075675295, 53.0190083589027, 1104.55314309441, 1856.15162274216, 12735.1108708023, 12756.6709400655, 1788.77444134187, 55.8837027444483, 21662.5978074101, 4815.26861108948, 6437.29084127741, 8447.38480783318, 4030.85840851474, 99766.9414639354, 33203.3538939528, 55643.3918320751, 56029.639847205, 55662.5590095013, 11135.6152626777, 19474.4223668388, 59347.5748841858, 58257.313682075, 16075.2328033676, 22780.4410719228, 7283.11560579652, 28502.9484160247, 27538.760045669, 27043.3178229638, 29542.1949442316, 30358.3657305552, 2150.05803676888, 783.959518459601, 1363.46302791599, 16075.2328033676, 2858.43849425123, 167569.483867497, 282169.727024432, 233054.143399179, 231502.508186475, 235773.32854261, 5053.3108516892, 2449.46742349704, 37322.3636485763, 1948.91010609371, 1174.15838554927, 1063.88962196208, 67025.970008597, 148026.813935764, 1919.65615760217, 2300.76513012454, 3405.13225365327, 5355.89660732085, 165.105593485501, 163.148000537549, 26027.9616937897, 26009.4520080295, 26228.069143246, 125769.949052716, 135441.050734977, 34437.4263846658, 7413.86205449632, 17017.3657687925, 5469.57680096827, 32778.3726714203, 34571.1620462153, 97021.234351596, 37504.6251945083, 35797.7878240843, 24282.5957665193, 153175.665720884, 1425.34731310714, 1344.57911108246, 666.915014712587, 1137.49587921006, 1768.91135350572, 2271.62996430812, 16075.2328033676, 40531.9929885463, 35247.2213737433, 16263.1089251954, 28560.9905215222, 1231.16655235924, 172.584973036458, 87.6629534755182, 255421.458901604, 210520.03499845, 78747.2746131727, 9114.540215376, 13327.5036118326, 11368.0286559487, 19673.9616537437, 34804.0299393815, 68623.6554764932, 6071.18981633121, 27796.3366387213, 3144.06856542178, 2931.70648725903, 87.4529205426775, 997.36331334313, 3821.60472714459, 550.810408734639, 490.463894102247, 51231.6252950158, 4234.5568150391, 54948.1000224028, 42799.0818477065, 14283.2986747574, 16266.2035177878, 34672.1236531627, 587.827601893559, 47450.2260517822, 15885.3539141143, 2794.48886834756, 180.99792663902, 269.188167635067, 123543.182968142, 124055.822818805, 17882.8877962245, 1311.00855355541, 5972.49174274833, 6264.6521722737, 25811.0732482626, 10313.7477821363, 12957.5653607732, 14019.7921000491, 12478.8646738514, 44731.0950562868, 40533.9239712727, 63571.5935003966, 55150.6945182499, 104133.557737914, 90177.7958534573, 15898.1503323044, 15519.2829417815, 15712.0011232625, 4063.05589236591, 17144.9270619346, 14576.5792173094, 3263.63297233387, 5040.54247213971, 6544.73474365032, 5035.40269654205, 8770.99671641627, 42480.452413689, 38821.7653495378, 43007.0906558849, 43451.4275437752, 52925.0539860187, 4229.2575585769, 1274.55381234526, 1856.15162274216, 20986.7632365196, 21778.3845365549, 58999.9631732753, 70873.963162552, 98344.1880775473, 4916.33099734983, 1738.55544992833, 6754.68935613241, 6908.82616123102, 67293.9660573345, 48181.1990354909, 67342.582033225, 9487.79535896649, 67808.567749679, 67694.9618973817, 67298.5107015604, 17938.2281370443, 54755.8418965939, 53052.1193047526, 3199.28902086768, 16075.2328033676, 13005.5724697739, 17590.5178591728, 22002.363873796, 12636.6446668637, 267337.820131312, 380.817770655907, 99997.3462487496, 1306.51620960465, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 6171.51152668324, 16075.2328033676, 102047.946925842, 97452.4476162777, 224848.260083921, 235506.340687316, 255924.953930362, 257702.081697406, 21841.1035047383, 398.206028873267, 100.68216531975, 84813.4212444939, 49177.8120655314, 52042.2306799063, 28502.9484160247, 27538.760045669, 53651.0168372577, 54160.1373780979, 60256.3454301609, 63571.5935003966, 55150.6945182499, 42992.4130052508, 35859.9573907905, 5811.28951558421, 2989.49900525221, 6329.17246407142, 16781.3761610836, 939.647131209686, 765.476897764711, 200.880466402473, 40216.0049096812, 40777.5044036449, 7508.54642053444, 4224.9645303479, 1194.29634753955, 153175.665720884, 13318.6028471849, 27746.2590914765, 28000.8672315738, 25158.3508485075, 1718.31353600515, 38692.7084683472, 38454.3016988542, 16075.2328033676, 30346.419248167, 9178.51413380821, 260426.036726402, 165936.795411209, 38914.1648793721, 398.206028873267, 100.68216531975, 247299.374615373, 22500.8103511594, 88464.9620936025, 90300.9018307651, 88850.247703025, 4001.95870596901, 4357.62032237333, 45435.2634418702, 46764.1814568378, 44799.8482983711, 2797.74343680167, 2159.59828758841, 14282.4973541115, 4574.6529366075, 29257.8637578383, 16075.2328033676, 45.4856214061357, 7521.04552208119, 7194.64645409364, 6426.11725583886, 29391.9051078171, 29085.8717665383, 104160.939539591, 102678.646139363, 311.454613547011, 7586.91289307513, 961.861785584727, 80778.6514001771, 12718.1309733411, 4695.60846503235, 41623.448045027, 64875.5759169255, 6776.04062325584, 8086.40729003625, 695.492487178245, 19987.0517689898, 25207.9227653862, 35560.4321347005, 18027.6302772485, 21641.7254111395, 804.405867082446, 104373.106552561, 16075.2328033676, 398.206028873267, 100.68216531975, 42627.5916110602, 91715.0492402556, 92243.8231133501, 22040.995608573, 1486.56284342968, 93823.9796754645, 130432.774697115, 939.647131209686, 765.476897764711, 17890.5429922912, 18484.7506544955, 59383.2623424327, 535.778320926114, 35.9876265013509, 430.335507715417, 19025.5714185641, 5170.63616327395, 92229.5928442649, 774.515631223369, 731.051549514966, 36982.9849286861, 37270.8763732936, 8576.78544994816, 84950.0703568982, 16380.0927036715, 26489.0428751419, 45302.9265003417, 28502.9484160247, 27538.760045669, 128375.56269203, 50166.8356197472, 50184.735933445, 60256.3454301609, 253.703101158969, 495.128084112005, 3271.14707782656, 718.87041183802, 3305.03650681389, 346.838663575876, 6920.66715407778, 351.345341301677, 47926.863652514, 47531.9225437699, 35389.4050848637, 32911.0282698143, 104307.808847732, 41525.910658414, 43678.1522701371, 48419.8194727018, 83588.8507976902, 75167.9518155436, 25991.3511098686, 380.817770655907, 5764.09516164389, 13902.1926931588, 14139.5820121751, 121.620466588186, 5.78559118236115, 6011.4104267822, 1327.96797296205, 5072.88418520369, 37348.3352913523, 63789.5195164285, 30124.2639028086, 6168.0908100805, 19337.8582553017, 93823.9796754645, 12660.7560900338, 10832.3429146518, 29619.6314264888, 491.348240069796, 317.564940225624, 6026.12025333998, 5479.17348804746, 113906.33067475, 380012.703976381, 379067.275311969, 406567.234805133, 29956.0676611137, 108169.887989096, 81111.3522757162, 84168.9077964221, 43381.00742567, 46097.175594869, 42871.567188306, 3412.41404803557, 354.71905918172, 32939.1179965398, 7002.84935315558, 32950.5536667716, 33360.7740404959, 71060.9423868003, 32396.5856701402, 5170.63616327395, 60590.9084446848, 61368.0424653673, 36170.5744826109, 658.254210804327, 3600.46668265695, 30593.3415922661, 40600.3786001986, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529483, 25460.6460476849, 2294.95676213211, 1687.86485837685, 16075.2328033676, 6674.97302012422, 24336.5802850426, 36982.9849286861, 37270.8763732936, 50129.3931508622, 36088.7405938668, 36982.9849286861, 37270.8763732936, 70113.8430918732, 58614.0708274959, 135369.297301492, 35758.9594124837, 115701.20464115, 16075.2328033676, 31955.7290104747, 14186.9101241177, 119124.037006475, 117641.743606247, 42561.8098394615, 19691.1287729218, 1320.38691566018, 2200.08617551444, 12487.3443239224, 284798.941358908, 1286.21126008244, 95399.6131528787, 86978.714170732, 89692.6136227088, 116719.42672549, 37448.7667123955, 7317.0985995268, 1972.26485165696, 1662.14786889335, 2366.78039895795, 1454.58776368471, 863.943437230725, 51.5718347588048, 154.87381167726, 2872.46767620551, 2961.57246361519, 3593.30428795536, 2959.95883520316, 2908.49373234157, 345.015274469704, 1399.66725275876, 46098.8014317216, 49345.9762470213, 31323.6772060349, 42351.4825866199, 20815.8933239177, 348.58739405551, 59282.4846290081, 57607.6703605139, 60256.3454301609, 5149.1243976634, 37467.8775424492, 126546.46750214, 2477.84904261542, 4015.66834029791, 8470.16334457858, 5703.49696830159, 79283.170191221, 59615.0775308787, 43342.6271750455, 3890.12374743093, 4415.65612589814, 6232.62792643737, 4941.77716359388, 36982.9849286861, 37270.8763732936, 12027.5391183339, 12489.7105976506, 854.935635892897, 385.386809890281, 583.737029424752, 18029.8308224517, 19342.4018732924, 66231.4253029387, 44438.3590369908, 45532.503690154, 24440.5335699091, 10335.4333213919, 8091.21344311246, 4606.72949893295, 59383.2623424327, 46510.2181843146, 36812.9130105098, 47256.3587757935, 44007.3911864396, 44414.9114690224, 39247.0516198934, 58044.1314722281, 44616.7132669068, 48165.4304130309, 47523.2581943154, 41941.4640947753, 82706.493130402, 71650.351945674, 46128.666096581, 71838.0739110387, 5481.9595776086, 4274.1517077609, 49937.163399268, 51605.220558093, 19599.5049812013, 48986.5406536361, 50315.4586686037, 46538.1012111909, 50767.1632255376, 50372.2221167934, 53619.6653510777, 1649.35456300999, 117181.20857421, 137762.904243237, 119724.20844741, 159314.466657267, 124161.192257143, 2436.08538779163, 1084.2237981447, 1186.10845234256, 337.844746988246, 17499.1234304369, 18309.0969354907, 25840.0088035693, 50062.9923915537, 667.663331675873, 566.070592134515, 380.817770655907, 74468.5859618555, 3035.06468178445, 3.10872267678539, 3.44279636543973, 37140.3188508983, 18104.1000255577, 114545.837726283, 351.155974903314, 622.862770777969, 1060.17745361734, 74298.3814697687, 83003.4756462942, 83655.0103059112, 55106.9267349238, 53225.6604585472, 116.113033013679, 56.4271046072093, 5639.72373275205, 4269.23233607219, 19337.8582553017, 159416.006285905, 70248.3287512563, 52298.3326772964, 16075.2328033676, 6674.97302012422, 24336.5802850426, 28034.3414168174, 19700.2271754792, 38914.1648793721, 398.206028873267, 100.68216531975, 4543.005008474, 1306.51620960465, 5554.53099829786, 7057.13116460945, 7331.44049810369, 13991.4785247324, 22297.4115225274, 37427.4798081652, 71247.1053452769, 8694.63968511493, 30419.7865075051, 139.714311292414, 2200.95801431387, 1304.14503276784, 1478.58024416557, 2303.94096584347, 978.210874007546, 1864.15501149668, 153175.665720884, 16848.7897054952, 10669.9224858769, 85306.609714591, 22813.2525009147, 40474.8597658331, 85306.609714591, 20285.8857419238, 21652.2227567732, 20456.8254321072, 55255.8360624069, 64258.6817863775, 13144.5414843544, 4897.80409584752, 5989.04133845639, 112735.099211739, 116595.900352187, 153254.7035693, 85831.006428686, 80834.6653109779, 92480.9689857394, 87163.3413461935, 86162.8756232146, 83486.9015747094, 86598.3066865573, 667.663331675873, 566.070592134515, 33335.7616345515, 28963.5064371901, 39293.7194449924, 380.817770655907, 19337.8582553017, 75669.0689332268, 83076.0848943869, 16075.2328033676, 16075.2328033676, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 17761.2341341104, 18085.9623203878, 1397.01391356987, 62109.4443988982, 2197.13931685018, 37273.0578736182, 45387.1765818314, 51231.6252950158, 37448.7667123955, 2894.62766262561, 939.647131209686, 765.476897764711, 8395.09417707267, 13772.9697767205, 19055.6629126859, 78673.5383316506, 78714.0813614746, 81276.9362021862, 16008.0418274388, 13120.8610366635, 16380.0927036715, 26489.0428751419, 45302.9265003417, 380.817770655907, 16075.2328033676, 22008.3871916686, 2.77197958308759, 66393.2863540575, 69836.8430485614, 4206.25042211626, 2896.69318138455, 1093.25948203726, 28455.4110235471, 27269.4755077968, 167729.496560257, 28930.2659675937, 28826.2604530184, 142146.127704349, 4585.40852079865, 85306.609714591, 6217.02411850391, 5271.73911023167, 7258.59590809476, 8011.75365441033, 4283.22780494892, 93823.9796754645, 46926.7013410627, 319.664456607144, 336.054567828929, 19337.8582553017, 38105.3396478392, 1598.66169952272, 93823.9796754645, 27179.5564533409, 28502.9484160247, 27538.760045669, 2267.69288065616, 16075.2328033676, 10119.1384434729, 16075.2328033676, 32414.507972232, 109586.741722968, 27937.0716786268, 16464.8403664945, 49804.364454298, 36982.9849286861, 37270.8763732936, 38914.1648793721, 75437.7166391433, 34813.3518860377, 82001.8066014086, 83462.3329095168, 83363.9763389944, 88978.0096158721, 83478.3135202865, 1994.49883505285, 54322.1214217786, 78898.3758033191, 76528.014555281, 2903.78917409162, 2815.19060472516, 158582.044055798, 160581.478049238, 35533.0723313702, 93823.9796754645, 184.181949259869, 1082.92788237865, 16075.2328033676, 1484.65328510058, 591.620405798511, 490.027666257153, 5952.25147718454, 28502.9484160247, 27538.760045669, 121.620466588186, 5.78559118236115, 19337.8582553017, 109057.008325985, 57235.3857125557, 23570.8942628486, 24125.0705904803, 33216.443177685, 22456.8615183149, 4263.50562358399, 75950.5210856416, 84832.436823615, 81403.4736150854, 76336.7691007714, 76238.4125302491, 75969.6882630678, 7996.77148618285, 19337.8582553017, 9859.78085885678, 9285.51618788549, 16075.2328033676, 37906.6222148728, 150786.156708085, 380.817770655907, 63571.5935003966, 55150.6945182499, 11180.2070080237, 5867.48215676759, 36953.9591885763, 37340.2072037062, 4013.24734688606, 29956.0676611137, 21271.6889074516, 18016.6150436397, 334.527608844724, 5503.04262448609, 4577.72563203885, 12116.3424890607, 1231.16655235924, 83564.2738201906, 85432.6339476324, 7428.76074139372, 312.088562228129, 312.486281619704, 189998.699404701, 114521.16012984, 220234.182170672, 165.399527635181, 173.985822833886, 558.137019612003, 2958.01032290773, 2926.75909982747, 4936.85306638324, 2205.19551410077, 53432.6227470816, 38102.3727928803, 45958.8346971516, 28066.8827334793, 85371.5560954432, 3322.73736861448, 3703.84634113685, 6.69158128226179, 29.0409139929666, 39507.9608653499, 40009.7551828205, 5376.85642649039, 14896.9207573857, 16075.2328033676, 6097.89011054725, 43000.4772609608, 19599.5049812013, 176.268750462866, 48109.4524848724, 41979.1558390077, 37349.8708255024, 254740.53558408, 244839.657777504, 254975.036741019, 10902.1365724842, 2209.14579521149, 1058.65153911583, 11262.8136356408, 33491.2166128256, 40906.3734494186, 1783.16899601624, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529483, 25460.6460476849, 19337.8582553017, 86937.34572533, 86865.5514888681, 22593.6497386199, 34475.5547855408, 398.206028873267, 100.68216531975, 152149.636123818, 139326.440772067, 162304.416613519, 146351.65528094, 152320.257818582, 127278.830143617, 155479.92962369, 141962.70276767, 12897.9411593887, 22711.2040828912, 153175.665720884, 515.537406887688, 1012.56210112466, 1658.13449840418, 54443.3411826379, 53354.2472360997, 32853.6868441261, 30866.0528814044, 30984.0168519732, 185440.418047176, 244573.675028574, 22813.2525009148, 40474.8597658331, 55.8837027444483, 2384.26504929427, 96746.4473064116, 1403.17892846079, 2446.98028391632, 7946.18036183444, 8100.98077392631, 380.817770655907, 120410.783694047, 45784.3062941917, 28022.2047611337, 25682.1131196096, 21548.1754277453, 21177.5723817938, 380.817770655907, 130.772243140514, 9639.06688628863, 8781.02743528346, 2114.45891542771, 19337.8582553017, 535.778320926114, 35.9876265013509, 430.335507715417, 206741.833059362, 208778.190980147, 6684.5780611735, 3937.14721726668, 8093.89914622179, 8063.57680274156, 1651.2658384956, 2014.18638945188, 16075.2328033676, 89306.3836372862, 63.0997426601247, 406.905881160247, 36982.9849286861, 37270.8763732936, 8341.70460909981, 8038.29739082572, 518.841670755239, 6972.68204727361, 9132.7145912444, 7533.92649666756, 7009.33828891281, 6674.97302012422, 24336.5802850426, 2267.69288065616, 217875.207060492, 201816.029722476, 248773.961023538, 149957.096355532, 23741.0293713657, 17105.9934773974, 127493.332221456, 92543.9764890578, 78641.3746625242, 127896.580056654, 131099.656286316, 92209.0907153349, 148288.812594606, 148586.189118064, 5811.28951558421, 2989.49900525221, 3019.45389866225, 6043.40378251175, 64839.6475099701, 64839.6475099701, 132660.42936183, 79095.3942196305, 16075.2328033676, 19337.8582553017, 26491.8499084941, 28210.3890296321, 33580.0506766456, 30904.801504514, 55.8837027444483, 13962.1088439381, 46192.2307493326, 135134.657146492, 9233.8623024297, 7791.38569431093, 9042.89367763893, 16075.2328033676, 535.778320926114, 35.9876265013509, 430.335507715417, 30500.4243863977, 32411.2965047531, 30429.8851565258, 3393.80364879718, 2068.07355696126, 1688.09468630649, 5747.83608798939, 36982.9849286861, 37270.8763732936, 21318.0444654981, 255.167752297303, 303.185109429245, 127529.626386309, 64361.2907621551, 260997.913113426, 45471.7008243132, 41351.8339332901, 22763.9860122093, 1386.30925733456, 19337.8582553017, 46890.1137010667, 36097.7808429589, 37581.3306224812, 28412.166880135, 2594.24212100073, 3547.04595907261, 63571.5935003966, 55150.6945182499, 31041.3913768473, 2976.09787919976, 4318.73547080419, 4334.77027103833, 16075.2328033676, 35752.0201847888, 21821.1352660785, 7415.356025518, 8233.93004993008, 181434.624901029, 46302.0321899017, 54340.2824042068, 40303.7963002726, 39982.2498142677, 44403.8008617124, 14831.6083992585, 3234.8551928678, 16075.2328033676, 18404.1686687147, 26710.1016665097, 41840.1699521475, 75659.7954892592, 13107.3298290972, 34832.4766514873, 16075.2328033676, 93823.9796754645, 28584.545558594, 16075.2328033676, 36982.9849286861, 37270.8763732936, 11629.0775533624, 29290.6848182808, 126478.715096237, 117946.590782133, 123894.69561174, 125497.795082286, 36378.500257182, 186120.377799652, 183753.347358467, 70626.9361145789, 37438.8232214949, 122658.95451955, 114238.055537403, 115724.437702802, 116951.95498938, 17091.5223628584, 16075.2328033676, 16075.2328033676, 16075.2328033676, 19337.8582553017, 16075.2328033676, 79.4231529103677, 683.380909499144, 1425.28989083278, 873.068243359673, 86729.1414506313, 28472.3145893818, 28737.4424561215, 17662.4035975707, 53786.8509266613, 54400.6993816552, 51944.1228195169, 1412.22009106794, 1241.1340850347, 16075.2328033676, 35961.0590579734, 36364.7644473596, 123591.813595676, 139500.17222067, 128182.488592739, 124537.881769135, 60256.3454301609, 5087.82847670597, 7074.56862852022, 3247.06076014562, 12656.8905155016, 8225.81318288306, 3569.0028071963, 5771.53509488219, 1864.15501149668, 14822.6199143262, 19607.4430295809, 13490.7513403648, 14107.4290278161, 9384.64628283886, 23589.7156610615, 209244.228662139, 125818.386666046, 42627.5916110602, 93943.7359473436, 93965.0906852852, 106009.226242353, 391.531497495759, 1237.08294572589, 1924.19771439397, 2627.45971441595, 142193.803650965, 143467.28228071, 226495.958843522, 215702.44521516, 402.091252578134, 7508.54642053444, 297.314519904182, 713.779297157666, 24.099113824523, 2926.75909982747, 4936.85306638324, 1231.16655235924, 38914.1648793721, 193525.770181796, 227206.235848581, 200660.916045712, 193201.179754093, 198352.852837012, 28328.9385857456, 1917.91288731017, 1714.61365197583, 4632.8337311905, 4398.42974886138, 4932.76411677888, 4318.78160422256, 3891.50922620793, 73284.4787264991, 255.833196573587, 2821.07630981241, 157207.048263701, 3313.85856569276, 1912.26404284212, 2309.15705582493, 22813.2525009147, 40474.8597658331, 24960.8156471497, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 30510.7980591894, 38025.6893229654, 36606.0501081736, 42918.7147512985, 38284.1733796336, 7754.2166880541, 36982.9849286861, 37270.8763732936, 16075.2328033676, 7677.7637070457, 75498.5455589055, 42602.6505750521, 27515.3642954531, 39948.7032953063, 1856.15162274216, 232362.747982282, 84659.9736248404, 216303.570644267, 263261.501945329, 164444.637277323, 192964.71992982, 191482.426529592, 11893.7754211391, 515.856579229091, 149.616593585133, 136.012689198563, 16075.2328033676, 16275.5284406054, 4902.69258852833, 15639.6462351156, 10411.3038051739, 4120.22007189954, 26959.3027910279, 58890.7186489761, 36982.9849286861, 37270.8763732936, 983.112463448204, 2049.31885329317, 28502.9484160247, 27538.760045669, 19337.8582553017, 46680.1420720144, 8617.60672440181, 11247.1865100581, 74436.8606144657, 7701.74519072103, 173388.118744749, 31782.1762265292, 16171.2272963912, 17005.8599292625, 80523.0939257477, 69466.9527410197, 43945.2668919267, 82658.3271938135, 4527.32270819748, 17354.9958677325, 1975.82091425038, 47648.7125008361, 4130.23366275556, 38904.3225708523, 32939.1179965398, 1046.99525242921, 1231.16655235924, 28514.4830375177, 138.196239687831, 8895.46278633758, 10685.4391764663, 380.817770655907, 75781.1002725467, 36982.9849286861, 37270.8763732936, 150.320781820585, 8114.1423428592, 939.647131209686, 765.476897764711, 11506.5425269236, 74468.5859618555, 100535.706918612, 398.206028873267, 100.68216531975, 255.167752297303, 303.185109429245, 33072.2565219458, 33007.6346893732, 19425.7476401415, 17511.6140223536, 26605.5951919811, 19238.0434717883, 19337.8582553017, 212927.135190133, 472.058349739684, 83768.2849412635, 54475.4336681302, 60783.7026188145, 36700.3411471541, 49361.1306769336, 3284.94402493544, 2571.42037173317, 3137.04463689257, 6405.45979470695, 5470.18024320641, 8415.55376126271, 3793.43462926929, 14356.175242238, 13221.1261537394, 12560.8561798202, 667.663331675873, 566.070592134515, 3813.15454536589, 4405.69823459937, 302.391806487668, 38007.8189796, 22510.4935134737, 9767.62942668929, 1207.20749239146, 4262.49447308578, 26610.4500862496, 28190.8194828699, 13060.7672464377, 71492.9481633673, 61055.33352154, 179164.055924268, 88755.5376031102, 60997.3813017722, 70375.1127325112, 72397.089605585, 60096.0000288835, 71866.6532278823, 73120.6410356456, 36982.9849286861, 37270.8763732936, 701.471741783623, 23023.6473133582, 79502.8166433854, 79020.9509052717, 79984.7119058648, 78959.242254053, 80018.9948382685, 29956.0676611137, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529483, 25460.6460476849, 75433.5112618909, 7754.2166880541, 381.637887102752, 477.603586253649, 1489.32643121507, 94965.4615703677, 106577.552992499, 109914.512898565, 380.817770655907, 55643.3918320751, 56029.639847205, 55662.5590095013, 60692.6251353383, 59659.8024182598, 28985.6937034437, 28051.837321625, 50071.2818005966, 30403.1891402543, 667.663331675873, 566.070592134515, 137930.422487581, 146914.12773584, 141423.328666148, 144475.620152051, 2877.56027937594, 3309.45079318779, 3843.61987449577, 16075.2328033676, 66574.8344085083, 6674.97302012422, 24336.5802850426, 55.8837027444483, 4263.71472038959, 1636.3387577496, 2555.65784578012, 2889.17035145001, 2496.96852140611, 29447.1962672944, 22672.3802180208, 418.656212670212, 1198.15104245461, 36982.9849286861, 37270.8763732936, 105325.293504264, 114269.245229656, 106587.565767817, 108323.839752039, 30625.8259450787, 26491.8882532144, 26121.2852072628, 24801.8103551609, 50321.1617944324, 48498.4258122895, 51319.7199293237, 71222.7067729056, 59890.0756324147, 380.817770655907, 64653.1838458866, 65256.0373149593, 45405.9175266995, 45750.5323208669, 45108.7641579047, 63571.5935003966, 55150.6945182499, 66700.1273913682, 65625.8490983899, 67086.3754064981, 66719.2945687944, 45.5777284527176, 658.254210804327, 16075.2328033676, 15985.5587229799, 30659.2908653184, 43885.3585955582, 28.5425439295029, 737.564022643526, 74468.5859618555, 6190.50965211366, 29683.9009883408, 2228.27583735487, 2529.44268346106, 4620.43191662203, 85306.609714591, 398.206028873267, 100.68216531975, 63571.5935003966, 55150.6945182499, 1412.22009106794, 1241.1340850347, 36982.9849286861, 37270.8763732936, 74468.5859618555, 16075.2328033676, 13718.7328984947, 51204.0193970262, 44774.5821175841, 14819.7525210398, 4847.52779726613, 100527.882254971, 36982.9849286861, 37270.8763732936, 70248.3287512563, 372.648621595848, 51231.6252950158, 1484.65328510058, 591.620405798511, 490.027666257153, 28502.9484160247, 27538.760045669, 16075.2328033676, 7571.78623449849, 7611.28886063494, 32171.3603141028, 29917.7634891495, 2169.48833135398, 841.3868698417, 79143.663113072, 28785.9691659794, 27762.1578464909, 27813.9181371362, 43648.2420398894, 31461.5587619452, 31289.8742605205, 3152.74877020057, 29956.0676611137, 29318.067091213, 398.206028873267, 100.68216531975, 52480.7181933902, 52548.5276819786, 222781.369245436, 166563.004232312, 146894.91157197, 60060.1870805093, 95846.9345938587, 121378.151010131, 2150.76057383058, 43633.1284333518, 18315.6533239007, 17029.3693708741, 12402.5292974008, 1450.77749504869, 27990.1134358817, 29027.6386873554, 5571.89473215555, 2793.70818829732, 42765.7509114969, 41973.531004071, 44621.5115904645, 2926.75909982747, 4936.85306638324, 49927.4719171202, 40993.7702021329, 41739.342925907, 16075.2328033676, 8343.54530083113, 8059.52140711173, 10069.6153736675, 25660.7449647027, 15211.8427443697, 1604.04546060564, 871.767144042084, 26412.478365793, 8707.46263067914, 11973.6270018693, 17261.7669821946, 9179.4351480092, 7439.0042844802, 3197.05867273829, 67.4924095059996, 136104.363590913, 132260.607647866, 150231.41992819, 210634.091279848, 86421.6519644637, 181262.340295759, 132627.816706853, 13902.1926931588, 14139.5820121751, 51494.6888631659, 46463.8470595971, 4581.84382411987, 24271.1577820147, 16075.2328033676, 1636.3387577496, 2555.65784578012, 21566.6413092789, 21197.7616023165, 237100.045987053, 240924.11366989, 240780.522721453, 223832.126639193, 17.165419793101, 3.5065993901164, 6781.4900187462, 1034.80646152364, 2926.75909982747, 4936.85306638324, 28160.3217809971, 97.965208627208, 318.690557961069, 47785.780886233, 215677.907678061, 204718.102940881, 114077.724339342, 2926.75909982747, 4936.85306638324, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 20649.684072275, 20609.5948685682, 20191.8556784103, 3087.25129522608, 15901.6697637082, 15531.0667177567, 12027.0333706757, 1288.15967357918, 9375.30675255404, 10651.6016029296, 28397.8142393711, 27650.4261650145, 10450.6062016643, 1385.6476236642, 23491.4836442643, 15249.211529621, 62836.2596019806, 70814.5823573094, 63176.6257668491, 71674.5552100355, 5811.28951558421, 2989.49900525221, 29203.3808696681, 30762.87522112, 28543.717612376, 38610.951698038, 30458.4949212675, 38496.7451355726, 38149.0466004047, 132645.80459304, 137170.888458086, 114710.704972212, 134887.029091966, 130273.601512685, 631.119551660822, 3551.80685861617, 1227.63342848997, 22556.560413986, 32939.1179965398, 7459.97312429195, 40861.5058612691, 21665.2784132899, 12055.4925479681, 12182.3694892657, 10242.6629962453, 36982.9849286861, 37270.8763732936, 17403.9759757348, 11832.8601530597, 29956.0676611137, 2933.19333388922, 27855.4583681965, 28224.2715490267, 216289.621714425, 216661.493299966, 266612.358276939, 215589.321590158, 1039.59619163916, 2106.66454997154, 64758.1004375956, 15906.1428786642, 639.171328423798, 3623.0346757757, 125350.999395544, 24075.3823242063, 24057.0572524693, 252243.8534938, 2926.75909982747, 4936.85306638324, 9369.40891720328, 1636.3387577496, 2555.65784578012, 361.968925651327, 348.435857781891, 479.071438528031, 2335.99249624132, 2301.00910686967, 81849.4145509252, 79884.1662723659, 74916.1568170735, 75167.5520166512, 75991.5010557809, 77630.5694474127, 73537.1655116789, 82746.1381091528, 77164.2282794483, 81911.8203207108, 75068.5954534936, 75341.940943175, 75190.6123493314, 66783.6541712699, 76010.0885204296, 75863.290954996, 77238.8345338086, 81151.9807403889, 82446.6973010807, 77072.5538865608, 80429.8426965471, 31544.5595313761, 13168.5186470904, 13530.2386484565, 2941.28696861646, 24506.2576994228, 114.825244851354, 930.56598884138, 4829.15883296325, 1409.82939848306, 2046.68257166363, 5717.51602100827, 45923.5233461217, 47657.0650965879, 59580.2250080093, 699.791691789299, 29956.0676611137, 3890.12374743093, 4415.65612589814, 307.303707156227, 626.138801443826, 1231.16655235924, 96520.8418569567, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529483, 25460.6460476849, 4598.14714961335, 19599.5049812013, 2393.10740203385, 2177.66441343433, 74824.7001415468, 67180.7878826826, 47512.6952223402, 16075.2328033676, 2731.27900493364, 2538.26410936149, 2091.68546164607, 2239.36308549066, 654.459849470721, 346.814019571169, 126106.152726108, 258711.113288239, 85036.9768633821, 83919.9394459136, 88071.5436132804, 88471.7380915976, 578.88859874516, 881.224366761827, 939.647131209686, 765.476897764711, 1856.15162274216, 170.506874490262, 1137.3632608997, 15173.0263109876, 19195.5874533745, 29646.7241449344, 28473.9361401898, 19355.3763189648, 23441.2858394263, 37195.1803163643, 37302.075915076, 20763.9497711034, 35326.9818657902, 85306.609714591, 6349.70000171946, 7098.02275585799, 391.531497495759, 182550.803639635, 180702.80922095, 794.81703139429, 16075.2328033676, 55643.3918320751, 56029.639847205, 55662.5590095013, 816.029212571259, 9581.10320366179, 9864.21271867636, 946.248765237421, 976.199501855401, 6514.46432575985, 14951.3108605985, 3279.59642851882, 46707.9162666559, 339368.820397039, 45557.9333302777, 14685.9737772662, 17235.6041018366, 21572.9733937576, 21605.3511776159, 21471.1554018841, 14680.4330551149, 26451.5189207907, 2599.86367626889, 5811.28951558421, 2989.49900525221, 33304.6756568867, 87304.5506569443, 2303.71538323335, 4961.42722411532, 58292.4535538452, 99863.4268788019, 91442.5278966552, 94156.427348632, 113630.445837363, 46.0558872177412, 1533.67725594651, 40180.438214303, 25409.6463701444, 4480.12432927184, 5269.3538327086, 8226.61342575517, 9602.39775774322, 63571.5935003966, 55150.6945182499, 424.808654185204, 49560.3931282093, 102932.359288436, 100132.066003265, 7533.889686026, 7278.00197165837, 6715.2989892047, 16075.2328033676, 93539.2797903399, 87278.3945653513, 163150.797869402, 87935.8748023906, 120407.084636298, 17260.044284049, 94432.2780347846, 12782.6079904439, 7106.27431670089, 2097.682220922, 686.289535316732, 137.994164559862, 349.450183552954, 1171.05708884114, 36982.9849286861, 37270.8763732936, 27942.1209532418, 25817.9005240231, 21638.6081085712, 86175.2662476198, 95805.9317315156, 95745.0729862663, 85964.0133001766, 96139.0994704878, 96037.2428364446, 96173.7786479644, 5125.85966259547, 5109.56990296357, 16507.5388894095, 15189.6156874141, 4929.9201050346, 9472.84331042014, 25125.3611008583, 25242.9465276348, 24982.7487101125, 11453.4180822796, 10986.937429771, 4658.50539586673, 4995.51013661551, 52.1147236033839, 107727.602075779, 1014.74467921055, 141.322077516658, 929.647613201762, 1714.24664199808, 3343.05861213307, 19337.8582553017, 3198.20199161574, 3951.35973793132, 10315.8228048286, 24608.8671568323, 18351.3370809733, 872.613052005574, 6225.73133862168, 4299.48701976927, 6094.55149660632, 157207.048263701, 48.1984294087988, 64518.0654561389, 65777.6721846526, 6149.66299658069, 11598.1488116443, 54696.0064218377, 54672.0605562797, 49388.1422879599, 9808.90235391811, 23968.614224662, 5183.8681232979, 37057.8360748157, 4229.2575585769, 1274.55381234526, 37322.3636485763, 1948.91010609371, 1174.15838554927, 1063.88962196208, 1856.15162274216, 696.571374207723, 2005.32386538385, 5317.89250698965, 1866.7522784447, 3025.82197073353, 36982.9849286861, 37270.8763732936, 49486.0793747375, 51935.7350502857, 15874.5808305882, 22538.2228821702, 24732.2726612654, 32730.111011718, 68840.2285070246, 67108.8753086251, 32354.853276225, 269079.683064024, 30287.8120965026, 59513.7195294096, 34071.4103897822, 55155.662211896, 34107.9119554993, 3131.91634594374, 362.575880709611, 28560.7692432607, 29078.3985977405, 30656.2525552847, 67992.3209253504, 171194.401466624, 291611.172896351, 72740.4214637372, 74801.6633541285, 190613.349306556, 7643.87972394265, 23395.9477180127, 391.531497495759, 16075.2328033676, 28137.468559337, 6186.98514459371, 351.345341301677, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 25464.1937351144, 35573.1439065848, 54387.0275317846, 36839.6963321614, 193388.669196641, 191021.638755456, 8955.74725983867, 352.942099977819, 120.942485019968, 19699.5074772109, 46680.1420720143, 7383.50907565915, 89.9569446043147, 237683.935773619, 221624.758435603, 268582.689736665, 169765.825068659, 46680.1420720144, 36982.9849286861, 37270.8763732936, 157701.502256114, 4886.5080008083, 5031.08554024964, 9894.98960473101, 4896.32245494989, 3691.70076417485, 3332.32786095816, 16075.2328033676, 663.544549880959, 1187.67615094594, 74468.5859618555, 38926.4297052914, 33214.1828464695, 13428.7728733385, 33109.2793183506, 2692.63611859071, 747.393720728987, 852.448689347357, 2209.8748039488, 1422.13950075631, 17260.044284049, 94432.2780347846, 12782.6079904438, 17279.2239720536, 7727.23206442239, 196473.760448503, 195941.33746191, 24506.2576994228, 24787.4756386855, 22604.5626415921, 33546.588185788, 38926.4297052914, 33214.1828464695, 53087.3369335227, 373704.383932183, 52714.8452447914, 379231.221197994, 55910.4481196982, 18153.8972076835, 23649.3719535519, 21606.0609711022, 200.440175479156, 232.281126662498, 27237.0346835231, 3072.67347495638, 4929.07259534371, 5912.8281378598, 5486.82324252998, 63062.0352190121, 130878.969808724, 16075.2328033676, 32357.4219904775, 1318.14776380276, 9179.4351480092, 6028.00910412306, 11177.8556813486, 18363.8418438612, 14570.6117745391, 12002.2639299139, 10020.2660989017, 29956.0676611137, 4391.4766419202, 3800.53117027922, 3753.33149270694, 15876.23055923, 6168.38614172603, 80053.2745696482, 19337.8582553017, 28455.4110235471, 27269.4755077968, 578.88859874516, 881.224366761827, 449.71235374037, 29243.876736155, 93597.8144478597, 146.813017747198, 204.052270805657, 38102.3727928802, 1105.96273999839, 63571.5935003966, 55150.6945182499, 28260.0304557253, 46234.2040057096, 123406.437756445, 41756.7677121044, 84844.6391237369, 74468.5859618555, 108622.701732594, 71143.2834015084, 88954.6090722519, 19195.5874533745, 51231.6252950158, 6149.87282875709, 566.892450637157, 288.589864900029, 285.537254043331, 2983.58565277598, 4043.01049343013, 566.892450637157, 7521.04552208119, 7194.64645409364, 75181.7586486951, 10259.5298974488, 10394.1798985183, 1837.06604405214, 80.5125562098083, 1416.39804722856, 35881.8763951754, 1225.60731214474, 1149.03949792227, 10558.8692532782, 6643.77366472442, 6202.13392568801, 4456.94251146803, 31789.1416899254, 4392.44428943977, 5614.82692444339, 380.817770655907, 1620.11199764492, 15674.0115845287, 15651.1316156076, 395.949036374041, 394.898339458005, 885.387831514171, 1063.60090266067, 99424.5794526357, 71907.4156794532, 163264.371825029, 26730.5910901463, 118832.657469715, 29956.0676611137, 2010.47948563859, 1182.18016607587, 36982.9849286861, 37270.8763732936, 8909.1024846944, 29786.4302884366, 34338.2289341206, 19337.8582553017, 39656.1579588946, 65729.197131949, 57317.765223813, 116723.393796143, 80560.0922702485, 76368.9982873867, 41713.5820182173, 19948.1002491149, 15397.6096877385, 39067.586141793, 29750.0595420194, 87026.4925360566, 28502.9484160247, 27538.760045669, 351.345341301677, 165.105593485501, 163.148000537549, 14356.175242238, 5890.8677830668, 5936.66524224353, 1004.36651416554, 12379.7961892953, 93823.9796754645, 5811.28951558421, 2989.49900525221, 28305.4843182508, 55885.3673155701, 28338.4165313062, 47836.612387009, 9739.474896013, 10251.6747488744, 161740.59416178, 16075.2328033676, 57184.7967815775, 50413.5011324701, 294688.560908575, 294540.498990435, 352.114954902891, 380.817770655907, 29956.0676611137, 16075.2328033676, 7650.21302182265, 15055.1907236777, 16474.2725932449, 1320.38691566018, 2200.08617551444, 535.778320926114, 35.9876265013509, 430.335507715417, 68106.4556501412, 47094.6906410586, 26078.2474883571, 119461.136644747, 635.181136894065, 931.930916233713, 1133.08618820949, 3197.05867273829, 67.4924095059996, 9724.70541100056, 37304.5884083199, 44180.7309896705, 201.921554556655, 1325.18158921821, 2503.22465938129, 12647.2066997829, 74.1206752749301, 10732.5464794634, 18388.5089997613, 23803.2432266763, 5313.63679626936, 3817.9386968542, 4818.77795109466, 3355.70249464945, 16372.7042010283, 7504.99870644126, 9696.51006616501, 37322.3636485763, 1948.91010609371, 1174.15838554927, 1063.88962196208, 3514.90535898419, 10592.5020026709, 5583.90990689204, 30165.1617378803, 25266.6951595151, 28272.2198080367, 32100.5831047186, 20695.5418583243, 843.467466229602, 164301.877755313, 136320.178729532, 139596.276425844, 12195.2672072337, 12026.3061977043, 40876.2035782217, 981.278941425343, 153458.374764131, 93431.0449970498, 53458.6081333798, 42383.6940703937, 10202.9791989588, 40559.9918805291, 55.8837027444483, 34965.0391069164, 5332.32578580511, 6121.71574205639, 25084.7320010508, 2926.75909982747, 4936.85306638324, 16007.7863068537, 15961.8990192797, 16521.5525479961, 49566.2498823656, 105931.127027328, 33788.5135644799, 6378.55929321679, 8954.8488450415, 74.3657790574448, 2698.69121284299, 2606.5947978441, 9607.30508516735, 22633.2648451817, 2583.38960469957, 361.254972199686, 10057.146321034, 2024.35068330918, 22813.2525009148, 40474.8597658331, 1034.30003979212, 16075.2328033676, 24956.6284794536, 89793.571584522, 23797.2300328085, 238891.02509894, 238782.662584178, 86165.4982332778, 55.8837027444483, 286.068856495644, 834.446899471087, 19337.8582553017, 2446.35050787984, 5867.61441198529, 2175.48177286449, 15824.8094353583, 63571.5935003966, 55150.6945182499, 5975.50949821097, 118177.632284212, 99168.3610960001, 66638.1978792176, 89993.8966591296, 100628.497251108, 16075.2328033676, 12487.3443239224, 370531.723081504, 370776.475984207, 372528.795231838, 2945.74692998072, 1048.45825736338, 10458.2880127193, 14327.0287101337, 74790.1497815539, 95450.6663381779, 10102.8729715713, 89537.7603416817, 47450.2260517822, 15885.3539141143, 44724.6673426582, 21051.2520625108, 45410.3020691748, 45540.3713010647, 689.433628219808, 16075.2328033676, 169829.987859393, 138568.826608458, 150161.895199051, 146971.345468001, 28304.8430691959, 673.529729328414, 750.451299329575, 153344.47656635, 77484.3893569239, 73615.7545770765, 56472.8942095809, 18187.7867329294, 60256.3454301609, 33077.0158479722, 1054.95092688303, 61519.7763343946, 64562.9450458191, 61952.1482131074, 64965.9805555459, 60900.4017754487, 4001.95870596901, 4357.62032237333, 141756.145508326, 137557.758396672, 55416.9014086957, 55803.1494238256, 55704.7928533032, 38914.1648793721, 2926.75909982747, 4936.85306638324, 41739.1581541397, 51255.5564414674, 4427.95576613552, 4523.74249400307, 51231.6252950158, 10637.1024505381, 398.206028873267, 100.68216531975, 16075.2328033676, 7617.46743438341, 7688.49716857165, 100952.498860384, 100446.584623535, 99759.7360495489, 102706.86712047, 102112.233988006, 6206.6798080795, 22395.9084028209, 34441.8154401673, 2104.98233089024, 19.3344304127309, 541.407831196675, 1066.08742571835, 40176.0406325788, 57837.6478974972, 56188.6176910881, 13625.8229929268, 12412.595352294, 16075.2328033676, 1079.67037849765, 1519.16733610608, 1892.77391203337, 36982.9849286861, 37270.8763732936, 54301.4324728619, 54960.1147992084, 6420.04136945592, 6378.26505696896, 33162.5236588389, 210529.558504145, 61670.887130665, 76695.5697286669, 55683.8047195843, 34667.3615668828, 128050.250723273, 40060.9893187885, 41004.4172207795, 39096.8009484328, 1603.12419353221, 28.5425439295029, 737.564022643526, 16075.2328033676, 9672.47147418066, 8075.33303232691, 16075.2328033676, 5718.08509573744, 7073.15565008135, 7700.93801540459, 5727.26473072548, 33526.5644336238, 33564.0519388847, 34687.965486003, 34088.7361522565, 33383.0632362515, 3259.37751534839, 3037.53136499794, 77549.5062289658, 76279.2033198957, 32939.1179965398, 380.817770655907, 2169.48833135398, 841.3868698417, 4875.82694625928, 4431.10085726903, 93823.9796754645, 84.0880402292551, 578.02143928184, 8476.42049941022, 19337.8582553017, 4001.95870596901, 4357.62032237333, 45567.4855396035, 19034.6072096849, 15437.3703350873, 40928.0940001169, 541.057213983119, 549.72737097673, 38926.4297052914, 33214.1828464695, 53909.823051173, 62853.7747765658, 398.206028873267, 100.68216531975, 32656.3775916035, 42765.3277630739, 61579.2113882737, 33034.7421860772, 6490.00727762105, 55.8837027444483, 18701.4868059376, 29956.0676611137, 2926.75909982747, 4936.85306638324, 4025.54663448944, 68540.0668495315, 69654.0194346588, 60256.3454301609, 16075.2328033676, 1604.04546060564, 871.767144042084, 19337.8582553017, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 72746.4471340485, 3708.72168880631, 14423.3059641673, 19337.8582553017, 16075.2328033676, 107020.984285254, 114099.617569792, 99294.3753778483, 55.8837027444483, 13026.3960069484, 10765.1212927552, 13305.4243926174, 10906.2671966206, 531.969185836329, 11136.1461683852, 11752.8238558364, 398.206028873267, 100.68216531975, 10471.0863846699, 1239.10061747058, 16075.2328033676, 19337.8582553017, 6674.97302012422, 24336.5802850426, 2698.54472051032, 2542.38627512965, 21046.5963622822, 3032.27547936263, 135882.607030865, 157385.213196945, 136362.73109529, 140299.167867856, 6674.97302012422, 24336.5802850426, 5811.28951558421, 2989.49900525221, 75181.7586486951, 33956.5718612827, 51618.179126201, 36982.9849286861, 37270.8763732936, 8932.49585576262, 8001.67041184488, 15015.1759766419, 2094.08174108814, 2096.77146686163, 159.099887233568, 208.596791903135, 3555.55755904594, 1925.24707500557, 3851.42221972128, 3803.87898078531, 222205.58913276, 2136.50605339577, 81034.3687015817, 77655.1274823483, 18228.7995469961, 70587.9005128455, 6691.40558335744, 221504.107560912, 83294.9108504599, 83681.1588655897, 83160.2345776375, 83582.8022950674, 83314.0780278861, 82006.5495241718, 18.0526857475123, 93.193980859494, 84265.1520518682, 253811.792966742, 116080.619105241, 105499.940289783, 12487.3443239224, 1434.76531228677, 2110.44832954459, 16075.2328033676, 14327.0287101337, 74790.1497815539, 95450.6663381779, 3223.90239894862, 24521.535402389, 22622.6388663411, 22243.7714758182, 22760.1172694667, 40421.7245343851, 32939.1179965398, 64504.8653766487, 36982.9849286861, 37270.8763732936, 16075.2328033676, 440.470022016028, 3104.53553790375, 300.038879640861, 316.428990862646, 28047.9809374163, 17305.6483936032, 32939.1179965398, 16075.2328033676, 183554.760661605, 16075.2328033676, 45807.9735741606, 30297.7220228298, 1066.52836260743, 1622.69096991406, 221396.174278472, 219143.44627948, 77723.5791150624, 2271.84710195518, 4154.48473263309, 36982.9849286861, 37270.8763732936, 38914.1648793721, 6156.42679603685, 961.861785584727, 2730.02435753449, 2967.6019647794, 36982.9849286861, 37270.8763732936, 3044.68054319809, 6175.80966506985, 415.103538829653, 165.105593485501, 163.148000537549, 426.433258535804, 1011.67106148182, 42736.3998500906, 28502.9484160247, 27538.760045669, 20125.4648902958, 58448.6853258981, 58820.2365002494, 18090.2165205772, 26128.4667348823, 53606.3301405669, 21207.9320627651, 10691.1425730899, 29885.4312932553, 29886.9380207289, 201836.01490057, 198645.46516952, 29956.0676611137, 622.176494602571, 680.470938199018, 102849.315411366, 37.6278552136606, 25959.1492898144, 85306.609714591, 79361.0907328648, 16075.2328033676, 12045.2966936112, 10628.3326775743, 100998.400550064, 111707.343051063, 27422.7024095259, 16558.4037697017, 42888.7291164084, 39885.2711425387, 98643.8101159576, 168255.32819502, 90222.9111338109, 92936.8105857877, 92936.8105857877, 28502.9484160247, 27538.760045669, 535.778320926114, 35.9876265013509, 430.335507715417, 57681.6742803675, 44697.2973485041, 3653.83169219106, 4124.69386905555, 70276.1135907228, 79158.0293286963, 75729.0661201666, 70662.3616058527, 70295.2807681491, 26120.2256859015, 93823.9796754645, 667.663331675873, 566.070592134515, 398.206028873267, 100.68216531975, 1412.22009106794, 1241.1340850347, 1682.79562704932, 6493.96147313932, 32668.5475257474, 35167.4246470151, 31482.6120099971, 46635.9234111151, 31471.2619033728, 26912.4080634073, 21322.8690677796, 14647.9122494648, 22102.844961176, 38914.1648793721, 16075.2328033676, 994.400463398142, 939.647131209686, 765.476897764711, 5915.2842459829, 7008.4468854998, 111.537810954324, 11.9265340475962, 55486.6741746049, 18430.1078379014, 20624.1576169965, 28047.9809374163, 17305.6483936032, 7439.9785505317, 8040.6116936092, 36930.4452444712, 5945.88108633189, 30134.2472478016, 86314.1600084239, 85968.3159500624, 2112.27026280629, 577.254833012537, 3788.82834702936, 132.977985957547, 155.61043086903, 19337.8582553017, 37.6278552136605, 515.856579229091, 149.616593585133, 589.632635475253, 230.341871803662, 535.778320926114, 35.9876265013509, 430.335507715417, 58999.9631732753, 179.85644727361, 17383.1290701478, 2390.81160509522, 7049.14002612071, 32860.9063420733, 1137.16735594068, 27035.460617007, 1881.02471102513, 676.269484835168, 26719.2343145144, 22813.2525009148, 40474.8597658331, 286.444632280221, 1279.61237595292, 16075.2328033676, 440.470022016028, 5375.87891950178, 4784.93344786081, 4737.73377028852, 16860.6328368116, 7152.78841930762, 135094.97493827, 146668.539353397, 29956.0676611137, 51271.748950337, 15277.5070466383, 4936.34586517734, 12354.1982101948, 66468.6117473901, 85453.5848480829, 106197.752115163, 1142.6740382567, 985.129972726055, 36070.6084492904, 32772.768530084, 939.647131209686, 765.476897764711, 5952.25147718454, 87745.2378098516, 76689.0966251236, 51167.4107760306, 95818.5005738439, 40531.9929885463, 35247.2213737433, 55.8837027444483, 16075.2328033676, 1268.24710699326, 1978.28678791113, 63571.5935003966, 55150.6945182499, 8641.650453007, 9881.77846966694, 16075.2328033676, 56910.2300583595, 4541.19383573212, 16075.2328033676, 24271.1577820147, 92011.4365938719, 91685.360328333, 73688.9742002567, 83210.6237172184, 30336.7507440109, 29976.0527177166, 95258.1117338167, 272326.167576933, 82516.0146536885, 57082.833417652, 47450.2260517822, 15885.3539141143, 173636.352965223, 42627.5916110602, 38090.0800166703, 24732.7917897775, 24070.3747012352, 24664.854777664, 681.437660722141, 363623.0342994, 363144.122982804, 21272.983034358, 120.061180462997, 248.666375320496, 19557.0116562827, 29472.2559963904, 885.387831514171, 1063.60090266067, 1917.18848097558, 2022.31134108929, 460.111785141671, 27608.6662035722, 6384.36974828639, 1375.77765250751, 36982.9849286861, 37270.8763732936, 398.206028873267, 100.68216531975, 53606.3301405669, 21207.9320627651, 767.659794592033, 1454.77456326011, 153365.501503204, 151333.40197923, 151364.375721327, 159115.37222571, 165235.981537964, 55056.0553333757, 7168.43322629519, 11808.7456332162, 10072.3189069713, 136.012689198563, 3705.94019290151, 3134.38703678669, 3530.8730422699, 43404.0255596169, 62251.3827708497, 201712.748850475, 61136.9111754039, 4001.95870596901, 4357.62032237333, 736.791696610977, 16075.2328033676, 1231.16655235924, 94632.3385430244, 44359.7426141151, 5247.99290427813, 5214.10268908233, 54625.7932420798, 40194.0125310833, 56193.9222594999, 55574.8181227342, 125148.270887331, 33033.9962026151, 74468.5859618555, 89996.2833950709, 89461.253154188, 295156.910769921, 272573.385314989, 276886.505215703, 278976.509551061, 284588.576944799, 258910.341437309, 283236.861017736, 93823.9796754645, 24418.7790417764, 15492.7810330955, 77301.7822690045, 12487.3443239224, 3278.45128945893, 2257.03914408656, 4769.65333031969, 4679.92088297921, 5811.28951558421, 2989.49900525221, 2590.93953092889, 4994.12490838922, 28272.2198080367, 32100.5831047186, 20695.5418583243, 28.8329952827153, 76864.5050646222, 77265.6282842183, 77738.1818583003, 2559.86427269535, 352.252252873975, 14144.0845876301, 174193.164507699, 121333.611736544, 153950.45476974, 196215.023393146, 124826.326707026, 301912.736119226, 138437.00289546, 7586.91289307513, 65626.291302274, 34979.3782673966, 21585.0016594938, 5541.07738247755, 677.326745456862, 138095.721874831, 155211.935577271, 144924.235825913, 139651.327702529, 138399.994847965, 19337.8582553017, 7568.25078703428, 2559.6586912554, 70309.0015394083, 70546.3690824553, 4080.17390339016, 51366.6202156981, 59221.335351104, 2267.69288065616, 19758.7264710706, 20723.5978031382, 50150.6725904749, 98248.6657159806, 97207.5315418026, 98551.4609935049, 18740.0437686438, 2923.15044503399, 3841.92779263698, 67007.259343013, 90466.8960368266, 21396.0651887841, 36982.9849286861, 37270.8763732936, 235.888335573082, 1079.57788014382, 12487.3443239224, 121093.186968869, 908.196150881241, 767.659794592033, 1454.77456326011, 7759.34201196058, 7510.23576231467, 699.630197523344, 764.086378987902, 206144.156865841, 210301.178461029, 206425.368433579, 185981.234773921, 204661.863465613, 29956.0676611137, 29650.9699561365, 283.2216221865, 555.409082255954, 10594.1282401533, 10962.3640013702, 702.693077636257, 85119.8250961479, 62163.6430327978, 654.566269291525, 2359.12306999383, 9032.5496306076, 9084.63220376391, 136.012689198563, 4474.48594943777, 3769.19849112471, 1561.92380332132, 1814.40127150958, 1515.4096269487, 4578.61934055599, 1621.99107677674, 2014.00887497785, 85306.609714591, 55486.6741746049, 81391.137415594, 11892.0953620346, 11124.9936842712, 19180.6789744664, 18546.4708746374, 18811.7511715562, 12212.2031809959, 11132.5687421378, 11175.593166808, 27155.254954156, 14849.1512396624, 9586.58728813155, 74.1206752749301, 63.6390060132865, 5811.28951558421, 2989.49900525221, 66623.3263215092, 67009.5743366391, 66911.2177661167, 66642.4934989355, 20078.1896898285, 16572.4633305905, 16075.2328033676, 398.206028873267, 100.68216531975, 83912.9430353036, 8424.46547585386, 9154.20536373538, 8951.28583145258, 9130.49983677968, 17.6904202093187, 304.249844338468, 170897.753812538, 176872.124959152, 45193.8467740272, 78845.3540771121, 76604.9763985161, 76475.6957504907, 939.647131209686, 765.476897764711, 181232.117426831, 243565.298451737, 208434.044782877, 207900.265508522, 223897.205791395, 208636.44772118, 92450.550732065, 179141.484528007, 107857.32885251, 161249.241604237, 105961.728812783, 144988.938487865, 305342.356519266, 17590.8017229446, 17075.1278135088, 28.5425439295029, 737.564022643526, 39676.5504801929, 57338.1577451113, 121293.398678073, 2926.75909982747, 4936.85306638324, 63.6390060132865, 1239.21553732148, 329.174371165468, 2605.4329739394, 252078.278956474, 117262.135285611, 192060.216058356, 5707.94822134323, 6233.48059981045, 37.6278552136605, 363.664733665199, 36713.409621457, 17474.6087679846, 10845.2932714308, 25982.141810856, 1164.42935736649, 1120.23165424879, 14.0408740227313, 93823.9796754645, 14327.0287101337, 74790.1497815539, 95450.6663381779, 6099.26304118264, 7442.5072217015, 306.441464881457, 177566.585738949, 295922.694882608, 310171.546301081, 16075.2328033676, 1078.62984126406, 398.206028873267, 100.68216531975, 63571.5935003966, 55150.6945182499, 28348.2586619949, 29351.8078848489, 16075.2328033676, 939.647131209686, 765.476897764711, 32205.5274340585, 34704.4045553263, 28024.5085071464, 5811.28951558421, 2989.49900525221, 190741.311278414, 49816.5963875827, 50495.2170310016, 892.126650340711, 1459.96585583202, 1856.15162274216, 74.3657790574448, 11624.8096425303, 38846.4546213561, 328.948537457794, 1137.1349600016, 5693.93511409781, 5292.04907139017, 12759.5908336876, 90834.7139900231, 99778.6657154159, 11621.3176642542, 12278.3555641501, 56403.7660448149, 2094.50134565274, 86314.1600084239, 85968.3159500624, 95258.1117338167, 13491.6215479211, 108910.469178033, 211522.838863086, 103695.560751296, 106656.617835467, 128.860797122121, 7955.95513570737, 4511.09279776832, 5264.25054408389, 8925.42336810784, 55.8837027444483, 5251.69986552512, 24355.2159018846, 36.6410442527216, 1528.26650950077, 5112.73512949626, 2560.62948411508, 5631.43544573204, 12.0165724250514, 942.887340344549, 3316.97231228116, 5498.91260517294, 5497.89962073657, 249163.152060474, 247547.68281435, 29956.0676611137, 87543.3881415423, 95875.4293058239, 96564.0682245958, 97522.4127640982, 106207.709142993, 93347.4168873337, 255.167752297303, 303.185109429245, 8271.51243623084, 80737.5474122474, 3980.84691725203, 3999.85816695707, 67628.0554172035, 63825.822073466, 10421.3173565549, 6674.97302012422, 24336.5802850426, 244170.913806276, 391.531497495759, 28137.468559337, 260.596333928371, 26288.7026845979, 26536.5205057584, 1231.16655235924, 13156.5475229025, 147850.722096189, 5547.17092139206, 4177.52289596451, 4760.79090444577, 4168.31008387098, 17953.9491150269, 23463.2467252393, 22680.7948530841, 20676.1652627654, 18051.2168125387, 17636.0091056322, 20805.4736394477, 132.977985957547, 155.61043086903, 939.647131209686, 765.476897764711, 10211.7670326864, 5041.81498086856, 3775.74097932475, 85306.609714591, 198121.526704852, 210645.396817158, 12062.3772608766, 7470.97163774495, 7470.97163774495, 108289.766347604, 31071.5955619915, 6674.97302012422, 14992.621615752, 12323.4615616385, 24090.2929848889, 24512.6859466473, 51604.4672661769, 112067.588337597, 132728.104894221, 51112.6088869908, 50922.3755548938, 51028.1019243397, 93413.8885612432, 51891.8126675425, 5728.6591078901, 503.730329977421, 590.221845487346, 36982.9849286861, 37270.8763732936, 48.8008458005068, 44522.1008977607, 43599.4765730038, 50268.243471083, 16075.2328033676, 65231.669848078, 380.817770655907, 227.142459758333, 53.3971236974194, 9179.4351480092, 248843.373832268, 203375.627286258, 239324.003230238, 130818.199916335, 212901.047315744, 203424.752476743, 103887.316723985, 16075.2328033676, 34227.6893314847, 61807.5723288041, 62095.4637734116, 67709.4970502892, 122793.090983534, 123536.353376381, 16075.2328033676, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 6164.33860287796, 89520.6748727418, 89524.4798004808, 1902.60092840145, 12213.988911664, 6642.87308898889, 19337.8582553017, 1231.16655235924, 317808.786825214, 329760.384329104, 3959.824736773, 16075.2328033676, 2926.75909982747, 4936.85306638324, 38547.260869027, 39046.5478516437, 39639.006244694, 5360.77596434193, 3162.33826715361, 1834.23680564133, 1823.00398028511, 7100.57324445251, 16075.2328033676, 14356.175242238, 28328.9385857456, 30738.7803417177, 42155.0345169433, 14210.5988219155, 74468.5859618555, 96669.6849250512, 11896.0113039493, 153175.665720884, 188883.386413419, 187843.553226443, 28.5425439295029, 737.564022643526, 132234.327991776, 122732.122710594, 131123.381998004, 121297.68740772, 91360.1361111959, 90883.9934713283, 84786.936541895, 91622.9155833755, 91129.254945371, 2926.75909982747, 4936.85306638324, 29956.0676611137, 36982.9849286861, 37270.8763732936, 8394.29706322292, 4564.2492553195, 19440.9191233816, 658.254210804327, 270.747002615783, 241.381499918386, 380.817770655907, 3437.26994859153, 2926.75909982747, 4936.85306638324, 101985.661656596, 96597.7717937726, 16296.3994555394, 69137.2336293169, 96460.3988916843, 101003.901084997, 31614.3184242311, 28138.9666751264, 31442.6339228064, 45218.6152113669, 68761.9907714481, 47750.2257623655, 26733.782609664, 120116.671766054, 55262.5288197443, 5782.58370207239, 153374.189566769, 2431.13950533151, 767.659794592033, 1454.77456326011, 9892.88508773531, 8450.75135759759, 255.167752297303, 303.185109429245, 36982.9849286861, 37270.8763732936, 163264.371825029, 35259.0430358039, 147850.722096189, 43290.6967082602, 57761.8450436003, 75566.8100471123, 45479.631261864, 16075.2328033676, 213.697715836692, 4168.95830258313, 16075.2328033676, 53612.7880250716, 28584.545558594, 9133.53024131936, 40514.7264419279, 51830.6100406274, 27419.2932924914, 28080.4379976091, 6674.97302012422, 24336.5802850426, 3301.66599654836, 1609.68048746356, 24336.5802850426, 9724.70541100056, 37304.5884083199, 5398.92008234254, 398.206028873267, 100.68216531975, 92214.0980567895, 255.167752297303, 303.185109429245, 16075.2328033676, 125799.324787779, 333338.0637891, 15095.2930517321, 3675.70610519469, 7070.06145693775, 6930.41016580392, 5166.39813573529, 99921.1922509027, 91500.293268756, 94317.7872629535, 17840.0314357115, 17099.9731763471, 16075.2328033676, 19178.6652634194, 12777.1404245551, 29683.7173256695, 585.105503929728, 27043.3178229638, 29542.1949442316, 13333.1557729338, 15982.1474939009, 6797.15328996963, 147850.722096189, 37953.8072856186, 64984.9061629212, 38897.2351876096, 36989.6189152629, 123944.559003358, 124240.598196754, 71359.255659395, 92905.858611783, 98058.7061411891, 109309.326329151, 102556.739818883, 16283.2309561036, 681.437660722141, 697.401439464038, 91287.0296654382, 122507.254915808, 33780.9410690381, 92165.1972438328, 6603.33530768083, 6603.98417725782, 22813.2525009148, 40474.8597658331, 36982.9849286861, 37270.8763732936, 63571.5935003966, 55150.6945182499, 43234.8791833435, 43893.5348366351, 56323.4799706448, 35311.7149615622, 14295.2718088607, 107678.160965251, 6887.49641429761, 11370.7101112596, 19676.6431090546, 34806.7113946924, 68626.3369318041, 6073.87127164214, 27799.0180940323, 16075.2328033676, 64875.5759169255, 3691.70076417485, 3332.32786095816, 83029.1669279268, 95094.6572229366, 771.903386534259, 31287.7030128526, 30392.4019717125, 16075.2328033676, 400.993672632477, 496.959371783375, 1007.79460327982, 46513.8001491124, 40430.1742999431, 1856.15162274216, 28502.9484160247, 27538.760045669, 16075.2328033676, 53188.7704001565, 58522.9973977792, 53476.661844764, 398.206028873267, 100.68216531975, 599.733819870055, 74.6790347158767, 32192.4620332683, 70515.6824688705, 70975.3533485045, 70887.2336432219, 977.609276577958, 21047.4056537877, 84608.5557268882, 69754.4890047677, 28272.2198080367, 32100.5831047186, 20695.5418583243, 42435.5663030035, 29956.0676611137, 6449.61153526057, 5370.80498146574, 19695.7957281063, 87829.1898424975, 9597.98064594813, 60386.3015054734, 52730.9188373698, 51927.4381613156, 27985.9136574295, 9578.09627607806, 9688.92217824012, 117700.264779187, 27868.5654983215, 9692.15827765379, 27621.5427223908, 91035.9767616929, 45547.1755331454, 174500.642090015, 942.557131508383, 935.050447483964, 398.206028873267, 100.68216531975, 13005.7297846326, 5858.6701679545, 28936.7153247409, 25323.293109751, 48419.2900446253, 277056.807533657, 276836.48816838, 276014.262711369, 275993.068941883, 279623.128150276, 279650.535609534, 278718.094288392, 275358.607010034, 26332.212969649, 42278.157661994, 45321.3263734185, 464.636706591329, 481.026817813114, 579.928084836374, 68572.0673080414, 16695.1769494066, 75181.7586486951, 16075.2328033676, 52403.5695189493, 51561.1986565586, 5479.55193370594, 13464.1758655061, 10352.4561170516, 10413.065074521, 32971.2892261068, 1577.81789061058, 826.756600931812, 2688.66837369881, 16075.2328033676, 96044.6993025502, 47829.8743683947, 484.616320205343, 195.723971482939, 6308.23964798715, 4766.77462060242, 59251.9316723664, 31461.5587619452, 31289.8742605205, 21524.7640608188, 9305.8207774906, 21830.7718363237, 16263.9282531951, 1086.61987060631, 8554.81932722502, 767.659794592033, 1454.77456326011, 658.254210804327, 42027.5646208175, 80390.3261941813, 96564.9331288038, 85986.6518278662, 398.206028873267, 100.68216531975, 6674.97302012422, 24336.5802850426, 107510.112100425, 107619.629316322, 104912.902972969, 104909.771595607, 4001.95870596901, 4357.62032237333, 1231.16655235924, 27043.3178229638, 29542.1949442316, 29956.0676611137, 628.392877511488, 1614.66445300264, 190912.014449002, 155918.500964272, 140299.042797903, 171243.921788659, 66623.3263215092, 67009.5743366391, 66911.2177661167, 66642.4934989355, 19903.2246196404, 54916.5975064994, 20927.4828010121, 91300.9727393339, 83888.6064018954, 77173.7392004845, 95680.872856554, 50313.61944654, 91493.4771989321, 35883.9832861311, 31916.0768619931, 34532.512040813, 34514.5033661103, 92479.6210160185, 30046.498785865, 81025.7949411477, 91538.7297542046, 85260.3772880562, 92565.9283229403, 91484.3307001196, 29103.0547034758, 19337.8582553017, 2105.52504679745, 9524.14720960478, 8839.41505485024, 2450.79377407316, 83212.3290126742, 245384.693721489, 54639.1033179677, 53993.8103514259, 65807.4090383653, 107289.920114286, 275.586391730983, 257.656453495347, 183.098774038162, 288.24143494958, 27043.3178229638, 29542.1949442316, 398.206028873267, 100.68216531975, 16075.2328033676, 78644.2076559101, 58976.1149955677, 398.206028873267, 100.68216531975, 1002.60799704385, 72825.5954882376, 184.199185303607, 230.023527073134, 12242.1180853322, 13205.5419593391, 51231.6252950158, 2926.75909982747, 4936.85306638324, 20439.4547422874, 19435.7860917232, 4932.76411677888, 4318.78160422255, 3891.50922620793, 76425.1583223025, 9179.4351480092, 56275.6265606142, 36607.5339002718, 753.540871219158, 2645.89766990121, 121645.131766704, 121889.865503885, 28502.9484160247, 27538.760045669, 23511.6787985573, 70661.6528786038, 70586.3670186746, 69587.3745856255, 71047.9008937337, 70680.82005603, 121093.186968869, 50579.7357456196, 199625.155297969, 3503.57400795354, 4308.46009655434, 104.725193601644, 85306.609714591, 2637.24978689933, 104160.939539591, 102678.646139363, 96191.6740818828, 43092.3621655858, 6714.4284686198, 11399.9293011226, 11354.2009710307, 6136.19299825192, 19480.438166679, 3963.36631502691, 60444.9518203958, 58817.9907585616, 37319.9539963416, 36245.6757033634, 73574.9552922195, 80804.3798125565, 39331.3988355692, 12429.6258355228, 22106.8629825079, 1920.22143449577, 29121.959694567, 19337.8582553017, 55855.4477927894, 54781.1694998111, 54943.1951870366, 2626.60501333993, 60683.8263272567, 103867.26269049, 76350.098917307, 18368.2723711312, 32886.9428937519, 102780.426749747, 101264.969671375, 102631.164594173, 87173.5096169723, 15467.5706394005, 10456.8589316354, 130963.038544133, 59257.0995665616, 515.856579229091, 149.616593585133, 120471.980157057, 939.647131209686, 765.476897764711, 9179.4351480092, 53134.9252164494, 29949.2515369097, 28780.9144934048, 22172.1729013736, 26630.9835886012, 30830.5896341655, 18368.2723711312, 32886.9428937519, 110.144521346197, 28010.7989544396, 27852.8785169448, 94986.7695193309, 196272.950316917, 135638.453431828, 126283.290913303, 38914.1648793721, 33564.0637676748, 47353.2133064777, 47240.8356977688, 9641.46443154389, 2187.40639533237, 1231.16655235924, 64596.7067074633, 29956.0676611137, 49308.0664466671, 33151.8139696841, 12812.7934754162, 80786.4063520156, 47568.1690686503, 50432.5379734911, 50070.3822055049, 74244.8827342774, 77617.3928559835, 71963.7453290975, 59477.846225111, 72776.0476401824, 81929.5712319565, 16075.2328033676, 23152.8007878737, 37920.7564343289, 23801.542031345, 17279.2239720536, 1826.28439661687, 2633.97740424419, 168.963385757726, 16075.2328033676, 27530.4466366291, 8787.29138730481, 10051.9810507305, 111325.365041501, 111187.140726555, 55643.3918320751, 56029.639847205, 55662.5590095013, 8261.55232582018, 171866.869761401, 152198.777101059, 135406.20496183, 398.206028873267, 100.68216531975, 39559.6447052985, 134750.861328155, 11439.9300833991, 148378.445108991, 144647.391118253, 173088.105168476, 123169.141507421, 131827.818107279, 163486.201758788, 13306.0537897857, 13072.5884086939, 79917.6148653405, 76925.4969841716, 509.219258025596, 1040.16206377234, 1478.58024416557, 2780.06450769997, 1371.5059187383, 608.481558394077, 136.012689198563, 0.279040550429499, 197.486127282385, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 1864.15501149668, 50091.1543099921, 29155.6593708493, 3035.06908335175, 3014.02388575789, 2926.75909982747, 4936.85306638324, 535.778320926114, 35.9876265013509, 430.335507715417, 107020.984285254, 114099.617569792, 11368.0286559487, 19673.9616537436, 34804.0299393815, 68623.6554764932, 6071.18981633121, 27796.3366387213, 4456.94251146803, 31789.1416899254, 398.206028873267, 100.68216531975, 23576.2625206416, 51156.145517961, 51444.0369625685, 824.642576732572, 3295.05621256917, 16075.2328033676, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 4620.43191662203, 4658.50539586673, 64112.9449836102, 1231.16655235924, 153944.283004912, 45967.142819243, 45960.2317276216, 39315.1880284767, 16075.2328033676, 60303.9528631446, 52648.5701950411, 52497.0074551236, 908.196150881241, 144317.912050802, 72756.5078357389, 58800.7459512823, 7650.20753108316, 2926.75909982747, 4936.85306638324, 175568.123117704, 6470.41921644488, 6634.74839685096, 74975.5010782936, 133073.462270456, 57284.7120006686, 75137.5409363869, 113202.582121113, 8647.71640569986, 8977.07154078851, 16075.2328033676, 92165.1972438328, 49759.9411040688, 175034.731183001, 33115.3855921289, 5211.30035177055, 53628.7936819859, 9737.01364015589, 490.963527188231, 10186.8548760226, 157959.487269137, 192339.137968375, 110.441908169989, 11368.0286559487, 19673.9616537437, 34804.0299393815, 68623.6554764932, 6071.18981633121, 27796.3366387213, 53878.8547551192, 66002.9909469008, 36789.9794518149, 142325.786173684, 142555.550682935, 54357.814579484, 140843.492773456, 145180.21540566, 156337.461811068, 16154.5989295264, 15525.0845426716, 54144.0393097803, 49230.8299890177, 5124.35690124769, 46902.8467046196, 15902.7168116905, 16586.171263766, 31461.5587619452, 31289.8742605205, 100527.882254971, 227.142459758333, 53.3971236974194, 3921.77359482017, 44725.8740290635, 62759.8634678953, 93201.1598714107, 93064.5696792991, 75181.7586486951, 17856.9645789661, 50870.9535619272, 87785.6212290934, 88744.814606663, 96918.8942388369, 93075.2714181536, 82404.4469305039, 5460.57542759886, 3728.49898930883, 4040.8154131577, 11380.3621406997, 12193.285691482, 16778.2310808809, 11824.3578885718, 15892.2353149545, 16198.2430904593, 8991.53874065187, 16075.2328033676, 12213.988911664, 6642.87308898889, 75490.0582885143, 60152.1951917269, 16075.2328033676, 16075.2328033676, 95894.9043973424, 17614.2181769122, 18190.1360593443, 18367.6112952084, 18949.2497853257, 19953.6441528453, 16075.2328033676, 543.909577471777, 44.6419783150288, 380.817770655907, 21541.2180621134, 21512.4236178523, 136316.120602636, 135276.28741566, 25932.6525005705, 38116.5629742173, 147850.722096189, 8575.20718596755, 695.169633237237, 16075.2328033676, 1012.56210112466, 1658.13449840418, 29956.0676611137, 16075.2328033676, 76425.1583223025, 7047.99670191291, 1231.16655235924, 8100.65293700648, 42424.3715271782, 217875.207060492, 201816.029722476, 248773.961023538, 149957.096355532, 85306.609714591, 11454.1230125181, 398.206028873267, 100.68216531975, 64404.8788285054, 28353.677817662, 24878.3260685572, 18291.2365144861, 28181.9933162373, 65412.8157096601, 31242.2826590399, 65114.8903511941, 1864.15501149668, 44359.7426141151, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 4365.02107578186, 136.012689198563, 40721.8586787968, 57140.2320733674, 1827.72578615523, 4464.13601452754, 16075.2328033676, 8405.44185681858, 30609.7028393112, 380.817770655907, 5647.0200301254, 844.798579275008, 1480.03457890593, 74468.5859618555, 9732.24313297653, 270379.466857225, 186257.422268197, 175890.225542032, 363663.694803919, 185932.921272138, 179188.731443021, 126452.40777013, 331701.905921671, 184838.568310018, 1226.8921572553, 16075.2328033676, 4631.92058337809, 3320.69229751883, 1063.37853077095, 1998.63945737085, 812.528575246205, 130.189402367952, 55618.1228589728, 4001.95870596901, 4357.62032237333, 22771.7281863657, 40433.3354512841, 38784.305244875, 189130.997100566, 190043.012233244, 190254.921443201, 20282.5102499741, 60155.6627673211, 53188.7736577209, 22331.4877904408, 16291.6463552664, 11189.9269529378, 14327.0287101337, 74790.1497815539, 95450.6663381779, 7508.54642053444, 16075.2328033676, 221779.193516932, 205720.016178917, 252677.947479978, 153861.082811972, 29956.0676611137, 22813.2525009147, 40474.8597658331, 939.647131209686, 765.476897764711, 93823.9796754645, 89753.0494145599, 89901.4195269985, 1297.28462233174, 131483.781959654, 144166.706956539, 149117.581331208, 127275.261965319, 4761.72785086846, 7665.61353154454, 35152.6888606295, 30554.1345157444, 153175.665720884, 16323.6878692158, 19940.9567681648, 6416.81207706452, 6420.04136945592, 6378.26505696896, 4456.94251146803, 31789.1416899254, 177791.234691971, 192960.788850459, 199450.525287498, 556.34343564502, 572.733546866805, 29956.0676611137, 11520.7419596666, 11405.2311028258, 34553.4880542934, 35575.4702473679, 1864.15501149668, 16075.2328033676, 39728.3969639091, 48116.1848895136, 28502.9484160247, 27538.760045669, 4357.1690729959, 12297.6290314722, 11538.5159408511, 12263.5426711915, 76044.1001512845, 74563.9897997603, 93413.0995729691, 90194.6912665844, 90808.5184320408, 74666.1000519696, 90804.9921509775, 29447.1962672944, 44359.7426141151, 38939.2587377148, 341457.264490541, 266427.995436116, 273946.165382156, 76658.3112521181, 55646.5462430356, 34630.1030903341, 128012.992246724, 58737.6680161304, 58843.3943855764, 59681.0959181214, 57773.4796457747, 132.977985957547, 155.61043086903, 22813.2525009147, 40474.8597658331, 240645.330985545, 198581.640398149, 235670.21094143, 175307.468212181, 10133.1291972557, 20771.436539465, 16075.2328033676, 908.196150881241, 72428.8293682904, 200.880466402474, 16075.2328033676, 1864.15501149668, 36204.4557304558, 53534.8567311206, 50880.9094513748, 52899.4415876215, 885.998967968593, 14929.2055915511, 1482.21658023898, 715.420111975387, 17617.3844379734, 9370.08802175013, 8530.11119081477, 17588.6344451765, 398.206028873267, 100.68216531975, 151762.139246897, 151986.448272112, 1084.73118521835, 719.390240453573, 20586.3394593287, 8420.1720315927, 49673.3311763632, 116430.060845369, 121634.474364463, 131032.371571324, 129759.944783252, 129080.702752802, 53754.7921645365, 31957.0275876477, 32356.1878324838, 27989.1211635097, 106362.263023261, 6920.66715407778, 2112.22461823153, 214992.010158622, 3630.85199179314, 5439.75898151133, 52699.3936438119, 34605.5501767839, 52987.2850884194, 51231.6252950158, 169545.111237265, 149877.018576923, 63571.5935003966, 55150.6945182499, 16075.2328033676, 128285.685976471, 24483.5561811614, 139320.89488646, 59139.5031721197, 128751.021251182, 50718.604189973, 2951.67083923163, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 1682.79562704932, 6493.96147313932, 2090.78496154058, 9459.55834462236, 9090.63054171216, 25852.4308488579, 33818.008704142, 34943.6524595991, 18482.7247107735, 18541.9150061132, 214144.197194515, 85223.4969691916, 4319.11423917167, 4353.03607768745, 4456.94251146803, 31789.1416899254, 8933.13509923114, 8951.86325068356, 44395.988065166, 53897.2635905682, 54185.1550351758, 3199.28902086768, 44359.7426141151, 14842.1423342692, 15063.1711211095, 4001.95870596901, 4357.62032237333, 1365.04903019086, 43034.4189577199, 19337.8582553017, 31200.045083288, 14215.7411504828, 27828.0041088566, 21442.8583355827, 153175.665720884, 79029.7396570736, 77910.4844822314, 84368.1917565887, 1142.6740382567, 985.129972726055, 23045.6359563481, 27883.3697466469, 23578.6445501559, 22971.3623895596, 4996.16856530678, 6566.39703617024, 605.698448481614, 1066.98567789786, 5811.28951558421, 2989.49900525221, 3728.49898930883, 4040.8154131577, 375.937084316765, 2926.75653195698, 2926.75909982747, 4936.85306638324, 55486.6741746049, 38795.7991166322, 41817.7247374889, 29956.0676611137, 1343.17433566773, 16075.2328033676, 76885.6170639886, 76426.0082005137, 78946.4627801228, 2267.69288065616, 79618.2838571261, 80004.531872256, 79483.6075843038, 79637.4510345524, 80020.5124830257, 1642.76743936655, 1679.56175482368, 36982.9849286861, 37270.8763732936, 36982.9849286861, 37270.8763732936, 380.817770655907, 100414.253634336, 81826.405713255, 55486.6741746049, 1864.15501149668, 25589.0175872592, 14144.0845876301, 11597.2531615025, 288.801430295814, 16075.2328033676, 37241.449776783, 34587.5024970372, 2829.03935329826, 6545.47137910312, 680.29939962052, 457.219851674169, 2435.21404021899, 38291.7807584217, 212126.378685521, 41257.969740155, 3603.77504922915, 5300.96680048257, 295.557739471973, 897.685180032961, 721.525209319147, 398.206028873267, 100.68216531975, 39931.5015580468, 39736.4766076507, 7803.1658420189, 7873.60631461535, 2104.98233089024, 19.3344304127309, 2112.27026280629, 1661.37903405997, 1502.58971185598, 398.206028873267, 100.68216531975, 2926.75909982747, 4936.85306638324, 11334.9149809785, 4605.63767870449, 4543.005008474, 16075.2328033676, 8110.50016319561, 7896.1757840266, 36982.9849286861, 82329.8375786527, 91167.6704957289, 83525.6789672513, 398.206028873267, 100.68216531975, 21349.0998014748, 20446.3494931145, 27653.8839499332, 59182.2315224222, 3265.673811529, 4067.10598615302, 24891.9027539873, 1874.64777121427, 821.946096245687, 223.065800887104, 55643.3918320751, 56029.639847205, 55662.5590095013, 4456.94251146803, 31789.1416899254, 92036.163008486, 69269.8991601077, 47479.93123639, 70330.5041540749, 47284.9464674783, 48224.6003861132, 46320.7580971226, 36982.9849286861, 37270.8763732936, 1277.34995492533, 156.815734849888, 1231.16655235924, 16075.2328033676, 14491.361972311, 40768.3219463978, 13606.0113879251, 12792.2627149967, 16075.2328033676, 4197.68733765309, 8226.61342575517, 9602.39775774322, 709.435380992402, 57.2873605990003, 5371.80216496029, 229.774123248535, 12245.9473411159, 7322.67220134522, 6025.35112282787, 7157.35667792183, 42579.5715166489, 47415.374959999, 16075.2328033676, 29444.9998864861, 22813.2525009148, 40474.8597658331, 9213.79410741709, 9032.26896890463, 14371.8268273659, 14898.5892684106, 1169.61472952164, 1260.22510969835, 503.482424537497, 4221.25024820685, 2607.53645239049, 56608.8373607729, 157915.644061441, 5778.24656131537, 4014.27062702832, 83511.8958242504, 86151.9188313244, 85787.9321345082, 130.189402367952, 37.6278552136605, 7284.94464057689, 10405.0395606493, 86.7113720302211, 63571.5935003966, 55150.6945182499, 2477.50386407499, 3043.55669863851, 16831.1625442096, 5125.44325513072, 5422.86388607329, 6279.52719598786, 29022.0149688602, 99773.6976784088, 98661.8883725601, 81795.0007082159, 35118.5151525607, 18220.1049721335, 11111.7789610738, 18978.9023846183, 9593.02787649512, 18704.9769254384, 241777.281654223, 6099.26304118264, 7442.5072217015, 1864.15501149668, 9604.78292872098, 28767.8194461795, 90283.1177708001, 142642.218736649, 671.886633540578, 939.647131209686, 765.476897764711, 16075.2328033676, 4220.40052045395, 1651.2658384956, 2014.18638945188, 17091.5223628584, 55153.7284688642, 52913.3507902682, 16072.9053002198, 908.680852818125, 1546.07000798904, 6047.1083519409, 28502.9484160247, 27538.760045669, 458.972235508176, 28729.5173812911, 27022.5486248149, 19568.1432006162, 15151.9577664729, 186826.335890652, 91910.9973001929, 16075.2328033676, 4843.72190583069, 6771.96105911908, 491.348240069796, 13.2641297538521, 96.6093168295493, 3313.85856569276, 1912.26404284212, 2309.15705582493, 4193.541670942, 4875.45025311416, 75303.8579518663, 74470.5529101269, 73603.8575658086, 72508.3696023602, 73865.6462315454, 78064.1711644827, 42447.4999214829, 35956.8306318594, 63571.5935003966, 55150.6945182499, 65686.8774473975, 31496.6194480066, 25568.9045958539, 23670.008059806, 23291.1406692831, 9492.63642562556, 24271.1577820147, 675.139112833662, 15284.3176942451, 28502.9484160247, 37270.8763732936, 97005.5842621115, 96267.689317331, 16075.2328033676, 15881.2848981925, 28.5425439295029, 737.564022643526, 2769.02898785043, 2626.56376872688, 100527.882254971, 36982.9849286861, 37270.8763732936, 42155.1810219693, 28502.9484160247, 27538.760045669, 52471.1305990026, 34579.1786353303, 27322.2281827943, 7974.55311577916, 16075.2328033676, 14004.4789938352, 16008.0418274388, 13120.8610366635, 7231.52983481069, 883.659008064973, 846.232018946051, 37817.4571229707, 37182.0419794716, 12168.1245226168, 96533.3116789294, 98987.6485462189, 110971.65388036, 97453.7461086309, 59691.3103268964, 89922.1961693438, 95172.603237391, 983.112463448204, 2049.31885329317, 18803.1702760808, 18145.3739337749, 30405.9669865797, 25816.0724182486, 200.880466402473, 16075.2328033676, 165.105593485501, 163.148000537549, 4309.03066226548, 3972.54230167648, 2778.86903262736, 210702.2912266, 193361.596428427, 209379.775826869, 210204.761730764, 163747.679339263, 163033.318845507, 125233.959974443, 209050.096973798, 268555.57059839, 163592.336712827, 192246.839519005, 193382.613320803, 164131.509437552, 254030.08656235, 242114.931201475, 43234.8791833435, 43893.5348366351, 21129.1196361214, 28502.9484160247, 27538.760045669, 29481.2768326057, 182325.164436804, 3695.54356526885, 5594.42086387115, 4849.53487400457, 22813.2525009147, 40474.8597658331, 13681.3753904675, 12929.2201683051, 9855.19570516019, 25645.4013530239, 2617.85848713418, 4980.11089683051, 1486.56284342968, 731.051549514966, 153175.665720884, 38914.1648793721, 380.817770655907, 36.3583549709158, 158.395733639211, 39633.637125597, 10628.1208172363, 76695.5697286669, 55683.8047195843, 34667.3615668828, 128050.250723273, 123445.467410674, 121107.325503763, 15580.0257315003, 88723.6647418944, 104160.939539591, 102678.646139363, 1943.99659167614, 17130.2521432961, 23049.4254198101, 4656.75372086722, 14876.3309815002, 16347.7850280154, 16421.7542765547, 13194.5756722358, 25091.6877071398, 50695.6994888352, 20593.1911739947, 19915.6097585009, 18891.3648888246, 35291.156336999, 40443.5878459114, 42379.0965161929, 699.159288069507, 2974.38406083584, 127440.594290867, 139685.886867366, 285.186697280334, 866.332228040084, 6293.93344919551, 40751.8845244277, 5902.50027377278, 10778.7013389514, 18916.6509294119, 2222.13324312017, 6623.55872976379, 398.206028873267, 100.68216531975, 82136.197695248, 4001.95870596901, 4357.62032237333, 3407.91189808171, 118129.584975783, 28297.885694918, 10121.4784742504, 12922.9113935853, 16243.8524543047, 149.39063000716, 89911.2831836484, 248315.513275208, 53909.823051173, 62853.7747765658, 3920.67409972033, 5267.18067365458, 48.8008458005068, 77362.2401827641, 197855.367772917, 101704.186278728, 31461.5587619452, 31289.8742605205, 71805.390211418, 103436.875605264, 145717.370767448, 54070.5119242875, 105955.532943169, 115270.466597135, 154232.528422445, 118967.731268754, 115148.297675195, 24880.0287041349, 23598.4770373999, 16075.2328033676, 44601.8633334139, 36397.6612828103, 39267.3159327397, 48692.8436146985, 28.5425439295029, 737.564022643526, 28.5425439295029, 737.564022643526, 36982.9849286861, 37270.8763732936, 28502.9484160247, 27538.760045669, 29956.0676611137, 40378.9713946759, 32723.5887265723, 3779.34108696646, 13103.7682542001, 106.0424062046, 4697.0431926362, 2277.21545950565, 21961.0559728985, 19700.8517366736, 16552.4395210255, 17069.8465953424, 19721.1553173466, 350.206256987162, 59.7099635404267, 6322.86792992675, 174892.968097699, 17712.9896921339, 3044.68054319809, 14928.1217744113, 14055.6062552242, 17185.4722382157, 16477.5290883606, 9002.65226754888, 4710.90414109405, 4724.13275861664, 19337.8582553017, 36813.7965482473, 7131.49435911357, 7336.84090648649, 11270.7120619953, 11101.2985919237, 3195.81784707596, 14356.175242238, 20379.1278153269, 20323.1003297647, 43313.7883270079, 35447.4092551147, 42977.5690468821, 39487.8089943268, 41727.6985784998, 31601.599502373, 35331.8339321473, 37352.7538456262, 37352.7538456262, 39795.3754571723, 38406.0398578838, 16148.7498694488, 16075.2328033676, 549.063997098806, 652.751602666035, 1638.53718781816, 55.8837027444483, 30969.7884309732, 6209.75846218885, 90852.5872820967, 671.634813890064, 6207.74294168439, 1856.15162274216, 10167.0210777135, 4001.95870596901, 4357.62032237333, 3405.13225365327, 6248.31845534004, 4227.60973736268, 6170.43193243687, 16075.2328033676, 16075.2328033676, 48404.0402565415, 49402.5983914328, 36670.4300190521, 1041.77242320952, 1059.37429622213, 352.942099977819, 120.942485019968, 153175.665720884, 29463.518745184, 53292.8607534304, 30053.6637930493, 1900.61563149658, 22813.2525009148, 40474.8597658331, 46785.3695331266, 44585.3976287872, 45257.745864396, 7650.21302182265, 99766.9414639354, 33203.3538939528, 2794.58783843174, 9045.06991256875, 3508.79673176626, 3931.29350538213, 16075.2328033676, 38265.0330009624, 36948.7758867851, 36366.7193909904, 19337.8582553017, 3301.66599654836, 1609.68048746356, 75030.0516269792, 13028.7267268129, 116806.082541655, 116383.228915565, 117752.150715115, 92388.1999352615, 1039.11229841826, 1117.19685248699, 7246.48055835241, 55803.1125999797, 19280.4337016607, 2894.62766262561, 69205.6644099387, 398.206028873267, 100.68216531975, 27919.7380792067, 22107.6533568137, 63571.5935003966, 55150.6945182499, 41496.3645637415, 36982.9849286861, 37270.8763732936, 67074.4436322678, 46062.6786231852, 25046.2354704837, 118429.124626874, 69978.8687776236, 9690.804229969, 9442.3131212584, 1176.84860407861, 149553.132079754, 115678.757698314, 97753.0851735469, 177744.011674266, 171797.334507719, 297991.299368921, 273414.48147302, 36982.9849286861, 37270.8763732936, 19907.4660984548, 17961.3991700641, 4617.71351581079, 2600.0791643643, 366335.341706168, 387051.194812018, 383869.663121972, 377908.906121294, 387680.793994575, 389075.025366533, 355669.223249644, 385452.24459565, 389219.918326944, 359812.656043019, 383482.141037751, 387818.93205301, 380820.39077143, 387687.383241305, 398.206028873267, 100.68216531975, 398.206028873267, 100.68216531975, 56557.960137786, 55885.052362686, 112434.168790111, 908.196150881241, 157517.539114682, 134560.243855769, 134251.174323311, 114583.081662969, 91960.2767462571, 56363.3705272317, 56651.2619718392, 72593.5320145643, 16075.2328033676, 28047.9809374163, 17305.6483936032, 124939.564439667, 118705.871104957, 118005.047622919, 117907.687693408, 82.0849869616635, 6.52034696105846, 34210.8458270749, 37046.2817632728, 1775.4632751878, 1915.3293161636, 16075.2328033676, 19337.8582553017, 63871.0059596136, 59295.4318975499, 69406.7456395116, 2797.74343680166, 2159.59828758841, 14282.4973541115, 4574.6529366075, 23740.4866324984, 23153.132358675, 54729.024205655, 40749.6377041627, 23382.0779186319, 4001.95870596901, 4357.62032237333, 6823.54590823966, 75328.6277700884, 133426.588962251, 85034.8617720389, 95496.046976288, 398.206028873267, 100.68216531975, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 27538.760045669, 3084.47193546195, 4581.704845101, 27504.0265233051, 26952.2733353687, 27043.3178229638, 29542.1949442316, 16075.2328033676, 165.105593485501, 163.148000537549, 250.858758090559, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 27450.4045576696, 41902.2756937695, 28099.1458011409, 1534.080623061, 8852.19438609167, 63978.8638250484, 59541.1186640616, 4620.43191662203, 4658.50539586673, 88156.8039855312, 36982.9849286861, 37270.8763732936, 51604.4672661769, 112067.588337597, 132728.104894221, 55643.3918320751, 56029.639847205, 55662.5590095013, 3935.81521401543, 35964.4279640979, 412.167282863424, 366.400150614964, 185.398085472987, 31925.8065522929, 16075.2328033676, 2315.44187691151, 3110.75348230553, 2879.81696540441, 3801.20825531493, 2399.6137324643, 2796.50674544711, 1930.80389378471, 7621.17857096456, 47568.1690686503, 50432.5379734911, 5782.58370207239, 954.96316208986, 41665.2792072056, 40155.9860679674, 2163.65241995417, 602.431608520084, 885.387831514171, 1063.60090266067, 85743.2067993828, 83411.9997690572, 38914.1648793721, 83958.8530333578, 68398.8675860248, 6658.47109656349, 515.856579229091, 149.616593585133, 11590.5993193077, 80798.7877027078, 74565.0943679983, 110512.932259418, 31461.5587619452, 31289.8742605205, 6642.42274553614, 9032.33806491232, 17338.2710627073, 32468.3393483451, 39483.3046070446, 500.024752415695, 6243.55026996823, 827.384260786539, 1427.9044591164, 7586.91289307513, 19206.9964518932, 14356.175242238, 474.848634451908, 17279.2239720536, 767.659794592033, 1454.77456326011, 6930.87177421107, 482.48079895025, 438.919118782044, 2576.21509683022, 32821.2775407264, 15334.7380774587, 1544.15672002622, 1322.62261875306, 2087.47142869769, 73160.1313106901, 18311.3563223386, 24346.5136495962, 2977.28701216933, 23854.0235396187, 7572.99616159196, 9850.14618524754, 20260.3566465425, 37301.4495783627, 13924.1820218772, 81.4693103636935, 2579.92526199693, 328.29871447654, 514.011276882571, 693.070101070364, 34.0319223991344, 17144.9270619346, 14576.5792173094, 1149.02549371943, 1619.6063582169, 311.913501026464, 2735.58234049427, 23443.649078635, 7551.35480338579, 7533.90390722933, 15215.2793956935, 19452.8358131609, 18139.0364595026, 72961.8672494751, 84157.6104392028, 16075.2328033676, 111283.70076063, 111181.854366861, 4001.95870596901, 4357.62032237333, 5734.45025673565, 109.689451817312, 2028.89682608262, 93823.9796754645, 3717.78716509019, 4063.05589236591, 5890.8677830668, 5936.66524224353, 102212.841611105, 98680.8436424537, 8362.06642257819, 6308.23964798715, 38102.3727928803, 1239.10061747058, 14790.0611965957, 41705.4564689477, 39896.750888999, 11072.9026655746, 35249.4263498954, 1231.16655235924, 15717.2812336059, 29474.670116627, 66287.9648854568, 3735.49922529484, 25460.646047685, 29257.8637578383, 19337.8582553017, 20990.2041034698, 53207.4692413207, 577.071810776637, 217.685457570606, 380.817770655907, 3044.68054319809, 36982.9849286861, 37270.8763732936, 22927.8207606824, 26023.612833877, 29059.6637210984, 66293.0141026398, 45608.2796666851, 47680.2404530115, 47987.5891853476, 63743.7672501012, 67188.5838555806, 54106.0336267498, 16700.5827129279, 16201.6090295007, 721.631049710239, 489.59426103625, 89537.7603416817, 36976.9738100325, 76146.0914023749, 35666.4058931361, 34431.4893684088, 40887.4827142004, 8648.84701994184, 15449.4490299116, 1756.5922619468, 1406.79882386257, 1878.47918078318, 9713.33379145454, 9900.36117288419, 3183.4265285059, 2367.36286511986, 2509.20062828354, 2002.06404393026, 2698.54472051032, 2542.38627512965, 200042.010308013, 197182.124547392, 67421.6507358567, 71713.2019367667, 3306.68711516553, 2338.24214080436, 3028.05339097455, 1484.65328510058, 591.620405798511, 490.027666257153, 38494.4508196036, 82891.663857933, 27122.5962742404, 26866.5755216649, 27037.5605228475, 21776.177536665, 72871.9943619608, 83390.5954741451, 24501.0869332755, 5395.29367358838, 7405.38764014415, 48.4390321367821, 521.375451964918, 429.992987061442, 246.393432282753, 380.817770655907, 56323.4799706448, 35311.7149615622, 14295.2718088607, 107678.160965251, 4001.95870596901, 4357.62032237333, 74.3657790574448, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529483, 25460.6460476849, 16797.5561905003, 16605.9005484343, 136010.875235726, 86764.2372731307, 577.693352328967, 15579.9133690415, 14261.9901670461, 4002.29458466655, 8545.21779005209, 24197.7355804902, 24315.3210072667, 24055.1231897444, 10525.7925619116, 21324.4908620963, 19566.5049107945, 28455.4110235471, 27269.4755077968, 17580.8191378037, 84675.6374381012, 11652.5256658679, 62012.8401583108, 105941.913970166, 398.206028873267, 100.68216531975, 16652.6560320721, 15475.9522961967, 16480.3466637164, 36982.9849286861, 37270.8763732936, 1167.7630320059, 1700.06076356889, 2924.72041470978, 60256.3454301609, 14491.361972311, 40768.3219463978, 55697.4155313614, 35244.3347553279, 42164.4483323206, 46163.2011388059, 63824.8084037243, 61453.8698429782, 28514.4830375177, 5055.3573778335, 2644.18497176553, 1267.87622956966, 1188.23961335125, 61328.1431781636, 767.659794592033, 1454.77456326011, 47191.0446287829, 17268.7767041599, 3999.06909749344, 5486.37129851606, 1097.30859867188, 32939.1179965398, 93823.9796754645, 85926.0349350367, 3105.1283209331, 3446.98557537899, 7469.23445983926, 7787.49016938389, 930.56598884138, 51231.6252950158, 39630.4497970534, 65703.4889701077, 57292.0570619718, 1106.88100910764, 1639.41345110031, 29696.6878719247, 27830.9299737006, 7731.78749313382, 105684.375690441, 32939.1179965398, 38914.1648793721, 85306.609714591, 5498.91260517294, 5497.89962073657, 292.844856742799, 9701.24611852389, 43297.385570285, 210803.679834486, 208436.649393301, 14048.6365824133, 12730.713380418, 2471.01779803843, 7013.94100342397, 22666.4587938621, 22784.0442206386, 61036.4454459255, 1012.56210112466, 1658.13449840418, 59027.0032913929, 61944.3941612328, 63434.0018241945, 59240.3846973969, 1138.55926028917, 28502.9484160247, 27538.760045669, 103186.902267299, 103642.340969225, 91850.7295359561, 92395.0413557302, 103183.397936366, 35865.1877187121, 30802.8569764396, 21245.6957883448, 4825.52906309139, 21315.6425605109, 18411.962513755, 1194.29653595872, 1183.17584998444, 1591.54740416144, 4111.00220864006, 45314.8425920429, 62400.0410969691, 1434.76531228677, 15611.1853530376, 130332.858430739, 40501.159149874, 22324.7519292063, 24422.1523549068, 23868.0130366245, 25126.1848485412, 2169.48833135398, 841.3868698417, 20125.4648902958, 58448.6853258981, 58820.2365002494, 2393.10740203385, 2177.66441343433, 38533.4237169129, 1348.26163508099, 1086.77552713723, 16075.2328033676, 7408.67861428948, 44776.5538467269, 44778.0605742004, 28502.9484160247, 27538.760045669, 97891.3602539888, 91501.7358921308, 111783.664042414, 111789.735168431, 141115.21839149, 398.206028873267, 100.68216531975, 29863.9922234504, 30682.4981762231, 380.817770655907, 140.959120076171, 944.573773670293, 2859.94683699838, 2059.96422853647, 29754.4711835021, 33885.6833851376, 16075.2328033676, 59595.594922586, 27106.0447625806, 102.369921957763, 1542.34645833776, 1746.13633341972, 872.327715142949, 608.318066899785, 11761.395157269, 20067.328155064, 35197.3964407018, 69017.0219778135, 6464.55631765153, 28189.7031400416, 34.9539391398454, 26.7416994084887, 153175.665720884, 2393.10740203385, 2177.66441343433, 49032.0354950965, 46300.9469224904, 31071.5955619915, 160.854671346707, 606.856326368966, 284.48116484099, 6678.62537418947, 4001.95870596901, 4357.62032237333, 29338.3421764329, 27376.3080669801, 27577.2477256152, 69683.9601780025, 42086.7574059303, 41631.4577385256, 40667.2693681699, 16075.2328033676, 16075.2328033676, 14226.0156655739, 6148.02153683992, 11186.2448703076, 18847.749696184, 9531.34077630762, 20099.4361880736, 24072.6652849166, 52019.5777076659, 24108.2869551718, 3361.48658489253, 15371.3165427829, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 5870.60027788525, 8321.64146645876, 5204.68573831189, 19337.8582553017, 200.880466402474, 14048.6365824133, 12730.713380418, 2471.01779803843, 7013.94100342397, 22666.4587938621, 22784.0442206386, 84435.5925192723, 12371.0284273401, 74792.2627381917, 77017.7438975225, 180295.715983313, 160627.623322971, 29956.0676611137, 342.923229576262, 3451.71239319415, 322.727568291058, 11937.1530995188, 196473.760448503, 195941.33746191, 5902.50027377277, 10778.7013389514, 18916.6509294119, 16075.2328033676, 25354.9979218068, 40749.7865823808, 92908.7718489514, 65391.6080757689, 45170.2096797905, 79353.7828648514, 46752.5827449409, 59685.6902045091, 4734.28074605783, 79.3103489218412, 361.111568637072, 380.817770655907, 33357.6460653597, 39259.5707868449, 22.1186361879498, 16075.2328033676, 18381.0214180526, 40580.3726499016, 55351.5375136396, 400.715738779316, 17.165419793101, 3.5065993901164, 87.5163918835083, 45799.5749772847, 26131.4823169424, 4001.95870596901, 4357.62032237333, 55644.7169613871, 982.447519791657, 16075.2328033676, 4456.94251146803, 31789.1416899254, 38914.1648793721, 16075.2328033676, 29914.6557914107, 29771.1545940383, 14477.8746934131, 63459.0467461882, 55777.3672843489, 7106.27431670089, 2097.682220922, 1142.6740382567, 985.129972726055, 16075.2328033676, 15030.9471229731, 8326.30499240953, 17895.6686843006, 217875.207060492, 201816.029722476, 248773.961023538, 149957.096355532, 4001.95870596901, 4357.62032237333, 22114.8511602726, 25842.0470909277, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 4456.94251146803, 31789.1416899254, 32334.666150259, 29307.2995291918, 3262.36150539655, 3650.28984089412, 5469.87541061336, 28376.954146616, 6242.13618540291, 85554.2975916059, 55982.0971530956, 109699.087753173, 82789.7193142299, 77029.8964821952, 44360.3485620978, 75515.2085555833, 110083.482228985, 77300.4592198542, 76062.8381008294, 7825.60622801287, 6730.67567928737, 1303.82811460993, 9807.78809560693, 2245.53547767326, 2040.63877884098, 48757.9350467699, 75181.7586486951, 41222.4220718446, 55174.7185541645, 45353.63427348, 16075.2328033676, 19337.8582553017, 1604.04546060564, 871.767144042084, 3183.81482057256, 151597.827483887, 134428.890151406, 12371.0284273401, 22230.1945586201, 2443.43089661354, 197.053078577301, 67124.3544228957, 75428.8699498112, 52925.0539860187, 6674.97302012422, 24336.5802850426, 28502.9484160247, 27538.760045669, 7284.94464057689, 22813.2525009148, 40474.8597658331, 165.105593485501, 163.148000537549, 19337.8582553017, 10199.8134264271, 10775.7313088592, 10953.2065447233, 3222.24007512687, 27043.3178229638, 29542.1949442316, 34667.0600823998, 19169.7346162735, 255.167752297303, 303.185109429245, 22813.2525009148, 40474.8597658331, 4665.78284393737, 5986.59302625692, 981.909202101254, 45.5777284527176, 160155.458335638, 163708.757489251, 187193.559544438, 9460.5871844831, 175965.519205514, 162145.476447623, 187812.139171536, 178507.108361739, 179297.659312574, 163589.840995929, 162007.672322303, 121296.669340634, 37757.9099011842, 13826.2058999632, 1600.87994812987, 12075.2404390597, 12166.5198843529, 127122.117675558, 131473.39514338, 11533.9655605889, 11552.5453378092, 22222.2480729635, 22349.0704467841, 1379.54025691323, 42818.1776431504, 29956.0676611137, 100527.882254971, 34452.3687602634, 428.194296702893, 327.67556996714, 75181.7586486951, 28022.2047611337, 1489.32643121507, 674.780234884749, 865.69410410813, 106907.294051327, 102765.32624503, 695.169633237237, 4186.07375250122, 1031.50851033971, 2391.17130610275, 2524.68126919999, 2310.44702386552, 215404.176501852, 214364.343314876, 182418.963480474, 103125.026628129, 110354.451148466, 14078.7204502843, 33371.5839338285, 51440.4185918208, 51549.971129584, 21751.110717181, 165.105593485501, 163.148000537549, 549.063997098806, 652.751602666035, 15505.8846119819, 13839.6628340057, 6308.23964798715, 6754.68935613241, 6908.82616123102, 16047.9197541244, 72080.2473241545, 3458.38954358547, 63081.0675542151, 1397.22812791188, 132.977985957547, 155.61043086903, 2329.22247578325, 121.94778797986, 65065.7497861239, 19337.8582553017, 77747.6507958368, 36982.9849286861, 37270.8763732936, 30718.554166055, 14257.4896437838, 34182.801311283, 93823.9796754645, 107020.984285254, 114099.617569792, 4836.23457870921, 36982.9849286861, 37270.8763732936, 127612.717122292, 126997.409826117, 126817.648893419, 126076.654734498, 126023.119406516, 35533.0723313702, 140606.054060676, 162639.947933799, 786.741911927342, 448.316652566323, 967.193216669715, 31641.3758750713, 57714.4150481256, 49302.9831399897, 5718.08509573745, 7073.15565008136, 7700.93801540459, 5727.26473072548, 49101.2259334692, 27553.3069860754, 5968.14790285678, 9041.34835880296, 10384.5925393218, 5713.51127605281, 3795.39947287935, 2923.81981536814, 153175.665720884, 173184.239935311, 172105.667496322, 6549.86364599525, 89.9569446043147, 1789.69399346924, 54984.0972027676, 60064.4843389535, 2280.9016320397, 16075.2328033676, 2267.69288065616, 37646.0059753403, 109771.096936945, 94632.3251107127, 26801.8809487613, 7586.91289307513, 86165.4982332778, 28304.8430691959, 571.323642221752, 27899.4502191455, 14294.2146003695, 64875.5759169255, 571.393685116687, 371.519807404406, 3045.1874979749, 69052.3060672601, 42750.5595122885, 17940.4754477086, 74468.5859618555, 36982.9849286861, 37270.8763732936, 237718.086614605, 1768.91135350572, 2271.62996430812, 185.141472700146, 121854.159956137, 113433.26097399, 112447.814004036, 116147.160425967, 444.389735129833, 284256.072534431, 54162.1723971563, 2951.67083923163, 26015.1132174876, 1651.2658384956, 2014.18638945188, 1764.57981874865, 3388.78554612204, 86216.7075639565, 69002.394551861, 86376.4734924137, 86082.7484262838, 750.36157773707, 382.843375717278, 11040.622797104, 17940.9337801435, 15047.5929340044, 14972.3866655308, 15866.0833627036, 17020.8347093242, 2000.88564435376, 16075.2328033676, 5799.02340376621, 13903.0232465271, 12383.2935704735, 50787.6872196954, 68449.2944846138, 77869.2151173542, 63571.5935003966, 55150.6945182499, 1374.91407938692, 1029.10560304347, 1463.05182881735, 9813.34069107378, 7965.82550533568, 1864.15501149668, 23547.8803159998, 51099.3673939962, 2144.17084741748, 816.069385905204, 804.836560548988, 5547.27224125166, 55488.32369291, 55776.2151375175, 63571.5935003966, 55150.6945182499, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 34646.7294040442, 939.647131209686, 765.476897764711, 20662.1689643283, 38914.1648793721, 3361.59974933275, 14896.1998193159, 237641.743476496, 237041.827077364, 236638.760118322, 402725.279918057, 237689.544834823, 238714.437537325, 39097.0304197939, 12564.1520898753, 312.486281619704, 245986.819406863, 22058.727444078, 51162.5777636665, 153420.563503669, 15444.9962185795, 99428.3478861311, 380.817770655907, 158238.598746871, 145862.197078688, 140642.486353713, 146167.71066205, 132981.623098472, 113313.53043813, 96520.9582989015, 65428.4626662336, 20406.1175556831, 41030.0351700222, 20521.7910232821, 11306.9465468384, 22760.5494708587, 18281.7903486614, 14078.7204502843, 811.956421540247, 21594.8765408694, 91206.3946199314, 16075.2328033676, 3189.97837550241, 25409.6463701444, 80053.2745696482, 34075.7071961636, 354.626752800892, 260257.619568898, 56608.8373607729, 157915.644061441, 5271.15650797377, 2470.32039326544, 1089.70675746206, 28502.9484160247, 27538.760045669, 93666.5223766577, 86314.1600084239, 85968.3159500624, 95258.1117338167, 30173.4319885217, 32480.5599043837, 32967.0096632093, 33505.0256562153, 31599.1031178943, 12535.0895548505, 51604.4672661769, 112067.588337597, 132728.104894221, 767.659794592033, 1454.77456326011, 28502.9484160247, 27538.760045669, 38904.3225708523, 55643.3918320751, 56029.639847205, 55662.5590095013, 37589.9142279959, 36213.2426814295, 37418.2297265712, 7505.60147661139, 316.577132124849, 1749.30945917116, 6674.97302012422, 24336.5802850426, 44359.7426141151, 153175.665720884, 4950.14602731271, 28574.050800645, 9459.55834462236, 9090.63054171216, 26770.6162779481, 26375.6751692039, 2150.05803676888, 783.959518459601, 1363.46302791599, 391.531497495759, 85812.1435012143, 38914.1648793721, 19337.8582553017, 36982.9849286861, 37270.8763732936, 380.817770655907, 6104.67685918386, 174059.785997407, 40081.6926138439, 38747.1460703486, 19418.9364756751, 19623.2972451728, 12948.340426858, 4983.84272639815, 182141.630314484, 23320.6903328671, 927.167926762553, 997.422556011751, 85090.0875948308, 18368.7199589683, 18235.5772292046, 9.70458186685573, 1734.2361706626, 42382.9218176956, 29664.017087839, 16615.520135611, 3197.05867273829, 67.4924095059996, 16075.2328033676, 7151.10047696127, 24918.0917096275, 15002.4315582681, 8114.36010684162, 48681.7906878179, 40862.3662673996, 39232.5909670738, 42864.3003891846, 42053.9423083543, 16075.2328033676, 92661.6240260131, 91435.9010594142, 5498.91260517294, 5497.89962073657, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 207046.741609647, 145499.216931835, 114000.630861976, 78747.2746131727, 16075.2328033676, 7363.44586590269, 353579.170798413, 270228.923158017, 374402.51519037, 353590.251659219, 289290.045024645, 301615.902487921, 85306.609714591, 4358.55312385092, 4038.40079129511, 93823.9796754645, 18802.5691575438, 20873.9442095526, 125148.270887331, 33033.9962026151, 5179.97508930656, 36982.9849286861, 37270.8763732936, 986.291590611856, 1070.25473454735, 100145.720931038, 91724.8219488918, 93211.2041142908, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 11624.8096425303, 38846.4546213561, 38315.4215221523, 37805.9812847883, 37996.0908890085, 19337.8582553017, 19388.5964389188, 30842.199362939, 20481.2602846657, 20215.5910364275, 26363.4402407418, 1397.22812791188, 5715.33151020784, 5881.00435243796, 6060.60023748355, 380.817770655907, 60256.3454301609, 1374.91407938692, 33183.3028208969, 25206.3169183078, 25909.2362865725, 175.136282586812, 47.7456844018575, 15266.03384063, 2731.27900493364, 2538.26410936149, 16075.2328033676, 194110.429400107, 108078.506109435, 129921.582470381, 89.2509179394983, 130133.221897819, 1023.3122550351, 56013.8606088662, 16075.2328033676, 93823.9796754645, 3350.83083638193, 3209.68774077068, 44667.5501677092, 11432.8391805373, 13247.7211411058, 31717.8955498694, 22008.3871916686, 515.856579229091, 149.616593585133, 380.817770655907, 3605.36485247208, 111603.892498398, 3443.5180504849, 3399.30416488461, 2243.66440113962, 3281.96123955538, 2777.80761127985, 3371.05171022943, 3256.87346957031, 380.817770655907, 2926.75909982747, 4936.85306638324, 1231.16655235924, 25650.2483405101, 29096.0513736429, 59.8330451261059, 52298.3326772964, 33095.9540592393, 76871.8796643619, 60345.4760809796, 147576.925573423, 55161.358203825, 36982.9849286861, 37270.8763732936, 10927.1803962292, 10571.9007598777, 4137.76151723993, 48172.8677574382, 38954.5708563562, 40809.798588667, 132.977985957547, 155.61043086903, 8973.88256857868, 4410.00906559181, 1857.41453093684, 14530.1246200534, 15098.9242273929, 145336.862979384, 7650.21302182265, 85052.041965137, 154024.072196321, 57534.8781919545, 3514.87081782576, 2339.89911747417, 8915.80592070546, 36024.2040865994, 1432.23041509814, 6656.73766323875, 132232.046062137, 109274.750803224, 36982.9849286861, 37270.8763732936, 42458.5005302341, 13054.7977621466, 7595.50771377897, 55219.6065374343, 53203.402316355, 60393.823114587, 6938.89083971031, 25186.9197783092, 23002.6566517233, 29645.7304655368, 33845.3365111011, 23193.3161319822, 152680.651875987, 541.407831196675, 1066.08742571835, 47125.7363399674, 12351.367235247, 106731.264207725, 253606.39434748, 255776.683760074, 1910.60956251177, 1630.61621715303, 16075.2328033676, 28455.4110235471, 27269.4755077968, 2775.35150362275, 7160.39172255059, 1540.26580709825, 2894.62766262561, 217875.207060492, 201816.029722476, 248773.961023538, 149957.096355532, 4001.95870596901, 4357.62032237333, 3936.21208893207, 9267.16329561688, 14356.175242238, 33956.5718612826, 51618.179126201, 68634.5924621894, 60213.6934800427, 124976.835139984, 19337.8582553017, 28502.9484160247, 27538.760045669, 76873.774227323, 30056.6840999384, 28712.3315605054, 36451.6530741599, 1439.3077690584, 16075.2328033676, 1790.590901636, 21789.739165832, 21867.3727001188, 132.977985957547, 155.61043086903, 1788.77444134187, 20125.4648902958, 58448.6853258981, 58820.2365002494, 16075.2328033676, 4735.32182628255, 17616.1312805137, 642.032128428266, 423.298460066737, 36982.9849286861, 37270.8763732936, 12772.8656556788, 129509.980504927, 130477.592828008, 56520.9154807501, 1078.62984126406, 36982.9849286861, 37270.8763732936, 13541.6816299208, 248411.4147893, 20434.5628597524, 16004.8069787501, 15795.7054156127, 13439.6436807757, 44367.3091257921, 253289.095117054, 45373.0745862078, 44803.6229657914, 44465.7593702634, 44944.5010431745, 9179.4351480092, 36982.9849286861, 37270.8763732936, 86116.1635789504, 88661.3391039315, 86502.4115940803, 85981.4873061281, 86404.0550235579, 86135.3307563767, 86518.39220485, 28584.545558594, 961.861785584727, 5322.09818027272, 17.165419793101, 3.5065993901164, 4944.85729745833, 21306.2915912201, 26198.7764544366, 20935.6885452686, 11370.7101112596, 19676.6431090546, 34806.7113946924, 68626.3369318041, 6073.87127164214, 27799.0180940323, 53606.3301405669, 21207.9320627651, 180034.73659262, 1553.23968277205, 1586.00568590166, 2625.62648152534, 3554.11735195358, 8258.89557955904, 8269.24208333249, 132426.492744095, 124005.593761948, 127864.791659647, 126719.493213925, 126719.493213925, 175.136282586812, 47.7456844018575, 313637.633232719, 180493.006821904, 211342.362891674, 132409.829025542, 112741.736365199, 391.531497495759, 32182.5836067529, 198180.164800165, 185170.828347064, 1141.04937535152, 994.730931573155, 5191.79633859947, 6076.01117592034, 38914.1648793721, 1687.96676578642, 1673.119641223, 65065.7497861239, 36982.9849286861, 37270.8763732936, 76695.5697286669, 55683.8047195843, 34667.3615668828, 128050.250723273, 178341.459511325, 185420.092795864, 1768.91135350572, 2271.62996430812, 13388.4587470159, 18467.5103593543, 28502.9484160247, 27538.760045669, 3735.49922529484, 25460.646047685, 44529.3042324108, 61010.2182582, 61130.908100149, 8919.99584851613, 30044.8392084153, 16075.2328033676, 21.6446245680635, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 526.632663642601, 643.40692923458, 618.212537109644, 543.022774864386, 220192.874320162, 204133.696982147, 251091.628283208, 152274.763615202, 6206.78361507429, 5637.69785234136, 121.401530999426, 285.350551274648, 283291.34628339, 106732.305688204, 91593.5338619723, 23763.0897000209, 75482.5204691513, 81910.7535491703, 71871.2920881413, 79281.9106612046, 68225.7694764766, 42704.0836273836, 306.162640283749, 1477.02637923588, 1278.742372013, 34155.2596621011, 1142.6740382567, 985.129972726055, 1343.17433566773, 2083.73395010837, 50129.3931508622, 160.854671346707, 606.856326368966, 58999.9631732753, 242.576734886539, 38914.1648793721, 38914.1648793721, 92154.3115693357, 108376.741422313, 4001.95870596901, 4357.62032237333, 4682.92313661785, 4721.49204904057, 8318.04851332447, 19588.0880062288, 8664.7428697008, 8875.27521098947, 9414.09472900916, 10006.0911370741, 4838.39080134605, 6530.63022512928, 8103.76892028819, 8496.64479452246, 29956.0676611137, 754.482933113425, 780.650058341217, 645.413303193101, 19642.5955036666, 12036.0549515629, 88007.8752290074, 79761.4778124405, 38914.1648793721, 16075.2328033676, 222737.361087851, 222267.055249404, 222873.002471789, 222530.364790711, 222558.674297495, 1622.43797332495, 3262.36150539655, 3650.28984089412, 5469.87541061336, 9179.4351480092, 398.206028873267, 100.68216531975, 1112.88121313281, 924.03658373717, 1015.4605186786, 264.991877603165, 9179.4351480092, 64586.0171836882, 21507.6116541601, 24468.3778787391, 24311.2721230253, 40322.4129084761, 47846.7220495479, 42554.6462239284, 40767.0536877281, 4727.00186340972, 16075.2328033676, 1880.44979111957, 2472.08879846393, 219.83812202564, 269.021031901013, 2003.48047965517, 8175.52734900791, 3166.93525322903, 143284.608823161, 6085.71980236485, 9603.36024052615, 93672.993420037, 193040.071609707, 96325.9132030291, 19337.8582553017, 3035.06468178445, 4001.95870596901, 4357.62032237333, 32939.1179965398, 395109.101799491, 2253.30656558634, 1707.96822458814, 64373.9349728853, 44705.842312543, 34761.5002263271, 27913.6536058529, 24956.6284794536, 24583.9253614491, 26757.1198762648, 38918.2553931742, 2590.00133174049, 2882.26724074116, 1479.71533859005, 7553.70716847842, 66623.3263215092, 67009.5743366391, 66911.2177661167, 66642.4934989355, 11519.2500501165, 6013.21589017719, 13938.6226149515, 31619.7710007259, 7382.68277789456, 205.948417057369, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529483, 25460.6460476849, 93823.9796754645, 16075.2328033676, 34283.2407298421, 4001.95870596901, 4357.62032237333, 20813.3613722516, 58231.1857382934, 14201.4520089998, 36982.9849286861, 37270.8763732936, 5023.86029939158, 10745.8603869891, 60904.5279144097, 8109.84854410532, 17868.8312706166, 17793.3633204379, 100614.373081477, 60369.8340051132, 9179.4351480092, 566.892450637157, 4261.88485132959, 3856.17819309665, 195.323738534107, 19599.5049812013, 85.4967846997154, 133.514141831658, 228066.379305845, 212007.20196783, 258965.133268892, 35585.5422362702, 36465.0577585853, 160148.268600886, 29190.3213594899, 20812.8930670588, 37448.7667123955, 99350.2687669007, 939.647131209686, 765.476897764711, 6291.01145054712, 859.238900421303, 84548.6670720023, 83455.0735167547, 60736.6437838198, 16075.2328033676, 5042.16871409172, 33692.5443487568, 51354.1516136752, 1307.4485207458, 1258.84644838854, 47390.3227154491, 47428.0499043894, 97945.0816959396, 3198.20199161574, 3951.35973793132, 10228.8926167711, 489.632605819653, 138.5791686779, 422499.825372588, 60256.3454301609, 39298.637316672, 56960.2445815904, 67474.5484475525, 63571.5935003966, 55150.6945182499, 74468.5859618556, 7106.27431670089, 2097.682220922, 70831.2915872307, 51163.1989268884, 1222.13360700813, 534.929670399472, 36982.9849286861, 37270.8763732936, 12487.3443239224, 2788.98290688768, 11465.5064898282, 19771.4394876232, 34901.507773261, 68721.1333103727, 6168.66765021074, 10.044201413172, 219622.00763682, 75510.0593774626, 8318.83829488295, 6379.13180186254, 38782.5409066438, 380.817770655907, 16075.2328033676, 381.637887102752, 477.603586253649, 39914.567532152, 14033.5912750953, 43123.2836337418, 18423.4855945522, 14491.361972311, 40768.3219463978, 352.942099977819, 120.942485019968, 146574.766712355, 128175.541878556, 31509.8567680531, 147000.677694204, 132394.752952555, 149032.24569904, 658.254210804327, 32939.1179965398, 3881.39831861647, 3817.69402491835, 26332.212969649, 19731.8080895389, 53693.5293901167, 52854.9747970431, 53199.3246051298, 52312.3347172832, 2166.16492250022, 2512.56121882425, 92661.6240260131, 91435.9010594142, 11810.3085316802, 162840.270765828, 27043.3178229638, 29542.1949442316, 4456.94251146803, 31789.1416899254, 778.408037894007, 22184.4067936007, 27954.93493759, 26584.4682526731, 28502.9484160247, 27538.760045669, 172041.215109481, 227127.470157848, 275067.801992136, 267848.553235021, 271727.140971574, 257591.280129218, 258475.155625497, 236306.798365662, 335924.29357712, 255569.321766888, 247170.444391399, 382584.183409234, 278149.179356949, 93823.9796754645, 5053.3108516892, 2449.46742349704, 28777.7541278035, 18398.7214603231, 36157.8702479186, 37697.3125001049, 36104.5985162888, 913.133664778742, 525.20954422219, 16075.2328033676, 24536.7609772881, 24931.0014053183, 24632.7661466552, 3320.18319770292, 7149.14231982712, 234345.143235607, 244386.42748719, 230139.763794283, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 55.8837027444483, 2592.31169468748, 3782.59883813101, 3734.12031219838, 112685.460826708, 2599.5540549556, 755.229104122553, 1046.63131618823, 658.254210804327, 1241.50970474322, 1825.79863551985, 121.620466588186, 5.78559118236115, 45567.4855396035, 19034.6072096849, 11262.8136356408, 4620.43191662203, 4658.50539586673, 17969.4019224986, 11100.3395968724, 12503.9161089836, 28868.7774944191, 28788.1403646274, 2698.69121284299, 56851.9552990755, 64445.09418865, 48681.9693659605, 14681.6820434038, 37630.5797532599, 40172.4057084334, 76966.6546322349, 2914.66482374556, 877.138717320542, 812.486590138845, 33322.0516074722, 50983.6588723906, 21028.6342956425, 19659.0690929773, 20111.8253101348, 19076.6280580905, 93823.9796754645, 1682.79562704932, 6493.96147313932, 380.817770655907, 64322.716776962, 76268.1530004576, 2894.62766262561, 673.529729328414, 750.451299329575, 80383.8355760701, 83978.576579043, 74230.6641633267, 54474.1715658941, 4832.75450638188, 4869.58697886867, 5424.16682742057, 6017.46317538071, 3483.52717200964, 27683.7202080324, 32974.8883387398, 2920.06447071514, 321.034053936711, 1008.1002157603, 1231.16655235924, 28584.545558594, 104160.939539591, 102678.646139363, 85306.609714591, 28749.4525019081, 29653.7800048227, 28047.9809374163, 17305.6483936032, 16075.2328033676, 30966.2999572503, 1216.57008312001, 5182.87596202077, 1815.88290388764, 1112.3086835979, 2894.62766262561, 391.531497495759, 4456.94251146803, 31789.1416899254, 255.167752297303, 303.185109429245, 5049.56192194985, 16075.2328033676, 394849.296374361, 397739.357986858, 406939.950822953, 396528.442687015, 399359.975905446, 395375.072030287, 394087.471462756, 29956.0676611137, 15485.7256991285, 46190.8328888935, 207.140771853515, 174.018472194646, 29956.0676611137, 21929.5313749717, 66450.383145318, 18229.5014058069, 11370.7101112596, 19676.6431090546, 34806.7113946924, 68626.3369318041, 6073.87127164214, 27799.0180940323, 7023.28264846086, 7317.70468665739, 8344.41794414367, 24250.9221492419, 3509.61610499153, 16075.2328033676, 965.273191014025, 8767.58717670904, 917.276039395541, 36982.9849286861, 37270.8763732936, 40944.3595149592, 40741.4045623277, 13112.2207130685, 55.8837027444483, 76695.5697286669, 55683.8047195843, 34667.3615668828, 128050.250723273, 833.533564263863, 44359.7426141151, 255.167752297303, 303.185109429245, 587.827601893559, 12550.4790912234, 9328.23617631828, 121.620466588186, 5.78559118236115, 46233.6635944985, 18244.2412762885, 50522.8411679685, 51117.422962275, 50152.1588348742, 47000.7829058251, 22102.5791367005, 28177.9168936611, 19816.1559831272, 23060.3873308559, 1268.45518078287, 70856.6671435548, 17659.6794562927, 17957.7984267472, 41350.1759834271, 37350.9987069057, 28104.6344971341, 163264.371825029, 11019.6516218576, 11778.0057784129, 8787.29138730481, 75437.7166391433, 34813.3518860377, 16315.5470565223, 149681.714006102, 5828.96804915238, 63571.5935003966, 55150.6945182499, 195435.663834861, 91829.89087749, 53909.823051173, 62853.7747765658, 68936.7006679633, 33883.6897564309, 7.21956416900866E-02, 86.7113720302211, 10592.5020026709, 5583.90990689204, 22813.232782196, 119298.264549623, 120227.676393726, 42818.1981192254, 43204.4461343553, 42683.5218464031, 43106.0895638329, 42837.3652966517, 28305.4843182508, 55885.3673155701, 28338.4165313062, 9470.12435548913, 11791.3881478324, 4278.19593759872, 1638.53718781816, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 398.206028873267, 100.68216531975, 52619.768044711, 3011.53987076423, 3879.9035788791, 1231.16655235924, 9179.4351480092, 1369.75719614958, 24570.6016449511, 16903.1428224563, 36953.9591885763, 37340.2072037062, 2574.08931781333, 854.935635892897, 385.386809890281, 583.737029424752, 58784.8981500592, 52827.885221665, 51457.4185367481, 52400.846438739, 50493.2301663924, 1149.02549371943, 1619.6063582169, 311.913501026464, 86376.8034278145, 155988.321506876, 77955.9044456678, 77504.9431343501, 666.915014712587, 13962.1088439381, 16075.2328033676, 9784.48996603282, 10402.3133039516, 24.2778010364449, 53.3355748057624, 1856.15162274216, 55568.0672302387, 57515.476030983, 89988.1933233015, 14703.4419646761, 186591.872519133, 187475.748015411, 184569.914156802, 9732.94036202506, 11394.5415022225, 1040.45842464279, 2245.53547767326, 2040.63877884098, 190248.534189444, 183269.140770135, 55643.3918320751, 56029.639847205, 55662.5590095013, 344788.840298742, 209972.69662788, 267717.733911457, 260648.987889108, 256464.341108696, 254443.903034606, 8258.89557955904, 8269.24208333249, 78362.7746676968, 79523.8484393243, 38914.1648793721, 35283.9783490881, 11649.6267579945, 11467.0222721474, 12783.8198311126, 219.83812202564, 269.021031901013, 398.206028873267, 100.68216531975, 7389.37527689108, 828.828413642999, 22474.3862420699, 25241.3365842963, 398.206028873267, 100.68216531975, 6674.97302012422, 24336.5802850426, 22813.2525009148, 40474.8597658331, 29956.0676611137, 345984.088190757, 274536.801567495, 273271.593904338, 24201.8097681174, 24796.6502448883, 21980.4188298646, 25823.5338323706, 22951.1057737444, 7343.34594109841, 7906.39140103584, 5805.39549625421, 4587.35571568058, 6919.49152023813, 6214.81465574903, 5443.26801211491, 1800.74162517009, 5392.66328633371, 1101.61776395545, 217.618004090373, 9739.7023937882, 30363.6200081273, 31686.6420194913, 49348.2492844096, 36982.9849286861, 2926.75909982747, 4936.85306638324, 340808.23573509, 348460.738872757, 8556.71360291658, 37403.5643040392, 9816.04373995832, 9701.63192148939, 19337.8582553017, 20199.8704348116, 4715.54619751394, 477.099810914381, 1108.52591653732, 1864.15501149668, 4001.95870596901, 4357.62032237333, 55643.3918320751, 56029.639847205, 55662.5590095013, 2894.62766262561, 39366.6006472387, 39030.5245603231, 39465.0265357583, 1296.89338122162, 2646.25341391727, 22813.2525009148, 40474.8597658331, 38734.7314672668, 112979.148414213, 111098.21779988, 112440.023082916, 36982.9849286861, 37270.8763732936, 63571.5935003966, 55150.6945182499, 52925.0539860187, 28502.9484160247, 27538.760045669, 49855.8575124448, 46417.3529746342, 16075.2328033676, 22813.2525009148, 40474.8597658331, 398.206028873267, 100.68216531975, 28250.559494834, 45912.1667597524, 66921.4725719869, 380.817770655907, 6674.97302012422, 24336.5802850426, 398.206028873267, 100.68216531975, 208482.355542094, 1569.49479857533, 1361.76790665147, 9216.66036504576, 1699.49664830758, 2452.65439462315, 37672.6682787865, 37500.9837773617, 667.663331675873, 566.070592134515, 2926.75909982747, 4936.85306638324, 1109.78136867705, 1346.93091072386, 4001.95870596901, 4357.62032237333, 31421.3271741667, 66775.5697957508, 695.492487178245, 378.923469385992, 1261.03329977177, 1871.26483497435, 168208.840573889, 147190.164177003, 148212.477244877, 2.77197958308759, 65049.7980485938, 60643.5614152793, 1146.95686244562, 1027.62874960833, 21058.5049226077, 38720.112187526, 17844.1949222681, 11362.8884864227, 16075.2328033676, 3728.49898930883, 4040.8154131577, 598.684104781358, 4568.56180562098, 10658.186409797, 99294.3753778483, 36101.5089941429, 10769.6990055979, 11428.2248542619, 69164.9467950069, 63561.5418070576, 4877.02215745897, 7352.94891695184, 14888.2730414435, 118862.909783924, 16075.2328033676, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 133178.680101674, 9588.70933842728, 4590.09742123281, 6841.27849452046, 206.652717893827, 176.268750462866, 54542.082789426, 54398.5939402253, 32201.3395607681, 35049.0520413232, 36684.130675501, 44558.6654423786, 16075.2328033676, 53606.3301405669, 21207.9320627651, 405.328898947508, 387.967268850007, 54000.4766432571, 54626.2721398822, 43175.0360197756, 1701.44967567367, 3744.23520012648, 7389.37527689108, 1596.14063143149, 1515.41634919425, 26743.6343500265, 14180.0301918805, 8414.61158604033, 17862.2836353767, 21496.6588411569, 7366.96007160114, 2323.52183319664, 18693.1443719325, 19260.0041587353, 2592.31169468748, 1429.81243656035, 2422.86036135067, 4456.94251146803, 31789.1416899254, 66777.0334209715, 29703.0162221485, 73202.0080425986, 73354.735276853, 51604.4672661769, 112067.588337597, 132728.104894221, 93041.1585261191, 6249.4968791526, 7002.81408603478, 54033.5208481893, 108303.987224926, 51727.0102214552, 6336.68807027647, 22697.9237947665, 26979.0143932284, 17017.3657687925, 5469.57680096826, 2682.43267394284, 16075.2328033676, 1914.98509356044, 173309.995851428, 206731.947356684, 228171.715834861, 180155.881565147, 176137.980981984, 34424.8215026981, 1258.46894676095, 46561.8655831464, 33028.340898677, 34752.2482792108, 46704.1364511364, 6674.97302012422, 24336.5802850426, 175.136282586812, 47.7456844018575, 1889.73231564398, 1887.05725264491, 3856.82284967842, 2022.37861662165, 48.8008458005068, 3258.55378322125, 120.061180462997, 248.666375320496, 398.206028873267, 100.68216531975, 9647.73302442208, 5134.07365950494, 380.817770655907, 28.5425439295029, 737.564022643526, 66623.3263215092, 67009.5743366391, 66911.2177661167, 66642.4934989355, 139144.099412222, 74115.4986284292, 73832.8171552837, 72138.2879264049, 51231.6252950158, 134493.841001508, 575.062541564361, 656.637906226134, 36982.9849286861, 37270.8763732936, 1122.35194789941, 48638.3915862555, 43353.6199714526, 43353.6199714526, 50129.3931508622, 12212.5829657212, 39443.2309234521, 16075.2328033676, 4025.82836189212, 16075.2328033676, 230.986746945598, 306.710043249217, 180632.088536749, 187710.721821287, 82203.4072004822, 67765.5807934495, 7451.20240718813, 11957.2639455322, 9032.33806491232, 17338.2710627073, 47450.2260517822, 15885.3539141143, 14356.175242238, 35291.156336999, 40443.5878459114, 42379.0965161929, 331.709599748123, 266.501023246508, 16075.2328033676, 51231.6252950158, 21597.1666433138, 19062.6188399072, 17592.0839815116, 36322.1899886525, 33318.9685043034, 33354.901989568, 17693.1389198865, 33353.4703985898, 12521.8580472133, 16350.3750314969, 18489.9812550801, 22912.2756210404, 17957.973492695, 23930.694034883, 17917.7687202917, 17535.3613970891, 4067.10598615302, 20893.3782784195, 20146.2238324897, 111908.684165063, 23806.9382872299, 377.56336333992, 1285.31327567751, 761.544296907184, 18677.7826207096, 39095.2660576285, 39309.3051594117, 885.387831514171, 1063.60090266067, 998.08081814435, 5805.98004756777, 3778.09171613081, 11368.0286559487, 19673.9616537436, 34804.0299393815, 68623.6554764932, 6071.18981633121, 27796.3366387213, 4289.92453754715, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 32866.8380415882, 36019.6439698062, 55643.3918320751, 56029.639847205, 55662.5590095013, 398.206028873267, 100.68216531975, 40531.9929885463, 35247.2213737433, 93001.6706827544, 94990.7618824203, 46789.3656114048, 107290.008900231, 12843.7724376984, 8326.83819607156, 28462.8612611565, 1890.09214554432, 455.618156809297, 1618.41327836119, 47285.4003172667, 110250.897255532, 116.113033013679, 56.4271046072093, 125148.270887331, 33033.9962026151, 43154.5115668641, 44175.7702868118, 43966.3335840679, 43099.7178766837, 102781.731720258, 31378.6127368576, 60482.4630564461, 1441.69291647705, 863.07309034689, 121.620466588186, 5.78559118236115, 59522.661011926, 51867.2783438224, 47060.5720158928, 225961.991551931, 227419.759715817, 229404.536004959, 41643.7580026758, 48941.2505641695, 74487.5755705622, 66066.6765884155, 115659.412540411, 13517.3527385998, 160778.182886648, 64875.5759169255, 41358.6142768877, 4114.72465597041, 6042.36668800969, 16075.2328033676, 380.817770655907, 14880.572903076, 29742.845776986, 17576.67834925, 74645.2595410128, 75326.1962559088, 75152.5737724433, 72691.3638350053, 34877.7235812743, 70450.9861564092, 16075.2328033676, 2291.89022269666, 1321.66526632052, 2043.23707979238, 1147.49503287554, 5301.9145293197, 15313.9288206433, 4729.06371968226, 248181.471446732, 264354.693445976, 13816.6120863513, 386393.385319582, 386908.149191093, 388304.156231306, 47450.2260517822, 15885.3539141143, 15602.6245183996, 16943.1467601851, 19823.0615988287, 669.748016552578, 6395.71960814362, 1050.85698907495, 34035.4243477195, 51697.0316126379, 2926.75909982747, 4936.85306638324, 25761.725109652, 25549.525147713, 25261.4491134883, 21442.8583355827, 10646.1396382676, 15522.3407034462, 23660.2902939067, 12064.7488366817, 30057.0076773555, 16075.2328033676, 59383.2623424327, 15792.1714253495, 939.647131209686, 765.476897764711, 120462.06986938, 114201.184644391, 112041.170887233, 111055.723917279, 38914.1648793721, 3777.14098988989, 54874.7200032305, 52609.0485117831, 51231.6252950158, 1093.54686539122, 1100.89413649991, 380.817770655907, 5029.51951983221, 4108.39978148098, 765.224730234081, 117.357759743728, 39368.0039228355, 10519.5194158867, 28498.1520801969, 12586.839400986, 9604.86302249818, 22822.0707881137, 51231.6252950158, 4082.30110938032, 53926.8204759382, 36982.9849286861, 37270.8763732936, 667.663331675873, 566.070592134515, 905.335298457411, 1063.83655389085, 58182.144130875, 37211.9252857887, 42193.329437704, 16075.2328033676, 130.189402367952, 36982.9849286861, 37270.8763732936, 56388.4552588762, 48733.0725907727, 48830.7513153565, 66492.3585802749, 102677.844494626, 30378.117636108, 30810.8963501437, 2135.40019886403, 960.428498512439, 1231.16655235924, 198342.172264288, 807.671102216867, 93823.9796754645, 3890.61769276069, 764.82895950078, 545.162816026653, 4382.37876294522, 1495.39165945304, 4030.05177210254, 2517.51426456451, 1495.39165945304, 5669.47813797244, 15835.1545616259, 2936.58148814138, 36789.9794518149, 7514.40913127497, 75335.1909831347, 60256.3454301609, 16075.2328033676, 38914.1648793721, 3198.20199161574, 3951.35973793132, 773.770507737793, 25761.9907975625, 18406.0142121727, 41847.8552661629, 58728.546487527, 205.948417057369, 108646.206907229, 26486.8501316919, 31353.0905519216, 34999.7623329259, 33753.2294143291, 292.516770149545, 206.696685041859, 380.817770655907, 46635.9234111151, 12266.2005184976, 13115.8278087424, 62838.4408009529, 140010.674551688, 58361.0045073478, 59723.8813559073, 59084.6328948789, 58830.9644883944, 124822.263666451, 124180.468466125, 125126.536639585, 6039.49663086529, 7321.91353593308, 26719.2343145144, 134.235444152803, 75.3575989596895, 16824.6315276429, 16756.6945155294, 55819.3113245708, 16859.8644956567, 17496.7639549616, 11014.9242129623, 21397.326467905, 10647.2067871047, 205985.317929187, 83364.3262743152, 281327.340620044, 193313.201810195, 232211.756994791, 230660.121782087, 234930.942138222, 14769.4724529928, 8223.61511468137, 21543.1125792705, 89518.7785095298, 380.817770655907, 218610.958090684, 183039.06843131, 195749.486227214, 198942.865430342, 28302.2040977211, 62650.6303903387, 88723.669563393, 80312.2376552571, 16968.9295714009, 1934.06068962367, 736.791696610977, 38914.1648793721, 49132.9777263849, 58811.9841443461, 62302.7141263766, 57972.1896521017, 51895.9151659774, 51704.1854894142, 16075.2328033676, 41432.1632202872, 42397.2018930015, 41996.6980579753, 398.206028873267, 100.68216531975, 16075.2328033676, 56.6741615112974, 2.77197958308759, 35467.7195138069, 667.663331675873, 566.070592134515, 27419.3507289026, 24851.0028842774, 16562.5015385432, 17321.0487098954, 163393.454929918, 18090.2165205772, 26128.4667348823, 5701.67185703183, 6219.35774650809, 436.923440134407, 374.276076154794, 1004.36651416554, 12379.7961892953, 6209.75846218885, 321720.125427909, 89185.276681541, 266061.654003304, 281735.927763082, 19557.2643353024, 260815.503495853, 284722.534682537, 308418.379475037, 19576.2755850075, 240380.103487538, 17144.9270619346, 14576.5792173094, 41245.4781277217, 50840.8708742633, 51140.8480800627, 80783.0822683061, 83360.0303452718, 226.097293890297, 16.5326326875381, 98704.428015567, 111457.100752975, 160626.533040373, 43759.9763311994, 46779.1401986401, 21771.176148186, 26396.0304022721, 2839.64146329735, 85306.609714591, 11996.496299241, 27304.2241644215, 177241.268891736, 209676.378820837, 207309.348379652, 110754.271413177, 4161.50899294993, 731.362216976442, 7732.07250429969, 20023.5484067143, 31775.5571309637, 121.620466588186, 5.78559118236115, 23024.6863815165, 26120.478454711, 27685.4350138065, 16075.2328033676, 2488.43666630912, 9721.62990087574, 9616.59992512998, 10918.4628381708, 9809.88758995499, 2914.66482374556, 877.138717320541, 812.486590138844, 5600.1268806048, 7561.48310338502, 18993.6816042875, 21997.4839544176, 46729.83554838, 28.5425439295029, 737.564022643526, 63432.9072145698, 110663.71006904, 83146.5462958572, 94173.8464218602, 102745.556234852, 1795.35441870061, 82787.179073802, 1682.79562704932, 6493.96147313932, 8243.71171665033, 28379.7347817353, 293.78973065295, 80805.4685836183, 530.748911250397, 405.510823787752, 193.573116984141, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 40583.7408939787, 34293.6362127229, 34205.3605710435, 26058.120846379, 34939.3390856448, 16075.2328033676, 16075.2328033676, 51259.8966549226, 53226.4510149708, 50013.3637363257, 18776.267703927, 298.748377534059, 12487.3443239224, 26711.5437118178, 22049.5303755656, 885.387831514171, 1063.60090266067, 4456.94251146803, 31789.1416899254, 5322.64402075399, 807.431905745569, 6239.46297748943, 442.821074928262, 26542.3402128664, 153175.665720884, 108352.389612781, 107979.89792405, 4278.2369663582, 2516.03944131743, 3857.78307250796, 16075.2328033676, 207.140771853515, 174.018472194646, 80489.791315613, 39185.9435003683, 60821.6986552707, 48854.3564093352, 6052.22221049831, 97222.6788190507, 38027.6604008696, 2082.76001490754, 1639.33106320002, 2581.38035908832, 102527.114374665, 82490.7691095879, 88485.4227832717, 398.206028873267, 100.68216531975, 2108.17772384609, 5447.84770222394, 2270.07215480244, 735.441897371628, 11761.395157269, 20067.328155064, 35197.3964407018, 69017.0219778135, 6464.55631765154, 28189.7031400417, 398.206028873267, 100.68216531975, 14790.0611965957, 6754.68935613241, 882.474477624182, 658.254210804327, 3058.36053399964, 3013.46142628419, 16075.2328033676, 153175.665720884, 23379.6403770777, 16926.8538480135, 77654.9946267744, 36662.1013903232, 20619.5137821244, 26701.5970896858, 27795.0804607385, 549.063997098806, 652.751602666035, 16262.1010369607, 21514.8859352454, 20618.5197644069, 21112.9295175897, 36982.9849286861, 37270.8763732936, 5555.07809657247, 961.861785584727, 16075.2328033676, 47546.7805044789, 25018.9940259246, 16075.2328033676, 163486.511300983, 179310.243107629, 164798.925936391, 138578.801903551, 159642.150447286, 186324.903951852, 164363.649895743, 46102.0450183129, 5811.28951558421, 2989.49900525221, 2570.34772716758, 22813.2525009148, 40474.8597658332, 5115.11129550889, 4763.39454127904, 26155.828620506, 182233.102679761, 182233.102679761, 172974.309812257, 4061.79209780473, 3845.11100473224, 51231.6252950158, 45365.6578262576, 29209.0157387826, 1713.36194208938, 1484.451894114, 2373.26485382418, 11046.5693195409, 6002.50724841574, 28502.9484160247, 27538.760045669, 16075.2328033676, 1677.12756837807, 2926.75909982747, 4936.85306638324, 84435.5925192723, 198502.651421323, 93823.9796754645, 106815.221492899, 41786.6207091058, 39809.4100070815, 41503.9234721245, 0.929645376106919, 446.931300398366, 1547.71862367023, 2781.48708783437, 26516.5882666406, 50001.3903218275, 209348.138416497, 21842.5220655211, 242.945286074339, 10604.4394745697, 727.237949697869, 4456.94251146803, 31789.1416899254, 10269.5272148046, 17923.2062466354, 5617.1025321418, 26124.3244076893, 30044.8392084153, 67768.6303400095, 46756.8653309269, 25740.4221782254, 119123.311334616, 726.625404761006, 36982.9849286861, 37270.8763732936, 175148.461497734, 16075.2328033676, 29956.0676611137, 4565.65552610272, 7861.49644837972, 1015.25263329992, 1186.32579633019, 1007.90681636612, 48811.4217235829, 49099.3131681904, 52235.6639830608, 52541.4545713139, 53821.0543828861, 51212.6266783739, 36982.9849286861, 37270.8763732936, 16075.2328033676, 19964.256429481, 20091.8515555983, 21503.8819653539, 19281.2026034976, 673.529729328414, 750.451299329575, 15609.5129670017, 5206.35955123814, 90330.5441806266, 94216.1806078267, 95194.2004036776, 94967.0488846865, 74.3657790574448, 9179.4351480092, 865.31844461964, 1247.65130231077, 763.725705078282, 8039.03043717126, 64867.8664691834, 20145.4062725195, 16343.4514141201, 38914.1648793721, 17978.2970968643, 3946.87924678815, 2477.36016414104, 16075.2328033676, 16075.2328033676, 16075.2328033676, 154061.05630944, 134392.963649098, 140579.532676782, 30621.4304878763, 48283.0377527947, 515.856579229091, 149.616593585133, 66854.0110213354, 36982.9849286861, 37270.8763732936, 130843.360188326, 207578.108805546, 67768.6303400095, 46756.8653309269, 25740.4221782254, 119123.311334616, 165.223660659323, 27379.1253218527, 69736.1238720441, 11619.4964391403, 9771.9812534022, 80274.5679919843, 82527.6737578726, 80411.2624805206, 69355.1212957926, 43833.4354466996, 79877.6209043181, 80836.8142818876, 89010.8939140615, 85167.2710933782, 74496.4466057285, 74421.8372538773, 21814.0781275725, 97869.3678159595, 27516.7860331003, 216404.505382719, 3544.37496585332, 2829.58776880448, 84435.5925192723, 125486.738228005, 53037.0838676818, 142115.926280253, 53533.7399373551, 53423.3318828117, 53056.251045108, 342.55533010548, 14912.1298817248, 35177.9678564077, 26426.1940338318, 36433.8801417797, 1856.15162274216, 4334.79323002807, 14537.5745157667, 19337.8582553017, 3805.47623790231, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529483, 25460.6460476849, 77285.6547481343, 78263.6745439852, 78036.5230249941, 167624.735878215, 939.647131209686, 765.476897764711, 2894.16588427567, 2797.00261800911, 1599.91328556599, 1484.50152993265, 136.012689198563, 93823.9796754645, 178155.474551345, 225364.60400068, 225287.565408306, 197064.901604999, 225441.010321761, 132739.533614074, 133388.515417683, 3010.9297245555, 11301.6499945144, 3503.57400795354, 49164.1310437513, 83789.057071898, 70735.2981333695, 2926.75909982747, 4936.85306638324, 916.180354671122, 649.960875448926, 159.099887233568, 208.596791903135, 67317.6681137094, 2343.7348947091, 2301.33045286824, 2767.76187634375, 277786.635375191, 228022.099162173, 243690.534151212, 223816.719720849, 241777.281654223, 16075.2328033676, 29956.0676611137, 1767.55487050511, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 37598.1501133725, 714.489708398233, 24636.2491393772, 25394.7963107294, 26031.6957700343, 6781.5621601804, 4381.41979632275, 6796.91941802312, 16075.2328033676, 32260.9107515519, 32786.4834938171, 27947.2324395659, 15378.4444957798, 62795.6448075275, 5687.12398212553, 3640.24829501594, 2819.8223879023, 1907.24180995453, 5217.61492808384, 11629.0775533624, 29290.6848182808, 12587.7663168623, 13204.3330851059, 13156.8616987923, 16747.1306044283, 115985.456950577, 11729.2379795839, 19706.8084453296, 9141.52877593042, 126540.890536894, 36709.1912560286, 9009.60466147242, 18532.7840353609, 20630.1844610614, 8179.51984565795, 20076.0451427791, 21334.2169546958, 33371.5839338285, 51440.4185918208, 51549.971129584, 126.21593135523, 3379.58394155665, 40545.7017734718, 4001.95870596901, 4357.62032237333, 143072.134773147, 150301.559293484, 351534.894276345, 218218.662102352, 352126.806886591, 352285.943543404, 2052.96940789063, 1585.72777625938, 116.113033013679, 56.4271046072093, 8699.9322905904, 40091.8016168959, 42324.0349323482, 40536.4423961479, 47439.6475129179, 78.8661602015281, 1385.77923218369, 380.817770655907, 375.503470055756, 84834.0770241765, 73777.9358394486, 48256.2499903555, 7754.2166880541, 138888.580947481, 47048.2906006299, 31420.2910879446, 50470.5271916799, 54506.1354773931, 50278.3678784859, 53809.9177725984, 3408.14639631326, 90029.6246309187, 75181.7586486951, 143529.564776475, 189627.346472865, 1908.00840219575, 2414.50565982347, 132913.503712801, 132510.436753758, 2641.27870694632, 622.192058773288, 11521.3334598281, 67616.8092223702, 67632.3456027196, 98474.5961445795, 42305.2678033633, 33156.8729283667, 55896.3196618911, 9257.62954142799, 16251.5305440038, 82716.586394709, 14770.9239908465, 30353.3983050173, 12036.0549515629, 35737.7036189187, 29012.5050518267, 29956.0676611137, 9658.17312208672, 34597.7867478208, 23932.0311049477, 9.77620251666667, 1876.63047947631, 2970.7430217973, 3407.9118980817, 118129.584975783, 28297.885694918, 10121.4784742503, 12922.9113935853, 20118.7565817869, 13556.866284347, 1531.94449159451, 68083.3165742877, 30176.0408102269, 165959.936204611, 21719.1680821797, 22395.9084028209, 34441.8154401673, 1856.15162274216, 6139.31897110159, 5774.03002008524, 67645.6337013346, 33083.5147178129, 47285.4003172667, 110250.897255532, 45958.8346971516, 28066.8827334793, 26405.4599854423, 19634.197471135, 22179.3851734391, 11482.1487847681, 33386.296572261, 27895.4454230002, 20057.6426328284, 45575.5846707738, 47472.5959841473, 49938.9377970477, 6908.82616123102, 117117.69985606, 87762.1352990928, 5805.7552485181, 5657.22800957319, 5816.60189980014, 9375.30675255404, 10651.6016029296, 1856.15162274216, 62924.8933892166, 82916.9489448837, 81288.5541303587, 68069.383738406, 68360.2069630028, 70473.1800331048, 3451.70292827145, 3608.73795032504, 106815.221492899, 41786.6207091059, 39809.4100070815, 41503.9234721246, 42296.7235571322, 40926.2568722153, 39962.0685018596, 3554.63510306016, 33990.0816124418, 34749.5231399551, 34790.4434182675, 74468.5859618555, 28502.9484160247, 27538.760045669, 2002.21688273405, 1984.90920456245, 83737.0126533958, 62725.2476443132, 41708.8044916117, 135091.693648002, 11368.0286559487, 19673.9616537436, 34804.0299393815, 68623.6554764932, 6071.18981633121, 27796.3366387213, 205.948417057369, 633.42261450348, 160.854671346707, 606.856326368966, 7246.48055835241, 16646.238530427, 8630.04477303453, 8494.87746778377, 52784.6033499057, 27019.6920317276, 26447.3773588871, 398.206028873267, 100.68216531975, 10193.5114322908, 3657.17611733982, 203758.270510476, 247107.744305489, 201858.541686114, 212821.558859616, 246928.32845559, 27930.2724191695, 50855.6155155059, 56179.0050997212, 55380.0974292401, 28502.9484160247, 27538.760045669, 37933.5437084819, 38876.9716104728, 62280.3687912754, 36969.3553381261, 2599.86367626889, 29776.1282946122, 213364.740662595, 627.672809104658, 69174.4488579006, 22813.2525009147, 40474.8597658331, 50616.9910239979, 9584.44521741818, 19148.5509140992, 38044.8345281442, 8629.9817365338, 8951.31752587595, 3717.93143819106, 1682.79562704932, 6493.96147313932, 2926.75909982747, 4936.85306638324, 1231.16655235924, 285534.27313522, 297580.769796114, 297508.672871068, 295638.087607728, 295805.916207651, 295783.301777054, 298098.597022548, 17798.9713166628, 18261.1427959795, 15621.7862383325, 93951.4888595654, 35979.3755888345, 141184.005296648, 121515.912636306, 31378.6127368576, 60482.4630564461, 26876.5356949184, 27815.5202949085, 72746.4471340485, 18226.6359698947, 19197.9800687734, 15836.5394301363, 127320.148571882, 37488.4492910168, 12919.0221809056, 19312.0420703492, 16075.2328033676, 1718.38222095214, 8942.06191125956, 935.357683121805, 7315.65633646663, 7389.19826076684, 4496.24900791657, 24968.4946002557, 25852.5794418844, 33930.5773423557, 30045.5638266052, 20774.4580805461, 20723.3608078529, 28141.2131528703, 25285.1532166965, 46237.1506916646, 378.838306337754, 469.592499842502, 133.120757649818, 19171.166524838, 44950.3318792694, 47662.8794895636, 47689.587585895, 1017.37098244191, 506.670960830974, 854.935635892897, 385.386809890281, 583.737029424752, 11220.9685439819, 2459.42998456002, 277.575621171587, 581.990057880112, 192386.716621952, 48714.121458542, 37.96708366618, 121.012110455494, 30868.6096526151, 32674.672470485, 49938.9377970477, 28272.2198080367, 32100.5831047186, 20695.5418583243, 17055.6364424753, 17055.6364424753, 18512.1364251876, 22151.0416985067, 1231.16655235924, 40876.2035782217, 7974.55311577916, 132.977985957547, 155.61043086903, 76695.5697286669, 55683.8047195843, 34667.3615668828, 128050.250723273, 114621.23145719, 32746.3000803895, 144520.112062147, 95846.43975611, 101918.019236198, 15647.0956392329, 90134.5486738796, 37302.5845014617, 9838.35492305386, 126.314528497176, 1749.46796187968, 8278.077209531, 8202.40918553296, 3225.79839883437, 153175.665720884, 22427.5203932581, 56363.3705272317, 56651.2619718392, 72593.5320145643, 9855.19570516019, 25645.4013530239, 398.206028873267, 100.68216531975, 307.895791651047, 1220.12815604955, 978.607816810773, 35.8383149928165, 174892.46257274, 200756.440426503, 1343.17433566773, 99029.6285500379, 104199.728547384, 66927.079733909, 42589.5446927088, 49572.9546292491, 43919.9602311171, 53107.7325021617, 3503.57400795354, 28502.9484160247, 27538.760045669, 14032.9469594158, 22493.5076204861, 93434.942346797, 98639.3558658906, 108037.253072752, 106764.82628468, 106085.58425423, 122722.252268876, 31075.3934257151, 92275.348098563, 131237.409923873, 34826.4945693093, 95972.612770182, 337702.328993311, 325031.440406317, 332142.096062064, 307983.481535446, 412521.917981757, 76695.5697286669, 55683.8047195843, 34667.3615668828, 38102.3727928802, 29105.9249288713, 26497.4972243591, 1070.60404853062, 29956.0676611137, 7656.55165555741, 93823.9796754645, 25269.7306223303, 6674.97302012422, 24336.5802850426, 3486.87842971356, 548.89858054728, 7652.2500575936, 380.817770655907, 112.901904441037, 116.330043966127, 99440.5306405717, 36322.4867815837, 78.0151057663068, 853.05921605838, 875.852518614541, 36982.9849286861, 37270.8763732936, 19337.8582553017, 2090.78496154058, 16075.2328033676, 16075.2328033676, 255.167752297303, 303.185109429245, 85306.609714591, 1412.22009106794, 1241.1340850347, 19395.1467166952, 28502.9484160247, 27538.760045669, 7571.78623449849, 7611.28886063494, 27043.3178229638, 29542.1949442316, 107020.984285254, 114099.617569792, 55324.5654929155, 55592.5206692464, 41110.249529837, 395.949036374041, 394.898339458005, 50113.2696022417, 57131.7184184801, 298.806723938854, 416.5795930824, 169.52281981971, 1184.67845743184, 1050.86309289985, 74.3657790574448, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 15901.6697637082, 15531.0667177567, 5134.67725071776, 40689.0457917755, 32489.5623721632, 1508.56785571373, 2150.05803676888, 783.959518459601, 1363.46302791599, 28428.0513699062, 375.270533127122, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 56089.2023386429, 1856.15162274216, 7727.23206442239, 71134.4252906892, 66592.3094514011, 74.3657790574448, 752.006047488311, 744.660230554516, 515.856579229091, 149.616593585133, 29956.0676611137, 93823.9796754645, 11036.9651062323, 11120.3553974658, 54284.539723499, 55057.1150017291, 62068.9727230567, 58654.5977535733, 50447.0729432918, 50394.4178399935, 56867.0027151309, 111137.469091868, 65351.7493997237, 75743.6217267382, 21325.1213421128, 21230.0381450699, 21863.7196079066, 12535.8012858801, 13465.8329886598, 85812.1435012143, 60626.0084309798, 53072.1288576136, 61095.8160611443, 24271.1577820147, 6674.97302012422, 24336.5802850426, 2717.99539859165, 3412.09845280897, 808.255024616811, 8794.61551025173, 1921.87632936221, 4023.92758095338, 53.7933222941156, 1296.77542289914, 71850.4782453601, 82233.3450048462, 74391.4876365635, 76977.5969320792, 16075.2328033676, 36982.9849286861, 37270.8763732936, 4203.37272627802, 4395.05107930894, 11154.5807916306, 33635.6707994986, 1412.22009106794, 1241.1340850347, 34999.7623329259, 33753.2294143291, 16075.2328033676, 4456.94251146803, 31789.1416899254, 5754.56563001634, 7106.267528882, 398.206028873267, 100.68216531975, 1992.36392759982, 1750.65892322951, 34487.588408568, 37550.3817441686, 38813.7093086312, 38348.749222286, 35868.0274985296, 39598.8071358888, 29956.0676611137, 380.817770655907, 10133.1291972557, 20771.436539465, 1412.22009106794, 30725.1084552427, 55.8837027444483, 70309.0015394083, 70546.3690824553, 16075.2328033676, 1122.26227238995, 1688.03628125613, 14059.7559396228, 13949.3169767571, 14089.7405464459, 7106.27431670089, 2097.682220922, 3565.6179958287, 126528.188426096, 18646.9546826085, 31550.3997409084, 671.354697274659, 29956.0676611137, 587.827601893559, 9724.70541100056, 37304.5884083199, 17930.2190322633, 2267.69288065616, 149221.133674606, 217041.915526466, 3728.49898930883, 4040.8154131577, 28498.8193557754, 7469.23445983926, 7787.49016938389, 16141.5665542235, 12861.380428752, 38914.1648793721, 2858.43849425123, 16470.2302470278, 16412.8512399382, 17152.2737402856, 16075.2328033676, 28502.9484160247, 27538.760045669, 41391.0671990039, 33268.2949201385, 36021.4311419688, 2119.22067500231, 1092.03343456361, 488.972630435114, 53184.7294026714, 56608.8373607729, 157915.644061441, 246.043076333188, 4019.93055276592, 2079.29089735499, 37295.530825122, 38341.6507339548, 10762.6524952033, 254314.651872219, 250116.264760565, 254787.541009399, 46305.454726647, 23139.0751043715, 47022.7608869969, 29956.0676611137, 15604.3536182116, 18558.9358129302, 32744.1647156284, 6133.63052943299, 13440.8766781651, 380.817770655907, 2926.75909982747, 4936.85306638324, 31578.5039230433, 1014.74467921055, 14537.5745157667, 11370.7101112596, 19676.6431090546, 34806.7113946924, 68626.3369318041, 6073.87127164214, 128050.250723273, 16910.1193498906, 16075.2328033676, 11187.3877442838, 14092.6294934269, 3198.20199161574, 3951.35973793132, 97653.1042903553, 103236.816712939, 150056.92761151, 106269.007742569, 126313.163239205, 103927.633567977, 145243.150244306, 6040.32683921663, 30641.9059666428, 29713.5155397438, 137668.250794397, 138813.572730505, 138682.412439964, 138390.387009029, 2047.73532763217, 2233.44065568295, 1883.90398221831, 671.012014414962, 18229.5014058069, 165.105593485501, 163.148000537549, 36164.5270420989, 35499.539492142, 47987.042891265, 48387.0963309364, 36982.9849286861, 37270.8763732936, 11370.7101112596, 19676.6431090546, 34806.7113946924, 68626.3369318041, 6073.87127164214, 27799.0180940323, 4001.95870596901, 4357.62032237333, 23622.1076341125, 2443.09626067721, 973.165395681061, 3476.59176352369, 644.754478705349, 5727.3543886454, 255.167752297303, 303.185109429245, 3608.80590729339, 59383.2623424327, 1638.53718781816, 293.177570406355, 62.1949804941589, 2736.64857526237, 3636.98875462988, 56608.8373607729, 157915.644061441, 67768.6303400095, 46756.8653309269, 25740.4221782254, 119123.311334616, 2794.34814158862, 2806.08390596893, 939.647131209686, 765.476897764711, 5707.73579948962, 380.175360365743, 245986.819406863, 25682.1131196096, 21548.1754277453, 21177.5723817938, 626.814235121668, 11232.6953369236, 7930.39930449692, 8010.28569025992, 36982.9849286861, 34687.2994925051, 36411.2068730389, 48363.0950449645, 54062.7338506995, 323224.446777302, 309898.693392439, 296939.447922038, 283827.033253775, 68174.7441609302, 45.5777284527176, 1783.16899601624, 14717.6935551536, 15640.514571935, 28502.9484160247, 27538.760045669, 1438.88076464098, 8215.45272160429, 19982.2841448547, 20404.6771066131, 52235.6639830608, 52541.4545713139, 53821.0543828861, 51212.6266783739, 16075.2328033676, 21422.7019579882, 515.856579229091, 149.616593585133, 90059.7917959958, 49435.4270428902, 28.5425439295029, 737.564022643526, 45747.5751609117, 36443.74285581, 34272.2429150216, 33660.4629764611, 121.620466588186, 5.78559118236115, 28985.5252124698, 28156.0515117744, 380.817770655907, 137462.05276256, 41036.8408986858, 35546.3309276587, 40064.6867553009, 57726.2940202193, 16075.2328033676, 7828.03890078541, 2819.44680500653, 11797.7038722173, 211666.681961562, 205811.98823971, 206778.528130259, 204917.777161595, 2133.71576737236, 5054.90619609122, 2636.43437817476, 5257.07955708209, 42627.5916110602, 4552.4664539353, 5167.51722797778, 10775.0131033758, 19599.5049812013, 18151.8213599309, 37043.8342983467, 13920.6060509764, 37363.7409542532, 16075.2328033676, 69216.8243896397, 21737.4246545607, 10026.6751693243, 9959.65067403277, 46373.5180758256, 84435.5925192723, 115374.672252915, 18841.207846972, 153175.665720884, 26500.4442807958, 27218.2374616497, 71700.0902599357, 127119.298591854, 69432.2668312307, 71044.8064017589, 11150.5648862207, 49735.2816267968, 12652.4028028579, 5762.39122322859, 33498.1316622661, 34496.6897971574, 0.929645376106919, 446.931300398366, 641.415481240421, 39353.067013833, 27483.7498826368, 35715.3363098871, 18559.9124928299, 9179.4351480092, 269635.641958756, 17409.6173675702, 153175.665720884, 28455.4110235471, 27269.4755077968, 65000.8813233896, 58922.2166531305, 28584.545558594, 22984.860100969, 21049.5293336065, 1604.04546060564, 871.767144042084, 1467.00097303736, 641.363575064923, 193513.14601258, 173845.053352238, 150626.455918552, 11304.840278542, 54474.1715658941, 48757.9350467699, 1562.90664199591, 86165.4982332778, 17677.7313538077, 4001.95870596901, 4357.62032237333, 16075.2328033676, 17995.4442923548, 3123.29985403103, 5209.0809877536, 14078.7204502843, 14491.361972311, 40768.3219463978, 1543.53280245707, 1100.10385074956, 10133.1291972557, 20771.436539465, 16075.2328033676, 66866.978131371, 62431.0277854336, 67123.2582762015, 59586.4218057612, 7650.21302182265, 12162.7122111066, 7023.75852914176, 398.206028873267, 100.68216531975, 11597.2531615025, 24998.4544997442, 14639.4607193604, 13887.305497198, 42891.6549907222, 104658.019429821, 15899.1406599728, 1819.03638074739, 15765.6971233189, 190799.799053398, 252245.762733372, 197878.432337936, 398.206028873267, 100.68216531975, 27799.0180940323, 6678.97451457694, 11252.8193795251, 5134.07365950494, 2648.39776050582, 7420.07206864827, 7925.36492872753, 1664.95375073746, 7704.01336175395, 73864.8506911595, 43845.3532432626, 236.783655248825, 3728.49898930883, 4040.8154131577, 3451.70292827145, 3608.73795032504, 366844.873538624, 362953.649641368, 364016.155213817, 53723.9799234121, 38914.1648793721, 60256.3454301609, 143.650275992601, 38465.421186204, 86533.3665126416, 74196.6866642223, 74189.7040897352, 63571.5935003966, 55150.6945182499, 4432.15004536735, 31764.3492238247, 74718.9111186178, 105291.247620727, 8951.28583145258, 9130.49983677968, 1864.15501149668, 3793.43462926929, 18729.0201044919, 16075.2328033676, 28502.9484160247, 27538.760045669, 1113.84361559347, 465.97664510312, 252.018548847023, 3417.20639829909, 13610.5713417139, 10958.2371110105, 10814.5267182624, 837.531698829998, 837.531698829998, 195.013030138647, 122409.668116594, 5049.46626637043, 5093.63422549426, 37448.7667123955, 4608.56561250729, 4184.21753040712, 3541.67172903644, 3704.90622789336, 34543.5899395263, 6010.38178803111, 6373.50065284679, 89133.7049978394, 40531.9929885463, 35247.2213737433, 76873.774227323, 6661.41903727445, 121.620466588186, 5.78559118236115, 38914.1648793721, 255421.458901604, 210520.03499845, 36982.9849286861, 37270.8763732936, 136316.120602636, 135276.28741566, 67077.630524221, 62721.309221233, 37270.8763732936, 38702.6931408084, 41014.6863364428, 39179.2889888672, 38104.9887909818, 4456.94251146803, 31789.1416899254, 552.157900928914, 1894.11390964291, 32454.0385599316, 75125.2288338277, 74010.0036989764, 29956.0676611137, 193.917651065032, 117347.960627951, 55464.9480380504, 36982.9849286861, 37270.8763732936, 172.584973036458, 87.6629534755182, 38190.0884871587, 2145.12244717324, 3279.31552029131, 20865.6213497745, 6674.97302012422, 24336.5802850426, 66736.5531439638, 65662.2748509856, 65503.0754638262, 67024.4445885714, 398.206028873267, 100.68216531975, 48.8008458005068, 26832.7995949944, 35881.8763951754, 233472.617002224, 29209.3171546973, 8691.98598920967, 4778.87249697422, 12432.5515288051, 34320.7195717526, 3885.21389333232, 4329.48021131991, 125071.011217462, 83777.6334808927, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 10387.3191265148, 10018.3913236045, 18361.8951062043, 2926.75909982747, 4936.85306638324, 58770.0252203925, 42052.0287164792, 1374.91407938692, 14356.175242238, 29683.9009883408, 48480.7161533392, 39042.7643914722, 41350.0545934463, 24804.7524814774, 20631.4794905314, 19742.7178989226, 16076.1257476185, 3931.37623514777, 24271.1577820147, 66404.1923946005, 11553.4369685885, 11180.4121908876, 17065.0501555631, 939.647131209686, 765.476897764711, 10632.1906793227, 10755.6395956176, 1241.1340850347, 1689.56978761417, 58499.4282996651, 3197.05867273829, 67.4924095059996, 16562.5015385432, 17321.0487098954, 7522.29072823977, 3458.38954358547, 20179.8551396914, 51231.1294106682, 1195.97853420636, 1440.37177992726, 1508.10722834177, 4392.99410339359, 3187.7173966304, 380.817770655907, 19599.5049812013, 484.438416675068, 54845.9402948702, 54608.6626945985, 142007.743874762, 7118.89473461017, 3664.09436874949, 96420.6427663675, 115206.82253356, 3302.95991306052, 1995.86933921473, 1025.64438283859, 851.474149393614, 1686.24850649015, 5795.30851131418, 53651.0168372577, 54160.1373780979, 28985.5252124698, 28156.0515117744, 38914.1648793721, 137122.689349203, 94987.1215551968, 23566.9159369059, 23573.8396002032, 233472.617002224, 1247.95157902729, 11853.8326808292, 6059.11742511729, 24055.3080299158, 26978.4529145259, 14180.4501320254, 13819.2997225143, 1579.57980782396, 168186.886393358, 4001.95870596901, 4357.62032237333, 36982.9849286861, 37270.8763732936, 15559.6498993078, 10350.8534566176, 2926.75909982747, 4936.85306638324, 75073.1496905823, 77522.8053661305, 77331.0756895674, 38847.1694433472, 14445.529319188, 16200.5667623235, 30572.0256278077, 7044.87476313035, 7276.85758355885, 14985.8688410095, 15065.7552267725, 13553.9106142832, 35085.5466214426, 65526.8430249579, 16075.2328033676, 16075.2328033676, 1856.15162274216, 14372.7528903926, 4456.94251146803, 195497.925890473, 127155.003254441, 112571.345559209, 380.817770655907, 1165.53054898893, 1166.14407645329, 799.415871280987, 4488.73401463331, 4913.45506226395, 107571.936932815, 101404.167038711, 7745.76860949995, 35804.3992046528, 183193.699501742, 38190.0884871587, 78065.9990241796, 57054.234015097, 36037.7908623955, 129420.680018786, 144610.304588345, 104109.909435888, 124942.211928003, 155737.31191619, 10490.2937070246, 10352.4087696773, 16075.2328033676, 37674.7182393407, 39959.3035291175, 40819.2763818436, 1239.10061747058, 2719.4412086326, 7408.06504692854, 21748.3013069694, 2165.93404692665, 3283.05108075711, 4905.07331094504, 6915.16727750081, 89537.7603416817, 16562.5015385432, 17321.0487098954, 1412.38578028691, 34518.2601438549, 33471.9686332755, 34692.8642351097, 35196.4332155938, 93951.4888595654, 163660.781261909, 80294.9885885066, 159146.471523387, 12895.5748562769, 14238.3685541294, 11592.2200426572, 12270.5794818925, 16075.2328033676, 5885.18867062766, 4179.95077336827, 2894.62766262561, 16075.2328033676, 44078.393108742, 2271.84710195518, 4154.48473263309, 3105.1283209331, 3446.98557537899, 1035.92396323839, 2183.82301234433, 1233.43337215684, 53909.823051173, 62853.7747765658, 1864.15501149668, 55.8837027444483, 52.1147236033839, 34171.7138100224, 69285.6049777308, 18816.5073119612, 50180.8496866807, 46349.6892525545, 155912.384120444, 61423.142805251, 86165.4982332778, 52187.5389609851, 21436.8922760543, 29956.0676611137, 8319.4263237931, 17134.2739317084, 3022.44233156181, 2376.73091874979, 35600.7237408511, 9732.42160086117, 28.5425439295029, 737.564022643526, 25151.8769618156, 25449.4524707123, 8918.20438386128, 5081.52947157119, 11942.9344201387, 12203.4912738158, 89419.1894130603, 48794.8246599547, 1638.53718781816, 32150.5621891199, 30277.0253431475, 30455.9933043923, 13439.975764442, 46116.3584692349, 49634.8290819867, 48399.9125572594, 14790.0611965957, 52743.6595439047, 35068.5817547819, 53031.5509885122, 24166.7537813751, 1671.87246311984, 6079.53436475853, 3375.76347579417, 1158.68401886978, 30578.7612434595, 55.8837027444483, 16075.2328033676, 16075.2328033676, 50166.8356197472, 50184.735933445, 112691.765284205, 11370.7101112596, 19676.6431090546, 34806.7113946924, 68626.3369318041, 6073.87127164214, 27799.0180940323, 939.647131209686, 765.476897764711, 63571.5935003966, 55150.6945182499, 42296.7235571322, 40926.2568722153, 39962.0685018596, 10150.976597184, 58687.9257506134, 11488.7962711547, 73821.8700898538, 2926.75909982747, 4936.85306638324, 53981.892705041, 59646.851923537, 38914.1648793721, 1046.99525242921, 57591.6803255789, 56760.7990497933, 4062.48361556057, 1585.84193959221, 28272.2198080367, 32100.5831047186, 20695.5418583243, 39213.2959969423, 150426.727989948, 5412.03277227784, 5869.13345999701, 3020.62466064264, 20164.6291378281, 20854.1536339702, 15659.8228721144, 4562.97386015207, 678.775189374734, 2197.4423255142, 14568.1647432157, 14078.7204502843, 137.075911401433, 11145.060159505, 449.392335250306, 15586.9061097518, 535.778320926114, 35.9876265013509, 430.335507715417, 74468.5859618556, 16075.2328033676, 2926.75909982747, 4936.85306638324, 251556.204979105, 251145.918696864, 256538.16753123, 24859.8606909763, 152984.259809127, 16075.2328033676, 102237.555908273, 130249.723525687, 67414.0453941158, 10592.5020026709, 5583.90990689204, 425.317570410484, 93823.9796754645, 8281.77231533278, 6019.51249877478, 4968.44795473146, 33357.6460653597, 39259.5707868449, 1856.15162274216, 2493.09388858937, 5151.06643631184, 99227.1545570501, 36982.9849286861, 37270.8763732936, 4389.35655051858, 5043.99738625688, 48447.2183840979, 71099.1823055761, 57943.4113685274, 47483.0300137422, 58239.7681852761, 70248.3287512563, 104641.488308056, 871.260427226931, 377.714335383027, 7106.27431670089, 2097.682220922, 75437.7166391433, 34813.3518860377, 2926.75909982747, 4936.85306638324, 29956.0676611137, 46052.2594040351, 45325.5268663334, 50859.4164529978, 53654.369006013, 52925.0539860187, 317.564940225624, 12487.3443239224, 1856.15162274216, 19337.8582553017, 11939.1918165703, 14969.3951157422, 26362.7012915856, 22813.2525009148, 40474.8597658331, 58550.9088998359, 9747.19449408919, 129051.845402887, 18952.5083926945, 18612.9673810505, 20297.9363911964, 24739.4019926611, 20847.6272699449, 4934.49119655608, 55.8837027444483, 1898.11470189693, 17293.334383969, 22059.8700161058, 9639.67119403886, 137641.91085309, 147247.168295695, 6456.82784209751, 4236.94893716542, 398.206028873267, 100.68216531975, 93823.9796754645, 303.13177435635, 250527.625015963, 12810.191805193, 12812.2432995907, 4328.45526937325, 91795.2317048725, 91146.2646541894, 635.181136894065, 931.930916233713, 1133.08618820949, 76695.5697286669, 55683.8047195843, 34667.3615668828, 128050.250723273, 22791.0605828707, 40452.6678477891, 16062.7837202716, 14496.493915976, 5811.28951558421, 2989.49900525221, 286.068856495644, 834.446899471087, 10781.0840618969, 63108.7066486226, 22939.2979600887, 26933.2826030145, 25710.0475104309, 48562.2552189146, 1122.35194789941, 78.1070038380331, 198784.601379654, 179352.006918092, 130.189402367952, 15850.0768683501, 15773.1332986639, 1849.76597709868, 879.54102072254, 629.611953387545, 705.370787277564, 95118.5516205542, 13224.5417361058, 12371.0284273401, 28502.9484160247, 27538.760045669, 737.616153793382, 34.8530650771695, 7106.27431670089, 2097.682220922, 4334.79323002807, 69043.3182127814, 13340.9572357484, 844.798579275008, 155.663795704028, 4135.80864873261, 16075.2328033676, 844.828503621919, 47125.7363399674, 9944.04009043492, 22062.0556343571, 48960.4376159185, 27043.3178229638, 29542.1949442316, 71665.6108921919, 84237.9700934032, 3601.35858949928, 1551.43106729662, 34616.7068129222, 35595.0054915115, 38242.9860779051, 130267.661847435, 1854.37792764216, 25084.7320010508, 107020.984285254, 114099.617569792, 8706.56030281087, 7210.76356621915, 19611.9555800196, 1856.15162274216, 7937.10275037639, 781.602604478408, 666.915014712587, 1137.49587921006, 6432.75048440458, 6755.92627179018, 5767.47279353146, 59139.5031721197, 128751.021251182, 50718.604189973, 44511.4447671355, 32462.4536377938, 5954.46819449568, 6035.25721638796, 29956.0676611137, 1496.810792264, 2967.47049062933, 55.8837027444483, 165.105593485501, 163.148000537549, 1407.80512308991, 17125.8028932678, 100367.198529734, 114064.394687858, 126278.931424225, 126693.942235353, 58779.4086693765, 31260.1722706402, 30473.8754808262, 30213.8807600607, 31434.7763618949, 32586.2255746248, 29956.0676611137, 7428.22484257609, 94216.1806078267, 95194.2004036776, 94967.0488846865, 6960.40251199226, 6896.96693630203, 7553.23080419276, 6674.97302012422, 24336.5802850426, 97384.6389835388, 86867.0227738823, 36.3583549709158, 158.395733639211, 29408.8943428247, 16075.2328033676, 11462.2805085879, 458.575194108289, 422.577156237603, 3375.21133822932, 136.012689198563, 2992.96087966576, 2781.11295895625, 28.5425439295029, 737.564022643526, 121.620466588186, 5.78559118236115, 14357.8530972185, 1231.16655235924, 3313.85856569276, 1912.26404284212, 2309.15705582493, 36982.9849286861, 37270.8763732936, 13975.2787313639, 13604.5933923312, 29956.0676611137, 25811.0732482626, 10313.7477821363, 157094.715596045, 161381.712254123, 117261.459381085, 96044.6993025502, 47829.8743683947, 1637.55792573775, 2142.79614674556, 36895.1964736525, 1591.74443803813, 10710.0463558623, 3391.67985444458, 5585.65654026387, 4712.50084521217, 61776.0301688144, 9179.4351480092, 16134.3728805598, 16089.0006525054, 1111.51931009835, 974.954919932931, 30413.7749648633, 2926.75909982747, 4936.85306638324, 3952.56403227262, 9305.16508071305, 20955.1297265097, 180935.140317514, 275116.071535101, 236827.299476818, 4292.46862072161, 4604.78504457048, 8469.63884526158, 13160.7693537167, 699.161584082383, 42206.2900673085, 37830.4039382628, 55643.3918320751, 56029.639847205, 55662.5590095013, 535.778320926114, 35.9876265013509, 430.335507715417, 82606.0089878967, 16995.7727258847, 10046.8777771119, 2140.84652524691, 13182.3305009348, 15315.743039222, 13070.5069500952, 14341.8230528927, 255.167752297303, 303.185109429245, 939.647131209686, 765.476897764711, 218360.924471302, 59526.5119495311, 61362.4516866937, 26124.3244076893, 13818.4044195589, 1374.2048502816, 64563.8789546893, 2667.35392788026, 35237.9181591188, 7117.61990428416, 8635.55103981667, 2439.72065206611, 2474.04311472186, 16075.2328033676, 1136.12668812851, 4213.43758794387, 3756.22756145576, 19775.2176056384, 7900.52578675977, 7627.07077569735, 13045.821400647, 144.228042474525, 991.656839875892, 732.953043964545, 5460.77855509813, 87.0705370516062, 9179.4351480092, 80763.7559533882, 61095.6632930459, 37877.0658593601, 75608.6392280551, 246442.91492201, 27806.7771431747, 122197.848978773, 250322.248096924, 1497.99564116431, 31237.3883154247, 128.362218368509, 16075.2328033676, 1922.84902850152, 7128.65591677249, 16458.0033959549, 34119.6106608733, 17889.3525757676, 5952.25147718454, 74049.8201663322, 73346.1035539872, 74436.068181462, 74337.7116109397, 74068.9873437584, 165.105593485501, 163.148000537549, 11912.2979773341, 9739.33889848768, 1108.79635087671, 5845.13741145856, 4610.05171493406, 4516.55363528143, 11684.4711831899, 22149.9012355677, 16075.2328033676, 28455.4110235471, 27269.4755077968, 20164.6291378281, 20854.1536339702, 38469.3135638807, 380.817770655907, 19285.8975772295, 15667.9257545897, 15750.0938113944, 20394.629561586, 29308.7782107194, 29683.9009883408, 17192.4033972732, 14527.8506236263, 4377.01525463656, 36982.9849286861, 37270.8763732936, 36953.9591885763, 37340.2072037062, 380.817770655907, 1231.16655235924, 80948.1330462666, 172.584973036458, 87.6629534755182, 62692.7880709011, 43454.9308658838, 4761.52718935942, 34425.0228007046, 63082.2995800719, 34160.5177961299, 62968.6937277746, 51262.9187594979, 35765.5932933716, 4001.95870596901, 4357.62032237333, 23266.2899355451, 23756.0141841739, 23385.4111382224, 50129.3931508622, 54536.2744430172, 68151.0097526695, 78416.346292647, 28591.0864962911, 142435.457208778, 142774.92775453, 150507.374605515, 141660.33163787, 141047.779388742, 151580.508051417, 7453.93095733601, 25084.7320010508, 3058.15317065785, 5527.76958369404, 17009.4446690573, 4126.92728149045, 170.506874490262, 207186.535273238, 145639.010595426, 114140.424525567, 28971.627427244, 38914.1648793721, 153175.665720884, 4759.83439230613, 5599.27775320534, 16075.2328033676, 153175.665720884, 38540.1870375401, 41512.5285090701, 10567.0370345754, 8064.3557058591, 15053.1643329777, 8908.66361200147, 16314.9587050097, 50314.6915427999, 93823.9796754645, 34999.7623329259, 33753.2294143291, 9441.46382690359, 10012.5961144067, 16228.1874248892, 15390.7059402213, 16593.3348817745, 1095.41945808009, 2304.44074710294, 40112.6008841313, 57774.2081490497, 55403.2695883036, 13033.4051198278, 6602.30639813715, 7945.55057865601, 24215.7538066742, 8153.29695120766, 32231.9503536612, 51967.1978959709, 35924.6102877721, 58054.3655215908, 53909.823051173, 62853.7747765658, 329.476038024962, 36982.9849286861, 31789.1416899254, 7694.36780697027, 2267.69288065616, 2768.99187028832, 3198.20199161574, 3951.35973793132, 2858.43849425123, 354224.479589483, 376857.842744811, 354414.270404242, 345431.028580778, 345350.884201087, 1672.00867923511, 7700.63415301952, 2021.8087249552, 3234.79560432299, 36323.2943826578, 165.105593485501, 163.148000537549, 9584.700435887, 9211.67565818611, 58017.2776693291, 255421.458901604, 210520.03499845, 48314.0527715969, 48112.8693810379, 53159.2913082351, 51231.6252950158, 37906.6222148728, 150786.156708085, 55.8837027444483, 3313.85856569276, 1912.26404284212, 2309.15705582493, 8966.2936795515, 70717.9839738825, 4731.81756149344, 27451.5276963566, 12487.3443239224, 4001.95870596901, 4357.62032237333, 1372.37460272785, 16075.2328033676, 20093.4085307662, 2332.89544155671, 58924.3545995404, 59516.9972327716, 128857.073201145, 129819.067280071, 137937.843044836, 134130.995194205, 123362.088106919, 123284.917648869, 9481.24574281643, 961.619334996549, 36982.9849286861, 37270.8763732936, 79614.3683895222, 1749.30945917116, 42956.1390872883, 850.84401605823, 308.15274181978, 230.906087798292, 939.647131209686, 765.476897764711, 27043.3178229638, 29542.1949442316, 7469.23445983926, 7787.49016938389, 153175.665720884, 14190.170374372, 68086.9989306044, 1222.13360700813, 534.929670399472, 22813.2525009148, 40474.8597658331, 77070.6985263321, 76267.9450523904, 37270.8763732936, 3798.90221170399, 4872.49136382291, 4668.9568559656, 28502.9484160247, 27538.760045669, 56057.095928187, 23345.0664862731, 22974.4634403216, 36982.9849286861, 37270.8763732936, 88567.4087753933, 95506.0753097092, 304.137416699977, 2797.74343680167, 2159.59828758841, 14282.4973541115, 4574.6529366075, 44.2671796269306, 171548.938897289, 5811.28951558421, 2989.49900525221, 64494.4430133265, 64880.6910284564, 63582.1904075737, 70396.3677348116, 14807.3289463277, 695.492487178245, 55.8837027444483, 23541.3983818899, 8478.36344286021, 10684.5220784136, 19143.7623896688, 33580.0069109427, 21375.9996058718, 25587.7117407219, 31289.8205002133, 31303.4124505506, 32347.3983948111, 11872.0200596811, 6297.83754911578, 34298.7108724577, 7652.2500575936, 42720.9204006638, 45875.3428330764, 4001.95870596901, 4357.62032237333, 1579.15018599238, 1992.00901593935, 67768.6303400095, 46756.8653309269, 25740.4221782254, 119123.311334616, 622.365549543305, 237100.045987053, 7750.0319968872, 7745.40806826308, 46364.453079953, 39107.5026274169, 47121.8297212417, 13756.5035547221, 12662.3232983822, 33476.2450700347, 11254.0860634479, 13218.8336672364, 5622.2701511546, 4686.99059965406, 7632.36411771037, 14356.175242238, 2984.12770056569, 7652.2500575936, 80802.5437252014, 72302.5549940947, 43765.533301234, 55587.9100303759, 3263.63297233387, 5040.54247213971, 1806.55959727361, 69891.9918615386, 44370.3060124456, 28576.267842757, 29066.7239675287, 16075.2328033676, 36982.9849286861, 37270.8763732936, 19337.8582553017, 3218.54512411954, 7141.34538745295, 35961.9454024408, 38332.5564557414, 31378.6127368576, 60482.4630564461, 5936.4952444154, 170784.971166722, 1000.18362927607, 313.977034259108, 760.00937614803, 1548.57537520954, 5979.77950063116, 16243.8524543047, 667.663331675873, 566.070592134515, 19251.1507853886, 18253.1590920583, 99187.5999751499, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 19337.8582553017, 4620.43191662203, 4658.50539586673, 16075.2328033676, 3844.66092419477, 75181.7586486951, 4620.43191662203, 4658.50539586673, 28377.8651589222, 416.817905958984, 32400.9718600453, 39143.2215867454, 41351.759314907, 31990.1953376752, 33071.3495971915, 57279.2300579991, 57695.0471785286, 58661.9727239278, 59160.5312814595, 67016.5131179485, 60489.5060804512, 3621.49195251049, 6529.59218398543, 6516.35956646932, 5538.00417983785, 32255.5733047464, 1386.30925733456, 1856.15162274216, 1689.56978761417, 63571.5935003966, 55150.6945182499, 2190.15197220587, 26009.5764918376, 160703.167242074, 158641.507877226, 154439.756305579, 44575.3612506825, 26375.7719879442, 21553.7619201316, 53674.2797682071, 27340.6801739114, 45324.5012749173, 25843.3733341327, 27120.4701254514, 42626.3675314363, 13189.7316550891, 24788.6974437841, 96955.47925898, 939.647131209686, 765.476897764711, 67615.0010442909, 46603.2360352084, 25586.7928825069, 118969.682038897, 75181.7586486951, 2888.95714616799, 68850.1199465834, 2849.73497662546, 66623.3263215092, 67009.5743366391, 66911.2177661167, 66642.4934989355, 1755.04800402804, 57308.3531806352, 48639.5293042238, 49493.0909098259, 27530.4466366291, 3279.59642851882, 30675.7270404814, 975.567570562615, 1071.47192005444, 23655.5542963484, 24604.3833887903, 32939.1179965398, 39110.5400599364, 31462.7744064384, 39004.9821438277, 84873.2018736307, 34237.1035482385, 34041.2264243957, 93823.9796754645, 746.746346589386, 629.636190317591, 4704.27756113488, 37856.8996455502, 46737.8010136089, 523.275461437359, 3728.63846082545, 3971.82888382537, 379.541722750137, 427.176005292627, 16075.2328033676, 44359.7426141151, 24582.6998040725, 34934.5130092167, 8885.16203110294, 863.512720033206, 248.541481771545, 12027.5391183339, 12489.7105976506, 18916.2282870204, 10143.3246683112, 37295.530825122, 38341.6507339548, 10762.6524952033, 118416.824884025, 103278.053057793, 35447.6088958419, 51.977322099217, 47125.7363399674, 6754.68935613241, 6908.82616123102, 31473.6519634937, 7909.76969901001, 3101.72266401925, 41263.4709099325, 3374.45326008622, 4951.24243636284, 3513.62276616804, 96.4078757783745, 2050.22916513745, 50018.6902017262, 24575.1576604419, 21441.7127540249, 22300.2406271923, 60256.3454301609, 362927.654908607, 307687.501603184, 334646.085554296, 46923.2162998595, 883.659008064973, 846.232018946051, 610.095662750163, 47836.612387009, 1480.03457890593, 53909.823051173, 62853.7747765658, 87557.9973604304, 48955.7642006406, 93986.2304404494, 91533.6111697374, 88654.8903662501, 4499.71822502178, 9.16137911301382, 19638.4588850516, 23478.0176105813, 24182.1113324673, 22693.3377280765, 24658.7045241761, 22371.8575017644, 25099.1687715762, 24995.9113253109, 23486.1571528189, 939.647131209686, 765.476897764711, 67396.4351814659, 227390.787211968, 235265.1044411, 231858.355955395, 6296.65512280591, 54933.6764300498, 53746.3328437305, 56650.0256081809, 221270.259363424, 205211.082025409, 252169.013326471, 153352.148658465, 29956.0676611137, 3842.61636333893, 6922.1347196059, 84435.5925192723, 1487.17108561885, 34658.3326065926, 6050.85387156675, 4361.22162634891, 65065.7497861239, 237123.970783316, 237053.701834988, 3675.70610519469, 147.712156395093, 14880.572903076, 29742.845776986, 17576.67834925, 55486.6741746049, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529483, 25460.6460476849, 654.459849470721, 346.814019571169, 939.647131209686, 765.476897764711, 667.663331675873, 566.070592134515, 134536.613094074, 66623.3263215092, 67009.5743366391, 66911.2177661167, 66642.4934989355, 4620.43191662203, 4658.50539586673, 3500.29247416595, 7108.66370892752, 1128.09705876689, 61318.5850462693, 60035.0763754801, 267011.037849238, 178996.899039389, 57085.4851212458, 217895.454223985, 216343.819011281, 220614.639367416, 676.507224251702, 227.142459758333, 53.3971236974194, 93823.9796754645, 80704.330794331, 79403.6475477822, 81335.5320530716, 3437.68750995873, 2202.60181343423, 56608.9879799709, 19337.8582553017, 7423.32457118665, 1599.91328556599, 1484.50152993265, 34342.3222505741, 33107.4057258468, 793.920564952579, 55643.3918320751, 56029.639847205, 55662.5590095013, 107283.672524999, 106889.057090138, 49.1903490315561, 34.4575564494474, 16867.4155157526, 834.757334648142, 1699.19463500253, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 14860.2010167039, 9851.60892092505, 10296.2510677667, 329.476038024962, 3905.73665245939, 2926.75909982747, 4936.85306638324, 25347.5162775869, 2849.73497662546, 13791.1164808939, 420.044597690908, 863.943437230725, 9569.44050119573, 83.8834666385696, 19.3544779274395, 23114.079949249, 10199.8134264271, 10775.7313088592, 10953.2065447233, 55643.3918320751, 56029.639847205, 55662.5590095013, 7406.06055363766, 7809.3313986279, 24271.1577820147, 47561.9893004157, 35773.8079539438, 398.206028873267, 100.68216531975, 6001.81094715006, 6606.63828560819, 26891.5735550478, 14356.175242238, 33858.8863164273, 16075.2328033676, 12703.2256084778, 10425.461681907, 35856.6217611251, 5062.21426063276, 3327.72378576113, 71815.6272636667, 80147.6684279483, 80836.3073467203, 1261.79575722989, 44359.7426141151, 586.368843549422, 181434.624901029, 425.317570410484, 104647.482815305, 165.105593485501, 163.148000537549, 2926.75909982747, 4936.85306638324, 21028.6342956425, 19659.0690929773, 20111.8253101348, 19076.6280580905, 7827.36088798967, 16075.2328033676, 57754.7444232741, 132981.623098472, 113313.53043813, 96520.9582989015, 74298.3814697687, 85306.609714591, 24715.8262370963, 5023.86029939158, 6792.04966521435, 2834.47735727069, 6965.28652893546, 9266.75788264734, 13588.1584703975, 237202.364666825, 673.529729328414, 750.451299329575, 380.817770655907, 4584.07202103273, 1202.36570763939, 36982.9849286861, 37270.8763732936, 171453.342486433, 180982.654921674, 178814.224716204, 181549.790971688, 178060.794187786, 4370.23908434504, 91.086517100784, 275347.511443646, 238021.43882547, 230194.917036258, 255679.418783303, 240416.133844853, 239406.96842747, 233490.562834287, 13118.4601440688, 20525.4723901523, 9285.51618788548, 42627.5916110602, 7739.67837408516, 4410.00906559181, 725.818744960656, 939.647131209686, 765.476897764711, 8626.45604445888, 1688.29553354156, 1975.05793765033, 1194.04726589195, 14210.5988219155, 37448.7667123955, 7705.74782093902, 77917.4429403135, 6385.5824187003, 96089.3557994501, 25602.4431327038, 23539.5670106811, 6793.18402412188, 5867.00805194317, 7566.06670727191, 8169.34831789374, 82491.6656677962, 71435.5244830683, 45913.8386339752, 660.055895792075, 352.772141928919, 78455.7258409915, 398.206028873267, 100.68216531975, 9992.52258780041, 37747.4208313322, 101736.30515122, 32196.9461284633, 17760.0525342547, 17121.5033888706, 160643.670472682, 16610.1728833531, 278.279535708356, 1308.32622263296, 1628.84767454926, 2942.2403187696, 3110.78916261453, 16075.2328033676, 27043.3178229638, 29542.1949442316, 96955.47925898, 380.817770655907, 17531.3583382672, 1329.27142055167, 134512.542346674, 233608.307509304, 31583.9978853253, 27518.8095190818, 36982.9849286861, 37270.8763732936, 1078.62984126406, 16075.2328033676, 1557.6867303227, 2450.35892059889, 281327.340620044, 193313.201810195, 232211.756994791, 230660.121782087, 234930.942138222, 4225.2500902214, 22813.2525009148, 40474.8597658331, 86426.4838683616, 88181.1992926501, 62501.6072438189, 57650.9909185965, 28531.2738023954, 29956.0676611137, 93823.9796754645, 27730.8572210472, 2703.08752928773, 105.693385458349, 26741.0541995313, 695.169633237237, 16317.4028086314, 14039.6388820606, 26701.4190678963, 22894.1103922164, 28985.5252124698, 28156.0515117744, 49966.9721468302, 78664.8164840113, 59139.5031721197, 128751.021251182, 50718.604189973, 380.817770655907, 2397.1915239389, 2344.98528554926, 2483.35305557812, 2264.26100331203, 139504.768993676, 140004.655474789, 139927.353754815, 25858.2380340544, 90336.8654554026, 25240.1118158957, 25207.9947192023, 25235.5891860891, 1341.00512831835, 14968.467622857, 49163.2804713073, 3059.16196765479, 54677.9997597398, 5018.29767759857, 21771.176148186, 4410.78701217527, 5380.25524457574, 4001.95870596901, 4357.62032237333, 5450.36303956975, 50129.3931508622, 14078.7204502843, 16075.2328033676, 6398.57709456943, 1099.6673727305, 4001.95870596901, 4357.62032237333, 3458.38954358547, 8493.29953169363, 5062.8176967768, 5418.47931318111, 16075.2328033676, 325.395515385831, 279438.403828231, 271112.838479157, 51414.605623425, 17459.3515880078, 19183.2589685416, 31135.1471404672, 391.531497495759, 19253.1019211351, 20447.0492091971, 28455.4110235471, 27269.4755077968, 12623.0745498007, 21083.635210871, 18540.7302535468, 280.134468434726, 16075.2328033676, 1357.10024634827, 1968.04026606545, 3497.31873123448, 2384.43768404876, 2607.68899854945, 34.6954117674916, 767.659794592033, 1454.77456326011, 36543.8887596343, 36583.5533683327, 310.668149357043, 399.82218095601, 20009.0143245189, 19083.522147641, 5053.3108516892, 2449.46742349704, 319255.172571199, 184439.028900337, 242184.066183914, 235115.320161566, 230930.673381153, 535.778320926114, 35.9876265013509, 430.335507715417, 22787.0699452251, 23333.7545917633, 40870.8237924635, 21594.8765408694, 91206.3946199314, 165460.102428689, 717.569675351082, 69680.1458886543, 50012.0532283119, 132.977985957547, 155.61043086903, 7968.3667179753, 2759.88560762792, 4674.93557244953, 3821.26931244109, 4.0147088005624, 7455.99962833527, 702.361440439901, 339.146718546778, 105980.520829246, 109858.846100058, 107643.993007288, 36982.9849286861, 37270.8763732936, 15256.1224959738, 725.818744960656, 9371.03607725115, 4711.01965979307, 34801.2723961633, 37123.8656276483, 10199.8134264271, 10775.7313088592, 10953.2065447233, 6028.00910412306, 1749.30945917116, 15675.9220839932, 45013.5122669696, 48157.8853870911, 16075.2328033676, 1864.15501149668, 1856.15162274216, 510.120838501591, 655.264908624581, 92691.4907122201, 147170.027234413, 31292.44159377, 23433.6504244665, 113071.303501863, 8181.76116749004, 16075.2328033676, 3388.27241745633, 11291.502124949, 8679.50689627454, 55.8837027444483, 121093.186968869, 939.647131209686, 765.476897764711, 3198.20199161574, 3951.35973793132, 135761.075287953, 136723.069366879, 144841.845131643, 141034.997281013, 130266.090193727, 130188.919735676, 139132.871461069, 380.817770655907, 4813.74181396923, 4743.58205483113, 1012.70680144016, 175.594808747193, 36982.9849286861, 37270.8763732936, 168208.840573889, 147190.164177003, 148212.477244877, 148458.7280231, 159353.185217315, 32906.2800262623, 40845.1966536895, 73160.1313106901, 1995.86933921473, 1025.64438283859, 851.474149393614, 85306.609714591, 70983.8016515822, 40695.0041574183, 40466.2413954362, 68130.4544323033, 68418.3458769108, 393.699749077506, 1012.26298607815, 4731.78293409963, 31774.4902415177, 71647.6427588647, 70097.71067712, 70469.2618514713, 37486.7118997562, 171413.704265743, 151745.6116054, 138356.801368377, 920.407564194793, 19599.5049812013, 34284.6479516653, 27916.9085030979, 28803.4365189405, 1045.5533374472, 1318.62441049618, 3426.43064748071, 128.982132604223, 340.626764458901, 1026.79406986596, 157.027209680212, 161.268125082424, 2701.71742783336, 117.070421964727, 3728.49898930883, 4040.8154131577, 4450.2406256717, 17409.6173675702, 3717.78716509019, 4063.05589236591, 10775.0131033758, 22813.2525009147, 40474.8597658331, 16075.2328033676, 3207.46123908132, 82675.3280843882, 112356.656732258, 2485.86660075211, 20952.2342784042, 35677.4640734851, 21348.2562860603, 4001.95870596901, 4357.62032237333, 38935.1458043805, 1016.51998726852, 798.748861134099, 323683.987716352, 318156.227938829, 28339.256483771, 15943.4199855454, 31183.4787493196, 14199.1748165144, 83042.1218178583, 130041.067220677, 1136.12668812851, 34426.3466428419, 61517.3288034213, 86004.3091028183, 47568.1690686503, 50432.5379734911, 15342.5234582297, 19337.8582553017, 60772.3850189886, 61770.5599913795, 1137.49587921006, 166057.65637755, 127618.336774358, 117884.785477071, 146389.563717207, 118226.610347435, 398.206028873267, 100.68216531975, 19206.463182029, 35451.3141808197, 295.557739471973, 897.685180032961, 721.525209319147, 939.647131209686, 765.476897764711, 285.186697280334, 866.332228040084, 252243.8534938, 1682.79562704932, 6493.96147313932, 1788.77444134187, 52335.981461527, 63571.5935003966, 55150.6945182499, 80384.3104669429, 69328.1692822149, 43806.4834331219, 20857.0456831285, 20538.6434794356, 81391.137415594, 11892.0953620346, 38914.1648793721, 44359.7426141151, 44894.4550075772, 425.115713495468, 14842.1423342692, 15063.1711211095, 2231.51561544093, 2616.56597096564, 2212.30926121041, 13191.5326659212, 49638.9563294436, 49571.1466593579, 5150.24606460881, 83657.8126353491, 81537.3534929819, 69633.3320243936, 85198.5936046321, 4798.77831912178, 3865.00514835965, 3160.50266435749, 93823.9796754645, 14327.0287101337, 74790.1497815539, 95450.6663381779, 755.991338885107, 10133.1291972557, 20771.436539465, 658.254210804327, 332.493226043116, 657.149073893211, 13724.3172928578, 13394.1301240815, 4778.87249697422, 12432.5515288051, 17355.684948379, 1407.80512308991, 3437.68750995873, 2202.60181343423, 11439.9300833991, 5333.09206265909, 1599.3869916106, 2758.18862301036, 1392.09010470108, 1971.59361415747, 1378.34518415157, 56386.929634131, 5353.89665200737, 4952.03958673414, 1831.47566791697, 5545.28368568372, 1768.85651295976, 38914.1648793721, 19337.8582553017, 232049.012193554, 46680.1420720144, 6733.61702247019, 3853.22007475944, 7733.63224014875, 55323.1355172148, 54669.6902770064, 25774.7857616865, 21597.6745934459, 58202.5831622546, 53127.006958253, 52932.0221893414, 53871.6761079763, 51967.8338189857, 46675.3178998997, 26782.8703268322, 1642.35988002281, 2336.06207183404, 443.860547994243, 473.357694963146, 47043.6616486465, 47611.5295745131, 47605.6624493885, 18714.20491939, 9549.25372502526, 257674.234463488, 220769.651459018, 238006.141803145, 224289.372539534, 221213.569663917, 221553.218194958, 220777.265383134, 63571.5935003966, 55150.6945182499, 16075.2328033676, 772.453802510686, 9012.86328398216, 2583.66951743621, 5138.89803014853, 28198.2585910473, 59061.0545275746, 120054.805942784, 103890.990012608, 6899.38368185746, 332.159111249946, 629.80901643584, 3324.47238959684, 3474.36412593445, 3325.97529436234, 29956.0676611137, 158973.75352684, 86615.8411098735, 1819.45503639136, 1255.16147518468, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 48078.2223560868, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 3512.42742939842, 3460.80733569178, 1145.28232292708, 5231.3367663647, 2512.33447107199, 483.589658631647, 106696.616230223, 24250.9221492419, 177185.290054521, 118052.585799378, 28.5425439295029, 737.564022643526, 156238.856010443, 34543.5899395263, 1890.67553766047, 2486.79016761023, 22805.1255924323, 22312.6354824548, 16518.7357173295, 6297.79040106472, 14858.524373798, 24540.0143423049, 4587.48300333325, 66861.2168126171, 62720.6024926429, 36982.9849286861, 37270.8763732936, 38939.2587377148, 729.354851039592, 184.000187015484, 939.647131209686, 765.476897764711, 11622.8028157919, 11001.9558233294, 11756.6585407591, 32746.4013585763, 48.8008458005068, 3937.36518643355, 862.231107428001, 28302.2040977211, 16075.2328033676, 53888.4017277723, 23849.5838366764, 23677.8993352517, 1864.15501149668, 328396.884082538, 11480.9074448348, 10924.4086338472, 11644.5410383496, 11736.8142665813, 104160.939539591, 102678.646139363, 440.470022016028, 18568.1596719813, 19451.8075120553, 8721.88116019096, 73147.6968452376, 33235.9992509206, 16075.2328033676, 32939.1179965398, 108.565643610233, 10550.6129336412, 7840.44631431687, 1263.1643682619, 73574.9552922195, 80804.3798125565, 118584.696360625, 127099.854015622, 27176.8637620037, 52739.2996908568, 26212.6753916479, 20164.6291378281, 20854.1536339702, 30071.1111325631, 29956.0676611137, 8932.77337314584, 12625.6870250925, 11116.6250555199, 21753.3728657946, 33984.1805374808, 8640.22393773386, 11176.5403902686, 8992.56876468488, 64526.6793512113, 270.068378267097, 267.476421852968, 19337.8582553017, 7586.91289307513, 27553.3069860754, 29965.0801514649, 1239.65193701848, 413.190657949767, 978.71221126869, 18.5168467750464, 398.206028873267, 100.68216531975, 22253.6468313205, 74030.6681347378, 69403.620911367, 69789.8689264969, 69422.7880887933, 16075.2328033676, 25409.6463701444, 398.206028873267, 100.68216531975, 3982.1203751288, 4636.76121086711, 10410.2631801306, 398.206028873267, 100.68216531975, 22184.4067936007, 110342.32665522, 95203.5548289876, 27373.1106670363, 77877.4115207514, 93823.9796754645, 11842.971473125, 11707.8041678742, 5748.04151633014, 285189.215698423, 73821.8700898538, 27954.93493759, 26584.4682526731, 56610.9515103374, 124431.733362197, 415.607179265534, 495.272915719861, 36982.9849286861, 37270.8763732936, 19337.8582553017, 36982.9849286861, 37270.8763732936, 380.817770655907, 55.8837027444483, 132.977985957547, 155.61043086903, 43649.624417983, 16075.2328033676, 961.861785584727, 5597.280003844, 4678.92253836042, 47568.1690686503, 50432.5379734911, 83029.1669279268, 95094.6572229366, 9741.57702610377, 9779.83855110139, 3728.49898930883, 4040.8154131577, 230135.047802112, 122936.554992342, 223256.461712986, 29956.0676611137, 2392.00795540349, 49953.9392123424, 398.206028873267, 100.68216531975, 66992.7277657802, 66596.7972390104, 68168.7786558277, 128386.960053394, 1780.62200017467, 52.1147236033839, 16859.8644956567, 17496.7639549616, 119414.658540385, 1856.15162274216, 7754.2166880541, 17218.1605619245, 44319.2154579291, 2929.1081836126, 8223.61511468137, 4451.11073633154, 38914.1648793721, 477.596911918156, 8803.21349694727, 7284.46241236863, 19295.6056141802, 16613.6068234123, 4456.94251146803, 31789.1416899254, 36982.9849286861, 37270.8763732936, 14078.7204502843, 1928.23454357027, 1231.16655235924, 16075.2328033676, 220192.874320162, 204133.696982147, 251091.628283208, 152274.763615202, 16075.2328033676, 53606.3301405669, 21207.9320627651, 68051.499554735, 67923.9392046879, 52870.3111946252, 206.154152085621, 408.092676066718, 4001.95870596901, 4357.62032237333, 2011.28400338239, 2261.5137632157, 20858.2253250677, 17196.7691208272, 12071.8264596814, 11701.1411206487, 867.166243311043, 3458.38954358547, 351.345341301677, 153356.110916474, 22813.2525009148, 40474.8597658332, 18315.6533239007, 17029.3693708741, 42388.2283403157, 66826.5129661575, 67114.404410765, 42296.451074553, 28640.5753295946, 29956.0676611137, 32.4838157011955, 101.282085562321, 4395.0203016827, 4481.28561559065, 540.985235007729, 1933.28236559719, 30269.523100005, 168696.627923435, 152236.170360321, 60386.3015054734, 52730.9188373698, 51927.4381613156, 68174.7441609302, 798.804622173317, 6449.61153526057, 5370.80498146574, 86650.9226943559, 54999.0958491387, 3561.18291966679, 9178.51413380821, 237100.045987053, 29557.5889194877, 43314.9778025088, 43590.0676505746, 4378.93298927904, 3352.31421364895, 2774.88743029247, 178461.58508381, 246313.464076537, 144991.187178217, 163550.976992066, 16075.2328033676, 32892.5474808613, 4132.12115017082, 4515.2947073061, 5108.93782367102, 36982.9849286861, 37270.8763732936, 74468.5859618556, 28584.545558594, 66700.1273913682, 65625.8490983899, 67086.3754064981, 66719.2945687944, 8218.8949162851, 8589.47030849911, 1178.21881730436, 99062.946014098, 105922.540650494, 38167.2184169388, 740.81608388202, 1427.93085255009, 2131.19285257208, 35961.9454024408, 38332.5564557414, 122061.849538996, 13242.7910481202, 12385.4157762241, 1365.95281001545, 14339.7917154465, 26713.2112833007, 93823.9796754645, 555.741511949935, 6650.5886148253, 32576.2307681397, 34705.2747451035, 32064.3731245469, 29694.8039707669, 16756.8050072887, 55.8837027444483, 136.012689198563, 72291.0435256734, 9478.46506076345, 51231.6252950158, 11019.6516218576, 11778.0057784129, 5141.8542231074, 3500.34949383662, 255.167752297303, 303.185109429245, 1016.51998726852, 798.748861134099, 44731.0118383221, 398.206028873267, 100.68216531975, 2945.74692998072, 1048.45825736338, 10458.2880127193, 495.109220548874, 877.442078240008, 38926.4297052914, 33214.1828464695, 7293.87092054278, 5698.05558360908, 26401.2989429442, 26963.2799974193, 9168.52938188143, 9832.01212558409, 10668.6147638799, 180.99792663902, 269.188167635067, 29956.0676611137, 62741.3839259554, 52087.5279870074, 3851.42221972128, 3803.87898078531, 166324.579310837, 158612.457236003, 154447.757569387, 93823.9796754645, 375.937084316765, 118313.658165824, 118805.127072064, 36814.569081055, 7990.72085763061, 38347.7335392009, 38959.0761234368, 125683.827681048, 107095.979759967, 243.104120249027, 12302.3531220727, 5805.7552485181, 11761.395157269, 20067.328155064, 35197.3964407018, 69017.0219778135, 6464.55631765154, 28189.7031400417, 398.206028873267, 100.68216531975, 160778.182886648, 36982.9849286861, 37270.8763732936, 40977.6613041572, 213036.979822553, 215036.413815993, 212669.383374808, 16075.2328033676, 43340.9753735391, 132419.81778611, 43837.6314432124, 43727.223388669, 43628.8668181466, 22813.2525009148, 40474.8597658331, 28160.3217809971, 38914.1648793721, 93823.9796754645, 98196.3912344689, 97283.3242662565, 97655.0224922222, 97256.5210771937, 2138.91017153203, 1431.4891467075, 30707.089768846, 30044.6726803036, 1670.90825812584, 29775.202420328, 30251.7982683868, 28960.9638178327, 11300.1962570989, 3174.46797624638, 9724.70541100056, 37304.5884083199, 4876.66153657707, 2455.83738444178, 4444.84345494065, 2092.69534033236, 3623.0346757757, 5108.62288363487, 11183.9606405955, 2822.19973006158, 4643.29532605212, 3860.1192477922, 27521.8394755346, 26051.304617139, 26152.3595555139, 100461.304463427, 83656.6168482166, 83804.7456129746, 72755.2198945888, 369408.822714257, 106554.917450298, 99638.6705090273, 96480.0565299285, 94166.6919905132, 96445.3263429557, 9312.405679006, 8859.7508799319, 27043.3178229638, 29542.1949442316, 1159.39832105123, 20276.5594159805, 7469.23445983926, 7787.49016938389, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 34003.0085945981, 21548.5729396758, 29956.0676611137, 28540.8428590215, 16075.2328033676, 77260.8345026832, 43488.2621968957, 29522.3183736751, 89.9569446043147, 4839.14892098163, 9650.31476707163, 4877.22240022633, 16075.2328033676, 7196.86844852712, 11109.7776753418, 22563.3805993621, 18962.7233400404, 7754.2166880541, 86165.4982332778, 1231.16655235924, 498.032302607833, 18299.5904242773, 25034.1244607342, 16075.2328033676, 16075.2328033676, 93823.9796754645, 16075.2328033676, 20199.8653061975, 20766.6411733941, 3694.38265862053, 119677.424911163, 105166.107739926, 78945.9837070858, 100009.332250821, 117890.890949383, 1100.884361502, 82.9043492013425, 535.778320926114, 35.9876265013509, 430.335507715417, 5479.33083317554, 63182.0812359504, 53624.7526156921, 64369.4892684073, 63577.2693609814, 66225.2499473749, 63614.4531146632, 63311.4090585021, 62562.7066770045, 128108.777727574, 24306.6479322646, 84822.1037817399, 74683.8236007068, 55797.7281025465, 667.663331675873, 566.070592134515, 681.437660722141, 136.012689198563, 16075.2328033676, 535.778320926114, 35.9876265013509, 430.335507715417, 72871.9943619608, 83390.5954741451, 5795.17915503766, 5843.32343266549, 23504.9306975839, 36982.9849286861, 37270.8763732936, 66098.4377721652, 1218.91076084671, 1411.71988185387, 41062.5330227848, 39931.5015580468, 39736.4766076507, 549.063997098806, 652.751602666035, 22813.2525009148, 40474.8597658331, 4367.31954792604, 4930.99030673717, 71661.0099604287, 45352.5691232179, 71425.6082962722, 63014.1763881363, 19324.8316804376, 19177.9684975482, 15901.6697637082, 15531.0667177567, 16075.2328033676, 16075.2328033676, 8502.86451795858, 1093.54686539122, 1100.89413649991, 4001.95870596901, 4357.62032237333, 380.817770655907, 27606.952970971, 45268.5602358894, 4875.53260631106, 4941.14671351242, 3150.02784665134, 106732.305688204, 91593.5338619723, 23763.0897000209, 331.153967486099, 11449.0158977434, 20813.3613722516, 58231.1857382934, 16075.2328033676, 835.731956140006, 1800.37822857719, 2133.40385546957, 36982.9849286861, 37270.8763732936, 16075.2328033676, 55742.3297993423, 54371.8631144254, 54477.5894838714, 53407.6747440697, 89.5642629285433, 47176.7730918181, 76280.6234114066, 27644.9082959893, 43401.2179352058, 42840.3001586238, 27094.7811057512, 872.327715142949, 608.318066899785, 16562.5015385432, 17321.0487098954, 7428.22484257609, 2209.8748039488, 1422.13950075631, 31523.9024435696, 32451.6048491967, 5126.18108774528, 22067.9693590987, 45833.2125791698, 339.948028851695, 211.226587005609, 46.209827408157, 3259.37751534839, 3037.53136499794, 285.186697280334, 866.332228040084, 15390.7059402213, 16593.3348817745, 48099.3492175414, 47382.0518273948, 1856.15162274216, 56.6741615112974, 38914.1648793721, 153175.665720884, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 228497.157313014, 260395.420495062, 208829.064652672, 219724.841232807, 193316.779432647, 189448.522583072, 192073.194864602, 194792.188100969, 22826.0787616213, 23545.3239738635, 55643.3918320751, 56029.639847205, 55662.5590095013, 391.531497495759, 41156.0961016767, 34958.5660523626, 63571.5935003966, 55150.6945182499, 26625.2082169048, 21999.1136834948, 20096.4211341093, 40891.1266219106, 667.663331675873, 566.070592134515, 16075.2328033676, 380.817770655907, 1638.53718781816, 144340.32689255, 61.9612772475439, 25409.6463701444, 238.643375961542, 917.597140387829, 664.210333954798, 85306.609714591, 10518.0894058091, 9065.63656594689, 42627.5916110602, 5308.60751905176, 7289.60074149418, 16075.2328033676, 58396.693930892, 55742.7466511462, 58245.5098244713, 61112.862100091, 59099.6132991567, 57887.253693528, 14586.1538443507, 139143.986637563, 118421.259283757, 106868.836117193, 91730.0642909614, 23899.62012901, 3024.31927727499, 55.8837027444483, 36982.9849286861, 37270.8763732936, 29669.9645748836, 47331.571839802, 109912.650332277, 121349.198391742, 124097.79014024, 118622.138491988, 112162.639306095, 121696.055690289, 123945.264355126, 1101.61776395545, 217.618004090373, 16075.2328033676, 52925.0539860187, 63571.5935003966, 55150.6945182499, 176.268750462866, 243.20823442136, 1976.90383199459, 35.0865110138648, 75181.7586486951, 139592.012014578, 24100.3624590957, 45181.7850410994, 19866.2368414547, 63907.9429491576, 53895.4569593283, 93823.9796754645, 51231.6252950158, 55123.3430573867, 58929.6331776818, 73192.177715379, 63491.9188419491, 59303.7549805591, 42627.5916110602, 7754.2166880541, 9624.19372876316, 9934.5368861168, 533.619117723752, 879.315985303013, 46760.0770500529, 23920.8005906146, 9243.89580631412, 93244.4542949474, 1768.42693600648, 1673.15569756699, 327.12927956425, 249163.152060474, 247547.68281435, 1610.69474359452, 38914.1648793721, 2046.53027672405, 1786.1827415674, 16075.2328033676, 1402.45218694316, 92165.1972438328, 1856.15162274216, 1231.16655235924, 49247.5386006396, 66623.3263215092, 67009.5743366391, 66911.2177661167, 66642.4934989355, 35109.9643505284, 4670.30837088028, 5658.28656141349, 5421.0217426154, 8168.02256937761, 38914.1648793721, 11893.7754211391, 4878.39575500131, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 2545.07588361373, 64868.2813173423, 65254.5293324721, 70202.508314965, 64887.4484947685, 16075.2328033676, 28584.545558594, 80119.892248356, 58499.4282996651, 17075.9169465509, 237125.677483749, 237134.17643505, 93823.9796754645, 31658.6600459411, 195.323738534107, 767.659794592033, 1454.77456326011, 60633.7780641082, 94824.880499618, 36982.9849286861, 37270.8763732936, 5630.97567777431, 1299.01867406935, 2286.11600791397, 2.4178226631966, 4620.43191662203, 4658.50539586673, 37448.7667123955, 5397.8312948193, 3674.87305852762, 82074.8275917156, 50488.9949161109, 47012.8068864268, 918.776377590654, 40507.8651110939, 33866.070855116, 37151.1548701137, 435.900568148822, 721.123002275422, 767.659794592033, 1454.77456326011, 230904.47383181, 34388.3616040603, 17507.825451943, 66574.8344085083, 398.206028873267, 100.68216531975, 254.837161067371, 576.265678320261, 163264.371825029, 179202.377100171, 116139.878870469, 26494.0099165712, 26.5363792937224, 18.026444278936, 8923.40745961544, 6985.30186972248, 17409.6173675702, 29956.0676611137, 171116.280932735, 159870.856751758, 170736.493389948, 149522.734135947, 156878.738870589, 10099.2008577312, 7469.23445983926, 7787.49016938389, 6754.68935613241, 6908.82616123102, 51617.6389267273, 50854.0648759946, 37319.9539963416, 36245.6757033634, 29956.0676611137, 44359.7426141151, 7581.93672061524, 5620.36374969393, 99754.157209946, 14602.8708667173, 19929.5133488795, 20735.7225129209, 24299.3370425168, 23524.5563114389, 36982.9849286861, 37270.8763732936, 286.068856495644, 834.446899471087, 11872.1933835487, 19256.2755946225, 587.766327283126, 1996.24460234267, 3199.28902086768, 9574.51635048763, 1171.8054635435, 29411.437827574, 7106.27431670089, 2097.682220922, 43235.7700779993, 28455.4110235471, 27269.4755077968, 3493.50637672112, 12487.3443239224, 398.206028873267, 100.68216531975, 93823.9796754645, 99756.3375058523, 130976.562756222, 41189.7150501499, 18929.5952628399, 1087.70835429531, 721.058349777034, 5029.63437049367, 1900.06810726137, 25049.627273546, 4447.11120144908, 1727.72416526678, 22743.4247788849, 40405.0320438033, 175.136282586812, 47.7456844018575, 28417.3245964757, 27353.516982086, 255884.112254504, 10433.5982951895, 25201.5539416446, 45688.1639062682, 36982.9849286861, 37270.8763732936, 277231.411518839, 65607.0520026663, 62720.6255572376, 53738.7497822166, 54369.9510409571, 130335.583111574, 125806.494053543, 141617.038586447, 535.778320926114, 35.9876265013509, 430.335507715417, 6754.68935613241, 6908.82616123102, 1672.00867923511, 43771.8485082078, 50377.3519203139, 121.620466588186, 5.78559118236115, 5691.5061155477, 25384.8260600771, 20825.031871937, 153175.665720884, 48907.1553316673, 754.627988949509, 4252.54127455885, 15706.1441985791, 87.5163918835083, 2206.90587083411, 222.880409948057, 30.0005819966535, 1674.08690328263, 38914.1648793721, 11052.3393942254, 4543.005008474, 555.275920776254, 270.96460938422, 1034.82901258292, 2036.14425736038, 1767.80822129169, 80768.7316854617, 28008.3262703835, 27904.8231701388, 16186.1343511794, 17741.9130522031, 1903.86934216233, 1384.90171061541, 3509.61610499153, 13945.9096079774, 67157.1207337701, 35237.6641008416, 43296.7793675834, 31617.7205653819, 4620.43191662203, 4658.50539586673, 45958.8346971516, 28066.8827334793, 1864.15501149668, 47836.612387009, 110782.106638406, 130224.534369226, 62307.6027350854, 5658.79285262421, 28502.9484160247, 27538.760045669, 1033.17261861494, 22813.2525009147, 40474.8597658331, 17621.7238633249, 79536.9538833319, 25179.0471019252, 398.206028873267, 100.68216531975, 28976.2676834887, 28166.0723855865, 58202.5831622546, 53127.006958253, 52932.0221893414, 53871.6761079763, 51967.8338189857, 29956.0676611137, 16075.2328033676, 1095.41945808009, 2304.44074710294, 36982.9849286861, 37270.8763732936, 4625.80289778272, 5253.58526310596, 2323.59621079507, 2048.52429989438, 11186.9566499969, 8091.48421425972, 38914.1648793721, 26559.1413688833, 380.817770655907, 133.120757649818, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 32347.2718172153, 31002.7634530744, 26639.1363948513, 1433.91241379757, 238569.248457425, 237144.77269482, 59942.9622766307, 55432.243407773, 62392.3192876418, 68863.3842322664, 105706.850525992, 118048.56672932, 3242.22794725051, 102.369921957763, 1542.34645833776, 1746.13633341972, 46189.7135263213, 63851.3207912397, 61480.3822304936, 383.711111787794, 12020.8302093121, 9408.63239350525, 78.1070038380331, 8299.68824474346, 8310.03474851691, 7008.55659906482, 151524.773091869, 243581.381960474, 247895.846444488, 391.531497495759, 3430.7598255303, 28502.9484160247, 27538.760045669, 74468.5859618555, 7727.23206442239, 68977.2139495376, 94216.1806078267, 95194.2004036776, 94967.0488846865, 380.817770655907, 248.922147697544, 872.327715142949, 608.318066899785, 5161.61681901106, 38205.0155408299, 14602.1489954547, 64087.9132179879, 12395.6682257128, 1768.91135350572, 2271.62996430812, 15575.3223976788, 285.994060753664, 71.1323003867875, 1783.16899601624, 2150.05803676888, 783.959518459601, 1363.46302791599, 20917.4844765944, 16315.2806152032, 8951.28583145258, 9130.49983677968, 7806.09391877893, 47836.612387009, 12517.8741209665, 96917.5398443538, 213084.716335962, 193416.62367562, 92919.8781575055, 89642.8197431693, 2051.05624585199, 42956.1390872883, 1078.62984126406, 73821.8700898538, 1856.15162274216, 2563.1074598093, 255.167752297303, 303.185109429245, 25858.2380340544, 54307.6664177307, 5875.95859899081, 5483.60906659406, 279628.252534697, 54829.6882704827, 120793.840012926, 121131.991572028, 122629.779750089, 22408.8727453804, 65800.2315730235, 67929.0948759319, 67474.7734816325, 17930.2190322633, 97846.0685297032, 83334.7513584655, 57114.6273256259, 78177.9758693609, 7586.91289307513, 420.967108144375, 117.803755443702, 22920.7766693053, 23741.0174462689, 13737.5114403796, 7627.92773038078, 122349.600808082, 32517.9015272171, 14341.4943065494, 17142.9272258843, 5022.89768041547, 8456.52638108484, 9786.46687667817, 1688.03628125613, 16075.2328033676, 36982.9849286861, 37270.8763732936, 20311.5491798028, 21516.9834555472, 1856.15162274216, 28498.1520801969, 7547.82025143785, 5645.95005115515, 6674.97302012422, 24336.5802850426, 7754.2166880541, 4514.90278310999, 78747.2746131727, 5530.49568266906, 8528.8747078562, 160901.046910527, 35879.0659195975, 36236.2647492248, 31808.1449901829, 38708.1648904298, 81011.9220765783, 46731.2137447322, 46541.4072626686, 63459.0467461882, 55777.3672843489, 5982.74873237347, 1348.26163508099, 1086.77552713723, 51231.6252950158, 55.8837027444483, 7127.91438904955, 2592.31169468748, 1048.24900217218, 10352.2306996201, 12714.4263922068, 13472.3401261599, 14535.3583793085, 541.407831196675, 1066.08742571835, 1012.70680144016, 175.594808747193, 1802.66874201853, 82.3298527478109, 31243.7614307744, 13229.4405478549, 44307.2836741281, 10.044201413172, 654.459849470721, 346.814019571169, 398.206028873267, 100.68216531975, 178.954177016128, 14790.0611965957, 55486.6741746049, 47.2174890217402, 9179.4351480092, 65457.6602244695, 2299.84555461337, 2928.48842594646, 1070.08361704373, 3054.56302635544, 4001.95870596901, 4357.62032237333, 16075.2328033676, 1353.89143655304, 380.817770655907, 39931.5015580468, 39736.4766076507, 32399.4600761342, 9197.53079946483, 55571.3711013698, 2176.68588078401, 2187.40657468509, 85306.609714591, 85306.609714591, 5811.28951558421, 2989.49900525221, 1231.16655235924, 3183.81482057256, 106831.806066361, 91693.0342401289, 23862.5900781775, 28502.9484160247, 27538.760045669, 50963.1512918397, 2436.08538779163, 380.817770655907, 16075.2328033676, 36982.9849286861, 37270.8763732936, 31461.5587619452, 31289.8742605205, 398.206028873267, 100.68216531975, 23757.4920400213, 25497.1470845492, 24806.0611290043, 6493.09075010516, 3484.56884695857, 7131.92891981638, 16075.2328033676, 16075.2328033676, 104160.939539591, 102678.646139363, 23946.8389058222, 20276.7409593331, 22922.2827983634, 20994.9435986893, 60957.784397762, 57146.3772470326, 4778.87249697422, 12432.5515288051, 31962.2079559857, 32021.1291877723, 315067.210666715, 260427.844781155, 306906.191575696, 186045.675088336, 258977.602502788, 21986.4714645596, 256812.369167763, 257982.508237635, 636.036393543407, 17972.6855031129, 16791.9911151664, 85306.609714591, 30352.1309994727, 90693.0465954338, 89651.9124212558, 1261.03329977177, 1871.26483497435, 2346.16862529863, 11619.4964391403, 9771.9812534022, 2047.73532763217, 2233.44065568295, 44336.6887900763, 18514.2329331437, 4409.13268462648, 6674.97302012422, 24336.5802850426, 1230.13346044966, 265120.047393954, 82491.6656677962, 71435.5244830683, 45913.8386339752, 51231.6252950158, 93823.9796754645, 398.206028873267, 100.68216531975, 398.206028873267, 100.68216531975, 48657.7429639708, 100891.27890436, 44072.1397129197, 43842.8689971565, 16075.2328033676, 38914.1648793721, 3890.12374743093, 4415.65612589814, 702.693077636257, 398.206028873267, 100.68216531975, 3435.7192466424, 28047.9809374163, 17305.6483936032, 28498.8193557754, 22813.2525009148, 40474.8597658331, 26494.8457242074, 17217.6524663527, 6614.39373456904, 134617.014227316, 44785.3149464508, 17085.7283518947, 26608.9077257832, 92667.9047697669, 92596.1105333051, 4456.94251146803, 31789.1416899254, 7466.45745562184, 8746.01114657744, 285.186697280334, 866.332228040084, 7523.75467359141, 20252.1312488726, 7368.00888817486, 14287.7106593756, 26235.5096363837, 28455.4110235471, 27269.4755077968, 1844.86262045265, 22813.2525009148, 40474.8597658331, 31156.6794461303, 44193.9259149793, 52925.0539860187, 24271.1577820147, 19185.2454047654, 36846.8526696838, 63302.9894378959, 90336.8654554026, 1125.75558043054, 5234.81558525457, 7806.09391877893, 31137.3444408677, 58357.3751702975, 55.8837027444483, 14262.8409017637, 14121.0354945135, 398.206028873267, 100.68216531975, 19337.8582553017, 25460.7535157337, 1310.68946687306, 303.599795967471, 329.766921195263, 194.530166047148, 2219.45913011214, 295.557739471973, 897.685180032961, 721.525209319147, 64693.6278446544, 4636.34070922656, 16075.2328033676, 23306.0478587436, 7656.55165555741, 3448.26005818695, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 25858.2380340544, 90336.8654554026, 6754.68935613241, 6908.82616123102, 3991.44182856068, 1811.69695200155, 34787.5720170134, 38343.3725716877, 34166.261403447, 1047.0607552425, 3581.73909557318, 2856.10497721266, 2565.5086618971, 6277.62774791792, 6618.99798969893, 3938.04783467574, 47568.1690686503, 50432.5379734911, 34921.4726431263, 15863.3593214284, 4617.71351581079, 2600.0791643643, 102.369921957763, 1542.34645833776, 1746.13633341972, 25396.2235757651, 27567.8831766306, 7260.59364527129, 5358.58153238528, 55486.6741746049, 38349.0052830687, 64062.6296741307, 36666.7179955784, 37473.892203962, 47516.0344391616, 36571.2190325424, 38914.1648793721, 2315.35038397556, 1631.61256168116, 81391.137415594, 11892.0953620346, 6754.68935613241, 6908.82616123102, 126075.155469166, 135906.496540478, 7106.27431670089, 2097.682220922, 2436.08538779163, 205.948417057369, 130432.774697115, 14339.7917154465, 26713.2112833007, 4390.76783617496, 263561.238016101, 230083.933568153, 268167.95826854, 231717.128271406, 243893.145355759, 230821.690481217, 1783.16899601624, 65457.6602244695, 7727.23206442239, 297.168360244944, 2074.22399407796, 36982.9849286861, 37270.8763732936, 3395.15534625719, 3059.11372822294, 3507.55858405895, 13093.4665420476, 11748.0455877037, 4325.86985206284, 5705.95996433113, 11044.3999836226, 1934.53086569818, 1722.95193193719, 19337.8582553017, 49570.9389593552, 43858.6921005333, 3920.62302333431, 3609.05180340692, 19337.8582553017, 73821.8700898538, 136.012689198563, 21058.5049226077, 38720.112187526, 23046.6385072794, 19014.9399931232, 18607.8321494227, 3419.78018687112, 23103.4588896023, 255.167752297303, 303.185109429245, 135814.880327048, 153982.061403686, 9175.97589707619, 304437.246616294, 301836.88002746, 1633.53274450465, 549.0089786012, 207.140771853515, 174.018472194646, 28584.545558594, 1972.70547004842, 532.791415936042, 701.508516745886, 115.08758967759, 681.437660722141, 3303.03950133616, 555.123316677392, 54892.763855015, 4001.95870596901, 4357.62032237333, 589.617888083756, 252.443324099672, 11235.8851670407, 16075.2328033676, 16075.2328033676, 16075.2328033676, 4001.95870596901, 4357.62032237333, 20454.9841218719, 1622.98227563787, 81642.4741293113, 70586.3329445834, 45064.6470954903, 11624.8096425303, 38846.4546213561, 153175.665720884, 30307.1376419989, 47968.7449069173, 4639.7875754833, 658.254210804327, 8186.05318988863, 104307.808847732, 10387.3191265148, 10018.3913236045, 18361.8951062043, 99227.1545570501, 29956.0676611137, 4370.41398831075, 4123.59534422692, 307.103135136199, 257.12486051682, 584.290103687764, 288.269084397988, 6612.3286381938, 5985.67905110819, 8710.42519742189, 40378.9713946759, 32723.5887265723, 16075.2328033676, 421.887624319924, 506.559115033679, 4966.22289923931, 1638.53718781816, 210.836464885607, 68033.0645622763, 69292.67129079, 106868.836117193, 91730.0642909614, 23899.62012901, 3024.31927727499, 81629.5129446835, 142092.634016104, 162753.150572728, 2545.98300847678, 16075.2328033676, 16075.2328033676, 4456.94251146803, 31789.1416899254, 56033.8084966131, 62462.0415766321, 15218.4902817243, 3285.71466983823, 74468.5859618555, 51231.6252950158, 19337.8582553017, 1231.16655235924, 736.791696610977, 31378.6127368576, 60482.4630564461, 2894.62766262561, 2235.69514894696, 6261.01812659405, 93823.9796754645, 36953.9591885763, 37340.2072037062, 2444.10092824447, 1458.12042605699, 104694.939974305, 237299.900536436, 40321.7854347451, 23298.2022976937, 39646.3077756555, 73067.7254309642, 25208.107262169, 25966.6544335212, 34999.7623329259, 33753.2294143291, 5820.79314720968, 3735.49922529483, 25460.6460476849, 16000.1429240728, 15998.4780911284, 172349.56521573, 170891.21120095, 205736.75199542, 16075.2328033676, 3569.0028071963, 325.395515385831, 2.77197958308759, 43296.7793675834, 31617.7205653819, 115902.297176438, 89988.1933233015, 58999.9631732753, 5134.07365950494, 1484.65328510058, 591.620405798511, 490.027666257153, 697.401439464038, 3568.66913417615, 10.044201413172, 6581.61709283386, 4170.71604329618, 3693.7865087293, 1442.91874787607, 4367.31954792604, 4930.99030673717, 9233.77816243861, 43560.7944431974, 6507.89702022705, 4001.95870596901, 4357.62032237333, 16178.8870682882, 15686.3969583108, 1261.79575722989, 6028.00910412306, 44511.4447671355, 29683.7173256695, 35484.5620254843, 68597.9992780944, 10426.8873529601, 37020.6397654603, 77.3707537622645, 55.8837027444483, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 36442.3317320073, 36481.9963407056, 34939.030789791, 27419.3507289026, 24851.0028842774, 27379.1253218527, 80510.930489027, 79156.5278918394, 43.0151553656216, 30207.0072555867, 1768.91135350572, 2271.62996430812, 132.977985957547, 155.61043086903, 87411.7375683934, 76355.5963836654, 50833.9105345723, 48306.9179112917, 176.268750462866, 398.206028873267, 100.68216531975, 22752.3090216765, 23058.3167971813, 23300.557696648, 6821.82166556698, 24019.4317756876, 136413.865942719, 81410.5529312905, 7505.60147661139, 316.577132124847, 93823.9796754645, 115916.84173754, 132019.937960079, 38914.1648793721, 13165.9593125545, 21471.8923103494, 36601.9605959872, 70421.586133099, 7869.12047293699, 29594.2672953271, 9596.12784255966, 11399.7959052955, 6809.05416385813, 9591.35826972365, 10035.4718182126, 32915.977887227, 36982.9849286861, 37270.8763732936, 296.569905436021, 488.285834127841, 1864.15501149668, 103215.132976722, 106552.092882789, 110354.154193899, 106525.685098375, 16075.2328033676, 84435.5925192723, 44609.5500893131, 37393.0276691912, 141847.531144416, 93823.9796754645, 37314.832589225, 482.566391559476, 17479.9099922143, 19840.7421812646, 9280.62780507779, 16075.2328033676, 74468.5859618555, 59634.7026729572, 10387.3191265148, 10018.3913236045, 18361.8951062043, 383.630968462958, 800.095745716442, 110.415562383299, 637.941993511787, 28502.9484160247, 27538.760045669, 10239.9368180531, 17899.4715149152, 16075.2328033676, 58863.2182431174, 81769.6404993856, 89143.3888064793, 83742.3797913459, 105560.851033052, 103829.497834653, 90064.8534035374, 89585.5403548283, 305800.305590052, 89182.9334679491, 91876.2847379238, 77002.9659546167, 29956.0676611137, 184534.463729755, 17360.0578814746, 12898.2441649326, 16255.4568342977, 307.895791651047, 1220.12815604955, 978.607816810773, 35.8383149928165, 29956.0676611137, 1328.62989932759, 64432.4229786787, 24968.2760237047, 12041.4881604171, 11454.7333159712, 10019.7212538402, 20263.9103429747, 8558.19105389586, 8855.61168483842, 6327.84147656951, 40177.9052149585, 41781.3701831291, 83418.8192650742, 33109.4858524646, 4001.95870596901, 4357.62032237333, 9873.3321925904, 2926.75909982747, 4936.85306638324, 27043.3178229638, 29542.1949442316, 42781.0586961929, 4087.65501966849, 46598.0337570263, 43032.9803767628, 535.778320926114, 35.9876265013509, 430.335507715417, 130.189402367952, 961.861785584727, 17864.9359702411, 3438.32241096177, 2317.52640269231, 3125.21941031963, 660.20539183316, 62787.1680926096, 46622.6436750817, 95275.9911914106, 74.3657790574448, 5811.28951558421, 2989.49900525221, 5127.82600211282, 168870.309634008, 98850.5875765531, 47460.5012459927, 66868.7744471572, 90131.6915198888, 89016.4663850375, 13872.9551283881, 7434.87024499709, 62533.9604411414, 26769.5766718243, 8647.71640569986, 8977.07154078851, 35207.0440759146, 24447.4624165445, 2992.96087966576, 2781.11295895625, 5902.50027377277, 10778.7013389514, 18916.6509294119, 80535.4787699346, 60867.3861095922, 38678.5301605754, 14356.175242238, 53909.823051173, 62853.7747765658, 3430.67735835373, 36178.0668494565, 61586.3847158433, 99350.2687669007, 22114.8511602726, 25842.0470909277, 622.073067702852, 753.719444903435, 964.130924010896, 661.583919873946, 91848.1536132946, 73459.7901994169, 14914.6798502388, 17322.4453683063, 19152.2362677061, 380.817770655907, 66623.3263215092, 67009.5743366391, 66911.2177661167, 66642.4934989355, 33.0671665660525, 832.096764935586, 114753.766119183, 3315.46336139672, 3880.7463376379, 5270.56604325094, 4713.68708235602, 21035.628981403, 23138.5049005746, 42419.3336487257, 99863.4268788019, 91442.5278966552, 94156.427348632, 19097.2832549869, 19129.6610388453, 939.647131209686, 765.476897764711, 11106.7143676761, 398.206028873267, 100.68216531975, 11370.7101112596, 19676.6431090546, 34806.7113946924, 68626.3369318041, 6073.87127164214, 27799.0180940323, 4377.60411656007, 10423.7305013251, 104694.939974305, 237299.900536436, 3263.63297233387, 5040.54247213971, 37547.5249730804, 16075.2328033676, 6930.60204602432, 7439.0042844802, 59139.5031721197, 128751.021251182, 50718.604189973, 29956.0676611137, 64875.5759169255, 95196.2263558234, 2182.70613061986, 2036.38768684149, 2356.64795637566, 2744.57629187324, 126.762004278028, 29956.0676611137, 6939.20572181965, 58366.4745937618, 76028.0818586802, 74379.0516522712, 74797.9912395919, 73657.1432979341, 16075.2328033676, 3352.60118615786, 136.012689198563, 57637.6383901011, 193341.503839374, 173673.411179032, 185233.552202216, 10620.3646514924, 18695.9382758212, 3135.31359591227, 3589.73774977889, 22813.2525009148, 40474.8597658331, 29956.0676611137, 562.926779216062, 1267.79568427121, 196681.404289394, 256868.453972907, 380.817770655907, 380.817770655907, 1612.23030545137, 1345.73185674988, 153360.104562628, 2926.75909982747, 4936.85306638324, 29227.3829487815, 28502.9484160247, 27538.760045669, 439.103320196925, 360.868201708451, 5952.25147718454, 48836.9745640185, 47623.8454132593, 16075.2328033676, 11200.0920698711, 11537.541581756, 68.1580259568495, 1640.6160156088, 802.217931546208, 37786.8318979861, 75656.0402533998, 91746.9688968761, 25012.414809345, 37138.9395129302, 67790.1865473604, 2649.77342104993, 9147.39254916866, 237132.478636854, 64875.5759169255, 46259.1440509615, 72536.1040250482, 55.8837027444483, 46876.7077560506, 17051.6589629261, 55093.2026402961, 49938.1449766135, 45094.3551212362, 16075.2328033676, 115306.387501673, 113147.332367668, 51187.3460429814, 100915.10524652, 54452.5902945465, 68920.538805107, 190000.20413655, 667.663331675873, 566.070592134515, 31461.5587619452, 31289.8742605205, 3990.06404129809, 72495.1459031468, 130593.107095309, 69845.1348485666, 11370.7101112596, 19676.6431090546, 34806.7113946924, 68626.3369318041, 6073.87127164214, 27799.0180940323, 63571.5935003966, 55150.6945182499, 25152.6776613788, 347.866481790658, 317.268927416601, 16075.2328033676, 4553.89061266121, 126740.374786858, 16075.2328033676, 6209.75846218885, 2797.74343680166, 2159.59828758841, 14282.4973541115, 4574.6529366075, 424.040471794759, 50327.4089428095, 4001.95870596901, 4357.62032237333, 202.51101307757, 220.330205787814, 93823.9796754645, 4252.54127455885, 15706.1441985791, 48099.3492175414, 47382.0518273948, 2926.75909982747, 4936.85306638324, 16075.2328033676, 42511.4798772977, 2378.58403439704, 5811.28951558421, 2989.49900525221, 16075.2328033676, 16075.2328033676, 148671.621197123, 143979.51075587, 14174.9809232992, 7939.04181153973, 26749.4502617073, 47415.8404913491, 30412.4948835746, 30327.4452974203, 59083.5034586495, 64674.9041059867, 38943.4952317178, 22562.5882179057, 50595.5259887069, 36982.9849286861, 37270.8763732936, 7660.19468510258, 7311.80747338856, 9321.90143994433, 9633.82596718497, 6642.42274553614, 255.167752297303, 303.185109429245, 5803.88406990719, 5917.35836778104, 51615.9496303433, 12219.7967211982, 11245.7702816191, 10479.5511700781, 2926.75909982747, 4936.85306638324, 3304.52806477955, 10453.3472118105, 9119.28245899499, 36982.9849286861, 37270.8763732936, 72.6702976130466, 153.416421021858, 16075.2328033676, 69727.1437914041, 72636.8549318516, 21481.9635098484, 10717.8083626606, 60712.8918154078, 28729.0319723583, 2011.96785568697, 9724.70541100056, 37304.5884083199, 2682.30812446827, 2743.99077402884, 1970.05326196887, 395016.617123131, 164962.407474513, 167781.552571598, 146374.559553432, 171129.951495004, 55643.3918320751, 56029.639847205, 55662.5590095013, 38914.1648793721, 3999.06909749344, 16075.2328033676, 246384.486141702, 177366.787664082, 250382.316131388, 179103.290927305, 190471.549161498, 429.355853101983, 14078.7204502843, 16002.0696003358, 16464.2410796525, 8400.23524160179, 5481.9595776086, 4274.1517077609, 10986.7200174807, 9905.66385269923, 491.348240069796, 51231.6252950158, 44359.7426141151, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 19758.7264710706, 20723.5978031382, 60739.3138965166, 32121.7239420735, 32504.8974992088, 33098.5406155737, 72378.6888092172, 71982.5736908917, 8106.78705896901, 5718.11933994288, 32939.1179965398, 84408.3953749348, 93698.1911586892, 94493.9707101391, 64620.7112800922, 66475.7050866483, 4118.65334316803, 4986.21725284933, 48480.7161533392, 39042.7643914722, 41350.0545934463, 1386.30925733456, 51895.9151659774, 51704.1854894142, 9179.4351480092, 95199.8923071781, 56275.5602935523, 290.358388108436, 67.4401820459382, 264.052575942059, 24080.848007651, 24075.9333979633, 69587.4355335904, 17749.7801077768, 49994.1077991246, 69956.8068951235, 73304.3508776144, 69097.8655490502, 11368.0286559487, 19673.9616537436, 34804.0299393814, 68623.6554764932, 6071.1898163312, 27796.3366387213, 52763.4597140482, 55938.0066081945, 14368.4656904499, 225433.543635591, 39582.0932379246, 209374.366297575, 256332.297598637, 157515.432930631, 961.861785584727, 663.603344683495, 69253.8053332007, 40642.5968513382, 1949.19317481384, 31612.6887861591, 31348.1837815843, 69865.6884242684, 60156.359713229, 12195.4537414315, 12118.5101717454, 76695.5697286669, 55683.8047195843, 34667.3615668828, 128050.250723273, 4.37967937871167, 536.584879506098, 200.992073274832, 1770.59573685091, 22493.0569156441, 21600.0139422981, 18749.4801010884, 18743.7656847836, 140736.05914757, 28992.6981196871, 46654.3053846055, 45159.3817937931, 11262.8136356408, 1646.45981123884, 1220.60592791059, 23069.067781886, 30767.1895367316, 55.8837027444483, 52478.8273591509, 60457.1501144797, 52819.1935240193, 13756.5852680871, 15883.4728942223, 30359.4245271343, 25215.2529654431, 32916.7044626987, 14876.5924532842, 14901.584999851, 4001.95870596901, 4357.62032237333, 872.613052005574, 69261.7310439592, 31251.428512336, 68491.2606827511, 62609.7038759373, 32184.5277042647, 170362.540883281, 162613.579570104, 90075.4553190617, 91108.4708387229, 88814.3778885529, 88000.4154225475, 69162.1412817252, 90854.156601286, 11312.4587701888, 11312.4587701888, 89653.2722484422, 69985.1795880998, 37603.0787351725, 16562.5015385432, 17321.0487098954, 44359.7426141151, 6921.43133831048, 2908.17596368083, 8213.25332374962, 3047.89269759696, 3003.67881199668, 2886.33588666744, 35491.8340120465, 40531.9929885463, 35247.2213737433, 8898.65451171048, 9132.20251645564, 31461.5587619452, 24212.5676135983, 24456.1166642627, 7733.4953686958, 16458.5311383836, 75284.2707219977, 5497.07375038261, 5784.96519499013, 29956.0676611137, 29612.2252170433, 29120.0878221353, 481.900800644657, 74468.5859618555, 14405.633189575, 15412.3227526475, 21643.1752991883, 2298.08527085467, 3308.1807949903, 45956.0368447762, 41565.0023967078, 2858.43849425123, 69625.3948941499, 52277.7363150475, 22998.7734012423, 23604.0648926775, 53054.5104548328, 50167.2402079459, 42758.0184573737, 52998.7463906577, 52689.1652849954, 256258.749857496, 222178.641090926, 249163.152060474, 247547.68281435, 31461.5587619452, 31289.8742605205, 53416.6234612498, 83680.0257672095, 62668.2607581269, 41651.8176054254, 135034.706761816, 72665.9089813114, 38914.1648793721, 406.794779116554, 6721.78344150969, 6599.31878437766, 2858.43849425123, 2764.86807180389, 1486.56284342968, 1321.75135126949, 65455.4061640212, 11505.9573042442, 20863.9213003772, 13028.2580703671, 12464.6572090722, 18108.7781256232, 34618.095326674, 34681.690130282, 1559.33781898445, 1544.92363164477, 16075.2328033676, 1636.3387577496, 2555.65784578012, 29650.9699561365, 296.755903317293, 3645.42909912761, 28545.3942038442, 4942.83466637713, 3853.08983385917, 63571.5935003966, 55150.6945182499, 538.984594344891, 10035.3588650716, 2608.99318049345, 211.892896013168, 294.015860043821, 114751.970945818, 117212.257063967, 29400.2089112647, 15994.3715995048, 16075.2328033676, 16765.8122075948, 255.167752297303, 303.185109429245, 106657.549863725, 6276.34441010314, 4620.43191662203, 4658.50539586673, 649.005102418596, 5785.30430951132, 1231.16655235924, 11380.3621406997, 55.8837027444483, 7777.50476266292, 65780.1348867323, 58845.6180699846, 59365.9753701421, 62996.8449755952, 380.817770655907, 14356.175242238, 267324.772368295, 268633.672616627, 276127.165575047, 267967.816213292, 28089.1513231524, 27954.001711383, 380.817770655907, 71800.2562246451, 489.632605819653, 138.5791686779, 3990.06404129808, 72495.1459031468, 130593.107095309, 69845.1348485666, 2459.4698424469, 27429.6842304149, 935.422770510184, 1344.59772461172, 60880.450324727, 67121.9510294673, 236993.149088946, 220933.971750931, 267891.903051992, 167244.689634549, 169075.038383986, 38914.1648793721, 3183.81482057256, 4098.79836935454, 1733.19974817627, 11019.6516218576, 11778.0057784129, 5053.3108516892, 2449.46742349704, 19312.6800175784, 36974.2872824968, 2926.75909982747, 4936.85306638324, 974.042978160914, 3448.26005818695, 4184.57195048264, 4517.78668255271, 3883.02488175495, 147650.594664824, 23800.8289709779, 22280.652819167, 39642.4173255453, 35487.6967759046, 4498.00082563288, 31356.4204529837, 1849.76597709868, 879.541020722539, 629.611953387544, 705.370787277563, 140.706750365811, 327.526570181857, 153175.665720884, 93823.9796754645, 71479.4052564091, 10592.5020026709, 5583.90990689204, 130317.581945033, 229684.660134703, 132970.501728025, 102692.989204696, 4570.95812558463, 4001.95870596901, 4357.62032237333, 19337.8582553017, 16075.2328033676, 237797.485436004, 239983.408542474, 94124.890272594, 250969.895889409, 964.847045360815, 91.2202819224776, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 178.938820191222, 27815.5202949085, 28502.9484160247, 27538.760045669, 101631.943312306, 4963.68057724146, 1862.00184914878, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 92995.9508970993, 68350.0517841188, 69038.8927591304, 105196.619615521, 104953.108040162, 16075.2328033676, 16075.2328033676, 658.254210804327, 334.954375624125, 36982.9849286861, 37270.8763732936, 3415.11965402979, 2799.18737511053, 24574.6128487203, 5811.28951558421, 2989.49900525221, 114791.104374954, 16075.2328033676, 773.220682188462, 1063.7569099595, 226424.406742762, 210365.229404747, 257323.160705809, 158506.296037803, 22380.5755503279, 21644.345267442, 24160.9340055678, 24282.0999955729, 24286.9706853765, 380.817770655907, 71665.6108921919, 84237.9700934032, 47102.7677868378, 8902.82169388581, 27485.6837001624, 24205.4975746908, 25782.2634556103, 74468.5859618555, 22939.2979600887, 93823.9796754645, 7542.01256648648, 4001.95870596901, 4357.62032237333, 31832.8298516738, 18418.0651646741, 16075.2328033676, 36982.9849286861, 37270.8763732936, 13920.5653120256, 3183.81482057256, 37290.3236492976, 23962.454844497, 23430.8301114278, 26320.4281350474, 2926.75909982747, 4936.85306638324, 16075.2328033676, 105958.521289132, 93590.7452797079, 5952.25147718454, 69164.9467950069, 63561.5418070576, 14491.361972311, 40768.3219463978, 73198.8232245918, 27377.0545098289, 31645.0104204398, 21883.2883546648, 25714.9181605427, 3734.12031219838, 380.817770655907, 130432.774697115, 16075.2328033676, 42566.7668272763, 14356.175242238, 48333.7512826481, 14397.7228337455, 26532.2080240805, 8034.02760018998, 24477.5239171544, 90335.3011341961, 16075.2328033676, 1581.70244271285, 1588.9903746289, 11370.7101112596, 19676.6431090546, 34806.7113946924, 68626.3369318041, 6073.87127164214, 27799.0180940323, 133560.312973127, 46737.8010136089, 32939.1179965398, 70248.3287512563, 31289.8742605205, 42993.2873688593, 22043.1602748918, 39704.7675398102, 136.012689198563, 16075.2328033676, 3792.57069176565, 3518.16041672489, 666.915014712587, 1137.49587921006, 38914.1648793721, 3263.63297233387, 5040.54247213971, 295.557739471973, 897.685180032961, 721.525209319147, 132675.00443321, 17183.354877728, 38264.7774597318, 12949.229260087, 56990.9353677899, 19793.3362161041, 4367.31954792604, 4930.99030673717, 393.716138903186, 427.976574313798, 43299.5556338254, 38018.6196658785, 153175.665720884, 15764.3340776246, 53840.0716454025, 38347.756779632, 45936.103052983, 2970.7430217973, 286894.852203864, 286868.572220853, 287383.336092364, 17355.684948379, 398.206028873267, 100.68216531975, 70248.3287512563, 1277.34995492533, 156.815734849888, 5287.05357551477, 1944.66276600819, 3202.92654698884, 2523.1616505037, 4001.95870596901, 4357.62032237333, 2829.24873670047, 36960.2148464598, 36955.3002367721, 14386.9520511941, 99134.3935919525, 111099.914196549, 96927.9133503339, 7333.39316351963, 16724.9046634256, 4001.95870596901, 4357.62032237333, 83029.1669279268, 95094.6572229366, 3320.18319770292, 4001.95870596901, 4357.62032237333, 83699.316564852, 82494.0495830223, 90911.6413169557, 89103.240983402, 82309.5464191597, 89739.0092264881, 86118.5106487512, 4642.83450207799, 4856.59030227359, 295.557739471973, 897.685180032961, 721.525209319147, 47285.4003172667, 112050.698518043, 113016.660471172, 106998.250378757, 53909.823051173, 62853.7747765658, 545.393502588625, 866.999981573534, 107020.984285254, 114099.617569792, 4502.47239439181, 5291.70189782858, 10251.7691660281, 33117.1379486033, 33233.5490086117, 46198.5526430571, 48423.0103094111, 49487.3132097688, 6308.23964798715, 35509.5628720399, 93872.7499805925, 130206.216336265, 44356.6610228148, 105401.712734403, 44564.1249479087, 400.993672632478, 496.959371783375, 1007.79460327982, 16562.5015385432, 17321.0487098954, 7652.2500575936, 269635.641958756, 2894.62766262561, 112.617890577633, 15715.2526428114, 16237.6843653342, 6822.59791382966, 17334.4339361896, 17509.0380274443, 101999.360086974, 103218.176171421, 103887.836423876, 16075.2328033676, 55.8837027444483, 256869.845783767, 322797.346902255, 274461.51175705, 247755.772349009, 19439.7747934876, 20779.8872701562, 10759.0904655568, 36663.2443566651, 18154.4392250713, 23378.8812477134, 247299.374615373, 22500.8103511594, 88464.9620936025, 90300.9018307651, 88850.247703025, 380.817770655907, 541.407831196675, 1066.08742571835, 391.531497495759, 939.647131209686, 765.476897764711, 42627.5916110602, 750.48106657495, 6095.92059555016, 33.4164858008953, 13.4410654442623, 9737.01364015589, 490.963527188227, 10186.8548760226, 96917.5398443538, 213084.716335962, 193416.62367562, 92919.8781575055, 89642.8197431693, 53134.9252164494, 8079.89891578692, 1190.014552416, 1206.07016138487, 135061.964040369, 267140.772671376, 5155.73427408903, 106220.065253578, 117486.092983822, 118154.548926402, 27905.5592235571, 25337.2113789319, 26247.3182521251, 3544.81878206588, 4961.50637411703, 49937.163399268, 51605.220558093, 380.817770655907, 14294.2146003695, 16075.2328033676, 6537.70854687212, 62484.9631335387, 55595.2889676136, 398.206028873267, 100.68216531975, 74468.5859618556, 793.920564952579, 1810.75259050688, 44511.4447671355, 535.778320926114, 35.9876265013509, 430.335507715417, 64758.1004375956, 15906.1428786642, 11490.703730422, 11724.5886144054, 1166.14407645329, 799.415871280987, 17331.5468684154, 1637.01441826392, 3320.18319770292, 1856.15162274216, 117386.239511927, 197374.83199191, 218693.046212595, 16075.2328033676, 14427.29666212, 3957.1517833575, 3011.96640731465, 12487.3443239224, 398.206028873267, 100.68216531975, 398.206028873267, 100.68216531975, 8868.59679557475, 1680.81367493197, 438.792115303027, 30516.9433794828, 33229.490989777, 13884.1871548504, 10471.0931288459, 9954.47395760227, 19171.9455506724, 20800.0775283531, 110394.91930554, 117710.389992884, 118565.837725249, 111248.863104891, 14048.6365824133, 12730.713380418, 2471.01779803843, 7013.94100342397, 22666.4587938621, 22784.0442206386, 54474.1715658941, 3129.82757875215, 16344.4884212454, 16651.0664518483, 16266.6696982451, 110250.897255532, 38914.1648793721, 255.167752297303, 303.185109429245, 3458.38954358547, 16268.5816881374, 50120.4308504413, 86165.4982332778, 297.182264217748, 304.223075558665, 259311.899161952, 212.870760504878, 1309.97685973903, 1248.49643999658, 29956.0676611137, 163264.371825029, 244949.191659126, 109617.514122987, 121160.463862687, 103080.510179269, 228890.01432111, 275847.945622172, 107527.41025221, 177031.080954166, 119786.943778193, 51204.0193970262, 2252.92432599085, 1111.83458103932, 1354.26992507075, 16075.2328033676, 29956.0676611137, 580.581698196118, 4432.15004536735, 31764.3492238247, 74718.9111186178, 56196.390322374, 28351.7467795143, 29210.8012962555, 29210.8012962555, 90077.6059095639, 6867.58418494546, 6214.63356345497, 6234.55825458224, 18498.9229297372, 4257.77723156615, 6263.31755005728, 1682.79562704932, 6493.96147313932, 64987.5729812036, 67609.6226478458, 88737.2790687208, 92667.9047697669, 92596.1105333051, 111528.792174127, 85027.8580314393, 103107.893191981, 104594.27535738, 12487.3443239224, 2945.74692998072, 1048.45825736338, 10458.2880127193, 9558.33925507138, 40976.0476567322, 43102.5979567112, 40804.3631553075, 446.669067444228, 36982.9849286861, 37270.8763732936, 46086.4453497147, 47192.2911774018, 984.72727847359, 141.830298575446, 46631.1323987907, 88538.1589061003, 2894.62766262561, 68503.5356138705, 8966.56711870903, 12356.1977089997, 4445.65730378682, 3629.59364040077, 24867.0322841098, 109375.355114356, 6674.97302012422, 24336.5802850426, 50091.1543099921, 29155.6593708493, 60535.2915296732, 62196.8327346856, 11368.0286559487, 19673.9616537436, 34804.0299393814, 68623.6554764932, 6071.1898163312, 27796.3366387213, 19337.8582553017, 18803.1702760808, 18145.3739337749, 30405.9669865797, 4043.15618977797, 3726.8611137051, 29956.0676611137, 7036.31309099518, 7794.86026234739, 79643.5723111587, 398.206028873267, 100.68216531975, 1231.16655235924, 59182.2315224222, 5811.28951558421, 2989.49900525221, 1462.74902252166, 3877.36690965169, 11473.4652140448, 153175.665720884, 68.52986480767, 760.534134138364, 166.572650378446, 10985.5445374346, 16075.2328033676, 4620.43191662203, 4658.50539586673, 4001.95870596901, 4357.62032237333, 36526.6922802562, 73396.6010657007, 75041.0234888801, 77742.8044987313, 667.663331675873, 566.070592134515, 7839.71160862661, 28272.2198080367, 32100.5831047186, 20695.5418583243, 5002.70547908315, 5901.8054138657, 1855.19357361381, 1793.72012651788, 5811.28951558421, 2989.49900525221, 106868.836117193, 91730.0642909614, 23899.62012901, 3024.31927727499, 24271.1577820147, 2992.96087966576, 2781.11295895625, 28502.9484160247, 27538.760045669, 1786.95144328581, 29956.0676611137, 4751.98518885083, 1732.44978906668, 263.306418813451, 263.29498130411, 39235.8381687124, 33099.2079953515, 28624.2736146935, 5718.26332137387, 304.719527815668, 305.388779892754, 235040.437354364, 239940.381227824, 237043.622560722, 149666.775811984, 149535.432553933, 233558.143954136, 239410.761881204, 239660.70948105, 237244.125432437, 29019.1952632734, 26517.8756533427, 1257.93140979714, 885.899661535001, 42511.4798772977, 1222.13360700813, 534.929670399472, 380.817770655907, 9041.4178901733, 8641.18553990815, 4001.95870596901, 4357.62032237333, 21958.9641389942, 30738.0018937777, 4001.95870596901, 4357.62032237333, 7888.83677377505, 8124.35634932655, 74468.5859618555, 131159.211289801, 92165.1972438328, 450.00774596852, 979.860975096807, 504.409562304463, 13915.680122719, 13546.7523198088, 9584.152387915, 16124.42112905, 16075.2328033676, 21738.4745379932, 44130.5181020209, 45663.1530418543, 36982.9849286861, 37270.8763732936, 84448.2569147497, 13724.3172928578, 13394.1301240815, 10843.8855108434, 12002.6832685512, 24840.0633790854, 91596.7930480916, 96801.2065671851, 106199.103774047, 104926.676985974, 104247.434955524, 120884.10297017, 29237.2441270096, 90437.1987998575, 129399.260625167, 94134.4634714765, 424.040471794759, 663.603344683495, 2686.09705439428, 3253.80526129414, 1012.70680144016, 175.594808747193, 108617.159664249, 110632.374931992, 106512.728157719, 112378.441585204, 123459.134725121, 10978.1721829133, 108970.428752903, 109257.118119638, 113471.467384711, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 206615.876814416, 186160.341394133, 160597.849178588, 38940.9003667399, 70309.0015394083, 70546.3690824553, 4620.43191662203, 4658.50539586673, 17.165419793101, 3.5065993901164, 8453.85371861961, 83826.9010785396, 72770.7598938117, 47249.0740447186, 62892.0245606327, 1928.23454357027, 36982.9849286861, 37270.8763732936, 14708.9601878213, 14370.3467721258, 587.827601893559, 28498.8193557754, 4246.9793347134, 1384.44841682534, 2935.75104885414, 1613.69820870616, 2777.89152710249, 11056.6758673485, 173475.266083499, 8002.4233915646, 92667.9047697669, 92596.1105333051, 614.794604743197, 3379.64021765474, 111.537810954324, 11.9265340475962, 38914.1648793721, 79551.6920879741, 149163.210167036, 16075.2328033676, 28.5425439295029, 737.564022643526, 76873.774227323, 3058.99450585059, 8762.7419239978, 16574.7893864099, 11019.6516218576, 11778.0057784129, 3222.42542652454, 2291.24094212046, 36930.4452444712, 577.693352328967, 4166.38933413729, 860.056430018303, 2526.85154681064, 5002.77830630351, 38922.0397555033, 32431.3704658798, 10746.8758557176, 11574.0288308497, 939.647131209686, 765.476897764711, 4908.57235204984, 55643.3918320751, 56029.639847205, 55662.5590095013, 11590.5993193077, 18368.2723711312, 32886.9428937519, 380.817770655907, 42963.8360986858, 45108.3431410676, 8805.66394958271, 157252.692100249, 74697.0191306785, 47663.5710476407, 47574.4218555095, 74539.0575798612, 3357.87696849292, 16075.2328033676, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 398.206028873267, 100.68216531975, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 5695.44220750112, 10390.1917382915, 398.206028873267, 100.68216531975, 27108.855167906, 725.818744960656, 19332.5906500741, 146736.990571531, 112777.724909986, 43417.4809314704, 40912.9012475572, 54022.3914104499, 6847.03715778415, 6073.34396254344, 13051.4879221713, 4727.71879939213, 145.222113418366, 593.649099743214, 1925.03338378034, 4094.89983702932, 89289.2975313069, 36982.9849286861, 37270.8763732936, 27893.8144726009, 228.150053497018, 3260.72769124889, 158973.75352684, 86615.8411098735, 38914.1648793721, 20814.2593769513, 2926.75909982747, 4936.85306638324, 1136.05495546083, 3269.09715506217, 217875.207060492, 201816.029722476, 248773.961023538, 149957.096355532, 66623.3263215092, 67009.5743366391, 66911.2177661167, 66642.4934989355, 7800.00272979872, 5877.45590605345, 7883.74915173454, 398.206028873267, 100.68216531975, 60990.6595775615, 210803.679834486, 208436.649393301, 4001.95870596901, 4357.62032237333, 2914.66482374556, 877.138717320542, 812.486590138845, 10048.5321268207, 38199.541638237, 72124.1993854226, 22813.2525009147, 40474.8597658331, 19145.0659714718, 16075.2328033676, 541.022059462945, 3226.89675550796, 1099.00964046036, 36982.9849286861, 37270.8763732936, 107289.920114286, 6674.97302012422, 24336.5802850426, 16075.2328033676, 191244.236999228, 154145.747366445, 171576.144338886, 154094.311418565, 84435.5925192723, 65971.5822598412, 3949.95500824488, 5899.97289008447, 203474.836614795, 203085.067545276, 236896.788120051, 258336.556598227, 210320.722328514, 206302.82174535, 203383.846779222, 38914.1648793721, 99754.157209946, 14602.8708667173, 19929.5133488795, 20735.7225129209, 24299.3370425168, 23524.5563114389, 26124.3244076893, 36010.532854814, 30305.127646821, 31164.4163418845, 33929.6271416844, 22870.82279683, 234805.549474839, 242458.052612506, 71130.7931058274, 109265.836644684, 4456.94251146803, 31789.1416899254, 31461.5587619452, 31289.8742605205, 220943.365557423, 221769.420396418, 16562.5015385432, 17321.0487098954, 77877.4115207514, 39200.8243277236, 29097.5948870095, 16075.2328033676, 38802.1554956787, 56033.8084966131, 62462.0415766321, 33216.443177685, 22456.8615183149, 4255.04421739872, 3721.93987020776, 176.268750462866, 10590.3842788763, 10452.499341529, 59496.2043235656, 368011.351958329, 364120.128061073, 368923.512579539, 51273.2105152168, 49474.0185353924, 36961.7459183491, 36369.7018581623, 36851.5645869291, 24318.2184670969, 43550.9228505162, 64397.8266521385, 729.354851039592, 65065.7497861239, 39966.0518322007, 2167.66644705385, 93823.9796754645, 26181.848534177, 26477.3813523239, 25763.6332490169, 2212.30926121041, 19599.5049812013, 380.817770655907, 54146.3379890327, 37532.3429871435, 36568.1546167878, 214477.376039495, 7741.75265109378, 7741.75265109378, 8530.98215453054, 7030.35537919195, 27010.416431644, 20673.9471082665, 20701.8286036836, 453.849412143434, 16075.2328033676, 36982.9849286861, 37270.8763732936, 196.913304574682, 63571.5935003966, 55150.6945182499, 12027.5391183339, 12489.7105976506, 14338.2078156816, 7111.0003226544, 1864.15501149668, 51774.3886844581, 1380.4625252241, 6835.56061327353, 3947.26660480418, 5006.69144545833, 165.105593485501, 163.148000537549, 716.656480374193, 47866.6305604207, 48154.5220050282, 16075.2328033676, 53829.2109433596, 31117.5214891549, 82894.5427925722, 78267.4955692014, 78653.7435843313, 53737.4336775969, 62233.6932570372, 62950.2546877615, 78286.6627466277, 91530.7271062392, 92349.5365161251, 25293.663413009, 5149.1243976634, 351.345341301677, 55.8837027444483, 50421.8618269367, 51966.4945944936, 50017.7949060139, 44679.976874789, 47628.9644387855, 7470.23493341618, 34314.2892206919, 55612.1827261055, 7717.32473717463, 96.9243753809769, 9812.81437321403, 1078.62984126406, 14491.361972311, 40768.3219463978, 666.915014712587, 1137.49587921006, 28.5425439295029, 737.564022643526, 197.456175230604, 326.964246294174, 1174.38026888168, 64875.5759169255, 351.730145651724, 939.647131209686, 765.476897764711, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 58999.9631732753, 77915.0886007471, 161696.823229018, 36982.9849286861, 37270.8763732936, 89403.3656786244, 1343.67131467016, 2649.77342104993, 9147.39254916866, 14356.175242238, 24797.4119628568, 14415.06025828, 79322.1937649063, 82096.5312779475, 22083.5589987289, 1485.86358963292, 6368.11034513541, 136.012689198563, 23852.82565473, 23641.7597161484, 16075.2328033676, 16120.786165679, 5007.23124055007, 16167.5943458243, 5082.68377492198, 66720.1903314193, 1523.11195034886, 1934.66334311212, 62965.289360981, 19043.4668722822, 32242.8967047935, 669.528703538482, 420.135747288163, 45.048259397008, 22883.8000255466, 33085.0087804805, 32944.2582716542, 31285.0978944059, 31491.2782366305, 34521.0241525736, 24640.5937711057, 32887.390925983, 24918.0917096275, 15002.4315582681, 284798.941358908, 75621.3860190066, 38940.3853519511, 33475.1422154046, 985.256450100904, 1128.89651902073, 104305.261747724, 60782.5082600999, 115052.974636837, 69267.2549446927, 36982.9849286861, 37270.8763732936, 286465.362972, 28502.9484160247, 27538.760045669, 3263.63297233387, 5040.54247213971, 20217.3077597791, 21784.80341964, 28502.9484160247, 27538.760045669, 285.186697280334, 866.332228040084, 45209.4409811501, 767.659794592033, 1454.77456326011, 69570.7426262668, 72745.2895204131, 2480.63106716703, 55.8837027444483, 16556.1771263363, 28584.545558594, 90126.4333649646, 127852.828632961, 20336.4142223329, 49245.6908275874, 218940.08792497, 202880.910586955, 249838.841888016, 151021.97722001, 37270.8763732936, 1656.30831864911, 116.113033013679, 56.4271046072093, 36982.9849286861, 37270.8763732936, 4862.66575106161, 5986.91323088359, 380.817770655907, 295807.891745435, 306750.680132375, 162166.272916349, 36930.4452444712, 14882.4254742198, 15743.4010269272, 13771.8834449048, 64758.1004375956, 15906.1428786642, 3328.76257257786, 14397.7228337455, 26532.2080240805, 391.531497495759, 17293.1549089864, 206.154152085621, 408.092676066718, 23807.0951253867, 23663.5939280144, 9681.58049067177, 12772.5827263747, 42837.3122182299, 9579.0522282297, 12196.1342500882, 12314.2548496219, 2452.67363322536, 26605.6534318315, 56556.8758710861, 27335.6754814134, 48094.0902206347, 58051.2670064189, 78688.875174606, 91916.8699673408, 79648.2198615837, 68592.0786768557, 43070.3928277627, 32796.0698452461, 67414.5781442242, 172.584973036458, 87.6629534755182, 1364.63201641609, 396.688498063385, 34205.0502284764, 36223.5823647231, 36728.0827145852, 31015.8358557633, 4158.5784452286, 8588.33936990981, 60365.3606733271, 55738.3134499563, 56026.2048945639, 380.817770655907, 127103.287423013, 127102.700501999, 1864.15501149668, 10164.9890567973, 21618.5919808175, 24349.1116625208, 25424.9141297324, 11845.9669778359, 25627.2754227141, 303.444276626844, 3834.98715692067, 5611.89665672651, 93823.9796754645, 141229.651236765, 134047.704108677, 134591.038671779, 9473.90487759292, 8381.62082534266, 61266.4666038691, 6097.07752844713, 4117.51161105502, 4079.70275827745, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 44511.4447671355, 6739.12529364723, 7911.89046514681, 16624.3932243086, 4983.99343661436, 11885.9073565244, 6091.19210081249, 16075.2328033676, 63581.5012180939, 165107.984150234, 181553.704272569, 150965.602303939, 4456.94251146803, 31789.1416899254, 59205.6842302504, 51148.1240386569, 2878.93883412043, 3339.39781057198, 6754.68935613241, 6908.82616123102, 29956.0676611137, 1549.21500557866, 66502.1455876113, 7423.52757036724, 15729.4605681622, 30859.5288538, 64679.1543909117, 2126.68873074975, 23851.8355531399, 28137.468559337, 398.206028873267, 100.68216531975, 15586.1825816713, 17991.6537855981, 8481.70250480732, 2686.98724909541, 153175.665720884, 1377.58692221662, 76596.721914708, 55584.9569056254, 34568.5137529239, 127951.402909314, 15300.4101348559, 16205.2454095731, 15968.2648061009, 16510.1995642458, 33077.0158479722, 106642.078470419, 64013.2955711973, 71080.7132822947, 64399.5435863272, 64032.4627486235, 13724.3172928578, 13394.1301240815, 17755.2035122277, 25948.9072098276, 19690.7028578657, 11661.4839860976, 398.206028873267, 100.68216531975, 16075.2328033676, 29956.0676611137, 16075.2328033676, 26015.1132174876, 37549.3131700503, 3093.94738532291, 22155.1582807623, 29733.5369116768, 3423.6656352052, 2887.66037832825, 3211.56904658005, 16075.2328033676, 3458.38954358547, 389.18552435887, 666.915014712587, 1137.49587921006, 3059.01779242644, 6381.60933492283, 3649.86227867631, 3234.16659762373, 4404.20266405286, 25600.5522849034, 64455.0383037344, 52707.6975003919, 52577.9372400563, 52502.929306833, 52339.0399953029, 54303.4388023185, 255421.458901604, 210520.03499845, 54146.3379890327, 37532.3429871435, 36568.1546167878, 2434.51046052823, 55.8837027444483, 4001.95870596901, 4357.62032237333, 23797.4400964963, 10158.7322680566, 15425.867253539, 16009.2152561326, 2964.23633074772, 21333.2325752547, 64875.5759169255, 75974.9117912375, 35350.5470381319, 814.156337121116, 80562.1571040449, 6209.75846218885, 4549.24668623929, 3954.21096768651, 9696.51006616501, 7568.0141476506, 11640.3155264497, 4123.15180971155, 4876.30955602712, 474.057550029458, 6681.84342712132, 10584.4160677763, 16075.2328033676, 4732.12066117582, 4252.81954603248, 16075.2328033676, 13065.5138567781, 4001.95870596901, 4357.62032237333, 34167.9159358654, 16075.2328033676, 2093.78286778191, 969.013067954155, 5616.05231908466, 1208.1010352357, 2196.64400215201, 5158.55744362665, 14356.175242238, 495.109220548874, 877.442078240008, 28502.9484160247, 27538.760045669, 74.3657790574448, 18090.2165205772, 26128.4667348823, 1122.35194789941, 5695.44220750112, 10390.1917382915, 1314.97162221057, 5126.93226620158, 460.247522883451, 53926.1569011661, 1850.32940754323, 7213.77903582164, 2060.39471923686, 503.212265919193, 1510.71652069891, 2148.10567586983, 26938.2911516124, 25898.0328776868, 20162.8632704084, 53931.1660612216, 58999.9631732753, 44359.7426141151, 6674.97302012422, 24336.5802850426, 36982.9849286861, 37270.8763732936, 4608.56561250729, 19337.8582553017, 180.110787600354, 2229.04712036413, 827.452597513494, 1224.3456104963, 3204.94350303393, 85306.609714591, 76076.061499913, 5537.24261454432, 16406.6991863639, 36982.9849286861, 37270.8763732936, 17365.9598486733, 6674.97302012422, 24336.5802850426, 16075.2328033676, 32744.0403184399, 2712.0548372898, 2468.31871054747, 93823.9796754645, 21312.2471700805, 27231.4204465945, 19163.0631724112, 9072.19450938822, 32549.373396527, 16378.0406891486, 20353.3552777774, 3105.03294537679, 10231.9091986702, 5115.12691193256, 41111.5969516287, 36414.5100538557, 35804.5571383276, 57754.7444232741, 80805.6504490253, 62213.5360508076, 38354.1702658603, 11821.2919359416, 35064.6287989435, 56867.8535268635, 107063.211642768, 34478.1380557966, 885.387831514171, 1063.60090266067, 7233.60906685124, 96955.47925898, 7650.21302182265, 15104.6232249203, 51510.1868386212, 51215.9536444437, 16075.2328033676, 693.97471921803, 46163.2011388059, 63824.8084037243, 61453.8698429782, 1442.91874787607, 3620.4443646707, 379.541722750137, 12439.5811409165, 14498.2389929028, 342.923229576262, 19599.5049812013, 198088.883704175, 49230.2123306951, 398.206028873267, 100.68216531975, 550.417770616348, 9.41058813544714, 9962.27603644867, 6540.83849573654, 11210.8428894724, 6715.84202535662, 116807.242640485, 22447.4243398316, 33901.0272638519, 37707.3494127667, 39750.5143830026, 40466.0250278876, 37909.7107057484, 43407.4667985267, 43735.2010534833, 47994.687478068, 7106.27431670089, 2097.682220922, 222141.664495017, 202473.571834675, 16075.2328033676, 97846.0685297032, 83334.7513584655, 57114.6273256259, 78177.9758693609, 4001.95870596901, 4357.62032237333, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 100244.697966766, 1544.15672002622, 1322.62261875306, 2087.47142869769, 15948.5707077825, 16092.1526808912, 143.168634116505, 151.658726218599, 44359.7426141151, 14790.0611965957, 36982.9849286861, 37270.8763732936, 1886.7781297687, 6619.52047334919, 7187.91351003979, 3174.65813541014, 8479.73549547892, 30664.3560793261, 28699.9120269668, 28065.5085317315, 6416.81207706452, 7751.58874088763, 4785.36439328066, 43968.6010642947, 30004.3367513918, 16075.2328033676, 4831.49864883291, 2861.3489239826, 1913.15698748931, 5023.86029939158, 1493.00386220941, 2026.41097922336, 2626.01583820708, 14099.5849352164, 13239.0216623156, 1864.15501149668, 33216.443177685, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 3084.01478007984, 71295.1448408014, 71274.314996877, 44511.4447671355, 33086.9073453115, 23421.9582092251, 73814.3182758455, 36779.5672794224, 73829.0999304551, 43955.1339580364, 9907.25863286219, 85306.609714591, 398.206028873267, 100.68216531975, 883.659008064973, 846.232018946051, 667.663331675873, 566.070592134515, 146156.654863526, 172914.804322468, 45552.4254171955, 4001.95870596901, 4357.62032237333, 282185.303644369, 222450.589474325, 238559.433908639, 234651.814973673, 204129.493199, 175034.007227568, 171316.984330047, 275867.805383827, 233656.149234853, 235602.280271166, 314330.609638905, 240274.318186282, 283478.187918463, 268883.072072261, 188380.203009246, 193132.290051078, 276828.380922906, 276509.6607714, 276123.219630392, 20121.128562235, 238022.227597428, 46807.966593272, 28801.6003000313, 356057.030586538, 354441.561340413, 89271.4733103841, 88690.2525971374, 87596.6590418899, 112096.861244535, 23369.0021592889, 76675.204514721, 161176.431684621, 131849.829468792, 117113.193598561, 137357.679866442, 221510.663190784, 6795.85592412815, 123599.989114834, 101420.730744249, 126696.587355215, 85370.9864904753, 1643.27747066537, 17349.4741978671, 17251.982957859, 18939.7348680128, 9964.63268064183, 11852.0352099763, 410971.497350927, 232573.574999595, 70812.332783606, 100045.389044821, 118475.088064275, 118783.486015706, 119705.261897673, 117306.920968427, 62.5672149217385, 50.8738834960313, 1367.55949249306, 1370.79828507022, 5149.1243976634, 13144.9452808776, 13158.1091401366, 45.5777284527176, 380.817770655907, 11154.9988873939, 170274.969961459, 21349.0998014748, 20446.3494931145, 6754.68935613241, 6908.82616123102, 1126.88917628523, 15502.2832055657, 8787.29138730481, 1856.15162274216, 1600.50903803875, 1702.3936922366, 854.129986882291, 1875.55073190318, 1506.97490883833, 2404.03919681238, 2209.8748039488, 1422.13950075631, 149518.503496448, 541.407831196675, 1066.08742571835, 60339.2247176437, 60549.6121972536, 664.927604283919, 38424.1023981046, 31597.7339102137, 14613.4299774085, 116759.049314033, 116117.254113708, 117063.322287168, 93823.9796754645, 24264.0074798165, 21989.0483388075, 16075.2328033676, 85306.609714591, 939.647131209686, 765.476897764711, 6867.74924373288, 39298.637316672, 56960.2445815904, 67474.5484475525, 28625.6667528016, 27434.5277080269, 26653.6276361777, 28351.6338384088, 26898.9948481617, 27704.8017983641, 14148.980567051, 26598.7409694788, 102117.021119148, 90617.2488547706, 63571.5935003966, 55150.6945182499, 17223.2744295073, 2017.36105395994, 16075.2328033676, 21094.8480073037, 7665.81872027092, 20561.5275287733, 21708.911236807, 15435.1542488622, 985.256450100904, 120197.68018813, 221358.949045921, 84397.8396545849, 427.176005292627, 134919.79155393, 134737.852962615, 138363.348248434, 1141.86086925282, 7714.425072299, 41507.0967832602, 9276.9650305857, 8749.79211257873, 380.817770655907, 2639.08732457886, 1803.0031984477, 302.82397703796, 233756.839000181, 793.533700165008, 64190.0604865768, 447.13908852481, 2978.87883120901, 13107.5409522923, 5845.10896983949, 19337.8582553017, 27521.750909051, 732.49056246372, 29336.8067687348, 16075.2328033676, 3317.62759237294, 33077.0158479722, 55646.9464670883, 73308.5537320067, 109494.039646358, 398.206028873267, 100.68216531975, 18412.4748529783, 28199.5371717598, 9947.35535365364, 30083.3784187386, 29956.0676611137, 4001.95870596901, 4357.62032237333, 36982.9849286861, 37270.8763732936, 16075.2328033676, 42627.5916110602, 9990.48798026241, 6802.91142492608, 27553.1576291403, 39464.1569143608, 20962.6870186442, 11368.0286559487, 19673.9616537437, 34804.0299393815, 68623.6554764932, 6071.18981633121, 27796.3366387213, 14807.3289463277, 377.416531328348, 393.806642550133, 738.667179367954, 7459.97312429195, 5782.58370207239, 329.476038024962, 26332.212969649, 41962.6523769007, 42717.7109154456, 41753.5225450899, 35.7093436203859, 15929.1714653148, 295.908548899917, 889.041574580731, 758.554048700454, 1532.8300430095, 28502.9484160247, 27538.760045669, 45688.1639062682, 9348.82123940908, 8978.13590037639, 3689.82004503821, 80536.2327829195, 10902.3758500494, 14163.3539056996, 13866.3659030392, 39286.7415421213, 3199.28902086768, 13858.2557871444, 39817.234388358, 70435.6205357522, 70565.6546470578, 19337.8582553017, 123147.76926003, 16677.950244447, 85306.609714591, 841.594770384346, 9718.79871245787, 44310.9883817894, 72908.4728168655, 61493.7668421551, 61138.9643036259, 872.613052005574, 1256.47506183857, 55.8837027444483, 6325.19071116503, 8126.74212098101, 4221.0603045628, 11033.3350747761, 3411.20046020645, 667.663331675873, 566.070592134515, 2227.21578536783, 1210.55708396565, 25634.8733483321, 6940.92049302448, 12568.7724643242, 16935.1255419858, 16830.4399314464, 7134.2862112084, 40940.1846583603, 7650.21302182265, 4157.12794071412, 398.206028873267, 100.68216531975, 150355.972515327, 91689.895392365, 122131.19179588, 127239.423003409, 53651.0168372577, 54160.1373780979, 28.5425439295029, 737.564022643526, 42301.3573465678, 51423.3953110564, 1084.73118521835, 719.390240453573, 124065.941096032, 14078.7204502843, 2262.79105162628, 2575.10747547515, 107020.984285254, 114099.617569792, 17100.5870834611, 8483.9310789461, 9827.17525946496, 16731.6592805509, 5156.09399619595, 32939.1179965398, 9178.51413380821, 1230.48901554754, 1605.94006742936, 82491.6656677962, 71435.5244830683, 45913.8386339753, 196.913304574682, 54861.0708148141, 1783.16899601624, 1850.16069769952, 49271.5798323015, 45377.6454103179, 55375.5329136444, 51387.5002046852, 4.92664234866027, 4001.95870596901, 4357.62032237333, 56363.3705272317, 56651.2619718392, 72593.5320145643, 14790.0611965957, 130290.988443418, 130109.049852103, 133734.545137922, 146675.201475356, 129886.294145032, 93729.6485051648, 35684.4246083643, 36418.4945175402, 185842.707441117, 4001.95870596901, 4357.62032237333, 165649.629754934, 157282.072663123, 123.149608074838, 75.5828630518521, 730.689898217356, 533.597751022557, 90900.6974844511, 128435.03834195, 52593.569072074, 9283.22462307994, 4727.19464134778, 5149.28693121563, 4778.68388526411, 16075.2328033676, 53245.5428776038, 47843.8069577467, 3509.61610499153, 46591.4324706849, 398.206028873267, 100.68216531975, 55368.300819351, 55594.8018794843, 30538.7729185607, 17097.7933110132, 102.369921957763, 1542.34645833776, 1746.13633341972, 63985.3615604668, 60376.0107656432, 19443.1333870594, 5149.1243976634, 11432.1480776184, 11236.898426975, 11043.4053780748, 198754.861220206, 189349.866382847, 192021.963242149, 194412.016539477, 198833.957792151, 87814.7341644694, 76758.5929797414, 51236.9071306484, 150355.972515327, 34353.394795159, 48601.4158219956, 48707.1421914415, 49544.8437239865, 47637.2274516398, 14356.175242238, 7577.22011595998, 8027.06135182666, 45.5777284527176, 22527.8738780017, 23004.4697260605, 93823.9796754645, 625.776006365553, 233.886906324313, 55.8837027444483, 22456.8615183149, 1788.77444134187, 64937.0567908202, 56729.618379303, 37061.5257189607, 382.882006816877, 1128.01783697731, 3500.29247416595, 7108.66370892752, 5811.28951558421, 2989.49900525221, 104160.939539591, 102678.646139363, 107020.984285254, 114099.617569792, 106536.416605281, 176147.934684343, 98115.5176231342, 98858.8207036819, 12843.7724376984, 29956.0676611137, 321.900854208561, 5761.43709489348, 6438.47522605578, 15088.6684143831, 12625.8130427304, 8459.98245207855, 31461.5587619452, 31289.8742605205, 70248.3287512563, 4001.95870596901, 4357.62032237333, 5149.1243976634, 3189.50119137769, 21120.7529532491, 28336.7608355685, 27248.8089494431, 1146.95686244562, 1027.62874960833, 16095.9464094884, 7510.85670870191, 39100.0136385763, 7989.88291020224, 78686.6523439607, 67630.5111592328, 42108.8253101397, 9737.01364015589, 490.963527188231, 10186.8548760226, 48638.3915862555, 43353.6199714526, 43353.6199714526, 617.48359386835, 9.12199578433297, 80727.3619038803, 72062.3104608364, 398.206028873267, 100.68216531975, 53909.823051173, 62853.7747765658, 31036.7150060095, 40387.1949213211, 81557.3391383125, 78724.8828640453, 255.167752297303, 303.185109429245, 216401.200691711, 218404.385898069, 214918.907291483, 219255.629923686, 30578.7612434595, 7988.73268769244, 2452.45950688995, 16075.2328033676, 41655.0141308286, 10147.5846002505, 20810.4515893455, 75.9535711527267, 233657.04094091, 243329.64927177, 251995.80199778, 257332.914886951, 256173.813132505, 283620.772027212, 102807.502104843, 242316.190894845, 288730.969483597, 234877.902995429, 38914.1648793721, 74622.4020022576, 77616.4292549024, 79863.3418630604, 91295.4477342613, 65412.8157096601, 31242.2826590399, 65114.8903511941, 7650.21302182265, 93978.2631495404, 125198.48839991, 148.399326029735, 133.522039975112, 16075.2328033676, 380.817770655907, 380.817770655907, 2758.18862301036, 1392.09010470108, 1971.59361415747, 1378.34518415157, 36423.1489929697, 33932.9851326169, 4410.78701217527, 5380.25524457574, 157865.750469156, 156383.457068928, 162158.542814166, 47450.2260517822, 15885.3539141143, 30772.2146980358, 13787.9107652306, 53921.2385277872, 70511.0014654901, 62855.6187973865, 58048.9124694569, 3275.11341438903, 1651.14814742116, 4405.65550130421, 70634.7451936634, 76030.6489951541, 73122.9739517281, 79251.8180105203, 515.537406887688, 3276.58716951476, 40378.9713946759, 32723.5887265723, 311672.205679647, 333441.893614474, 309366.496773458, 294350.062311215, 311863.698892741, 312300.408129739, 311716.129477086, 1064.03219290881, 54800.5440685167, 55077.3411393711, 54647.5903973154, 2926.75909982747, 4936.85306638324, 3313.85856569276, 1912.26404284212, 2309.15705582493, 29956.0676611137, 14490.4251413874, 11382.472414445, 12125.4727028121, 36982.9849286861, 37270.8763732936, 78445.4304550097, 28001.0765506018, 131874.374098839, 33975.9881362306, 34390.4791104976, 230587.120925498, 231540.180302648, 220686.243118922, 105625.496325644, 203941.992260956, 206426.467670201, 206309.455079521, 85306.609714591, 173450.124932517, 36982.9849286861, 37270.8763732936, 652.6624199943, 645.891940130457, 12981.2350903387, 121093.186968869, 95991.5696319239, 15901.6697637082, 15531.0667177567, 15901.6697637082, 15531.0667177567, 60516.336405779, 46766.2050959259, 45581.8504425135, 16075.2328033676, 17279.2239720536, 72233.3262091597, 34047.3537305732, 5291.52379716449, 1622.2637064516, 30809.9211902232, 31246.9752484699, 71566.8288005878, 217875.207060492, 201816.029722476, 248773.961023538, 149957.096355532, 133095.829909835, 113427.737249493, 6869.83378008424, 136.012689198563, 2899.04800419296, 3818.36709222348, 2939.8773286878, 135111.714440333, 36982.9849286861, 37270.8763732936, 38914.1648793721, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529483, 25460.6460476849, 516.557838435252, 9696.51006616501, 90877.723354638, 90368.5892770567, 93572.0661392623, 90667.0122440158, 41628.5683010326, 85154.7525342006, 77499.369866097, 82003.6385181224, 90136.1566861159, 79869.9809193976, 91584.6693815131, 132218.169609512, 38090.6607635372, 94901.0596266478, 35291.156336999, 40443.5878459114, 42379.0965161929, 95250.9253051953, 24552.9255105467, 29683.9009883408, 109133.408700509, 106973.234353291, 943.91833550857, 198502.651421323, 1225.60731214474, 1149.03949792227, 10558.8692532782, 74468.5859618555, 34472.7400838702, 66961.5631826713, 24824.4337589759, 24369.9660051753, 31503.339583105, 21314.9115242568, 398.206028873267, 100.68216531975, 380.817770655907, 23046.6385072794, 19014.9399931232, 18607.8321494227, 3419.78018687112, 23103.4588896023, 10996.1026148907, 13937.1045709411, 4396.90596387754, 4124.68529797064, 38805.8604898161, 38351.4395749466, 28455.4110235471, 27269.4755077968, 180034.73659262, 890.113244917289, 4304.02632537075, 18924.9256835612, 36586.5329484796, 36982.9849286861, 37270.8763732936, 56910.2300583595, 63571.5935003966, 55150.6945182499, 4001.95870596901, 4357.62032237333, 82219.270318958, 75181.7586486951, 105689.389921265, 96202.8742487299, 15329.0106420139, 1231.16655235924, 44259.0397128576, 91862.6198066085, 17864.9359702411, 53909.823051173, 62853.7747765658, 5553.03502632361, 4828.81809318158, 1788.77444134187, 13166.4980068272, 2926.75909982747, 4936.85306638324, 16075.2328033676, 6155.84223254777, 5592.62444885369, 46635.9234111151, 87.5163918835083, 9178.51413380821, 54307.6664177307, 29683.9009883408, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529483, 25460.6460476849, 10363.042764834, 36.3583549709158, 158.395733639211, 16556.3213314428, 20512.6403225972, 16994.593450031, 34973.4961861501, 132387.93979768, 30479.3341832774, 229149.421230861, 52506.6515297658, 49512.0909022408, 50032.7898314659, 110788.462064289, 108544.506486199, 106915.131682801, 25067.2869238082, 26273.0890342569, 24123.9050365877, 1674.08690328263, 100642.434336304, 8787.29138730481, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 96.686921562581, 756.582478900506, 515.205300433674, 6122.81274968247, 118887.953871982, 73847.3085524501, 42453.826716251, 68114.3225075368, 70080.057686257, 42880.3295169419, 43733.4265278232, 41124.998823311, 8223.61511468137, 2981.1921764042, 172.514404599562, 481.914347800913, 123000.179360901, 121621.103566701, 121484.722282529, 122850.917205328, 36982.9849286861, 37270.8763732936, 15056.8587993982, 19483.2842563953, 54307.6664177307, 14026.1267111453, 5987.12705152631, 72825.5954882376, 3920.67409972033, 5530.49568266906, 8528.8747078562, 16206.0478217791, 24511.9808195741, 39642.0491052119, 73461.6746423236, 10909.2089821616, 32634.3558045518, 31196.1537867481, 19337.8582553017, 3403.68072063434, 25999.2364243352, 24952.9449137557, 26173.8405155899, 5782.58370207239, 58986.5540924611, 61958.8955639911, 60825.0910299632, 35349.8337264147, 18545.1461112046, 18693.2748759626, 7643.74915757676, 304297.351977245, 41443.4467132856, 541.426098286146, 257.094025600879, 72291.0435256734, 36953.9591885763, 37340.2072037062, 484.905995992705, 22707.0824934047, 16075.2328033676, 16075.2328033676, 1080.9423781904, 1001.03942341392, 761.470197992657, 1334.8637148769, 21872.9668296125, 19337.8582553017, 65019.6126056549, 2945.74692998072, 1048.45825736338, 10458.2880127193, 11624.8096425303, 38846.4546213561, 1976.72018165027, 652.347758529337, 93823.9796754645, 55883.2837125609, 120361.911133909, 80222.3637126693, 134183.752644865, 88533.6647492119, 247870.22773951, 92943.025244036, 16225.1962034979, 16046.4304427822, 224216.61358898, 183602.917932778, 183434.544384146, 204548.520928638, 181285.639651202, 182736.110602359, 183376.680083113, 658.254210804327, 7650.21302182265, 1164.42935736649, 1120.23165424879, 85.51495633994, 7650.21302182265, 39097.0304197939, 12564.1520898753, 450.742998007021, 34418.7112044886, 33286.0421953504, 44151.2302516985, 44449.349222153, 28502.9484160247, 27538.760045669, 117210.993303546, 70079.6475629441, 114454.032959247, 28584.545558594, 106196.177987774, 18396.3288907663, 26631.6750699653, 26367.0969679321, 23146.5941589882, 26431.6781739859, 5820.79314720968, 30461.2188010246, 101455.845569559, 2448.50673281841, 4180.13687766456, 125543.213513257, 127057.874659653, 137957.712466572, 26332.212969649, 7571.78623449849, 7611.28886063494, 2442.6225437696, 2439.87454984859, 15734.8930977507, 14819.03156407, 8830.05363838709, 11975.7705566039, 85071.9995181371, 82911.8251709188, 165.105593485501, 163.148000537549, 19337.8582553017, 45591.7664334266, 19058.8881035079, 38487.0582402913, 1759.54203189111, 7106.27431670089, 2097.682220922, 16075.2328033676, 37.0066084751157, 63571.5935003966, 55150.6945182499, 398.206028873267, 100.68216531975, 79215.0973316811, 59547.0046713387, 44998.7420247188, 152684.6186048, 169617.758796896, 29401.446306116, 8630.04477303453, 8494.87746778377, 16075.2328033676, 75993.2178437773, 42659.0510020732, 56325.125183435, 2598.41353348238, 2261.92529486709, 15553.8382244036, 14635.187747529, 60695.3331867654, 53606.3301405669, 21207.9320627651, 24271.1577820147, 10491.4620583035, 55242.7937122294, 57955.3413225236, 23567.3793885969, 24161.6201569773, 182325.164436804, 16075.2328033676, 7485.11230667488, 70142.2280533544, 1259.14325538398, 1429.30426752746, 12470.6095919668, 13285.6468819291, 4604.39708615642, 29956.0676611137, 1995.86933921473, 1025.64438283859, 851.474149393614, 85306.609714591, 4456.94251146803, 31789.1416899254, 1780.62200017467, 4627.3387724847, 4689.11207673801, 20118.7565817869, 13556.866284347, 2700.15846350253, 9084.16103942462, 28272.2198080367, 32100.5831047186, 20695.5418583243, 14248.0801194984, 15047.951275681, 17468.2533801542, 114882.696991684, 16000.1429240728, 15998.4780911284, 104160.939539591, 102678.646139363, 1365.04903019086, 17279.2239720536, 1345.94678065165, 16347.8465615092, 50070.3822055049, 667.663331675873, 566.070592134515, 83029.1669279268, 95094.6572229366, 701.471741783623, 1856.15162274216, 3888.54002587654, 2889.63015557117, 2243.25379869297, 658.254210804327, 18561.3754364165, 4112.63800824237, 4619.23146386679, 19076.8589233627, 36738.4661882811, 89462.3368696753, 166297.984870307, 29956.0676611137, 2290.97373443344, 1754.78103930431, 7549.09285753057, 3437.68750995873, 2202.60181343423, 7586.91289307513, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 6415.39571038818, 13891.5458587692, 13492.9759219502, 16075.2328033676, 140837.86362526, 144919.21741951, 73789.6790941654, 6064.31648109536, 10126.763171809, 8074.41044765112, 9296.64277911795, 23299.9068531316, 14204.629284174, 380.817770655907, 4563.21437395795, 7632.81944067281, 14919.1050806024, 18352.6879210678, 18790.960039656, 24367.0274756184, 23203.0744929639, 19661.6314860522, 16075.2328033676, 40060.9893187885, 41004.4172207795, 39096.8009484328, 327.526570181857, 16075.2328033676, 28.5425439295029, 737.564022643526, 30424.4598950916, 32923.3370163594, 47300.5397183578, 93823.9796754645, 695.492487178245, 125652.874678769, 7106.27431670089, 2097.682220922, 398.206028873267, 100.68216531975, 14356.175242238, 93823.9796754645, 3020.62466064264, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 3263.63297233387, 5040.54247213971, 16075.2328033676, 64868.2813173423, 65254.5293324721, 70202.508314965, 64887.4484947685, 83794.7258708122, 132266.159608464, 285815.84595879, 3437.68750995873, 2202.60181343423, 2926.75909982747, 4936.85306638324, 90561.0513845603, 89269.7509440711, 114817.212368895, 67741.0297940647, 3960.92017129125, 4328.6202841704, 16294.276215066, 22813.2525009148, 40474.8597658331, 33794.015986924, 13741.396280421, 22226.6472179279, 27596.3088649413, 24921.0596928097, 32345.057432442, 34061.7529644317, 31493.4051198065, 34021.5275573818, 33268.1631531142, 2537.52424882566, 4074.19371955562, 1445.99026423816, 29305.7816023672, 55643.3918320751, 56029.639847205, 55662.5590095013, 68553.7591341591, 7321.19965600983, 29683.9009883408, 47890.8167455793, 51790.9110335756, 46520.3500606625, 45556.1616903067, 90063.8052253278, 108686.973796726, 10133.1291972557, 20771.436539465, 180.99792663902, 269.188167635067, 93823.9796754645, 104160.939539591, 102678.646139363, 594.073815484729, 857.86544270307, 716.138282657327, 3473.63946872872, 17144.9270619346, 14576.5792173094, 4535.23512731413, 1547.85245625347, 3755.36636147028, 10068.9988766523, 10737.4122578074, 21525.8366791358, 26869.9713366157, 26869.9713366157, 27200.8097536581, 21503.4778373258, 37536.1586148759, 15368.9739026745, 25091.7671235836, 13933.9618405435, 9906.98888902982, 255.167752297303, 303.185109429245, 19337.8582553017, 25539.375337135, 28302.2040977211, 26214.2213200366, 15781.3220132237, 1598.28209608404, 208.210151788166, 13970.5019810973, 14303.8609556435, 295.557739471973, 897.685180032961, 721.525209319147, 8888.55156116432, 13126.1079786317, 2938.52777346029, 2600.41820656301, 14904.6478591268, 398.206028873267, 100.68216531975, 50383.216971105, 68044.8242360234, 65673.8856752772, 16288.826208571, 16810.1470718376, 977.945927521519, 298.745556068201, 16075.2328033676, 55.8837027444483, 4868.62484113524, 19337.8582553017, 4206.28589753395, 9811.70078375269, 1583.01025917516, 2619.70710824082, 27419.3507289026, 24851.0028842774, 27379.1253218527, 3320.18319770292, 2926.75909982747, 4936.85306638324, 91211.881225792, 20980.6484711835, 65550.7758179233, 74328.5270051612, 89331.6225316692, 123272.118013099, 60712.3163424715, 81471.7648601715, 270670.66439592, 286565.874276289, 286393.559060829, 282145.839327732, 59944.3179180832, 59761.3185328254, 59749.2929676872, 5671.39795918955, 177468.129963972, 4041.25475381675, 6399.51254893499, 2916.588173478, 3705.81767691476, 6555.02532257246, 4319.68782261309, 1231.16655235924, 2926.75909982747, 4936.85306638324, 12487.3443239224, 29444.9998864861, 36982.9849286861, 37270.8763732936, 154145.158662803, 73561.6323547461, 55429.448109276, 44359.7426141151, 83.8834666385696, 19.3544779274395, 39931.5015580468, 39736.4766076507, 16075.2328033676, 12223.4579812347, 7045.54832179861, 20563.4842679275, 19954.631359223, 24268.6697765267, 1682.79562704932, 6493.96147313932, 71657.6744265813, 63815.8170582985, 66401.9263538143, 104160.939539591, 102678.646139363, 8843.4396799811, 9159.36349283227, 12429.4127222617, 13798.1627797559, 13223.8734803077, 18459.3015981117, 17666.0908258874, 10304.1846514036, 4001.95870596901, 4357.62032237333, 2044.95565483138, 479.439637011205, 934.561530148578, 433.680398522666, 11955.4856294183, 20261.4186272133, 35391.4869128511, 69211.1124499628, 6658.64678980086, 28383.793612191, 32875.8161969182, 1554.53386779922, 93823.9796754645, 27919.7380792067, 22107.6533568137, 36714.4643213537, 1496.30840177241, 18960.2743739306, 16966.0720358785, 939.647131209686, 765.476897764711, 4871.73614226449, 111789.934048852, 92121.8413885097, 60256.3454301609, 44359.7426141151, 16075.2328033676, 48955.2182273224, 48951.7591891755, 26962.7310796978, 912.718984948469, 1416.68981975299, 136.012689198563, 1839.16910970692, 398.206028873267, 100.68216531975, 14777.9961816197, 14783.5793182651, 26544.8276048701, 14078.7204502843, 28498.8193557754, 88749.2689313818, 54307.6664177307, 4126.57574636342, 5594.24573964917, 5320.4090077886, 456.246954010151, 3829.22724901912, 398.206028873267, 100.68216531975, 29956.0676611137, 16075.2328033676, 93823.9796754645, 137054.108368261, 269659.068930393, 1756.71804561588, 28455.4110235471, 27269.4755077968, 50541.8276552601, 50346.8428863485, 51286.4968049834, 19657.6776926974, 939.647131209686, 765.476897764711, 1262.2684133119, 12291.3579859739, 11266.801878515, 179736.166641135, 136400.061049697, 135941.203728072, 54220.3037111123, 55.8837027444483, 176677.986936227, 36982.9849286861, 37270.8763732936, 82700.7466260773, 77164.1173338337, 39548.0595090644, 41678.5817728279, 1864.15501149668, 45.5777284527176, 285.186697280334, 866.332228040084, 26455.5923366599, 16075.2328033676, 1486.56284342968, 1231.16655235924, 2935.71796008662, 2926.75909982747, 4936.85306638324, 1164.42935736649, 1120.23165424879, 40060.9893187885, 41004.4172207795, 39096.8009484328, 3143.06809689449, 8361.79702232819, 3353.20492654931, 83460.5173757844, 44053.6586087507, 28077.9996817681, 54476.2809265491, 100527.882254971, 41557.4994209142, 38302.3701540929, 16075.2328033676, 105647.216175969, 63976.5444724255, 160870.200205654, 573.852452439261, 2083.39070685783, 352.942099977819, 120.942485019968, 16075.2328033676, 89403.3656786244, 5126.93226620158, 153175.665720884, 20214.7741998161, 47073.193827167, 20044.4035443004, 34693.8203785157, 34332.7400029789, 5985.93861504761, 4494.25507768811, 4232.66633343104, 17022.4519638316, 25499.4244014649, 29890.1209570664, 20363.3884437149, 26297.368448332, 54202.8373803658, 2083.47770302014, 1231.16655235924, 398.206028873267, 100.68216531975, 54560.0369635466, 48374.4764397946, 54847.9284081541, 35080.3499702169, 8630.04477303453, 8494.87746778377, 2995.58915483788, 6659.58587629836, 6121.53628669579, 287926.588907929, 183243.673731842, 403.475288184631, 158.841662440743, 23997.8618907698, 21385.8666620954, 702.361440439901, 339.146718546778, 4642.83450207799, 4856.59030227359, 6308.23964798715, 2970.7430217973, 944.573773670293, 74468.5859618555, 3320.18319770292, 3634.86313150933, 658.254210804327, 24221.4915986223, 22544.7753126547, 48480.7161533392, 39042.7643914722, 41350.0545934463, 658.254210804327, 756.582478900506, 515.205300433674, 138.196239687831, 364181.877560372, 20106.0118947339, 425212.449513192, 30269.523100005, 13318.6028471849, 29447.1962672944, 20132.8275216919, 37794.4347866103, 28502.9484160247, 27538.760045669, 16075.2328033676, 142944.278160054, 121526.555752724, 100790.600450502, 5498.91260517294, 5497.89962073657, 295.557739471973, 897.685180032961, 721.525209319147, 380.817770655907, 25668.5611177137, 26149.893375766, 29875.1866476754, 70248.3287512563, 3458.38954358547, 51181.9525938593, 51389.4861275378, 51394.4814249105, 28502.9484160247, 27538.760045669, 11624.8096425303, 38846.4546213561, 16049.8815240747, 18674.9776162973, 28498.8193557754, 285.186697280334, 866.332228040084, 5022.89768041547, 20280.2611027806, 52331.3531225398, 535.560524728869, 667.663331675873, 566.070592134515, 2789.21564675047, 3417.85851808356, 51636.8556128821, 45146.1863232586, 17936.0706539405, 380.817770655907, 2461.86189231787, 79193.6212417645, 59525.5285814222, 71774.4758630722, 48628.7162421434, 49083.5290151983, 48788.7547758703, 323.072904942078, 36982.9849286861, 37270.8763732936, 7650.20753108316, 48648.0771063187, 351.345341301677, 2592.31169468748, 40800.5984043714, 41018.2921449516, 37542.9403958468, 40846.6076435269, 72729.6941305906, 3542.97822565099, 29948.4484387113, 31608.667549419, 1308.65612835683, 10237.8671143829, 12516.7289868634, 19128.0973172789, 19105.2770592265, 61.2054948271594, 157525.174345415, 1958.30647084039, 2066.63682406262, 2909.79581583743, 1354.4611251038, 1088.60915706118, 221112.801230837, 228191.434515376, 912.718984948469, 1416.68981975299, 398.206028873267, 100.68216531975, 1305.81436396662, 4252.54127455885, 15706.1441985791, 8630.04477303453, 8494.87746778377, 93951.4888595654, 577.071810776637, 217.685457570606, 16075.2328033676, 3313.85856569276, 1912.26404284212, 2309.15705582493, 3317.74993858713, 36953.9591885763, 37340.2072037062, 782.553533695178, 16075.2328033676, 16075.2328033676, 28114.1363224432, 29670.5389515141, 28998.2555552554, 32351.6927399106, 29159.2161500809, 31037.8933862523, 29567.3339599575, 6092.7361147792, 9569.44050119573, 7408.67861428948, 65238.2081225615, 29429.8251711595, 72713.0397708908, 23885.7771369811, 23668.1993826338, 54284.539723499, 55057.1150017291, 62068.9727230567, 58654.5977535733, 50447.0729432918, 50394.4178399935, 120241.083331747, 93672.993420037, 193040.071609707, 96325.9132030291, 939.647131209686, 765.476897764711, 140736.05914757, 35977.7664308614, 156470.894021015, 56327.2348465749, 16075.2328033676, 28022.2047611337, 1489.32643121507, 3168.30818597001, 44115.1837335519, 38914.1648793721, 208002.253246426, 1039.11229841826, 1117.19685248699, 4778.87249697422, 12432.5515288051, 28498.8193557754, 38926.4297052914, 33214.1828464695, 231.255460834852, 170.909633068826, 44511.4447671355, 7469.23445983926, 7787.49016938389, 17017.3657687925, 5469.57680096827, 30071.1111325631, 3346.04523128274, 1029.10560304347, 1463.05182881735, 1084.73118521835, 719.390240453573, 23146.5941589882, 26431.6781739859, 16075.2328033676, 28166.8428570221, 11929.4665981571, 13.2641297538521, 96.6093168295493, 130.189402367952, 189324.494980295, 28994.7240767698, 18846.3312411767, 12171.3744228619, 19626.307134573, 5463.40810599837, 21058.5049226076, 38720.112187526, 43272.3387677838, 42065.2644693067, 50523.6888732174, 165.105593485501, 163.148000537549, 35001.715929987, 34714.0965322037, 3819.03527931564, 3875.96748484236, 41662.4853510659, 30524.7289132605, 4625.80289778272, 5253.58526310596, 2089.18385632576, 8787.29138730481, 736.791696610977, 196473.760448503, 195941.33746191, 93823.9796754645, 1682.79562704932, 6493.96147313932, 1754.80368612371, 49073.2730693428, 51677.3441798858, 8326.61794138679, 43824.3926913366, 4501.64919815621, 141159.307753979, 141389.07226323, 53191.3361597785, 139677.014353751, 144013.736985954, 142144.21106791, 3128.48789290818, 2866.89914865111, 587.827601893559, 17117.6399252047, 16588.4930900653, 16382.5181991665, 21589.6388750012, 25084.7320010508, 96704.8114140605, 100657.499990203, 131877.725240573, 63571.5935003966, 55150.6945182499, 1633.15449807794, 1863.22909358396, 1440.07334372282, 4252.54127455885, 15706.1441985791, 4304.8217217668, 55569.4197694361, 54915.9745292278, 108232.994835704, 123795.091264856, 242.915519629276, 5907.78032222474, 13124.2742916264, 5844.34474653451, 6500.60861442523, 12700.8464668468, 95890.8092683587, 95890.8092683587, 21164.8992934744, 18935.3915638729, 16608.023500998, 17564.140246683, 3020.62466064264, 25905.0893420694, 10133.1291972557, 20771.436539465, 17604.0845576829, 17234.9080669705, 1417.0080902942, 535.778320926114, 35.9876265013509, 430.335507715417, 153175.665720884, 104047.08063166, 103185.328162331, 12665.7856554632, 12405.587837941, 18270.349054044, 225460.400362246, 182687.84118689, 184156.552547001, 205792.307701904, 3250.18045410655, 380.817770655907, 444.531221452017, 2402.93670619426, 160292.0996721, 158809.806271872, 4684.69752876139, 5602.6361924112, 2413.09287048808, 211.594602574613, 3520.99104595635, 83576.2606250436, 6809.05416385813, 5354.70929570943, 5347.52039485329, 5352.41306642329, 122754.071056673, 32922.3717758076, 14745.9645551399, 4392.70036543696, 6157.64051216331, 6483.95043195557, 153175.665720884, 1149.02549371943, 1619.6063582169, 311.913501026464, 1864.15501149668, 24271.1577820147, 1856.15162274216, 3840.51455639174, 4191.50580289979, 165.105593485501, 163.148000537549, 24752.9792207351, 40522.8520295367, 4334.42073566198, 51126.2729967447, 4024.86775196434, 34478.6920134024, 33182.0312966663, 23471.933335201, 24034.0853977506, 23267.6401948618, 88525.1188681499, 49600.7868545241, 885.387831514171, 16075.2328033676, 84547.0143760505, 84487.4622463408, 22813.2525009148, 40474.8597658331, 48560.4957620367, 11590.5993193077, 28.5425439295029, 737.564022643526, 39358.0583797923, 40061.1583548606, 40511.842035412, 26157.8145281948, 138692.198384127, 61368.2192910547, 32939.1179965398, 74.3657790574448, 19414.8215595163, 19442.7030549334, 2337.65585492165, 3662.70814647698, 209729.318946865, 281579.009155069, 158319.401627426, 180.99792663902, 269.188167635067, 3403.68072063434, 2654.23909431, 534.334391326376, 23.6343697154393, 380.817770655907, 12082.6547167457, 4281.21844051456, 12633.2787748487, 13612.7199512589, 6278.1849341522, 51283.323938868, 273524.250711415, 283628.065183922, 283773.279353248, 16075.2328033676, 398.206028873267, 100.68216531975, 17372.1137511474, 8081.654826498, 13454.699312598, 64970.8069419449, 79347.5606545383, 77656.8317008736, 66258.5594624337, 16266.6696982451, 28624.2736146935, 198.425829261069, 15794.5291319482, 166.572650378446, 77.7053430151971, 124.704628097013, 6674.97302012422, 24336.5802850426, 1261.03329977177, 1871.26483497435, 391.531497495759, 1193.30472402282, 2281.20524789561, 1626.70684676574, 9223.21516881004, 12559.3057801235, 13763.3011700571, 33077.0158479722, 28328.9385857456, 59614.508407503, 39946.4157471607, 2411.15507062695, 2418.443002543, 2558.98389487755, 380.817770655907, 79419.7749346339, 14602.1489954547, 398.206028873267, 100.68216531975, 16075.2328033676, 6646.7769955005, 1231.16655235924, 26369.448786526, 30615.5847323211, 99566.6253232767, 91145.72634113, 90160.2793711759, 58547.9586392746, 58637.675392149, 9179.4351480092, 230.266926232439, 287.506179290898, 314.997237832076, 38914.1648793721, 1637.11263354618, 5811.28951558421, 2989.49900525221, 252243.8534938, 8828.66122502488, 31461.5587619452, 31289.8742605205, 1907.95719201132, 4233.03670063375, 45314.8425920429, 62400.0410969691, 16075.2328033676, 36982.9849286861, 37270.8763732936, 2679.25218223047, 61187.6395926012, 52.5569908071031, 9991.67336354495, 34931.286989279, 24265.5313464059, 343.276443974901, 42773.7987658876, 52376.3381147366, 4287.02798381562, 19723.6841685878, 19257.2156142163, 4814.9191544167, 29683.9009883408, 31692.1972719867, 28333.1608861245, 26432.1350689899, 54012.0180663093, 54299.9095109168, 2681.81080887255, 90698.4578104438, 144044.890995276, 15529.2642685819, 27210.841311611, 53571.5299417105, 26465.0672820454, 1089.00540085492, 509.317551434586, 22813.2525009148, 40474.8597658331, 149561.987542043, 92402.9954471136, 93001.8048574988, 165047.710639945, 129893.894881701, 1231.16655235924, 131286.785684354, 89616.1139808104, 186509.769714039, 16933.3908009589, 184725.689757738, 55.8837027444483, 52.1147236033839, 939.647131209686, 765.476897764711, 8831.05194223026, 21445.3919765118, 366126.939611927, 362235.715714671, 367039.100233137, 363363.810774753, 323083.406347295, 361472.649745964, 363161.926517215, 55643.3918320751, 56029.639847205, 55662.5590095013, 2926.75909982747, 4936.85306638324, 40925.7864645752, 39813.1478383524, 7650.21302182265, 6674.97302012422, 24336.5802850426, 49558.8453729988, 4001.95870596901, 4357.62032237333, 64837.2452882707, 56555.2061960915, 97769.0328496656, 9743.19586511631, 8217.8131354631, 1261.79575722989, 16075.2328033676, 667.663331675873, 566.070592134515, 16075.2328033676, 24478.8222567985, 179890.702995304, 16571.398660606, 162847.133950872, 75894.8113200732, 56226.7186597309, 22844.9492988855, 2926.75909982747, 4936.85306638324, 52458.8403883743, 51443.9290133242, 50495.5706171656, 28769.5317442929, 11869.3770757686, 16075.2328033676, 84131.3213344214, 127677.957716347, 87091.9553699722, 87020.1611335103, 1512.324774643, 2150.05803676888, 783.959518459601, 1363.46302791599, 14111.3194799416, 39938.7398555284, 22102.4439992288, 153175.665720884, 36982.9849286861, 37270.8763732936, 74468.5859618555, 52.1147236033839, 22941.5016408479, 16458.5311383836, 7586.91289307513, 2970.7430217973, 106808.984359433, 98673.7188302859, 266084.691769458, 109340.826373206, 108620.481842201, 66703.1824109853, 36982.9849286861, 37270.8763732936, 42511.4798772977, 60256.3454301609, 111.537810954324, 11.9265340475962, 53606.3301405669, 64087.9132179879, 12395.6682257128, 22813.2525009148, 40474.8597658331, 19599.5049812013, 16075.2328033676, 12223.4579812347, 7045.54832179861, 535.778320926114, 35.9876265013509, 430.335507715417, 1864.15501149668, 860.668209128104, 4161.90570649953, 871.067280945304, 6747.12546673929, 3645.44673864661, 6785.19894598399, 38782.4964950819, 5236.51152444444, 5699.56053771781, 30800.5326705703, 38940.776032533, 12407.8977026144, 31836.0678393978, 36982.9849286861, 37270.8763732936, 65457.6602244695, 111.537810954324, 11.9265340475962, 121093.186968869, 1932.7577262328, 16562.5015385432, 17321.0487098954, 5513.74171656778, 4620.43191662203, 4658.50539586673, 139.59668729804, 637.051939728638, 720.536221174176, 129014.301025699, 29956.0676611137, 309592.033701842, 165.105593485501, 163.148000537549, 227887.186711648, 211828.009373633, 258785.940674695, 159969.076006689, 53026.125812917, 17103.3377944688, 5995.12944494798, 48.8008458005068, 275144.226616386, 252282.754752916, 256351.557055521, 238907.025478626, 255476.133956044, 241179.618116072, 16075.2328033676, 21442.8583355827, 939.647131209686, 765.476897764711, 90558.9058840176, 398.206028873267, 100.68216531975, 19337.8582553017, 659.145255279456, 11174.3535333551, 19060.9875728843, 16239.7987385163, 36982.9849286861, 37270.8763732936, 153175.665720884, 1444.1210645491, 19.4546922960994, 22813.2525009148, 40474.8597658331, 2815.96026109652, 398.206028873267, 100.68216531975, 2663.94040905034, 1249.56781999344, 1342.65699269506, 11624.8096425303, 38846.4546213561, 42264.0370309069, 4001.95870596901, 4357.62032237333, 10175.5821778987, 38914.1648793721, 53188.7704001565, 58522.9973977792, 53476.661844764, 1856.15162274216, 13577.2233638382, 21883.1563616332, 37013.224647271, 70832.8501843828, 8280.38452422076, 30005.5313466109, 153175.665720884, 47450.2260517822, 15885.3539141143, 51905.5677729975, 47060.2348500278, 48465.7297221292, 48114.2266355855, 54996.5700087004, 53820.1793270818, 29956.0676611137, 4867.17473573299, 4620.43191662203, 4658.50539586673, 165.105593485501, 163.148000537549, 522.202254010239, 4406.00864028319, 152816.939112793, 144.790442368183, 992.21923976955, 577.373333829017, 31461.5587619452, 31289.8742605205, 73160.1313106901, 38940.776032533, 12407.8977026144, 31836.0678393978, 667.663331675873, 566.070592134515, 44609.1020645368, 37355.941560786, 76454.6179215845, 86164.6584825914, 718.518143963733, 727.188300957344, 920.884958456139, 982.896121892898, 728.997281282361, 10259.6945092305, 93951.4888595654, 22390.8030821832, 95596.7326093315, 126038.029012847, 29956.0676611137, 1487.02653647761, 108.827511339023, 8374.27855826392, 107496.038999335, 39417.6812632426, 3972.09937150983, 5403.15075178146, 6343.52825591555, 33701.3557018473, 94512.7842676877, 540.437273333271, 16075.2328033676, 285.801915600917, 764.939284101423, 1827.99691820983, 353.787856191927, 2330.71552901222, 16075.2328033676, 5313.63679626936, 3817.9386968542, 80688.3262966511, 188181.179570729, 299394.611563735, 182928.207723053, 121133.819807441, 268700.857248724, 2628.96344158434, 1960.33487492317, 23732.3780584946, 3667.12138455096, 94694.7736645351, 25380.3344637447, 22901.1064831176, 9661.00808813282, 290.814857083104, 71599.3044980899, 14421.9368704328, 19030.6795230451, 16010.6303694444, 39097.3620723117, 16172.7656895537, 44359.7426141151, 171952.155226778, 46436.2922967545, 45283.2848224753, 8502.86451795858, 2942.2403187696, 3110.78916261453, 55538.1916713392, 54463.9133783609, 55924.439686469, 764.82895950078, 5058.91508368307, 3923.84893372032, 344.515894474898, 11830.7751692186, 11651.8924337135, 90080.1567216211, 15923.7456525716, 847.870581086446, 22862.5927338473, 23067.2798001301, 8735.38821956893, 7783.95325788539, 2970.29654265218, 1508.12227310438, 1470.69528398545, 9696.51006616501, 61286.9972871029, 3960.88317471543, 29322.7313673382, 26004.0587963621, 9696.51006616501, 4328.08401478133, 3978.1100761442, 33584.8151607183, 34212.5592881898, 37321.2483355852, 5969.67095239207, 7751.58874088763, 4785.36439328066, 136.012689198563, 65569.5708002545, 65019.6126056549, 24039.2250274514, 153458.374764131, 93431.0449970498, 136.012689198563, 26621.7913469792, 1063.60090266067, 48.8008458005068, 2926.75909982747, 4936.85306638324, 55.8837027444483, 16075.2328033676, 59096.8163409224, 51231.6252950158, 2926.75909982747, 4936.85306638324, 1616.44586620644, 902.016725515691, 1420.17436353492, 73904.6549983483, 73922.1903020445, 19337.8582553017, 144329.208557319, 398.206028873267, 100.68216531975, 36982.9849286861, 37270.8763732936, 34975.0365561811, 551.960124234927, 36982.9849286861, 37270.8763732936, 9743.70311561861, 9870.34794622175, 400.993672632477, 496.959371783375, 1007.79460327982, 667.663331675873, 566.070592134515, 29022.0149688602, 98850.5875765531, 7428.76074139372, 23791.2738521886, 16971.2246831511, 58302.7244983047, 380.817770655907, 1637.01441826392, 41962.6523769007, 42717.7109154456, 41753.5225450899, 55643.3918320751, 56029.639847205, 55662.5590095013, 477.099810914381, 1108.52591653732, 14356.175242238, 28438.1441569848, 76543.4998152575, 8814.97677244159, 8811.15456221555, 351.345341301677, 42670.4220509817, 3977.01837445735, 48502.6106109542, 70344.1468671987, 52381.2823817447, 71893.5136239119, 62184.1849128726, 263350.310819749, 78287.4669856566, 3991.44182856068, 1811.69695200155, 26071.9745337913, 87.4529205426775, 997.36331334313, 19337.8582553017, 4766.58504822056, 969.325974174402, 68174.7441609302, 262012.085695931, 97176.260699008, 22813.2525009147, 40474.8597658331, 6594.42840997139, 4456.94251146803, 112571.345559209, 4291.98067892521, 380.817770655907, 19337.8582553017, 16075.2328033676, 428.194296702893, 327.67556996714, 11262.8136356408, 5134.07365950494, 128415.184477162, 135793.596569761, 141148.546655923, 27043.3178229638, 29542.1949442316, 98532.0935620021, 71014.9297888196, 550.417770616348, 9.41058813544714, 12104.1508331759, 14318.3762864921, 16075.2328033676, 16000.1429240728, 15998.4780911284, 32939.1179965398, 74845.1581371533, 55177.0654768109, 464.580352875118, 20743.3330285867, 24259.6365876355, 1033.05943232783, 28502.9484160247, 27538.760045669, 125027.328131395, 110195.08589204, 136158.697641845, 127616.524905653, 128308.666677946, 112271.659423434, 110728.129064029, 69570.7211389348, 40126.715717159, 87024.6468699532, 80421.0186754373, 86719.0573350366, 16075.2328033676, 14356.175242238, 55846.5549344759, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529483, 25460.6460476849, 36982.9849286861, 37270.8763732936, 16075.2328033676, 116.113033013679, 56.4271046072093, 18469.5189941293, 18549.5098847969, 153175.665720884, 1532.69940745025, 2414.02256409977, 1966.64563322413, 32939.1179965398, 1892.89094015922, 2010.4169496854, 34108.3824754557, 36607.2595967234, 9316.88293902355, 8721.89167776235, 7522.29072823977, 807.599472915153, 523.267400229887, 13902.1926931588, 14139.5820121751, 4252.54127455885, 15706.1441985791, 1535.66201166634, 672.067237144709, 279522.166440429, 212966.576290534, 255.167752297303, 303.185109429245, 55353.7647349047, 79152.0240843425, 73015.3719998231, 212.408446192817, 218140.331007518, 216658.03760729, 218548.401851315, 77201.8915702578, 11673.1349720002, 15911.2189583794, 9805.11516396335, 15984.9141957112, 27.5689710286836, 884.659944766603, 118.817472434866, 177.982547299709, 112.727124468353, 652.827118362417, 11371.1566155374, 19197.2943504418, 14019.3846910057, 2672.85699433128, 16075.2328033676, 14356.175242238, 85306.609714591, 88727.814169282, 20649.4564331897, 40739.3812029535, 79062.6016385558, 74545.2796501054, 79522.2725181898, 79434.1528129072, 20252.578050347, 63571.5935003966, 55150.6945182499, 38102.3727928803, 53606.3301405669, 21207.9320627651, 2926.75909982747, 4936.85306638324, 16075.2328033676, 210869.074978838, 175875.561494108, 160256.103327739, 191200.982318495, 46675.3178998997, 26782.8703268322, 70077.4516855593, 68526.3828087604, 69879.8079490264, 45828.0852168248, 18487.6420109134, 3263.63297233387, 5040.54247213971, 12565.5950069777, 109.054466574646, 5643.58312478785, 1098.75430738303, 2981.39193806094, 15230.9873526267, 60256.3454301609, 74468.5859618555, 11315.9628576188, 2933.19333388922, 250593.856078877, 857.86544270307, 716.138282657327, 27612.1327046701, 2755.22546706941, 398.206028873267, 100.68216531975, 172300.524786367, 21207.9320627651, 4616.76980542257, 1574.88973526905, 5134.07365950494, 9405.64270706611, 5990.7220166665, 10090.8947812896, 23866.4754482235, 91712.6485474508, 110435.021056021, 59208.2985405046, 57180.2694126751, 4064.42384351391, 2245.53547767326, 2040.63877884098, 16317.4028086314, 14039.6388820606, 667.663331675873, 566.070592134515, 78716.405353903, 2039.27270097841, 573.852452439261, 2083.39070685783, 21592.4348473964, 39254.0421123148, 10550.6129336412, 12102.5784775613, 35402.9427583481, 62232.7023452814, 62227.6823985002, 3083.07213428639, 7447.61302877449, 2723.6992310697, 2216.06791691439, 4966.60697537566, 185392.337993236, 20556.5129963128, 2228.27583735487, 2529.44268346106, 3448.26005818695, 73574.9552922195, 80804.3798125565, 31962.4088063783, 49624.0160712967, 31288.6628338547, 15523.0050514232, 16075.2328033676, 3400.31951597058, 2279.52350770112, 2889.7550429037, 3087.21651532844, 19337.8582553017, 14501.3923222412, 11093.4738338845, 5149.1243976634, 1632.34266262339, 247.045541658672, 25258.8892866758, 33236.2858289789, 662.74366164328, 662.74366164328, 1934.8555507788, 610.959651876815, 2235.13211748969, 501.764732894915, 1459.96585583202, 1647.11463281722, 1647.11463281722, 868.369103451818, 1973.0937797026, 4621.24117720512, 4799.47772899749, 1651.2658384956, 2014.18638945188, 391.531497495759, 98850.5875765531, 61669.0868353439, 4755.6883615648, 47961.8564079353, 12487.3443239224, 380.817770655907, 854.935635892897, 385.386809890281, 583.737029424752, 126.762004278028, 29956.0676611137, 16075.2328033676, 6674.97302012422, 24336.5802850426, 47450.2260517822, 15885.3539141143, 18172.9724805578, 26118.4625205342, 380.817770655907, 85306.609714591, 181816.88563871, 22904.3243956398, 19918.4110274579, 1078.62984126406, 24271.1577820147, 1872.69835733611, 3828.31149676547, 76596.721914708, 55584.9569056254, 34568.5137529239, 127951.402909314, 1348.26163508099, 1086.77552713723, 2212.30926121041, 61406.381468242, 28955.8553417832, 1774.80187081428, 10136.5761778576, 7106.27431670089, 2097.682220922, 5464.04886155535, 530.472063038322, 8012.27983129867, 25673.8870962171, 89988.1933233015, 1589.58422758006, 168.253484264981, 22791.0605828707, 40452.6678477891, 64751.8929857613, 67441.1977506126, 52870.3433816979, 161258.176560508, 160844.177594828, 8955.74725983867, 55643.3918320751, 56029.639847205, 55662.5590095013, 93823.9796754645, 126675.781553948, 108292.406586506, 133905.206074285, 38922.0397555033, 32431.3704658798, 16075.2328033676, 25455.1533746543, 9085.64339813866, 11102.3742181498, 74.3657790574448, 11624.8096425303, 38846.4546213561, 19337.8582553017, 3333.30711948458, 18790.6852829664, 37448.7667123955, 16075.2328033676, 3161.68949867507, 23425.5179844675, 25992.1653824804, 99373.9465582884, 342.55533010548, 31789.1416899254, 1881.02471102513, 676.269484835168, 16075.2328033676, 29269.9331394896, 26738.3543131221, 44359.7426141151, 1350.54561753717, 1746.17025009247, 13884.1871548504, 12319.7358746413, 6229.41796736924, 24101.0306950624, 22399.2073363062, 10557.4129520362, 76835.0917296158, 78915.998588696, 78666.7623296846, 1864.15501149668, 13900.8139628033, 13511.5779558541, 12303.8422468536, 63571.5935003966, 55150.6945182499, 380.817770655907, 1806.55959727361, 28.5425439295029, 737.564022643526, 1864.15501149668, 21442.8583355827, 20489.1692981774, 3781.3416399493, 135219.545576814, 3683.32640687501, 83890.7345119835, 87410.5672507294, 87693.0789671487, 89796.6847797268, 28502.9484160247, 27538.760045669, 10853.7688073958, 9924.17532472495, 36870.9833731792, 1636.3387577496, 2555.65784578012, 85306.609714591, 76695.5697286669, 55683.8047195843, 34667.3615668828, 128050.250723273, 29956.0676611137, 2100.82140989689, 1182.09032364635, 873.757996628427, 46418.8032688663, 35575.4172872022, 17712.7998355385, 204070.125282766, 208832.795547852, 209627.349440927, 3801.20825531493, 2399.6137324643, 2796.50674544711, 1930.80389378471, 32939.1179965398, 8408.38358766359, 16075.2328033676, 93823.9796754645, 56323.4799706448, 35311.7149615622, 14295.2718088607, 107678.160965251, 13531.7668343418, 93823.9796754645, 36982.9849286861, 37270.8763732936, 642.301879534228, 663.468610305428, 40649.6537371088, 3156.39087867493, 3320.51300889577, 42683.6921716962, 11375.2727607338, 3685.66431028875, 87565.5858333572, 85846.5316685534, 87699.2839148422, 85695.1277979803, 61037.1497689119, 39052.1970762826, 39995.6249782735, 38088.0087059268, 29956.0676611137, 7790.8812173317, 7790.90833392026, 111603.892498398, 38372.9030102482, 38995.460260127, 41889.9121956419, 44583.3915106863, 42620.9020573729, 16075.2328033676, 380.817770655907, 15187.8873202767, 37302.5845014617, 9838.35492305386, 11188.2584690038, 10739.8203475058, 1788.77444134187, 55460.3593763331, 2594.24212100073, 3547.04595907261, 41300.2939972772, 42472.3172214099, 43431.4906754905, 78.7528842154161, 38914.1648793721, 14210.5988219155, 23858.4541056816, 22151.4853492053, 10280.8944908633, 78288.9388873545, 1356.38091482097, 284571.815144345, 285086.579015856, 141.322077516658, 929.647613201762, 130432.774697115, 80316.8657901285, 88300.5741090331, 88738.7401298826, 1138.40393106052, 3767.98371671679, 66957.6578211244, 222.542397379737, 165.105593485501, 163.148000537549, 19337.8582553017, 6818.67597781236, 4019.98951284539, 1767.55487050511, 36982.9849286861, 37270.8763732936, 38914.1648793721, 11491.5610129913, 7926.47887782163, 9194.7213374349, 1856.15162274216, 165.105593485501, 163.148000537549, 2495.43563613076, 7325.83890684172, 123414.183252659, 172876.108447666, 103746.090592316, 15027.2293927086, 4659.33208516771, 1133.82617786274, 169545.111237265, 149877.018576923, 7272.62066865355, 380.817770655907, 12487.3443239224, 87862.3508866386, 45097.7129377761, 38554.523109514, 41616.6844380206, 14639.5074554906, 16445.5702733604, 1103.25729153255, 2914.66482374556, 877.138717320541, 812.486590138844, 52882.1079713832, 3740.32348974564, 17091.5223628584, 19599.5049812013, 13.988046340612, 0.795547373363888, 2269.75975290979, 4045.73857437827, 8005.86669414135, 9302.12728822785, 4456.94251146803, 31789.1416899254, 681.437660722141, 37319.9539963416, 36245.6757033634, 16075.2328033676, 31591.831814151, 32803.0652755293, 49925.9498120114, 32326.7647055941, 50628.8691802761, 47741.9651002123, 14226.1504977607, 14625.827277826, 74.3657790574448, 1204.95323789083, 8473.2487535164, 14119.8496430008, 15327.572765483, 8278.19485304665, 19337.8582553017, 53624.5027648667, 7716.1684813387, 22172.9871675276, 22438.1150342672, 14043.2063402693, 3443.81838334729, 4780.00607223178, 5024.80212765631, 5023.25794834704, 52635.489794463, 89240.5457093225, 135368.885011212, 109731.819690874, 5945.38434219785, 9018.50921814871, 35899.3979848361, 30173.4319885217, 14790.0611965957, 55643.3918320751, 56029.639847205, 55662.5590095013, 2135.40019886403, 960.428498512439, 2731.27900493364, 2538.26410936149, 4620.43191662203, 4658.50539586673, 60674.0567835322, 56856.7520277835, 48.8008458005068, 7712.76481211331, 8053.65291900602, 22635.9056437391, 19697.9814168526, 52628.3726326205, 45733.8809422093, 63395.4882071277, 45446.4720021269, 3.74488937492447, 19337.8582553017, 2686.2511654795, 29936.8690037648, 28645.4392662743, 38914.1648793721, 2435.56709350915, 2621.27242155993, 11370.7101112596, 19676.6431090546, 34806.7113946924, 68626.3369318041, 6073.87127164214, 27799.0180940323, 36894.9170405414, 3173.13547856176, 2768.99187028832, 3197.05867273829, 67.4924095059996, 18515.5155112178, 36177.1227761362, 53909.823051173, 62853.7747765658, 9126.32759727666, 36982.9849286861, 37270.8763732936, 29956.0676611137, 110.441908169989, 16075.2328033676, 24870.030408406, 24892.6745238987, 38914.1648793721, 2286.40719863082, 7877.80933095407, 76695.5697286669, 55683.8047195843, 34667.3615668828, 128050.250723273, 67563.8055072966, 112102.331048552, 65785.8628731573, 9696.51006616501, 16075.2328033676, 653.655775426585, 360.499288035191, 807.838380903096, 107020.984285254, 114099.617569792, 53277.0454175642, 32605.0892018463, 162054.01606239, 183225.289170653, 192893.793293983, 191930.136041599, 177753.757765274, 109785.23504849, 103551.541713781, 107601.131100836, 103035.883584314, 4617.71351581079, 2600.0791643643, 12487.3443239224, 1604.04546060564, 871.767144042084, 114217.367476722, 5672.77152049826, 5081.82604885728, 7449.68102030409, 115509.603186028, 18418.2779035728, 18573.7842013003, 43731.9622484382, 51980.5115017779, 28726.5460099411, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529483, 25460.6460476849, 36982.9849286861, 37270.8763732936, 53534.8567311206, 50880.9094513748, 52899.4415876215, 132544.192675562, 104380.059731011, 126572.989604283, 125609.675858814, 103092.442441411, 126837.193145392, 38914.1648793721, 29956.0676611137, 4456.94251146803, 31789.1416899254, 37437.2080264048, 44292.9623709701, 36740.358340575, 24122.5675543193, 11615.1473628981, 4001.95870596901, 4357.62032237333, 4001.95870596901, 4357.62032237333, 45051.4754530819, 80009.9534806213, 30923.4247645318, 31973.8855124749, 286.091120181027, 19337.8582553017, 30579.2310374927, 23732.4680305181, 136554.60741004, 116886.514749698, 11370.7101112596, 19676.6431090546, 34806.7113946924, 68626.3369318041, 6073.87127164214, 27799.0180940323, 88525.1188681499, 49600.7868545241, 796.164423027838, 93823.9796754645, 16367.7518053689, 16302.9790000617, 14356.175242238, 33812.3032072605, 16827.9992744552, 17876.9322666397, 5199.48914162513, 7310.08566795073, 28.5425439295029, 737.564022643526, 9254.65276098091, 17560.5857587759, 32690.6540444137, 66510.2795815254, 3957.81392136342, 25682.9607437535, 48640.523743867, 89.0849779412126, 54838.8633566907, 67002.1730693264, 1484.65328510058, 591.620405798511, 490.027666257153, 17495.8644399082, 110.144521346197, 32704.1761908844, 37730.3088928585, 2894.62766262561, 658.254210804327, 22398.9654166579, 22593.6520232493, 307.103135136199, 257.12486051682, 38914.1648793721, 16075.2328033676, 17270.0569563309, 21728.8676435586, 25928.4736891228, 32745.7711314928, 34460.4689344714, 1486.56284342968, 7688.85194506656, 37448.7667123955, 29683.9009883408, 1864.15501149668, 123904.776846619, 134693.97664289, 380.817770655907, 44998.474376128, 46691.0657772289, 57844.08509469, 9965.14750177418, 1230.13346044966, 30655.8341124462, 61558.4713383006, 37566.6029107695, 14534.8586332968, 153175.665720884, 93823.9796754645, 22813.2525009148, 40474.8597658331, 49452.6430198405, 19614.5939079335, 19760.9096950493, 20441.7468830656, 104160.939539591, 102678.646139363, 58999.9631732753, 78140.4194521693, 3717.78716509019, 4063.05589236591, 184.267843884025, 28.5425439295029, 737.564022643526, 207.140771853515, 174.018472194646, 90609.7108301421, 73466.8504626465, 80217.9153480769, 1552.10875111636, 1253.31958534311, 10177.7232552941, 8267.39480371269, 6291.01145054712, 6189.26682949271, 8253.67572975828, 7819.11217485265, 4520.77925115079, 57223.3032639385, 116167.738413064, 121.620466588186, 5.78559118236115, 16720.761254025, 16348.7727181757, 18560.3061018092, 74.3657790574448, 6674.97302012422, 24336.5802850426, 1012.56210112466, 1658.13449840418, 28022.2047611337, 1489.32643121507, 32499.9069935158, 171778.196857634, 131164.501201432, 130996.1276528, 152110.104197292, 130938.263351767, 22482.915018219, 22238.918489934, 25276.9338494591, 22854.4629740336, 35221.733850409, 32632.91667946, 33067.1324317175, 32108.2308077898, 32094.4404903957, 30675.7270404814, 1829.15237311077, 100527.882254971, 3198.20199161574, 3951.35973793132, 16075.2328033676, 54197.5231587763, 57169.8646303063, 52699.3936438119, 34605.5501767839, 52987.2850884194, 1098.10801204631, 1098.10801204631, 1276.3210831928, 1109.09106037749, 78104.0996549812, 47706.0664359833, 58436.0069946388, 20933.5945364974, 21458.3081114037, 21053.1700585322, 20943.7340738461, 1913.45015322525, 165.105593485501, 163.148000537549, 23327.0658348538, 39916.8287725567, 743.854366255563, 1290.25196549189, 16075.2328033676, 27844.7297148313, 27844.7297148313, 95665.511566691, 12746.7607988716, 14003.4977493873, 4620.43191662203, 4658.50539586673, 667.663331675873, 566.070592134515, 12487.3443239224, 4562.73259917194, 59099.9079934169, 59212.9064034715, 59846.9310676191, 58982.3038144261, 56373.8761099139, 12218.8713077111, 4510.24439902771, 3450.67577613694, 2662.61918073936, 5072.88418520369, 150701.604821942, 15488.3146608201, 96947.2405810525, 91324.7128484818, 58454.1441932773, 1231.16655235924, 33474.4226409377, 33386.5419077751, 16075.2328033676, 38531.8086435148, 64037.364888943, 6464.96180599924, 110480.107271517, 108192.985577961, 130208.266453322, 118339.428916092, 110968.685525819, 116087.365270693, 112356.894482514, 5109.52841342016, 5999.02843659974, 14517.9296752013, 13368.0690154604, 85291.9908663405, 16939.2076130313, 18764.9928364869, 38102.3727928803, 9179.4351480092, 93823.9796754645, 62588.9929009505, 26464.6077449709, 19878.1744258682, 18897.5726407439, 34016.4713847544, 275392.240993234, 296737.693281641, 288147.820138348, 287601.975631052, 329152.028973788, 322400.511388906, 197622.880843441, 296875.831340076, 8374.16482430504, 4405.4852828101, 1864.15501149668, 643.923645342334, 52312.8583349405, 52742.836171228, 9971.40497675922, 53606.3301405669, 21207.9320627651, 1231.42181179091, 1581.70244271285, 1588.9903746289, 2926.75909982747, 4936.85306638324, 70151.333751545, 49649.4120088504, 15365.7317411117, 12976.2424239751, 15330.686751561, 45832.0279771142, 46142.6695432388, 45416.566939226, 16075.2328033676, 723.765891286958, 761.542780130787, 699.352234097839, 192241.2985922, 192773.036422745, 197431.262602867, 4383.38525943078, 206.102244941948, 436.176840447964, 13.0210905868303, 1231.16655235924, 65065.7497861239, 1412.76821665531, 4439.66144429365, 28022.2047611337, 1489.32643121507, 19135.0893095709, 116048.726244148, 116606.749311867, 63571.5935003966, 55150.6945182499, 391.531497495759, 4589.82918538859, 20676.7128812771, 22744.3445920546, 20127.0314505095, 12592.030165145, 3568.66913417615, 3183.81482057256, 1261.03329977177, 1871.26483497435, 61678.3941724292, 84913.4236328461, 61584.8114211731, 21593.3531921218, 16483.7669943847, 4543.005008474, 19337.8582553017, 42537.2010122291, 43294.5776535178, 43192.5169114383, 74.3657790574448, 59063.6053327163, 55.8837027444483, 4208.55253769903, 4142.65449269978, 65155.244807026, 53905.4266440693, 54193.3180886768, 12687.9615775658, 12725.5810365213, 108987.933384987, 37281.9944074152, 106519.425982855, 14822.6199143262, 19607.4430295809, 6264.6264287296, 964.67805995575, 529.222019978935, 54140.3252711063, 100981.367936237, 56530.4362156383, 77044.4035869105, 142457.500578421, 146911.354655212, 122973.202170902, 145951.178012354, 129998.416679775, 78375.3978920788, 135967.019217417, 79132.3184853053, 139126.691022525, 125609.464166505, 11940.9534715809, 10537.3707094334, 27995.9811834532, 16586.2755020388, 49920.7006337194, 29269.6720822945, 617.48359386835, 9.12199578433297, 36982.9849286861, 37270.8763732936, 45140.4068798525, 53909.823051173, 62853.7747765658, 12931.0161960051, 198465.6983481, 43911.3974010671, 44247.1988635001, 32997.4804607704, 41648.2240673178, 85306.609714591, 5954.46819449568, 6035.25721638796, 31857.7267634389, 18427.9214008552, 1230.13346044966, 28779.705242883, 17272.0104929045, 17100.5870834611, 8483.9310789461, 9827.17525946496, 16731.6592805509, 5156.09399619595, 15901.6697637082, 15531.0667177567, 56910.2300583595, 2926.75909982747, 4936.85306638324, 228133.669690929, 229192.825965708, 229718.74307122, 13153.0940490681, 4194.79720251721, 222429.033885837, 223250.219142458, 16075.2328033676, 16075.2328033676, 200.880466402473, 44359.7426141151, 6003.42308817357, 5578.42490268206, 84435.5925192723, 14356.175242238, 33991.6874912037, 86093.9354714919, 6888.388951365, 33955.7607960512, 35689.3025465174, 47612.4624579388, 63571.5935003966, 55150.6945182499, 33662.4733888684, 89.9569446043147, 45959.978742447, 45439.6251944115, 23696.1742760948, 22583.060482915, 2273.66628986441, 16878.7399006516, 30973.5798496895, 20922.636926032, 32454.0385599316, 75125.2288338277, 74010.0036989764, 3477.7786659692, 38914.1648793721, 53612.7880250716, 272941.649595596, 225289.320859142, 330990.367529877, 273229.65269343, 266010.403936316, 269888.991672869, 255753.130830513, 256637.006326792, 234468.649066957, 334086.144278414, 253731.172468182, 245332.295092693, 276311.030058244, 37322.3636485763, 1948.91010609371, 1174.15838554927, 1063.88962196208, 632.984537694608, 2164.50905008392, 2471.20912910516, 93823.9796754645, 16075.2328033676, 15274.6686206953, 6674.97302012422, 24336.5802850426, 6264.6264287296, 964.67805995575, 21442.8583355827, 3533.31138782213, 2683.19186304844, 1864.15501149668, 14184.9836151071, 16667.8066822032, 8223.61511468137, 255.167752297303, 303.185109429245, 4659.85046246713, 166.572650378446, 16075.2328033676, 12782.724199466, 27296.6706797147, 29566.8389693184, 1979.276984159, 2733.61736953555, 13724.3172928578, 13394.1301240815, 129626.557448174, 321955.279212436, 124978.438063979, 129571.844023154, 182915.41999789, 187072.441593078, 162752.49790597, 181433.126597662, 5742.82193782201, 1908.59114836289, 1003.44204296612, 5733.80190699746, 2036.14425736038, 1767.80822129169, 8787.29138730481, 150477.727810327, 150672.279121789, 127582.58381994, 139059.917637574, 133041.507545159, 1222.13360700813, 534.929670399472, 515.856579229091, 149.616593585133, 29956.0676611137, 13208.8904053529, 18180.3788380272, 1456.36694956513, 1319.80255939971, 1634.58002071163, 1023.3122550351, 5706.73961707753, 5076.43176688941, 7483.64911688336, 307.303707156227, 626.138801443826, 1921.39145622923, 1990.78596599304, 39931.5015580468, 39736.4766076507, 752.006047488311, 744.660230554516, 301095.873999799, 220302.758074452, 46311.1447953471, 46787.7406434059, 45496.9061928519, 7754.2166880541, 31111.9162030986, 3254.39662479641, 3403.60426416333, 40312.1951127871, 35615.1082150141, 40154.2746752923, 78747.2746131727, 17443.358810995, 17379.0339900044, 16794.1011171382, 17079.018822017, 14418.2268456167, 9392.07231933674, 19337.8582553017, 1544.15672002622, 1322.62261875306, 2087.47142869769, 4001.95870596901, 4357.62032237333, 4316.06271679858, 2689.64904879238, 15881.931532926, 9436.62852992599, 7434.5183521477, 7552.98115204013, 1008.93628426974, 75482.5204691513, 81910.7535491703, 71871.2920881413, 15058.2162159271, 16075.2328033676, 83097.5053456626, 103725.810367891, 90590.8374918006, 90084.0987899106, 38120.3321461751, 70650.1057261311, 29956.0676611137, 883.659008064973, 846.232018946051, 1636.3387577496, 2555.65784578012, 37985.9273087296, 36799.9917929794, 35995.1642822198, 36767.73956045, 43779.5972817775, 40365.2223122941, 32157.6975020126, 32105.0423987143, 38569.2137107637, 32667.0234531894, 33286.1149763152, 39450.278563853, 34064.1781086581, 55493.5768492114, 7408.67861428948, 166.572650378446, 11272.2367444065, 11346.2434899338, 7403.0063720298, 3487.61150126468, 55125.2761815281, 38914.1648793721, 6209.75846218885, 23046.6385072794, 19014.9399931232, 18607.8321494227, 3419.78018687112, 23103.4588896023, 36982.9849286861, 37270.8763732936, 3263.63297233387, 5040.54247213971, 6536.66301768838, 5676.09974478764, 29409.4300483002, 4369.90659892624, 136.012689198563, 398.206028873267, 100.68216531975, 2236.8661960339, 4223.72299389699, 398.206028873267, 100.68216531975, 17293.334383969, 535.778320926114, 35.9876265013509, 430.335507715417, 66623.3263215092, 67009.5743366391, 66911.2177661167, 66642.4934989355, 41472.6404613106, 2595.72742028362, 712.496849801259, 13.6446995588202, 257.969813736824, 8758.51316115088, 2832.13513115466, 11973.1462862575, 32939.1179965398, 16946.8648060307, 17197.014656299, 228499.314309229, 228347.50068248, 16075.2328033676, 36982.9849286861, 37270.8763732936, 35572.6599599241, 29956.0676611137, 4001.95870596901, 4357.62032237333, 28665.9195857364, 128019.874583473, 23391.572889387, 16075.2328033676, 27530.4466366291, 202.51101307757, 220.330205787814, 27043.3178229638, 29542.1949442316, 658.254210804327, 29956.0676611137, 3532.33304806931, 601.071009089264, 2204.23158655703, 2192.99876120082, 2430.82263816723, 29956.0676611137, 36982.9849286861, 37270.8763732936, 16075.2328033676, 16075.2328033676, 3198.77148476733, 3916.27634077136, 19337.8582553017, 13430.9483498091, 16075.2328033676, 35762.8695849685, 23036.1481661357, 23929.6455723292, 12487.3443239224, 2426.44600814486, 207.140771853515, 174.018472194646, 141336.145454005, 122744.031055788, 132836.156722899, 342676.164310753, 343190.928182264, 19115.9530983382, 7410.23380925932, 7707.65444020188, 7745.31135295238, 9162.81944293926, 261879.953849376, 121989.379442961, 10053.7579107728, 2692.63611859071, 380.817770655907, 7053.26745540345, 235.985927847079, 2282.09506899778, 55643.3918320751, 56029.639847205, 55662.5590095013, 121740.562651823, 113319.663669676, 114806.045835075, 112334.216699722, 51231.6252950158, 130925.840986491, 152375.975011277, 30769.1951186004, 33268.0722398682, 2104.2569259859, 2275.3787980012, 31698.6036273209, 6028.00910412306, 36982.9849286861, 37270.8763732936, 93823.9796754645, 666.915014712587, 1137.49587921006, 25396.2235757651, 19040.9810501281, 36702.5883150465, 350.206256987162, 59.7099635404267, 36982.9849286861, 37270.8763732936, 14327.0287101337, 74790.1497815539, 95450.6663381779, 16807.1972290683, 13640.7169832752, 47451.4031450722, 6417.14463380188, 32821.2775407264, 15334.7380774587, 391.531497495759, 113850.38727144, 1687.3907925202, 1879.52512438332, 2541.41353395399, 28502.9484160247, 27538.760045669, 92938.0215397739, 81090.0626863962, 61421.9700260538, 36658.7120847623, 3691.70076417485, 3332.32786095816, 17957.9506892189, 664.598079073716, 53934.9343504391, 4920.6679645992, 14356.175242238, 93823.9796754645, 10721.3305500717, 19337.8582553017, 4707.0617378078, 5998.88372324693, 19035.64534308, 18667.0092597408, 93970.774067387, 709.367510197726, 104.911427043819, 382.244651502849, 116.113033013679, 56.4271046072093, 8372.13491741287, 380.817770655907, 939.647131209686, 765.476897764711, 37632.6627186177, 36668.4743482619, 6721.10003806489, 36982.9849286861, 37270.8763732936, 37319.9539963416, 36245.6757033634, 7523.75467359141, 20252.1312488726, 7368.00888817486, 6511.54378618934, 28502.9484160247, 27538.760045669, 19842.2417666199, 207.140771853515, 174.018472194646, 512.456256639008, 2241.11088363222, 60256.3454301609, 1636.3387577496, 2555.65784578012, 13247.2016673941, 12154.9176151439, 7625.37106805759, 31804.6372601163, 16723.2563138418, 78966.2170280767, 67910.0758433488, 42388.3899942557, 78488.6113285123, 78153.461556694, 90926.3598260507, 3567.33473436492, 210.623004280547, 9781.68181908518, 12828.8302335551, 172378.126128186, 152710.033467844, 135917.461328615, 187537.544651454, 187322.794054275, 98679.1170102981, 92735.5537456321, 16075.2328033676, 1098.21904366061, 2422.60300332476, 24715.8262370963, 9837.92377465362, 8971.44347985864, 32143.4704234966, 28.5425439295029, 737.564022643526, 1412.22009106794, 1241.1340850347, 19168.7248879393, 30878.1164627099, 17388.8412625143, 17366.4169865942, 17453.2993196772, 19334.2664456436, 748.556548429188, 477.914743024454, 6099.26304118264, 7442.5072217015, 18534.2292652687, 19871.1939048245, 8839.19293719553, 65919.4581156191, 295.695471427636, 897.822911988624, 721.66294127481, 1528.49091485835, 54789.2500793389, 8977.17596971751, 11087.7724960431, 9131.31277481613, 767.659794592033, 1454.77456326011, 845.864607914582, 16317.4028086314, 14039.6388820606, 883.659008064973, 846.232018946051, 101998.951577098, 103848.601854869, 87036.6611255633, 28502.9484160247, 27538.760045669, 12544.4904958423, 10939.8421721262, 448.653718429222, 258.582596713439, 4294.22965452007, 4294.42414545881, 4296.48450366967, 17334.4339361896, 17509.0380274443, 9283.02367210432, 10370.233168829, 9290.5987299709, 9333.62315464112, 25313.2849419891, 217875.207060492, 201816.029722476, 248773.961023538, 149957.096355532, 22604.5147546427, 734.638875649947, 38914.1648793721, 207379.278434549, 125068.719490618, 7284.94464057689, 32939.1179965398, 21403.50194931, 28.5425439295029, 737.564022643526, 7292.68118963279, 207329.328297082, 31461.5587619452, 31289.8742605205, 885.387831514171, 1063.60090266067, 73371.034258731, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 3728.49898930883, 4040.8154131577, 4001.95870596901, 4357.62032237333, 123000.179360901, 121621.103566701, 121484.722282529, 122850.917205328, 37319.9539963416, 36245.6757033634, 6679.73361917437, 18291.7941708458, 26.5363792937224, 18.026444278936, 50129.3931508622, 33701.2049335417, 4480.12432927184, 5269.3538327086, 20917.4844765944, 16075.2328033676, 9576.2893509225, 24271.1577820147, 31461.5587619452, 31289.8742605205, 16075.2328033676, 52925.0539860187, 30124.2639028086, 29956.0676611137, 64353.3297851525, 65478.683235832, 2625.62648152534, 3554.11735195358, 37757.9099011842, 13826.2058999632, 106314.130681859, 83478.1110423414, 83309.7085191184, 171632.147905808, 987.858683850167, 444.516286152885, 342.923229576262, 3349.38512541549, 4288.30833629401, 22.1186361879498, 16075.2328033676, 2762.80445813404, 460.941746962774, 27043.3178229638, 29542.1949442316, 2021.5931249974, 8733.52190362541, 11945.5378372105, 53972.0966035937, 39855.6275763572, 50079.8439159438, 4001.95870596901, 4357.62032237333, 56994.1068628128, 55214.0695889306, 56803.8735307158, 56909.5999001618, 57736.0143119272, 54618.7395211911, 40104.325268411, 109043.249908057, 67181.2791987516, 56285.0822078442, 40706.5628246039, 9072.66653533737, 70053.8996534609, 54702.0545046425, 55717.9471500361, 67214.6325340557, 67015.3065364626, 681.437660722141, 290786.821722641, 1260.7749038034, 1196.12277662171, 111836.886471339, 111836.886471339, 133209.463385579, 133505.502578976, 176269.584195323, 239725.196185243, 162382.581321969, 3165.08794658356, 40219.4121066097, 41416.1392771814, 41300.0742581644, 5322.64402075399, 8916.66545688654, 11151.3253457809, 47308.7265660449, 49183.5946577544, 2393.10740203385, 2177.66441343433, 97846.0685297032, 83334.7513584655, 57114.6273256259, 78177.9758693609, 48854.3564093352, 133991.010237997, 30188.880442688, 129818.909694684, 121430.396207678, 134478.309584338, 28455.4110235471, 27269.4755077968, 380.817770655907, 49.6978887724682, 49.0608110406474, 642.275025754166, 4406.78328006853, 79796.4462926299, 14726.7812075028, 23185.7461695197, 10391.0538365954, 36982.9849286861, 37270.8763732936, 196099.342225111, 398.206028873267, 100.68216531975, 18442.249194715, 6021.05462493087, 50351.6887333157, 171670.975028125, 148174.552665336, 16075.2328033676, 16075.2328033676, 380.817770655907, 16075.2328033676, 10539.9732541717, 5285.07023754642, 11109.7776753418, 22563.3805993621, 18962.7233400404, 10216.3076722676, 29330.6706407086, 373.911097421504, 1864.15501149668, 132676.801167117, 74269.486593038, 77241.828064568, 74566.6114175358, 78698.3356363601, 45102.5911606318, 62.1064308541099, 24759.5898207334, 85161.6106248031, 16506.0972844472, 17191.1614700544, 17405.0301213916, 24004.3227376429, 255.167752297303, 303.185109429245, 23738.1430048852, 18959.6531337017, 36621.2603986201, 77698.8666480926, 77302.7515297671, 86086.6545736971, 86904.4295695527, 16075.2328033676, 6481.10656491351, 8727.26868228432, 6277.62774791792, 6618.99798969893, 3938.04783467574, 7814.47805543532, 7395.18644660074, 259846.541893784, 252243.8534938, 75999.2909413296, 36932.1856312094, 7439.0042844802, 136.012689198563, 7229.43293932532, 75181.7586486951, 205.948417057369, 13.4714075500078, 398.291634309268, 3179.58083942866, 2552.93125234306, 1284.35931701759, 60256.3454301609, 4814.39197131151, 24954.3107210148, 30129.6870793073, 22152.3939462509, 25974.2422801527, 153175.665720884, 20793.4277794041, 3226.89675550796, 1099.00964046036, 52925.0539860187, 29956.0676611137, 299631.562383766, 89608.1540002479, 166486.935972951, 197336.292042721, 3.86877047562848, 55.8837027444483, 26332.212969649, 1809.65118691383, 414.956943109339, 9032.33806491232, 17338.2710627073, 7112.5025761645, 100344.646397673, 4887.80488798865, 9179.4351480092, 125148.270887331, 33033.9962026151, 14453.3425616295, 27755.499433914, 26798.2581804295, 29817.5686070855, 23997.8618907698, 21385.8666620954, 55915.410543523, 52888.0439224559, 34692.3622060942, 44357.9604089767, 104821.081480397, 125481.598037021, 2894.62766262561, 19337.8582553017, 6139.54056009143, 4794.65529716429, 26832.7995949944, 535.778320926114, 35.9876265013509, 430.335507715417, 37609.9206055892, 70090.9631906641, 20876.1683097793, 9425.27850855039, 380.817770655907, 111960.704671604, 103539.805689457, 106253.705141434, 106253.705141434, 73384.2822773089, 70732.9589271241, 53606.3301405669, 21207.9320627651, 47125.7363399674, 313637.633232719, 180493.006821904, 211342.362891674, 1459.96585583202, 17334.4339361896, 17509.0380274443, 29956.0676611137, 206.652717893827, 34667.0600823998, 19169.7346162735, 69866.274582556, 13915.680122719, 13546.7523198088, 9584.152387915, 16091.0376736456, 153175.665720884, 1971.62787504435, 1499.11050352675, 718.895592447867, 2486.80429051696, 398.206028873267, 100.68216531975, 16075.2328033676, 1343.17433566773, 76.8940550146904, 390.339954616517, 93823.9796754645, 110.144521346197, 14356.175242238, 7964.78276562149, 153175.665720884, 62769.7950983742, 28827.4376123513, 36982.9849286861, 37270.8763732936, 4001.95870596901, 4357.62032237333, 352.942099977819, 5780.38873429405, 5911.73139329342, 2926.75909982747, 4936.85306638324, 55.8837027444483, 9990.38551919708, 10218.7782218666, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529483, 25460.6460476849, 8470.16334457858, 5703.49696830159, 47836.612387009, 2926.75909982747, 4936.85306638324, 1856.15162274216, 682.029291087356, 4452.00028990605, 3738.72706472858, 18532.4130843569, 18675.2821026964, 33246.0118566354, 33187.5391191829, 3400.54771970459, 55.8837027444483, 19097.2832549869, 19129.6610388453, 100527.882254971, 72260.1891931475, 71613.8687666516, 83436.2454957935, 667.663331675873, 566.070592134515, 213.127908077519, 5033.04607707885, 4501.22001711581, 295.557739471973, 897.685180032961, 721.525209319147, 1058.12222965094, 2078.65845198898, 135814.880327048, 153982.061403686, 9175.97589707613, 304437.246616294, 301836.88002746, 398.206028873267, 100.68216531975, 767.659794592033, 1454.77456326011, 23360.899725085, 39361.5319147998, 23503.7687434244, 1078.62984126406, 16867.9883489059, 380.817770655907, 15750.5380315222, 165.105593485501, 163.148000537549, 5023.86029939158, 19337.8582553017, 104160.939539591, 102678.646139363, 59383.2623424327, 13292.9918703534, 17551.0465680989, 17864.9359702411, 28809.6894399389, 85306.609714591, 89988.1933233015, 15358.8383216072, 121.620466588186, 5.78559118236115, 33701.4201449138, 2045.87341356367, 47450.2260517822, 15885.3539141143, 9641.46443154389, 2187.40639533237, 5784.2521876207, 5822.3256668654, 46706.938322827, 12536.4052722068, 14280.2734835701, 11770.9580582019, 16075.2328033676, 19337.8582553017, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 472.058349739684, 777.586645640291, 27546.1825957374, 28511.8447447272, 118.044279934204, 29956.0676611137, 9842.70742387815, 9937.80004043506, 20863.8438087922, 400.993672632478, 496.959371783375, 1007.79460327982, 3295.41541861314, 1039.55350661595, 3151.23582908743, 2896.02936815971, 13155.5365574643, 13143.4412231219, 13125.9903269655, 372797.791726039, 6809.05416385813, 103343.079978853, 102267.654187499, 15724.6083974267, 15734.7479347754, 2080.02387941595, 311.454613547011, 652.093248476968, 358.523749941245, 26803.1118346336, 18204.5454149357, 33991.6874912037, 7319.32292546929, 46717.3927221604, 46686.1297754383, 47144.8148491079, 47980.1736666974, 43170.4220150599, 153175.665720884, 6754.68935613241, 6908.82616123102, 16243.8524543047, 19337.8582553017, 6872.51732497081, 3434.98067092909, 1039.8549294792, 1438.51019612108, 20874.1375378148, 18879.9351997627, 11565.9054413183, 398.206028873267, 100.68216531975, 4001.95870596901, 4357.62032237333, 1494.47226158637, 1968.65319070841, 8164.77719259632, 66052.1668020421, 66974.925983037, 42846.4813278909, 13007.1812274955, 26966.5909985441, 78743.6123019614, 74116.5650785906, 74502.8130937205, 74135.7322560169, 74518.7937044902, 38914.1648793721, 16075.2328033676, 12487.3443239224, 43296.7793675834, 31617.7205653819, 14451.3285696793, 391.531497495759, 85109.0536176848, 85693.6229197137, 60256.3454301609, 16075.2328033676, 136.012689198563, 1547.85245625347, 3755.36636147028, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529483, 25460.6460476849, 14074.624322903, 4886.5080008083, 5031.08554024964, 9894.98960473101, 4896.32245494989, 127575.205254904, 113063.888083666, 86843.7640508264, 107907.112594561, 85718.2566455446, 97213.2485573607, 4456.94251146803, 31789.1416899254, 74468.5859618556, 148.96931621408, 392.758584534458, 410.754491483078, 4028.51467947899, 3872.35623409832, 3734.35019781469, 44292.1437860922, 60522.3052734248, 988.98126580948, 1896.83231142931, 1231.16655235924, 4193.541670942, 4875.45025311416, 16075.2328033676, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529483, 25460.6460476849, 40683.8191607831, 1773.28067786811, 41033.4063687099, 4358.55312385092, 4038.40079129511, 153175.665720884, 3317.74993858713, 38940.776032533, 12407.8977026144, 31836.0678393978, 16075.2328033676, 45688.1639062682, 939.647131209686, 765.476897764711, 5811.28951558421, 2989.49900525221, 91086.1603294284, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 11926.3973191353, 28137.468559337, 55643.3918320751, 56029.639847205, 55662.5590095013, 3663.30231606121, 3794.66422804525, 12487.3443239224, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 200.880466402474, 34553.4880542934, 35575.4702473679, 85306.609714591, 1016.51998726852, 798.748861134099, 956.436268557543, 1105.06212704932, 5631.11673770491, 1636.3387577496, 2555.65784578012, 58591.0695156547, 58878.9609602622, 64492.9942371399, 36982.9849286861, 37270.8763732936, 535.778320926114, 35.9876265013509, 430.335507715417, 6674.97302012422, 24336.5802850426, 13027.3160893058, 16075.2328033676, 52684.8573539623, 14397.7228337455, 26532.2080240805, 954.96316208986, 2731.27900493364, 2538.26410936149, 8787.29138730481, 380.817770655907, 44359.7426141151, 22813.2525009148, 40474.8597658331, 95957.71587313, 3013.76849698571, 391.519204227073, 1718.53600697751, 933.619181772469, 42529.5174159411, 35644.2150611762, 433.132429023618, 564.778806224201, 709.994459269384, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 172.584973036458, 87.6629534755182, 4001.95870596901, 4357.62032237333, 4019.57058350848, 3558.35833429495, 14108.0390285809, 1400.74266578408, 1393.4349648508, 1665.33382305915, 120.942485019968, 36982.9849286861, 37270.8763732936, 7893.37931890678, 55.8837027444483, 4046.29066394961, 2282.76929529624, 7093.93514138624, 3775.44286118853, 1174.88804254983, 162.697498121248, 13593.7896978067, 21899.7226956016, 37029.7909812395, 70849.4165183512, 8296.9508581892, 30022.0976805793, 11602.3475761035, 116.113033013679, 56.4271046072093, 1477.82761272786, 29161.6174486761, 106305.976274394, 93823.9796754645, 29.4891742640255, 131.543230074176, 50144.8161279369, 48869.3403399161, 40060.9893187885, 41004.4172207795, 39096.8009484328, 13531.8977644274, 3379.41380826927, 15172.118590297, 9877.62764798867, 1599.91328556599, 1484.50152993265, 398.206028873267, 100.68216531975, 63571.5935003966, 55150.6945182499, 3611.70915651773, 4815.70454645128, 40314.2458521653, 53025.6133973696, 11654.0664558477, 22885.6916094685, 19197.4488015368, 18576.111012987, 1105.44047382744, 1643.24188350687, 1332.55575849036, 65065.7497861239, 286.444632280221, 1279.61237595292, 4001.95870596901, 4357.62032237333, 939.647131209686, 765.476897764711, 4832.73910023211, 2284.9639582692, 85306.609714591, 49502.1933404199, 32047.5209990725, 31856.5523742818, 2166.16492250022, 2512.56121882425, 24956.6284794536, 9462.81337408141, 9781.06908362604, 470.422379258816, 2027.49722422851, 1596.14063143149, 1515.41634919425, 4999.02431487006, 4333.10977529671, 44424.0921445311, 54227.7741746525, 2926.75909982747, 4936.85306638324, 2677.88306647104, 1383.02585596076, 398.206028873267, 100.68216531975, 32684.8726778877, 32170.2178902543, 666.915014712587, 1137.49587921006, 83445.3361198853, 42514.5892522111, 30512.5938708932, 42628.6608754818, 30282.9503217166, 42511.0299525196, 132.977985957547, 155.61043086903, 380.817770655907, 1280.96426683924, 18476.1418075856, 3291.77593065794, 13093.4665420476, 11748.0455877037, 19337.8582553017, 207312.578193898, 20093.4085307662, 2332.89544155671, 9869.73877132115, 19337.8582553017, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 106274.019028977, 90837.5540804111, 82824.7650441328, 61813.0000350503, 61609.3742860584, 40796.5568823487, 134179.446038739, 9639.67119403886, 28074.4046175653, 3214.12416058994, 3341.46433952071, 602.431608520084, 107686.732444097, 108225.843155044, 24271.1577820147, 24082.3802734419, 2945.74692998072, 1048.45825736338, 10458.2880127193, 5498.91260517294, 5497.89962073657, 23592.9102729604, 74.3657790574443, 100145.720931038, 91724.8219488918, 93211.2041142908, 16075.2328033676, 380.817770655907, 132.977985957547, 155.61043086903, 58499.4282996651, 4580.0937478358, 391.531497495759, 6674.97302012422, 24336.5802850426, 54574.5066999164, 80647.5458729707, 72236.1139648348, 70587.0837584257, 81656.0345975752, 71006.0233457464, 69865.1754040887, 31244.872194001, 39493.4214473407, 5149.1243976634, 11210.8428894724, 87717.5490403122, 90481.30614284, 3019.45389866225, 6043.40378251175, 7327.5011300752, 19337.8582553017, 153175.665720884, 2150.76057383058, 11629.0775533624, 29290.6848182808, 257.224430960302, 16075.2328033676, 380.817770655907, 28631.6071519938, 36982.9849286861, 37270.8763732936, 36982.9849286861, 37270.8763732936, 31461.5587619452, 31289.8742605205, 6623.97743006213, 6002.90569022454, 10662.4099013128, 8294.1734653621, 2757.9002845596, 8507.9292655577, 38914.1648793721, 233219.84568364, 673.529729328414, 750.451299329575, 1306.64557131441, 1269.21858219549, 1763.63929966896, 27711.377509827, 28466.4360483719, 45976.3035920134, 45546.5528499577, 16752.5322583189, 56365.8183456555, 35382.1361450556, 28047.9809374163, 17305.6483936032, 117236.179949463, 1768.91135350572, 2271.62996430812, 19097.2832549869, 19129.6610388453, 60256.3454301609, 391.344131248787, 6675.27087509316, 4027.16956022344, 148.004023152807, 43477.2767954516, 74468.5859618555, 67050.3198831379, 65117.2475555427, 12036.0549515629, 18229.5014058069, 872.947559077592, 462.529244081492, 1386.92651759727, 177284.569601983, 115737.044924171, 84238.4588543115, 36982.9849286861, 37270.8763732936, 195140.038680026, 175471.946019683, 194124.841186997, 17279.2239720536, 1222.13360700813, 534.929670399472, 106810.9262398, 91672.1544135676, 2325.39917129701, 8205.91273723204, 68188.3668569187, 28329.2882238683, 4843.72190583069, 6771.96105911908, 71943.5516035958, 3496.04738410235, 426.433258535804, 1011.67106148182, 205.948417057369, 3388.17290705375, 1489.62586146814, 2267.69288065616, 5333.29117195581, 7724.91485095787, 93141.3250537491, 93159.2253674468, 14057.3173737222, 79427.2912962753, 54535.2103516901, 54989.9279646545, 15662.7027146355, 531.766514320605, 197.749300889454, 352.942099977819, 120.942485019968, 17144.9270619346, 14576.5792173094, 16075.2328033676, 201.921554556655, 1325.18158921821, 1412.22009106794, 1241.1340850347, 40597.7395117183, 16028.5790926527, 41525.4419173454, 22230.1945586201, 60318.6157149059, 61506.0237473628, 63361.7844263304, 60447.9435374575, 59699.24115596, 165.105593485501, 163.148000537549, 53681.7957203762, 107952.262097113, 59888.0971842537, 62166.5424049689, 180751.062444821, 31892.3910713408, 25710.7460734468, 93531.5279253066, 39966.4927831072, 79877.6209043181, 80836.8142818876, 89010.8939140615, 85167.2710933782, 74496.4466057285, 74421.8372538773, 1231.16655235924, 252300.140318517, 255164.509223357, 1987.6655739414, 29392.5453407188, 4816.65523436457, 9179.4351480092, 75338.6114549663, 107773.721384067, 41992.088815113, 18936.2757583182, 36597.8830232366, 44511.4447671355, 1247.85143198612, 464.810235215233, 49039.0118359232, 98581.4569505123, 62535.0957505061, 21587.118275869, 939.647131209686, 765.476897764711, 3850.03792530492, 29267.9222597617, 24920.7888973912, 28248.7581162308, 12245.1359694737, 8908.82807956876, 20477.0810553827, 930.56598884138, 6284.52450425089, 8440.75073864778, 6176.48254864273, 48905.6865979965, 53968.6410615518, 18257.8165639896, 35919.423828908, 15766.0320094713, 15441.1950123264, 200.880466402473, 418.849896114216, 343.088309115343, 1172.41986012349, 606.059567727308, 63609.3785010555, 148.1698452394, 942.563043519036, 1046.99525242921, 26496.0632322425, 27140.7249977331, 3630.85199179314, 5439.75898151133, 255421.458901604, 210520.03499845, 55486.6741746049, 51601.4603519145, 57624.2738888342, 60.3909505990891, 94941.5518581774, 156432.459587338, 175605.095368964, 13910.5098350685, 13337.2668256549, 88051.7135056316, 37220.3029536803, 36982.9849286861, 37270.8763732936, 38020.6619011088, 38197.5890286788, 44359.7426141151, 2471.25650273097, 5964.79104172685, 9225.76909737704, 49715.4866110084, 39070.6904396267, 2926.75909982747, 4936.85306638324, 3946.08184166062, 48747.7823359169, 48250.5583733709, 876.187790402431, 10286.0175457584, 217875.207060492, 201816.029722476, 248773.961023538, 149957.096355532, 664.927604283919, 28502.9484160247, 27538.760045669, 84538.05415983, 185392.337993236, 20556.5129963128, 9658.4779523469, 12248.0766401073, 10640.893254664, 1438.88076464098, 153175.665720884, 8164.29141514406, 35272.743304281, 40766.273006542, 55.8837027444483, 412.624802354742, 276.657775336949, 50963.1512918397, 10926.4153341806, 11232.4231096855, 1521.4874084693, 1425.44573122892, 5456.27850512041, 63571.5935003966, 55150.6945182499, 16075.2328033676, 3183.81482057256, 7969.66035924351, 8833.71981975875, 29956.0676611137, 380.817770655907, 47836.612387009, 186527.978900707, 190446.792440026, 16075.2328033676, 28502.9484160247, 27538.760045669, 47568.1690686503, 50432.5379734911, 55643.3918320751, 56029.639847205, 55662.5590095013, 483.014123243695, 551.03545670155, 457.350898839505, 142241.478983736, 71326.6606803989, 1343.16034337497, 29956.0676611137, 2426.44600814486, 23427.135373479, 15316.8838625395, 45397.9077297282, 46750.3885912946, 98921.9652336526, 103523.71342908, 5035.40269654205, 8770.99671641627, 5902.50027377277, 10778.7013389514, 18916.6509294119, 47197.0108921771, 168873.536172332, 1483.33022655674, 36982.9849286861, 37270.8763732936, 5805.7552485181, 90976.5578105084, 37935.908100123, 238052.568689295, 158793.49240022, 3432.04718788301, 1741.18934677076, 37241.449776783, 34587.5024970372, 4975.99138411238, 312143.702030069, 288882.449716306, 283936.370669754, 284151.277389964, 311356.875152423, 288684.474713462, 310833.255027242, 313035.314289443, 311033.146621035, 244.451717062043, 365.854085462469, 170.800716250559, 26015.1132174876, 4140.4035489135, 4145.87607372417, 3187.7173966304, 70559.1429585911, 196212.488563385, 163790.035591034, 164326.625682026, 160104.21827268, 5672.77152049826, 5081.82604885728, 7449.68102030409, 4922.048851197, 6176.93572846779, 60107.4538463989, 52452.0711782953, 54822.6822315959, 13891.648879358, 1297.02578107137, 18129.2052968253, 16075.2328033676, 1222.13360700813, 534.929670399472, 576.807541478588, 974.254334765185, 79896.6519520766, 35422.0081135327, 19354.8068921899, 19667.7846983662, 37201.9589468583, 56608.8373607729, 157915.644061441, 75154.0447938475, 29956.0676611137, 53909.823051173, 62853.7747765658, 67091.0498294596, 65528.4571936478, 16128.4246792098, 13575.1936437391, 317.427924008591, 305.730843181664, 98955.60275924, 93970.8576864598, 89830.2433664856, 21396.0651887841, 1535.43317107445, 1313.38360721386, 153175.665720884, 4456.94251146803, 31789.1416899254, 16075.2328033676, 291981.363898936, 291924.491024185, 19455.052001756, 31534.915929451, 23978.4721706065, 24284.4799461114, 34692.3622060942, 3449.34554186629, 4236.41538533069, 45314.8425920429, 62400.0410969691, 4001.95870596901, 4357.62032237333, 380.817770655907, 400.993672632477, 496.959371783375, 1007.79460327982, 100414.253634336, 81826.405713255, 25181.8965109711, 27920.3780232754, 28862.6796453447, 29733.6951566551, 8489.87079627615, 8176.950430354, 7710.74260826317, 8505.22805411887, 23841.7102516162, 62011.6468547839, 42343.5541944415, 80000.4830063654, 29956.0676611137, 28498.8193557754, 17091.5223628584, 352.942099977819, 120.942485019968, 2981.19217640419, 6092.7361147792, 54.7479894023345, 25100.0464322166, 666.915014712587, 1137.49587921006, 136.012689198563, 7691.27943338792, 8785.64759605363, 7263.66591522562, 2926.75909982747, 4936.85306638324, 405.937732055221, 1749.30945917116, 32939.1179965398, 667.663331675873, 566.070592134515, 1231.16655235924, 64612.1486710363, 64916.4216441706, 7751.58874088763, 4785.36439328066, 1910.42128104539, 1695.51653621786, 52925.0539860187, 1164.29532068955, 13206.7253691176, 73574.9552922195, 80804.3798125565, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529483, 25460.6460476849, 30327.0088274984, 32004.3059374326, 28145.5009330477, 31189.1981811114, 51231.6252950158, 33824.8079918068, 25634.5954946092, 52966.7946730665, 10061.1697181628, 35000.7833438968, 24335.0277010237, 412.772798592705, 74583.0911817935, 54914.9985214511, 16075.2328033676, 55.8837027444483, 6288.05315951029, 6851.72391832141, 2836.84564159496, 64653.1838458866, 65256.0373149593, 38914.1648793721, 6674.97302012422, 24336.5802850426, 65876.7917823234, 55643.3918320751, 56029.639847205, 55662.5590095013, 52376.3381147366, 37640.6493496251, 45146.6277288187, 4832.75450638188, 4869.58697886867, 17864.9359702411, 10152.5158977106, 97935.1365240164, 109757.513253158, 47134.1388477728, 49781.7477460521, 2875.71034250341, 3361.05247095723, 36982.9849286861, 37270.8763732936, 686.088875912981, 3611.85709321779, 99148.9535328762, 90728.0545507295, 88495.0975939282, 4001.95870596901, 4357.62032237333, 5902.50027377278, 10778.7013389514, 18916.6509294119, 6987.34986417011, 4001.95870596901, 4357.62032237333, 3942.25947323037, 3354.65746052506, 3897.36036551492, 83593.0903790087, 190339.60241803, 189421.625858336, 175248.574806269, 1823.59458743254, 1893.62473784441, 1366.11084585865, 34172.1973164336, 1349.19409950295, 2726.84215747307, 1581.70244271285, 1588.9903746289, 17393.9630245537, 20450.5566822138, 18697.8749489521, 19910.1415969105, 13117.1214746318, 36982.9849286861, 37270.8763732936, 6209.75846218885, 4001.95870596901, 4357.62032237333, 3620.4443646707, 21673.2305458373, 22629.6879993062, 18642.1096796797, 99439.6070374987, 100138.60550966, 102070.343576272, 27043.3178229638, 29542.1949442316, 667.663331675873, 566.070592134515, 2345.46199476762, 3852.38696510946, 36982.9849286861, 37270.8763732936, 63623.1985047773, 64175.579870593, 807.599472915153, 523.267400229887, 9083.82971181822, 18603.8940427135, 44974.5310970714, 32602.274519434, 327635.48383281, 337253.907661769, 340375.031428864, 325263.178649817, 36982.9849286861, 37270.8763732936, 9032.33806491232, 17338.2710627073, 954.96316208986, 11368.0286559487, 19673.9616537437, 34804.0299393815, 68623.6554764932, 6071.18981633121, 27796.3366387213, 44337.2993869377, 4001.95870596901, 4357.62032237333, 152120.572302137, 164604.694454292, 10696.2430234787, 601.868707290059, 326.441222681459, 73416.2689840748, 62851.0164609327, 93823.9796754645, 22484.1901273836, 38071.2218751628, 20970.0781790241, 1192.16891851584, 5862.12891536664, 7872.22288192241, 14880.572903076, 29742.845776986, 17576.67834925, 386.954245877936, 2772.18937355112, 6674.97302012422, 24336.5802850426, 237123.970783316, 237053.701834988, 106732.305688204, 91593.5338619723, 23763.0897000209, 1033.17261861494, 51075.3532942306, 14193.213621535, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 8684.77038549894, 3389.428110952, 10491.4620583035, 232449.70272813, 380.817770655907, 158138.445119361, 5984.9783371001, 1974.11209246546, 956.565989564562, 25161.5820613546, 71233.6833693912, 3197.05867273829, 67.4924095059996, 187691.680679734, 24842.617960658, 11617.9713919086, 24144.7414109125, 17840.7803148696, 17660.2287963385, 969.79445282124, 22395.9084028209, 34441.8154401673, 38914.1648793721, 16992.1647849917, 2104.98233089024, 19.3344304127309, 2112.27026280629, 351.345341301677, 136804.42165617, 213583.876094279, 137066.564588064, 162930.51404261, 137493.235597373, 130.189402367952, 84435.5925192723, 34752.4516948551, 36654.4612881035, 36495.2484725668, 36418.1161699503, 28498.8193557754, 16075.2328033676, 5890.8677830668, 5936.66524224353, 2894.62766262561, 87770.3901689243, 67352.9806158084, 84352.4425261721, 35868.2257390822, 85288.3119519395, 68145.451584444, 154054.347116415, 149285.329776698, 398.206028873267, 100.68216531975, 26694.3326506435, 28629.841320925, 260.482788713516, 5139.45604460607, 4408.54817631947, 82028.3537375055, 82407.0273522647, 11355.6945624467, 10549.7035926678, 11240.4231548716, 99863.4268788019, 91442.5278966552, 94156.427348632, 347.866481790658, 317.268927416601, 872.327715142949, 608.318066899785, 16075.2328033676, 42891.6549907222, 104658.019429821, 380.817770655907, 95709.5942215713, 49945.9413169829, 12342.6911615731, 5238.64778769604, 13672.6316571664, 170898.446472214, 16075.2328033676, 177284.569601983, 115737.044924171, 84238.4588543115, 1856.15162274216, 374.838070904152, 10507.2413246721, 2509.89782944552, 46107.5342565551, 55608.8097819573, 46168.3647027603, 309592.033701842, 65100.5420650995, 1012.56210112466, 1658.13449840418, 1459.96585583202, 15587.6197039678, 1084.73118521835, 719.390240453573, 380742.891720349, 366135.917466074, 381409.583142897, 365312.426748824, 368203.961442927, 187703.003527581, 190192.204802227, 169598.127257928, 270872.445951028, 296736.42380479, 190079.330025681, 255421.458901604, 210520.03499845, 8480.38305096107, 7965.49758427161, 409.590807306403, 1856.15162274216, 671.038980503116, 616.072940100319, 7523.75467359141, 20252.1312488726, 7368.00888817486, 120298.418795421, 103645.544488544, 111877.519813274, 102551.922825262, 6680.1301969538, 4398.92767838269, 260731.40489844, 249748.759044441, 106076.163881031, 29956.0676611137, 2731.27900493364, 2538.26410936149, 19097.2832549869, 19129.6610388453, 8888.94269627035, 9009.64331568363, 6197.43795321554, 3638.33891348493, 72143.4207753336, 130241.381967496, 78666.8778683149, 81849.6547772842, 398.206028873267, 100.68216531975, 571.096441299434, 584.756081781814, 19592.9726740097, 21585.8431052491, 232.459205162712, 746.070449292452, 23067.6205829915, 14461.4738510181, 115146.272355945, 106725.373373798, 108211.755539197, 83409.3686137186, 1961.13519892716, 3522.18582427452, 15437.3703350873, 40928.0940001169, 7389.37527689108, 85812.1435012143, 9459.55834462236, 9090.63054171216, 4499.2763186769, 5850.44648893083, 4575.70521791428, 18014.2833626938, 14352.8271584533, 14757.3538659936, 103304.564714712, 138521.390404683, 41855.7052941805, 102738.386725133, 103258.601060096, 102278.788815913, 104158.273260574, 93884.8764115917, 103397.816520386, 164229.409857984, 110080.856683787, 97078.9512126411, 102584.733994776, 101866.650853983, 7106.27431670089, 2097.682220922, 3717.78716509019, 98005.6809761511, 95338.5679066787, 96169.0300548501, 96247.7043067616, 86015.9764321607, 98123.6854321452, 97774.7998103262, 5519.28651126374, 3578.64685585281, 9248.69922555774, 14194.2830298939, 14767.1013932876, 14943.8602084214, 25724.2778004331, 32661.5103845688, 28.5425439295029, 737.564022643526, 91522.0232503651, 122073.195308269, 36.3918337640264, 84.4091908959688, 1050.95495428744, 1506.13274878397, 7275.64059988314, 7780.93345996239, 8143.20450956444, 9540.19639949797, 8387.16878531682, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 59139.5031721197, 128751.021251182, 50718.604189973, 58007.6708390919, 69051.845746519, 14971.8874229647, 14423.7352705075, 19259.6832164032, 15299.9653270698, 4982.66303253475, 17091.8933030834, 105026.395845533, 92124.5712903021, 50648.3419846891, 35856.6017906211, 11646.4986464042, 3337.22386818078, 28502.9484160247, 27538.760045669, 227.476612698351, 53012.5882961808, 53300.0209813447, 53223.1700886014, 50614.7423840892, 7325.83890684172, 2858.43849425123, 36789.9794518149, 38019.4648505359, 212.408446192817, 725.818744960656, 15391.6935594357, 10385.473355782, 7501.53010459866, 535.778320926114, 35.9876265013509, 430.335507715417, 10060.3114955846, 166.572650378446, 4863.79458451096, 16462.760373206, 380.817770655907, 205868.444624777, 99863.4268788019, 91442.5278966552, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 9179.4351480092, 42998.306580988, 39363.2560558965, 41379.1959954957, 41579.3690372552, 40818.044251515, 23046.6385072794, 19014.9399931232, 18607.8321494227, 3419.78018687112, 23103.4588896023, 245004.443535566, 248923.320821084, 244420.164882913, 80562.1571040449, 29956.0676611137, 2673.67401027199, 62790.1143993884, 63061.5091466866, 62301.1273053248, 111678.075252801, 75739.0810023433, 54651.368685716, 55327.4782076622, 380.817770655907, 11590.5993193077, 535.778320926114, 35.9876265013509, 430.335507715417, 4112.69358868675, 147627.22338425, 147075.47137063, 148995.820958281, 673.529729328414, 750.451299329575, 1385.21547111684, 1224.53366955984, 417070.181734336, 372168.757831182, 196473.760448503, 195941.33746191, 1066.16602268734, 203.491080857353, 1244.37909383384, 2846.04664650645, 1725.25063823698, 2532.9436458643, 232106.282398144, 74.0646474677702, 333.176284299135, 120047.954322087, 119246.668616815, 44292.1437860922, 60522.3052734248, 16075.2328033676, 60072.9163418456, 63495.1529328956, 68343.3524856405, 67232.6262997402, 66834.5435138141, 1364.17583053984, 56847.0165333866, 56356.1014353598, 56427.9883224993, 12538.3601120544, 794.666694851875, 129.185725798554, 6562.87268163249, 6564.23840375506, 39366.2067827743, 39483.7486385264, 41325.342492718, 1512.13461174059, 5650.84514130613, 163107.854997529, 635.181136894065, 931.930916233712, 1133.08618820948, 142998.832550001, 6674.97302012422, 24336.5802850426, 35694.1037675362, 28715.5195298107, 18950.2123758996, 36611.819640818, 1012.70680144016, 175.594808747193, 2107.82940891339, 7781.69673765881, 21433.0195548027, 39511.6244392138, 33884.7889385618, 36970.1427570535, 53033.8258642346, 2894.62766262561, 56.6741615112974, 49572.2553982016, 2608.46721355878, 2882.13607796834, 7107.86251115839, 20240.8132248647, 18422.7513218878, 43699.9499922767, 7033.46442344867, 3104.87895466374, 856.651616350442, 44359.7426141151, 11624.8096425303, 38846.4546213561, 8262.86840906672, 40053.5409309422, 6674.97302012422, 24336.5802850426, 3142.12234312229, 578.88859874516, 881.224366761827, 1122.07052045908, 814.49674834357, 13344.8335501362, 1068.79665978244, 1461.20070776816, 1218.91076084671, 1411.71988185387, 628.392877511488, 47836.612387009, 277546.348396659, 277547.450793221, 280402.587699844, 289836.323915431, 289943.721175376, 16075.2328033676, 398.206028873267, 100.68216531975, 658.254210804327, 58476.2568264582, 49038.3050645912, 51345.5952665653, 28047.9809374163, 17305.6483936032, 164220.807932648, 4456.94251146803, 31789.1416899254, 50396.4206820282, 1682.79562704932, 6493.96147313932, 12102.9880346129, 14563.2210880976, 16802.4612243485, 19351.6529390111, 7389.37527689108, 3380.8438338204, 120495.817236464, 70248.3287512563, 72336.8029629715, 76360.2764601228, 209139.929937476, 9789.54704572815, 939.647131209686, 765.476897764711, 128.982132604223, 28.5425439295029, 737.564022643526, 18235.0483382353, 44871.8388337277, 28739.4111569074, 28280.4935198612, 3388.44559163067, 132.977985957547, 155.61043086903, 2090.78496154058, 3900.40858360299, 867.493737643888, 2210.71727061496, 3192.06282303487, 4620.43191662203, 4658.50539586673, 16075.2328033676, 9989.29188779732, 16075.2328033676, 230.411118588209, 22230.1945586201, 288493.211494399, 13996.1687903036, 9440.13880857139, 9862.23109843925, 9491.62805248772, 9877.94352541671, 2094.83288646514, 1690.58027765522, 93745.2323336993, 68476.3451824007, 68469.4340907793, 63631.012259431, 65036.5071315324, 64685.0040449887, 74003.3033175499, 74276.6471941187, 11624.8096425303, 38846.4546213561, 207383.573808745, 114.203290637088, 380.817770655907, 3498.54547438718, 3497.0012950779, 9441.19790422316, 11959.0900443382, 2274.26740178367, 75140.8637683784, 75114.8588463451, 222696.249495175, 206637.072157159, 253595.003458221, 154778.138790215, 46718.9656108554, 43493.3572042924, 398.206028873267, 100.68216531975, 50545.7782401374, 58728.1260169679, 24012.8999102187, 42228.7104413734, 54814.1030804426, 46730.7190659661, 20197.8407360474, 38287.676361067, 3214.10363059576, 36.3583549709158, 158.395733639211, 1682.79562704932, 6493.96147313932, 94156.427348632, 2021.63499521118, 1270.41937713873, 98232.4835058661, 67585.5704709886, 66306.298379043, 910.553323308341, 541.426098286146, 257.094025600879, 38394.3342597233, 7139.78203108509, 165.105593485501, 163.148000537549, 16075.2328033676, 939.647131209686, 765.476897764711, 113962.684540799, 84674.2353631566, 110545.23134289, 89085.871527515, 110464.95305445, 565.368380899956, 163264.371825029, 1804.94935398757, 6113.74183538568, 99040.7375146359, 14215.9714067886, 26932.8744405107, 908.196150881241, 2753.91266089495, 4456.94251146803, 31789.1416899254, 8997.36830675118, 6514.26422142062, 63571.5935003966, 55150.6945182499, 80390.4525742548, 178369.350747506, 52925.0539860187, 17822.2945819952, 636.036393543407, 27035.460617007, 1046.99525242921, 5890.8677830668, 5936.66524224353, 50359.9680292924, 55199.6361412701, 1248.65010899295, 34973.4961861501, 132387.93979768, 16075.2328033676, 16878.1777032784, 18080.8066448316, 9462.81337408141, 9781.06908362604, 4063.05589236591, 137193.167685553, 120606.56676584, 2883.86935127528, 11129.598400937, 33063.5326825924, 35562.4098038602, 24574.6770077218, 22643.7925438356, 3728.49898930883, 4040.8154131577, 4543.29045969248, 42866.5108952947, 4013.01544473573, 32939.1179965398, 107860.090613275, 108111.568522589, 2553.40749080395, 171.400361883439, 1082.08389588677, 1393.40349830418, 8703.23632315906, 1760.40510573097, 6409.43990922625, 77138.6143994569, 5445.25153887054, 63571.5935003966, 55150.6945182499, 19337.8582553017, 38914.1648793721, 1012.56210112466, 1658.13449840418, 52086.8452369827, 53581.3630833353, 52325.1353903159, 11559.4176132565, 19865.3506110515, 34995.4188966893, 68815.044433801, 6262.57877363901, 27987.7255960291, 69511.1160654503, 16752.5322583189, 56365.8183456555, 9826.37550192853, 108030.374859086, 108071.112585831, 106594.945685032, 110008.586097877, 102909.795381405, 108053.008919045, 82705.3625701837, 71649.2213854558, 46127.5355363627, 71836.9433508204, 416.817905958984, 153175.665720884, 149221.133674606, 217041.915526466, 57911.363705363, 57109.857071081, 54673.5360035307, 55468.0701959175, 50250.1057019303, 50841.0200547209, 52342.4171667544, 53624.0208609305, 5510.86595776633, 3458.38954358547, 64687.5244866898, 65461.6338072507, 90059.7917959958, 49435.4270428902, 17959.5269590872, 19482.9117382446, 77747.6507958368, 4378.59522844899, 37448.7667123955, 257.224430960302, 55643.3918320751, 56029.639847205, 55662.5590095013, 34999.7623329259, 33753.2294143291, 151329.485152883, 177089.202212589, 151670.832088901, 145061.534891232, 1229.11183254332, 957.558659717758, 1856.15162274216, 5022.89768041547, 142993.914807927, 4925.73508167045, 4740.19512882465, 6968.29153221825, 7454.58522910861, 5087.429557285, 939.647131209686, 765.476897764711, 3301.66599654836, 1609.68048746356, 15984.1118052611, 35431.477931222, 11370.7101112596, 19676.6431090546, 34806.7113946924, 68626.3369318041, 6073.87127164214, 27799.0180940323, 172249.81682829, 198770.875805932, 234582.997853196, 61693.1512768982, 60993.0251739937, 61049.3842398068, 60804.782132511, 3850.72120102695, 3334.30615124719, 2290.13664384609, 1443.94149065909, 179923.024232941, 146970.586258744, 221844.954736016, 90105.783737138, 8999.29748365319, 8474.82223870937, 9489.98111105745, 8433.49692835409, 9518.36408379667, 121.620466588186, 5.78559118236115, 3313.85856569276, 1912.26404284212, 2309.15705582493, 75181.7586486951, 85306.609714591, 5782.58370207239, 2526.85154681064, 5002.77830630351, 45675.4013944197, 2883.25980746391, 8501.80839309896, 45525.1506787219, 49905.5844778644, 49103.1750861965, 28118.7866568068, 49475.3647518026, 266372.474655913, 258046.90930684, 3782.58265486411, 8229.20377820772, 6448.16258412327, 8708.46417695298, 11893.7754211391, 14048.6365824133, 12730.713380418, 2471.01779803843, 7013.94100342397, 22666.4587938621, 22784.0442206386, 34388.3616040603, 17507.825451943, 60785.6588338624, 99192.1711884282, 2598.41353348238, 2261.92529486709, 19337.8582553017, 26842.3774698291, 20663.7109915213, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 4531.51870866338, 6616.37814526732, 398.206028873267, 100.68216531975, 1827.72578615523, 4464.13601452754, 255.167752297303, 303.185109429245, 12161.8513948163, 12107.9815345219, 317.564940225624, 767.659794592033, 1454.77456326011, 6804.93828800212, 7807.05376390216, 18195.1111540441, 35856.7184189625, 10592.5020026709, 5583.90990689204, 1046.99525242921, 149821.884461621, 1484.65328510058, 591.620405798511, 490.027666257153, 104350.541931364, 12086.362268634, 24709.6534963942, 28255.4500604415, 28502.9484160247, 27538.760045669, 342236.33820172, 351.730145651724, 23556.0373871065, 3412.09845280897, 808.255024616811, 12487.3443239224, 1559.51685296278, 172155.666893591, 570.293365812091, 118.786848486364, 199288.241088455, 19337.8582553017, 37.6278552136606, 2480.88797920513, 5134.07365950494, 42859.2161005138, 29506.9450543041, 29421.8954681498, 146205.039277558, 72053.9914621474, 22284.1210058804, 56012.2253491769, 22937.1946335856, 11140.1568066984, 341.519978208402, 11603.2547842519, 29696.1306957661, 12891.4430805559, 13039.5718453139, 1990.04612692812, 298643.648946597, 35789.743682637, 294236.874959571, 67144.7537461026, 66070.4754531244, 67531.0017612325, 128784.347540924, 67163.9209235289, 67546.9823720022, 295.557739471973, 897.685180032961, 721.525209319147, 38926.4297052914, 33214.1828464695, 17076.2959950535, 31590.2424753022, 33860.4107649059, 36098.2090557038, 21016.8281094293, 9595.71224934499, 25421.1099591237, 9651.16741694083, 20893.4709408169, 22352.421551613, 21804.2382366525, 135814.880327048, 153982.061403686, 9175.97589707613, 304437.246616294, 301836.88002746, 57526.0457011182, 51145.472924913, 3615.83219779521, 198917.964909981, 214914.905192853, 199654.147122639, 234913.318171145, 199432.879389296, 89734.6587285749, 12279.6707094868, 65780.1348867323, 58845.6180699846, 271899.72515629, 273594.45774812, 269646.111229555, 273603.114716605, 257730.846481054, 276921.271262275, 254102.095369791, 11473.4349226603, 1656.28740507045, 8193.4574165235, 7650.21302182265, 51887.5140094926, 52065.0310680023, 38203.8868570366, 939.647131209686, 765.476897764711, 162408.077440794, 120199.519197558, 140731.394785895, 115194.590006959, 165668.22414938, 265018.431270074, 10468.2459355438, 1743.57125509262, 44085.2646670979, 16075.2328033676, 16914.4790278631, 17912.8136350365, 41575.9477858774, 16202.1956307407, 37258.5049121731, 19164.6614451451, 14790.0611965957, 38914.1648793721, 40252.9087982365, 43412.1213478491, 22230.1945586201, 16556.3213314428, 20512.6403225972, 16994.593450031, 1486.56284342968, 2030.89540798761, 22395.2580115575, 17324.1765906246, 23212.6897250703, 21977.7689794232, 30283.7019772182, 45413.770262856, 79233.3957999677, 16680.9301398057, 38406.0769621958, 30231.0876198181, 51604.4672661769, 112067.588337597, 132728.104894221, 9661.00808813282, 252243.8534938, 1299.16165625218, 2094.57780747345, 16075.2328033676, 11399.1490227455, 16441.2420677016, 75594.0110634712, 61676.6432709485, 182553.081271314, 171317.283996302, 183066.829589758, 170899.402122791, 51231.6252950158, 32372.3738273318, 65604.4483411535, 20086.6172335992, 20073.8577106741, 91347.3722309489, 28502.9484160247, 27538.760045669, 33762.8563670856, 39097.0833647084, 14711.7682871915, 26467.6951095124, 63571.5935003966, 55150.6945182499, 1080.09334155874, 1062.66920450828, 7843.40687167339, 6059.00064741785, 33786.9664480794, 5866.6221247245, 21425.0858399869, 93823.9796754645, 94755.0523172225, 29956.0676611137, 11291.999630765, 12524.0222324501, 939.647131209686, 765.476897764711, 16075.2328033676, 10786.9625481033, 1549.96884086963, 60260.0676961756, 15791.5394818881, 136.012689198563, 38753.9897871916, 84853.289965003, 40529.8439359256, 219.83812202564, 269.021031901013, 71665.6108921919, 84237.9700934032, 261.640100948476, 93823.9796754645, 6237.44870219875, 7737.42498328878, 29603.5681504586, 56908.8495891947, 237132.478636854, 1084.2816853851, 3036.28666844002, 5322.64402075399, 10926.4153341806, 11232.4231096855, 301095.873999799, 220302.758074452, 1575.65902792068, 255.167752297303, 303.185109429245, 36053.4048608281, 26075.2355373132, 30115.6352765253, 21253.3123758881, 58725.2338232078, 5134.07365950494, 63.2002724781892, 153175.665720884, 567.254166510616, 175.136282586812, 47.7456844018575, 5323.21899782507, 314.626902046184, 7521.04552208119, 7194.64645409364, 218449.195975136, 7239.62494918217, 54586.6213039622, 54556.3636741447, 53078.5553330687, 54066.3014801874, 109800.463577668, 36771.6892197682, 10293.2757495576, 10022.8221909381, 10903.6128075972, 9788.84869404798, 4947.77716181313, 69224.1804020617, 1805.39933652826, 6963.95365615685, 6820.51194763704, 7710.76288803116, 5876.25757295133, 4001.95870596901, 4357.62032237333, 80247.5262948767, 7692.01083672651, 3434.99055460128, 88639.0245337591, 86268.9816095694, 87545.4309785115, 112045.633181156, 23317.7740959105, 76623.9764513426, 161125.203621243, 131798.601405413, 117061.965535182, 137306.451803063, 221459.435127406, 6744.62786074977, 123548.761051456, 101369.50268087, 126645.359291837, 85319.7584270969, 33489.4669088035, 15365.9068974133, 89388.4292744728, 8686.95561875252, 16992.8886165475, 32122.9569021853, 65942.582439297, 3390.11677913504, 25115.2636015252, 23521.3062190883, 43235.5521009728, 5537.38496864811, 43245.5246348073, 46072.7513602738, 47176.1174761153, 4456.94251146803, 31789.1416899254, 2150.05803676888, 783.959518459601, 1363.46302791599, 16075.2328033676, 642.567109820339, 67816.1811953376, 21082.4492444437, 74468.5859618555, 68979.0485745033, 74144.7243571758, 71798.6877158666, 73491.2791169675, 16075.2328033676, 84915.3640338018, 73859.2228490738, 48337.5369999808, 84437.7583342374, 1895.50101268306, 2433.46374533125, 1305.81436396662, 74468.5859618555, 7448.535417009, 7694.15309699817, 40876.2035782217, 5436.98499559952, 12401.6284458094, 159613.027271484, 7191.00143860461, 166941.010851005, 1122.35194789941, 34782.3576095915, 152120.572302137, 164604.694454292, 939.647131209686, 765.476897764711, 3747.0674603284, 35699.8022228929, 16075.2328033676, 1376.93645478482, 1261.52469915147, 1596.63492262703, 44395.988065166, 53897.2635905682, 54185.1550351758, 16075.2328033676, 44359.7426141151, 6674.97302012422, 24336.5802850426, 667.663331675873, 566.070592134515, 45.5777284527176, 89537.7603416817, 29257.8637578383, 2858.43849425123, 14356.175242238, 3412.09845280897, 808.255024616811, 147854.187353362, 174041.361988627, 166576.559861932, 22813.2525009147, 40474.8597658331, 50019.2347075013, 30808.723907122, 50135.7219157687, 28502.9484160247, 27538.760045669, 121.620466588186, 5.78559118236115, 1864.15501149668, 2341.00027600648, 229452.202494312, 43600.7520966457, 213393.025156296, 260350.956457358, 161534.091789352, 8787.2913873048, 160884.017911135, 164133.138625406, 160786.891744787, 160511.009452939, 160849.23419155, 41849.4038000144, 83021.2407698637, 63571.5935003966, 55150.6945182499, 5767.17926266336, 74.3657790574448, 22813.2525009147, 40474.8597658331, 2475.57448977984, 36982.9849286861, 37270.8763732936, 3899.42888183706, 176.268750462866, 41594.6708928996, 50794.2007122055, 42980.3241376378, 75181.7586486951, 2030.89540798761, 221921.897528534, 232750.618788178, 235724.286038069, 20737.1154995678, 14473.220457225, 56409.1159204334, 144503.383076397, 54404.9598035716, 1831.60099917102, 137516.983418045, 138930.676268922, 138965.888355072, 139408.844027242, 146036.294089862, 198412.367935078, 178744.275274736, 19337.8582553017, 1521.81646046176, 3516.53153898294, 285.186697280334, 866.332228040084, 22184.4067936007, 229583.085017903, 168035.560340091, 136536.974270231, 3313.85856569276, 1912.26404284212, 2309.15705582493, 16075.2328033676, 398.206028873267, 100.68216531975, 243.20823442136, 1976.90383199459, 35.0865110138648, 44511.4447671355, 16075.2328033676, 36982.9849286861, 37270.8763732936, 20173.6247292505, 19704.5364505492, 3809.81870112332, 38914.1648793721, 6308.23964798715, 63571.5935003966, 55150.6945182499, 6352.98240000075, 6484.03816522764, 0.571913282219612, 20359.453795439, 5061.31467498644, 250399.110344323, 257477.743628861, 89111.7094348437, 86384.4821492677, 112659.37004318, 98206.8588784096, 316901.981043703, 324690.212270749, 316831.712095375, 26599.7710179717, 26839.544031546, 68098.0566545423, 68098.0566545423, 68783.9453405742, 63795.3609689568, 74960.7164552031, 71804.0667447239, 2319.66740019675, 2498.6748196612, 2216.2382060537, 219153.780959996, 41426.4948378549, 39698.0780259475, 3792.57069176565, 3518.16041672489, 3785.57896314708, 3773.0353622085, 202.887533202113, 77950.2685299248, 70108.4111616421, 125527.619493561, 66908.2365842119, 67840.5877329371, 88594.7628429193, 82810.7147862498, 99847.5412118042, 21419.2046332419, 23876.6372585501, 6356.16969421227, 13747.2718439389, 88258.4569980874, 65301.1617391746, 2596.81734533044, 85306.609714591, 25715.5714753557, 171740.154122373, 116787.405234036, 117130.619938423, 117733.473407496, 84305.9744320666, 73249.8332473387, 47728.1473982456, 72984.2717317539, 9179.4351480092, 47803.6909899736, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 6021.05462493086, 329.476038024962, 25539.375337135, 12718.1309733411, 7428.76074139372, 4427.95576613552, 4523.74249400307, 34299.3981723081, 202658.063097994, 211084.52043377, 211329.25417095, 203214.749015101, 200331.031893587, 204784.407129384, 28984.4191252192, 25347.391781654, 9696.51006616501, 6349.0289327156, 8921.00707100119, 28736.4609216233, 1412.22009106794, 1241.1340850347, 255.167752297303, 303.185109429245, 63571.5935003966, 55150.6945182499, 17864.9359702411, 63571.5935003966, 55150.6945182499, 217020.334910296, 220898.922646849, 79020.3678263595, 5766.30017380387, 8355.8988615643, 193792.818453792, 241758.438104143, 241001.947903127, 212702.245507447, 246029.070357111, 245069.066587824, 82222.4182625753, 240656.582822252, 244113.197630828, 245809.042185752, 18.6403045752668, 244902.971492028, 16075.2328033676, 1231.16655235924, 20164.6291378281, 20854.1536339702, 72808.8305425205, 56049.4630418148, 7106.27431670089, 2097.682220922, 159382.86215924, 166977.492406715, 158410.691895978, 148389.644485634, 21953.8609880697, 21846.2054544797, 32939.1179965398, 46737.8010136089, 400.993672632478, 496.959371783375, 1007.79460327982, 1239.10061747058, 238389.479650343, 228402.165456931, 161160.474863849, 160518.679663523, 163660.173016393, 160861.89436791, 165354.599242204, 163773.73077687, 162932.569627414, 161464.747836983, 26332.212969649, 19337.8582553017, 21769.558358177, 22653.6431998057, 30731.641100277, 26846.6275845265, 17575.5218384674, 17524.4245657742, 121.620466588186, 5.78559118236115, 21038.181947542, 38699.7892124604, 8449.19130782257, 9157.35032864484, 24271.1577820147, 7677.7637070457, 75498.5455589055, 16075.2328033676, 58985.2847008668, 2653.61521951693, 11249.0566627083, 7605.25409551363, 34428.9002839202, 33766.4831953778, 34130.7791942306, 5833.11129482746, 6188.77291123178, 3584.77478231347, 4621.29163464538, 5246.76089096064, 939.647131209686, 765.476897764711, 2926.75909982747, 4936.85306638324, 2095.49403226991, 2619.99943786699, 82903.881433092, 86007.7274082999, 50200.7471414225, 221899.39120985, 205840.213871835, 252798.145172897, 153981.280504891, 39168.4482361591, 1122.48234087512, 854.774975936349, 29103.0547034758, 30609.7028393112, 11154.5807916306, 33635.6707994986, 4856.95060397779, 3481.64976676604, 2894.62766262561, 132.977985957547, 155.61043086903, 21560.4675641777, 398.206028873267, 100.68216531975, 1191.69572328064, 104160.939539591, 102678.646139363, 63571.5935003966, 55150.6945182499, 7053.26745540345, 75356.858529601, 6295.63345031565, 960.455039706507, 9369.23587775222, 2278.87198983255, 25176.3988917833, 22522.4516120375, 1023.3122550351, 4944.85729745833, 85306.609714591, 24271.1577820147, 398.206028873267, 100.68216531975, 10507.4294480934, 916.180354671122, 649.960875448926, 12965.7579172561, 25409.6463701444, 4001.95870596901, 4357.62032237333, 130480.080076783, 88103.1464718662, 16075.2328033676, 104002.872931872, 104775.854991285, 110720.503460054, 2897.28288939692, 535.778320926114, 35.9876265013509, 430.335507715417, 658.254210804327, 16075.2328033676, 1305.81436396662, 93823.9796754645, 28967.9118610871, 33144.5223047407, 8210.78229953289, 1273.19317026905, 658.254210804327, 16075.2328033676, 16075.2328033676, 140736.05914757, 55.8837027444483, 36982.9849286861, 37270.8763732936, 1288.92955823832, 1929.35298916898, 348.331532671143, 22334.0467944491, 85800.9972486639, 20791.3532661347, 21056.4811328743, 13626.0753257882, 11778.7959971364, 12690.0015525745, 74468.5859618555, 4288.93507846527, 4456.94251146803, 31789.1416899254, 29956.0676611137, 192.421999740447, 11135.6152626777, 7703.02893691055, 4065.6442287473, 2960.24909508257, 3917.54647067997, 2096.08807940482, 10189.0293633898, 72218.5283820092, 72448.4531565266, 398.206028873267, 100.68216531975, 5622.2701511546, 4686.99059965406, 7632.36411771037, 38914.1648793721, 12263.5355720701, 164831.491484566, 208758.662434345, 233338.773368062, 15899.2237786347, 24247.2560631399, 2694.79140022825, 3516.63003928804, 7784.58594989887, 21613.7846631704, 48731.7513848187, 28.5425439295029, 737.564022643526, 255.167752297303, 303.185109429245, 4620.43191662203, 4658.50539586673, 420.044597690908, 1581.70244271285, 1588.9903746289, 45.4856214061357, 73265.3933036375, 527.428036157947, 2219.8440197317, 181.65757594412, 66098.4377721652, 10450.6062016643, 57471.4389160475, 57276.4541471359, 58216.1080657708, 58219.8820491268, 58208.5949283473, 65019.6126056549, 398.206028873267, 100.68216531975, 33203.0075608925, 6992.95666976297, 82873.9216676051, 59642.9541150696, 25718.8023826731, 163264.371825029, 3198.20199161574, 3951.35973793132, 24723.5820961135, 9941.6638518224, 23547.132058523, 75181.7586486951, 310.668149357043, 399.82218095601, 43234.8791833435, 43893.5348366351, 4101.53615601212, 4563.21437395795, 7632.81944067281, 2926.75909982747, 4936.85306638324, 67500.6137114512, 110126.616770585, 91927.7320561661, 108394.865043287, 91470.7055971844, 92091.1006761883, 108118.324567187, 20537.7821612674, 60256.3454301609, 16097.2340274022, 15985.0436262996, 56357.0185983811, 29956.0676611137, 3590.90953032047, 3081.31467758081, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 11219.2029420159, 14111.9432535999, 130527.553244308, 872.613052005574, 19296.2453801073, 19420.0809473769, 7814.47805543532, 7395.18644660074, 26837.3963343888, 147.309850572088, 384.245184028303, 38914.1648793721, 8996.17042633451, 8092.24327064296, 623.50688066851, 58459.3171043933, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 16075.2328033676, 228106.893938251, 212047.716600236, 259005.647901298, 160188.783233292, 130038.173168251, 160231.418782811, 205229.984841988, 212495.551674682, 155022.259190654, 113682.982566909, 212955.460525763, 9847.37823608761, 5679.33231932048, 9444.470781261, 7073.31479954905, 4456.94251146803, 31789.1416899254, 29956.0676611137, 1065.8140974554, 8597.23475933171, 8665.7673686549, 1236.39365505756, 3260.57563359022, 1605.09912911428, 93823.9796754645, 255421.458901604, 210520.03499845, 8485.09109696442, 161989.234189382, 161951.929096612, 161497.388901529, 296721.758231649, 3313.85856569276, 1912.26404284212, 2309.15705582493, 4241.80473259183, 2872.15670716428, 3455.42471564553, 1892.89094015922, 2010.4169496854, 6192.57377623014, 9432.79523902102, 1682.79562704932, 6493.96147313932, 939.647131209686, 765.476897764711, 38914.1648793721, 85306.609714591, 28829.3566771197, 21394.7210735474, 173.368921606322, 37307.7321262178, 37623.8166365731, 61036.4454459255, 118592.182782374, 144194.854494341, 391.531497495759, 12213.988911664, 6642.87308898889, 16075.2328033676, 1484.65328510058, 591.620405798511, 490.027666257153, 398.206028873267, 100.68216531975, 33987.1088690005, 26719.2343145144, 694.307807754708, 1864.82275991952, 27043.3178229638, 29542.1949442316, 35915.6286236694, 9010.76222243097, 10241.7343216975, 25545.2290715704, 95061.7650950244, 92775.4415472274, 89154.5299951749, 91335.5697190857, 93208.4317259385, 193749.676463243, 29956.0676611137, 17574.0798232355, 17879.0944873583, 84645.8224618742, 28047.9809374163, 17305.6483936032, 35476.4571241806, 59226.9227190309, 132.977985957547, 155.61043086903, 24940.0326977315, 25735.2743875532, 28095.3140481876, 54861.0708148141, 20613.9733905144, 55245.9677063735, 65840.8934000056, 54851.0265976293, 58098.4698319136, 14356.175242238, 55.8837027444483, 60140.5252397158, 57841.7416044554, 53606.3301405669, 21207.9320627651, 217875.207060492, 201816.029722476, 248773.961023538, 149957.096355532, 22098.0614964743, 39759.6687613926, 123.312080660295, 380.817770655907, 2156.61975503595, 17645.8434018688, 17017.170637399, 28616.136426094, 10436.7095368221, 1459.96585583202, 26332.212969649, 146762.651570949, 1019.16725041944, 65.000481359953, 858.673246447354, 808.551610924988, 832.050992006983, 84538.05415983, 39019.8118464648, 5521.34076091966, 19337.8582553017, 49772.3772621189, 50728.9860534272, 8045.01742618211, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 66795.6775547194, 61003.7025488528, 6106.70599661025, 6114.52770081361, 2243.07347729466, 876.974958985378, 2671.11420829722, 1456.47846844177, 28.5425439295029, 737.564022643526, 127296.47695118, 6317.0887566572, 51231.6252950158, 64.3269574204342, 3324.72655507088, 60995.2511687054, 47204.7136142133, 44796.0937813197, 56941.5332097162, 56204.697232486, 38271.0907596902, 7991.55479752349, 8654.8182959883, 6420.04136945592, 6378.26505696896, 66623.3263215092, 67009.5743366391, 66911.2177661167, 66642.4934989355, 5149.1243976634, 36495.8036246146, 39129.6728858248, 19337.8582553017, 3288.96350435002, 8430.66750286357, 122127.608709679, 50129.3931508622, 63175.4877003767, 10068.9988766523, 10737.4122578074, 91867.3057544091, 100451.441153572, 15258.1718199457, 102345.992345042, 1811.94846978399, 45191.004210406, 40286.3368688704, 33401.1053996584, 53071.9709034944, 44557.5988975191, 47509.6871586735, 49215.7888051151, 190519.712028037, 218301.709659433, 90771.5558656936, 132981.623098472, 113313.53043813, 96520.9582989015, 38914.1648793721, 36.3583549709158, 158.395733639211, 35298.8150929559, 38926.4297052914, 33214.1828464695, 25131.418470723, 22753.03826172, 3400.97059296041, 383701.777026761, 939.647131209686, 765.476897764711, 93823.9796754645, 35755.8919462581, 6495.3882186827, 12029.3500870143, 10759.3724608976, 23556.0373871065, 60014.9737921143, 77793.4540012533, 167753.632650659, 168069.959112991, 231035.456051256, 51971.1701830603, 180434.496037932, 26530.8987129323, 39645.4493610555, 103092.416102746, 109539.450094915, 3696.44551283469, 16075.2328033676, 58.487356203872, 876.321234691526, 1078.97033554565, 60445.8594148036, 22493.4335236437, 42777.0419563425, 75181.7586486951, 2076.80066217283, 2122.39202885919, 3011.51636298705, 3496.85849144087, 4162.2723331616, 2040.42901756839, 5080.57109138612, 359.148316297472, 202.325586042575, 11112.3888735111, 206.154152085621, 408.092676066718, 1574.48569871046, 36982.9849286861, 37270.8763732936, 7751.58874088763, 4785.36439328066, 2852.65675864196, 4219.17288197732, 239489.582261117, 148458.7280231, 159353.185217315, 75181.7586486951, 2846.58146962086, 16075.2328033676, 12191.9279508481, 367.01128052428, 989.557926122531, 13740.9378404403, 13739.5809457046, 14356.175242238, 19337.8582553017, 22431.3081239714, 22977.9927705096, 7781.3220723484, 9917.84530784735, 4381.57212704486, 2228.27583735487, 2529.44268346106, 44022.1830896314, 16075.2328033676, 39920.8810942876, 63719.1404437254, 57582.4883592059, 18396.3288907663, 80656.7057547964, 4710.87836832188, 3597.99732113616, 143.650275992601, 31155.3572683901, 24757.7658824302, 3880.45093845086, 5890.54490500663, 27043.3178229638, 29542.1949442316, 25550.4177547416, 12794.0445355127, 2499.49605239359, 16075.2328033676, 3334.47924461234, 6690.09103668397, 7526.64669732635, 3685.18899945073, 3223.90239894862, 314231.61199904, 317492.971154757, 313372.424223055, 307291.085217789, 303101.471345088, 31953.3573158833, 34053.6263868577, 27466.5368327866, 84140.7523154057, 29639.7313476023, 17358.497706284, 28021.1988027594, 31506.9365719987, 33746.8261561717, 30411.9200689523, 23620.7270800448, 27350.9615098192, 250.720797383518, 775.400391905192, 2301.67867170392, 2.77197958308759, 74794.2624562952, 42906.2483789369, 45602.6776002042, 1496.30840177241, 242.915519629276, 46192.2307493326, 16075.2328033676, 18927.2399168595, 36588.8471817779, 9724.70541100056, 37304.5884083199, 88.0031803512315, 7650.21302182265, 37204.5719675397, 21170.7696553755, 4001.95870596901, 4357.62032237333, 491.348240069796, 53909.823051173, 62853.7747765658, 4918.60979281355, 6928.70375936932, 2512.17736005088, 85306.609714591, 38914.1648793721, 2854.62936071346, 28502.9484160247, 27538.760045669, 4001.95870596901, 4357.62032237333, 18172.9724805578, 26118.4625205342, 136316.120602636, 135276.28741566, 19337.8582553017, 1661.37903405997, 1502.58971185598, 315063.125264239, 284484.515692807, 283211.133478404, 273759.277448994, 274449.429608036, 274281.056059405, 281494.634207045, 283353.015382491, 295395.032603897, 281980.839683862, 274223.191758372, 279913.006800339, 6545.3500472656, 5873.13944222681, 14356.175242238, 398.206028873267, 100.68216531975, 113098.019167341, 114228.470055133, 113294.295592223, 27043.3178229638, 29542.1949442316, 115339.152804919, 16075.2328033676, 55486.6741746049, 12487.3443239224, 398.206028873267, 100.68216531975, 1529.0499631441, 37319.9539963416, 36245.6757033634, 7284.94464057689, 31414.7853364605, 63571.5935003966, 55150.6945182499, 3105.1283209331, 3446.98557537899, 63238.8894937381, 63231.9784021166, 58393.5565707683, 59799.0514428698, 59447.5483563261, 456.246954010151, 3829.22724901912, 22813.2525009148, 40474.8597658331, 380.817770655907, 83133.7251543077, 100717.475462435, 92296.5764802883, 36982.9849286861, 37270.8763732936, 3097.73793367409, 76566.5523428937, 7505.60147661139, 316.577132124849, 25385.3341350759, 4387.73517468441, 237123.970783316, 237053.701834988, 213362.29555194, 200081.779792747, 190500.469733514, 200045.187634509, 278342.502738211, 241501.907313687, 237728.807082008, 237560.433533377, 241244.013105428, 258674.410077869, 240516.206372128, 236861.99975159, 241643.172536735, 237502.569232344, 241445.533657858, 200.880466402473, 3437.68750995873, 2202.60181343423, 10359.5407569895, 10658.9848180244, 28553.6029465233, 47945.1815627182, 42910.2073670149, 28047.9809374163, 17305.6483936032, 398.206028873267, 100.68216531975, 9724.70541100056, 37304.5884083199, 3410.42783168138, 3593.26919047491, 93823.9796754645, 50655.2480126061, 48874.5609539648, 49284.7813276892, 32585.2330653844, 101524.15770503, 59662.186995725, 48765.9900048176, 33187.4706215773, 1553.57433231077, 62534.8074504343, 47182.9623016159, 48320.5929573335, 4651.39083245284, 8135.56195349104, 6032.79711990686, 19142.6431978428, 19164.203267106, 398.206028873267, 100.68216531975, 4445.65730378682, 3629.59364040078, 121.620466588186, 5.78559118236115, 34098.670298267, 3509.61610499153, 16075.2328033676, 618.668588388747, 653.607391922335, 4141.25166009212, 4135.68975926483, 4027.41494621602, 6829.66536915831, 4548.82875266257, 16540.9585904449, 28869.5029661544, 255.167752297303, 303.185109429245, 27419.3507289026, 24851.0028842774, 27379.1253218527, 55554.7873338112, 34538.3441811096, 127921.2333375, 74468.5859618556, 8646.88361939588, 8915.80592070546, 36024.2040865994, 39650.3563572607, 59061.0545275746, 1257.93140979714, 885.899661535001, 1864.15501149668, 19337.8582553017, 52376.3381147366, 255.167752297303, 303.185109429245, 60256.3454301609, 3624.16220065358, 33324.3148409313, 30651.6989390405, 32370.8997693038, 162159.546721212, 50677.5152204429, 398.206028873267, 100.68216531975, 16377.7135262666, 26395.2117910869, 18197.5339254204, 200.880466402473, 7516.72257040313, 34586.0773192992, 6360.66042922092, 11100.5987984576, 31236.6218635426, 67768.6303400095, 46756.8653309269, 25740.4221782254, 119123.311334616, 16137.1432491008, 14736.5593422685, 3488.10040804138, 4530.39834356337, 4530.39834356337, 4875.66707083909, 16075.2328033676, 10453.3472118105, 60610.6332672632, 97273.1835956881, 18396.3288907663, 22939.2979600887, 57927.8311074069, 1192.16891851584, 5862.12891536664, 7872.22288192241, 105205.528586602, 90066.7567603696, 22236.3125984182, 3320.18319770292, 64.5414530290441, 85306.609714591, 12842.9979742439, 14498.2981460965, 14440.9344002263, 784.17829950441, 784.17829950441, 16075.2328033676, 75842.4372850443, 72262.5051733076, 80452.2609447819, 43202.3838131115, 72306.2341327, 36821.9535714838, 59437.6488596136, 45588.5700258639, 2844.29803937616, 15049.7857593645, 16075.2328033676, 16075.2328033676, 78353.9325664235, 78543.9426303328, 695.492487178245, 22939.2979600887, 19337.8582553017, 116952.421196194, 111785.442707754, 91989.6691997962, 252243.8534938, 4001.95870596901, 4357.62032237333, 2241.55915880202, 122044.095738603, 42305.5590304444, 206460.912712638, 69532.062608832, 121355.007857752, 64428.6182125737, 4698.73421108529, 2858.43849425123, 1651.2658384956, 2014.18638945188, 45644.7755464387, 47554.9593135106, 11079.4472885407, 45500.4992766102, 49237.4975673283, 46273.8547793097, 500.624776033201, 468.522001154977, 484.912112376762, 83215.2748375998, 62203.5098285172, 41187.0666758157, 134569.955832206, 36489.5282195617, 9179.4351480092, 51896.4422959785, 54544.4228823721, 16823.0088066804, 16818.4861768738, 207.140771853515, 174.018472194646, 7053.26745540345, 6377.17939681318, 5777.48484002229, 8884.43357819453, 31800.4031185831, 12874.1052951719, 33428.6229824606, 31680.5470608009, 939.647131209686, 765.476897764711, 380.817770655907, 380.817770655907, 74468.5859618555, 16075.2328033676, 85306.609714591, 22813.2525009148, 40474.8597658331, 132.977985957547, 155.61043086903, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 779.815832979321, 678.223093437963, 1258.46113119549, 8449.93411537696, 2931.29111251035, 8604.07092047557, 55554.4082185762, 54480.1299255979, 55842.2996631837, 45244.5011878391, 2849.73497662546, 1651.2658384956, 2014.18638945188, 5811.28951558421, 2989.49900525221, 79896.6519520766, 20336.4142223329, 50536.599473524, 1522.58560579167, 4587.31708187429, 697.201163566997, 130029.239634275, 160222.485248835, 205221.051308012, 212486.618140706, 113674.049032933, 187215.275153066, 212946.526991787, 2150.05803676888, 783.959518459601, 1363.46302791599, 37095.8010743253, 19337.8582553017, 24022.1036343365, 28374.8156924383, 53909.823051173, 62853.7747765658, 11062.9987320699, 12406.2429125887, 4615.90268534648, 13968.0134688298, 7735.1616493197, 15752.8147277728, 14288.6376408584, 6146.03214049149, 7547.82025143785, 87.5163918835083, 53377.1335466242, 11629.0775533624, 29290.6848182808, 56322.3882500131, 56629.6240244706, 51349.1208488968, 16409.9007317744, 17949.5262676473, 16810.9759083942, 3883.89001941218, 939.647131209686, 765.476897764711, 2847.89949909125, 2757.92373005208, 31461.5587619452, 31289.8742605205, 2197.13931685018, 1892.65548382226, 285025.542024432, 320790.91351053, 27530.4466366291, 33891.1759764014, 36285.3996114882, 77196.5767758557, 349.355422482261, 36908.7753310816, 51712.2024142716, 29683.6898379264, 34922.5591508636, 33965.9124515144, 35162.332164438, 33918.4410652008, 16380.0927036715, 26489.0428751419, 45302.9265003417, 7469.23445983926, 7787.49016938389, 41424.1418649155, 41905.5123703417, 41733.827868917, 33177.6889270762, 43684.0216887158, 44883.8031615448, 6589.09565826896, 57411.6759997244, 24.7442465283261, 388.195150043704, 3729.59711184043, 396.793262779679, 3639.62134280126, 18924.9256835612, 36586.5329484796, 16075.2328033676, 948.828885502464, 1069.98948814975, 63571.5935003966, 55150.6945182499, 65.6514226056949, 73.3378829552607, 72.0922011886014, 38914.1648793721, 398.206028873267, 100.68216531975, 73216.5689052017, 2425.017607503, 1911.82916325294, 3485.18155826203, 3907.60765900004, 3728.49898930883, 4040.8154131577, 45.5777284527176, 63471.5874672333, 95016.0157530185, 131859.482046744, 96013.1073194839, 112982.113847448, 47568.1690686503, 50432.5379734911, 854.935635892897, 385.386809890281, 583.737029424752, 138091.168220281, 191237.192284169, 171569.099623827, 157532.223072124, 166.940288064969, 29956.0676611137, 51231.6252950158, 3127.6564022114, 2443.05800912684, 108.441758314415, 2395.37894894422, 4889.25948823447, 91519.6118281019, 14453.8548779767, 15546.2260324413, 24402.9820978196, 23136.0379792252, 29956.0676611137, 380.817770655907, 5811.28951558421, 2989.49900525221, 38043.9389925614, 160778.182886648, 91332.5754911367, 86877.4692151246, 131289.225632791, 111621.132972449, 34503.3585142805, 84456.0815848091, 84384.2873483472, 196126.605038445, 69154.805114495, 71218.9807786532, 87151.1258221146, 67404.5703893814, 336.071531343345, 339.608526240846, 77747.6507958368, 13902.1926931588, 14139.5820121751, 12952.5352880269, 109598.877268168, 36982.9849286861, 37270.8763732936, 74.3657790574448, 17929.557030349, 15859.1622193323, 159.510557402545, 98379.0446008595, 74468.5859618555, 255.167752297303, 303.185109429245, 12583.7800700429, 128.982132604223, 297774.917392874, 250122.58865642, 355823.635327155, 298062.920490708, 290843.671733594, 294722.259470147, 280586.398627791, 281470.27412407, 259301.916864235, 358919.412075692, 312581.398017428, 278564.44026546, 270165.562889971, 301144.297855522, 297608.776557589, 1296.89338122162, 2646.25341391727, 41678.5817728279, 51231.6252950158, 31424.5482784849, 29470.5191612991, 9462.81337408141, 9781.06908362604, 19337.8582553017, 1192.16891851584, 5862.12891536664, 7872.22288192241, 7302.627014617, 46133.305679748, 17092.9329233974, 18226.6025271727, 27766.822214691, 23377.6885996266, 10782.6254821864, 10702.0758807406, 10400.0214986596, 2186.58852514483, 7186.81440433099, 21058.5049226077, 38720.112187526, 16075.2328033676, 5053.3108516892, 2449.46742349704, 43234.8791833435, 43893.5348366351, 16075.2328033676, 22760.1172694667, 40421.7245343851, 104010.459508194, 142654.60062326, 18588.884143216, 21254.8600463254, 18718.9018053809, 167954.099756985, 15291.9825997376, 19507.7115055277, 32939.1179965398, 19337.8582553017, 3168.8572869195, 2874.04195533974, 1267.97366579649, 43684.8382185621, 33176.9785839663, 3361.48658489253, 2699.89315455574, 1677.87192632401, 667.663331675873, 566.070592134515, 2625.32678734072, 93823.9796754645, 398.206028873267, 100.68216531975, 29956.0676611137, 5072.32276471039, 1607.23661535299, 26332.212969649, 3080.68649783874, 140580.880421397, 126069.563250159, 99849.4392173192, 120912.787761054, 149369.387469939, 43296.7793675834, 31617.7205653819, 4019.93055276592, 2079.29089735499, 398.206028873267, 100.68216531975, 8475.82216479344, 170.800716250559, 71324.3213009376, 69663.5269482678, 69175.511249828, 53944.2026719058, 55279.8244618687, 29481.2768326057, 11368.0286559487, 19673.9616537436, 34804.0299393814, 68623.6554764932, 6071.1898163312, 27796.3366387213, 23866.4754482235, 81755.7787957971, 119755.244131173, 24506.2576994228, 30548.0433154232, 28462.4793163777, 1162.75386700238, 5404.22462180235, 4491.85492679756, 8050.80588738644, 14215.9714067886, 26932.8744405107, 37927.9473714848, 64518.0654561389, 65777.6721846526, 16075.2328033676, 398.206028873267, 100.68216531975, 36802.1565601856, 31192.0113741746, 31224.3891580329, 2428.26064703858, 18920.0382296906, 23171.788547361, 154496.676874864, 10383.5691614789, 3793.43462926929, 3215.08321453504, 84754.3679092868, 84754.3679092868, 83419.8342894088, 76695.5697286669, 55683.8047195843, 34667.3615668828, 128050.250723273, 93823.9796754645, 1456.36694956513, 1319.80255939971, 44839.4606864026, 725.818744960656, 4444.84345494065, 2092.69534033236, 77441.8108054661, 75381.6174483027, 19751.3127093249, 48069.6073359021, 69862.9049005533, 391.531497495759, 106.0424062046, 2715.65468122902, 20933.2659387134, 51203.1971436623, 58862.1150625982, 16075.2328033676, 1472.07006050165, 721.306900710019, 2213.43542546805, 1164.55454336095, 15624.464334503, 1442.91874787607, 42296.7235571322, 40926.2568722153, 39962.0685018596, 36893.3003124705, 33273.718156656, 34227.3846826133, 93823.9796754645, 19359.5783223624, 16354.4547508628, 276649.043566088, 283727.676850626, 68174.7441609302, 16075.2328033676, 1355.82880441946, 20721.604876596, 23584.5154968128, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529483, 25460.6460476849, 26451.5189207907, 904.851767212577, 2435.93273050901, 24872.9872515065, 22909.65173138, 25631.5344228587, 43029.1076415522, 46917.7919360262, 41205.5450772043, 27179.5564533409, 1038.19802717208, 1059.93418107794, 472.227398873204, 250593.856078877, 126.024441337697, 176.371985981885, 2636.96248688573, 261.813218632195, 1654.11034922165, 421.456108906891, 1701.68374281491, 1431.34626643505, 101975.843224729, 70248.3287512563, 292.87782785488, 7893.12668698992, 10926.4153341806, 11232.4231096855, 21552.4792426663, 19319.5689275961, 15929.5882638689, 18596.2995525572, 20595.5743155191, 124797.391408322, 1634.58002071163, 4067.10598615302, 136.012689198563, 12773.6468298913, 24350.1441674516, 2135.62710830354, 41218.6129323469, 31461.5587619452, 31289.8742605205, 4286.09662451202, 3928.3365254064, 7652.2500575936, 230591.649965527, 214532.472627512, 261490.403928574, 162673.539260568, 36847.5936014935, 36265.7012154485, 16075.2328033676, 1320.58057019634, 2638.87275349562, 4103.60839188073, 4221.29827624666, 34553.4880542934, 35575.4702473679, 38914.1648793721, 47125.7363399674, 14356.175242238, 31461.5587619452, 31289.8742605205, 6232.62792643737, 4941.77716359388, 1864.15501149668, 38914.1648793721, 230.296581381005, 2545.98300847678, 10025.9565016144, 5609.96577355043, 12992.929075689, 295.557739471973, 897.685180032961, 721.525209319147, 45.4518162255458, 534.268745572552, 44909.2575880087, 83351.374161389, 235050.690351548, 81866.9794679806, 97157.7783070613, 79947.5251352916, 23489.9004626663, 4759.83439230613, 5599.27775320534, 24874.8922577654, 24947.1415739958, 21081.3815395445, 42481.2559157668, 33077.0158479722, 667.663331675873, 566.070592134515, 63571.5935003966, 55150.6945182499, 742.624153252877, 590.48284051512, 58483.3778923309, 60376.5806446237, 64052.5631809315, 38914.1648793721, 66626.619543859, 38963.7148204181, 32473.0455307946, 144668.864627711, 97113.9518699742, 97082.8012741442, 98146.2562282906, 97537.5188871086, 95317.3752316772, 9743.87934489678, 97221.4402103269, 3728.49898930883, 4040.8154131577, 71491.4403160765, 72776.6428874297, 69433.0758358863, 24465.5391936918, 23339.9694084853, 41641.70392212, 32939.1179965398, 311.499458809912, 7839.77135546636, 11015.2141426805, 13938.6052010456, 1150.78364041652, 782.062035761683, 3385.49077318526, 12360.986960204, 13318.6325406583, 13647.9876757469, 1595.51109228215, 3880.75020205238, 4037.20135653173, 4311.2748793455, 22762.6585191542, 27045.1858283562, 3632.91502201753, 97444.0830233883, 95718.7263741623, 80837.8456582655, 83765.7323446166, 49248.3265198921, 63606.4185948771, 57616.9023044546, 58843.7192664338, 2219.12750692631, 1513.11003279499, 15890.6814819036, 17286.1281125608, 32192.4620332683, 70515.6824688705, 70975.3533485045, 70887.2336432219, 12609.2911496576, 20711.2241279534, 398.206028873267, 100.68216531975, 104160.939539591, 102678.646139363, 57411.6759997244, 119.947791803656, 49941.5984029991, 203364.588466562, 376849.841948581, 196638.847820155, 161693.916763018, 258587.572496246, 197452.963892348, 196763.719046391, 197620.384766924, 195953.943128218, 206662.793962932, 196507.644492622, 185784.414879235, 190230.241505738, 203447.761811326, 197590.087139519, 198249.334590686, 22697.1620382325, 21697.1318315428, 21606.4684142989, 380.817770655907, 8723.51987534693, 60967.7573433756, 17244.8133001303, 63571.5935003966, 55150.6945182499, 1083.97597604648, 873.137965327408, 23809.621616496, 28594.4447317507, 85849.6462950096, 80176.0200038785, 883.659008064973, 846.232018946051, 18425.4799595753, 18125.1432535256, 20942.9232751149, 20548.1869090041, 14355.6085672178, 32939.1179965398, 359.148316297472, 202.325586042575, 15668.8385621059, 398.206028873267, 100.68216531975, 73600.6391636122, 1605.30392603517, 23110.0461135298, 10567.3022144901, 36.3583549709158, 158.395733639211, 4620.43191662203, 4658.50539586673, 126616.049355877, 129480.418260717, 84178.0433730742, 48925.8016552165, 575.062541564361, 656.637906226134, 46178.6056410475, 39543.5697470792, 38227.3126329019, 39510.0593098613, 47563.726690026, 50514.1271965403, 39584.0243649045, 22599.7204320993, 27345.9884027852, 514.681655707878, 52842.3042424336, 71941.2508189268, 74468.5859618555, 309633.554831156, 192315.175290169, 172702.707932473, 174217.369078868, 184846.423831315, 184532.7390433, 185117.206885787, 7325.83890684172, 285.186697280334, 866.332228040084, 113666.180141421, 112763.763211986, 3717.78716509019, 4063.05589236591, 872.613052005574, 63321.2530878389, 56180.2084879616, 64248.955493466, 66518.9996549822, 29010.6625196438, 2599.17646092388, 20432.1509350748, 1365.04903019086, 19337.8582553017, 26667.976679861, 14551.6607845505, 37672.6682787865, 37500.9837773617, 41643.791506509, 51423.3205010644, 52702.9203126366, 50094.4926081244, 45111.1301878446, 46988.233779452, 666.915014712587, 1137.49587921006, 6763.06073250337, 7076.76941711321, 38102.3727928802, 16399.2145901539, 16861.3860694706, 52925.0539860187, 6830.90853456602, 6534.07239356383, 7096.16656774873, 7087.2462391833, 6572.15197159372, 6892.72074579389, 6126.82606287529, 29956.0676611137, 40739.9915847254, 38472.7542796797, 39839.4461375731, 37256.8097165544, 10777.8300248468, 90900.6974844511, 77644.2270359621, 77113.3889618632, 5035.40269654205, 8770.99671641627, 535.913132566717, 6005.13210584808, 683.590756411308, 256.561599648061, 1325.79700896131, 117.99001270891, 9464.96527881381, 5662.56290457657, 12397.0969410335, 3313.85856569276, 1912.26404284212, 2309.15705582493, 28427.6002350109, 523.358575608285, 20591.9841615471, 20897.991937052, 15331.1483539234, 21197.2829360608, 22295.7918041333, 12395.0105418885, 12539.0097538841, 20902.7065170489, 11619.4964391403, 9771.9812534022, 22813.2525009148, 40474.8597658332, 667.663331675873, 566.070592134515, 391.531497495759, 69174.9923455401, 158534.35711765, 110606.18362895, 113049.162018223, 112842.224371787, 3910.5596327805, 3033.95401833267, 3871.4121032366, 7514.19586546648, 5562.31383191583, 17015.9167559361, 19746.4364376394, 9998.46234085844, 345834.520655145, 340234.865394759, 345552.551224751, 351896.627833315, 75490.0582885143, 60152.1951917269, 32939.1179965398, 11358.4198717764, 1078.62984126406, 98989.8904272128, 64149.1946602301, 72127.5174155589, 64489.5608250985, 66842.7458007559, 3131.11855812919, 941.120317559907, 7111.33842487029, 11458.6398042715, 7258.70490850456, 14091.804268566, 16000.1429240728, 15998.4780911284, 16075.2328033676, 243351.772677424, 242844.376538813, 243116.803467092, 93823.9796754645, 155231.583351999, 37730.893203413, 177552.552764488, 94648.5234941987, 67434.9893707071, 38002.2879507112, 104603.129533735, 94504.8603853142, 37241.9061093494, 86753.2335279477, 59915.2110584999, 40385.5012646971, 42023.2590948276, 34766.3086422916, 16977.7534415373, 20351.5200295681, 16082.3597090039, 16075.2328033676, 380.817770655907, 4246.5893110582, 4410.91849146428, 72751.6711729069, 130849.632365069, 55060.8820952819, 72913.7110310002, 110978.752215726, 12313.1416715711, 3342.00551951783, 2363.80673386683, 172.798839577803, 313.671519948036, 11235.8851670407, 44728.8553894847, 74442.9999461946, 19097.2832549869, 19129.6610388453, 23469.0284834523, 136037.216959857, 219.83812202564, 269.021031901013, 99.4572270699257, 16264.5057148987, 24315.5737288896, 16291.5328723397, 11099.2090658443, 15880.8202787405, 14929.8663733744, 14081.1195855727, 55.8837027444483, 79877.6209043181, 80836.8142818876, 89010.8939140615, 85167.2710933782, 74496.4466057285, 74421.8372538773, 18984.9587912183, 136900.054313594, 5845.64890964899, 50562.1752933077, 55304.5614795905, 53392.3082705639, 61112.0373338855, 61640.0629462616, 2018.19830452236, 1676.70099014583, 119457.199229013, 122321.568133853, 122741.286211151, 47836.612387009, 20078.1896898285, 16572.4633305905, 40312.4058635667, 658.254210804327, 31544.2026700962, 33446.8244942795, 21334.1100353963, 14902.1499005996, 24729.9395514659, 26307.4058596767, 28520.4827726496, 9459.55834462236, 9090.63054171216, 1691.81365503639, 4613.00408375525, 2194.53226583879, 24373.6804397612, 31462.2307738586, 32219.6074151474, 1649.33180986244, 14583.903739703, 1308.427823984, 23560.5248775076, 16575.9635969705, 16740.0857271913, 18095.8791031279, 249491.91523559, 262096.351793723, 261065.479650717, 261680.230122765, 38406.4990715559, 38223.4047865675, 60230.931644224, 58171.7112946984, 19539.939406348, 94307.048984512, 78747.2746131727, 19337.8582553017, 752.006047488311, 744.660230554516, 56449.6805514173, 14356.175242238, 20862.2626294657, 20862.2626294657, 22264.3788132631, 26402.0778325944, 20267.2231417325, 380.817770655907, 33551.0574752735, 51212.6647401919, 4830.24325059441, 20314.4332476111, 6208.06442868916, 130.189402367952, 50307.6524509516, 16075.2328033676, 51359.6775242161, 51132.9536808768, 50763.3655819441, 30812.8957683429, 631.212954796511, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 295.557739471973, 897.685180032961, 721.525209319147, 14790.7051358327, 11906.9562861225, 8818.91193034729, 8513.32866117829, 43205.9443742264, 4456.94251146803, 31789.1416899254, 17144.9270619346, 14576.5792173094, 44359.7426141151, 22408.8727453804, 1829.6614611384, 4969.41366847578, 4001.95870596901, 4357.62032237333, 2442.49371895027, 1063.22821811696, 19599.5049812013, 26031.304531883, 701.471741783623, 17799.9838201411, 152216.135701793, 178080.113555556, 3263.63297233387, 5040.54247213971, 61882.5877188983, 42214.495058556, 44482.5200234524, 22255.9707067323, 25205.9999275914, 26952.1138573739, 34613.6706834423, 704.349186393028, 315.730964162932, 338.10920074907, 36982.9849286861, 37270.8763732936, 131759.579323256, 93823.9796754645, 17621.7238633249, 56329.3493988437, 56635.1399870969, 58817.5376627132, 57914.7397986691, 55306.3120941569, 44460.6768060732, 38995.4336695266, 28963.3513399469, 1296.89338122162, 2646.25341391727, 48067.1043818042, 5348.06039341391, 2927.23624127861, 25084.7320010508, 75061.5709741481, 66640.6719920014, 104775.715530858, 31173.7521866458, 14369.0645714357, 14517.1933361937, 3467.66761780786, 300121.270437476, 37267.3651735167, 295714.496450451, 25532.9940266509, 63571.5935003966, 55150.6945182499, 5811.28951558421, 2989.49900525221, 11590.5993193077, 32939.1179965398, 16075.2328033676, 26111.2821724874, 667.663331675873, 566.070592134515, 5545.36380441706, 2292.96068578427, 10364.973579667, 16075.2328033676, 108638.597779764, 63508.0626928067, 2245.53547767326, 2040.63877884098, 254.190708623128, 15967.7319777471, 26701.4190678963, 22894.1103922164, 380.817770655907, 20198.375139672, 153175.665720884, 398.206028873267, 100.68216531975, 14078.7204502843, 4897.37929862458, 4615.2473514945, 4463.89770493498, 16075.2328033676, 73574.9552922195, 80804.3798125565, 38914.1648793721, 4938.82159774985, 1010.23612896491, 12707.7608186086, 17065.4803546442, 75897.4349230162, 31457.2885183836, 26802.6007676464, 550.077848770969, 88.8655995574445, 16075.2328033676, 5266.96642552849, 1192.95856145257, 1061.3120296027, 888.904010998728, 46925.4252670205, 46528.8102282069, 14868.6815159847, 40359.4051810142, 9927.01553271952, 87306.3943662295, 22214.2747861794, 21695.6314025777, 56369.5952286206, 47568.1690686503, 50432.5379734911, 541.407831196675, 1066.08742571835, 2926.75909982747, 4936.85306638324, 2163.65241995417, 91086.1603294284, 21587.118275869, 93809.8731308876, 2759.56699918143, 3318.67783471596, 19503.1730749432, 24271.1577820147, 27553.3069860754, 623.307007911532, 700.906834754915, 380.817770655907, 46680.1420720144, 18393.4290453221, 22620.522763477, 40282.1300283954, 135867.506233443, 93823.9796754645, 16075.2328033676, 29956.0676611137, 4620.43191662203, 4658.50539586673, 133095.829909835, 113427.737249493, 4049.78940010759, 28455.4110235471, 27269.4755077968, 7127.91438904955, 26980.5396760824, 27012.9174599408, 26670.4282546067, 37120.9022605109, 34927.6169196598, 35053.9447079523, 7582.37244322862, 69532.0388124578, 69689.3367147847, 71440.1737772714, 74274.4249987407, 72362.171789714, 75534.0317272543, 535.778320926114, 35.9876265013509, 430.335507715417, 125148.270887331, 33033.9962026151, 18646.8075758805, 12223.4579812347, 7045.54832179861, 26157.8145281948, 48811.4217235829, 49099.3131681904, 16075.2328033676, 22760.1172694667, 40421.7245343851, 1412.22009106794, 1241.1340850347, 31461.5587619452, 31289.8742605205, 65457.6602244695, 2604.8400625898, 3502.37510179566, 2003.4634332603, 2929.73425000019, 63571.5935003966, 55150.6945182499, 21103.2409264293, 66098.4377721652, 398.206028873267, 100.68216531975, 60256.3454301609, 5782.58370207239, 74.3657790574448, 1810.34408035194, 347.956190490045, 2169.48833135398, 841.3868698417, 60386.3015054734, 52730.9188373698, 51927.4381613156, 63571.5935003966, 55150.6945182499, 2926.75909982747, 4936.85306638324, 48854.3564093352, 96780.3711546721, 47666.3251648926, 48039.3680963391, 20646.3848706613, 17025.5010773972, 2257.43473379443, 4456.74561960662, 3924.91955964358, 1459.96585583202, 93951.4888595654, 76596.129233954, 58983.7794531693, 22813.2525009148, 40474.8597658332, 1596.14063143149, 1515.41634919425, 356.757339761886, 881.43693428356, 2140.28314072847, 1014.74467921055, 29447.1962672944, 89281.2300628918, 98225.1817882845, 7015.93093282163, 90543.5023264453, 16075.2328033676, 60179.9679805909, 47688.188482866, 55442.3275130016, 26203.8534608696, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 1638.53718781816, 939.647131209686, 765.476897764711, 84705.3067522258, 17183.4762399731, 16075.2328033676, 47302.0435018091, 47107.0587328975, 48046.7126515324, 46142.8703625418, 1801.04521599116, 163649.075838707, 46195.177467134, 7751.58874088763, 4785.36439328066, 380.817770655907, 275636.33607252, 267399.933706027, 4068.23707489989, 184.038404122548, 165677.982559032, 18209.7956513386, 37168.2211566252, 40479.7864223485, 4598.14714961335, 117.091039205543, 398.206028873267, 100.68216531975, 1496.30840177241, 242.915519629276, 4161.95878384074, 1864.15501149668, 31914.0356427729, 29624.5689520269, 33792.3704895495, 8007.23667455387, 11166.665256954, 217225.381408895, 33311.4004757702, 32162.5375748029, 34221.0935940858, 45613.7438366821, 35152.1689955363, 19080.8655067634, 85306.609714591, 5890.8677830668, 5936.66524224353, 153175.665720884, 104641.488308056, 153175.665720884, 7284.94464057689, 2020.01112830903, 2731.84354655977, 7.29751611328288, 28.5866467324404, 4058.03861012816, 14790.0611965957, 14397.7228337455, 26532.2080240805, 38914.1648793721, 31894.1564664511, 31926.5342503094, 53822.2991284911, 57722.3934164874, 52451.8324435742, 51487.6440732185, 54248.599165044, 11545.444772854, 60038.4565510415, 68426.244476646, 27267.2659864539, 136.012689198563, 6361.2985160835, 3589.03967306279, 1231.16655235924, 907.378157132882, 1416.90260792588, 73821.8700898538, 286.444632280221, 1279.61237595292, 36496.6762021472, 54033.5208481893, 108303.987224926, 51727.0102214552, 31598.7480603542, 56615.9899526123, 80165.0489749543, 121142.683005229, 30860.9368857481, 30209.6846305911, 4630.35917345137, 4382.45674226798, 44943.5468606034, 47656.0944708976, 329.476038024962, 27043.3178229638, 29542.1949442316, 1603.25574583459, 3865.77098485339, 2128.77184756155, 34630.7379718209, 37300.6719025949, 34477.3657248695, 16075.2328033676, 12133.8710951581, 1206.70131958435, 12174.7646350843, 69439.4709369774, 9825.50432636544, 26963.7722891462, 36982.9849286861, 37270.8763732936, 51741.9497258933, 60327.5202910729, 51666.0288317657, 7562.17169258271, 29956.0676611137, 190876.012933958, 72828.7662358379, 49278.1042951796, 88215.2345639772, 85845.1916397876, 87121.6410087297, 2196.56948852425, 39890.4166709659, 120752.93478174, 15765.1883065478, 3313.85856569276, 1912.26404284212, 2309.15705582493, 398.206028873267, 100.68216531975, 12376.1113467147, 11915.4298614662, 82570.6191601724, 268684.617946118, 207137.093268306, 175638.507198447, 83722.3864289461, 89896.3512280807, 36010.424054196, 19026.1201213908, 86165.4982332778, 113174.508193994, 278072.635063265, 113236.810066342, 29956.0676611137, 41962.6523769007, 42717.7109154456, 41753.5225450899, 36982.9849286861, 37270.8763732936, 80579.8308499257, 7458.62670544805, 93823.9796754645, 10868.0914348758, 939.647131209686, 765.476897764711, 4001.95870596901, 4357.62032237333, 20587.9185616116, 18289.641774897, 1442.91874787607, 15706.9859345837, 2028.96277280937, 37220.3029536803, 42296.7235571322, 40926.2568722153, 39962.0685018596, 19337.8582553017, 148146.189001775, 139315.221552228, 125844.464217704, 162293.197393681, 162528.997605428, 146340.436061102, 152309.038598743, 127267.610923779, 155468.710403851, 26332.212969649, 26292.5985621234, 6449.61153526057, 5370.80498146574, 40064.6867553009, 57726.2940202193, 2281.17337355253, 2109.77528787597, 24276.9748088487, 39366.1939622203, 27800.3851483576, 40818.1019397999, 49614.536748347, 34543.5899395263, 34172.1973164336, 16075.2328033676, 15750.4590817142, 15224.4054195006, 21007.7116412173, 47421.1724211692, 581.55733243844, 3954.53762744741, 6307.52892402948, 7727.23206442239, 68696.9856912804, 58292.4707790326, 63605.4816627409, 69758.5768269686, 57600.6939656118, 5035.40269654205, 8770.99671641627, 96.686921562581, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529483, 25460.6460476849, 90373.0246837598, 73440.0731178053, 73716.8109753609, 72013.0883835197, 96058.9099168597, 36.1416508139367, 30.5876756009786, 74468.5859618555, 3918.22229231661, 3836.42019210666, 16075.2328033676, 59446.3189319805, 32133.0247924527, 21083.7917614439, 33062.6630074965, 14356.175242238, 55091.9336719613, 64802.1405688806, 54896.9087215653, 3335.3883926218, 3308.41389659244, 16075.2328033676, 16458.5311383836, 2381.87648001949, 235.888335573082, 1079.57788014382, 3265.47177548816, 8102.12948634913, 3972.4425308432, 53517.3093186957, 398.206028873267, 100.68216531975, 512.265878039168, 12040.278820516, 4782.96349517708, 20224.9566213167, 28445.600900177, 76376.0395540738, 69551.3997422656, 43977.641476272, 65065.7497861239, 2219.12750692631, 1513.11003279499, 1574.56863970513, 393.716138903186, 427.976574313798, 642.389727595789, 436.976134734277, 83133.7251543077, 100717.475462435, 92296.5764802883, 110.441908169989, 42385.2667713094, 35894.5974816859, 4019.93055276592, 2079.29089735499, 57622.5171077901, 55982.7038764768, 98712.6550079291, 7754.2166880541, 741.18916026791, 457.298088335605, 380.817770655907, 589.846945856218, 448.711110059493, 606.237057078003, 11148.465061722, 12046.8003118282, 11240.5005777553, 12797.2247501701, 398.206028873267, 100.68216531975, 36982.9849286861, 37270.8763732936, 667.663331675873, 566.070592134515, 29447.1962672944, 10211.7670326864, 39397.1826767899, 20028.0524096779, 61110.4372303698, 119685.465196446, 81041.6371493106, 14790.0611965957, 83857.1976708216, 6232.62792643737, 4941.77716359388, 201.921554556655, 1325.18158921821, 398.206028873267, 100.68216531975, 16828.0307407156, 361343.924479427, 203490.241258725, 224398.635579899, 227973.765337606, 214140.419841746, 17383.1290701478, 165.105593485501, 163.148000537549, 1247.85143198612, 464.810235215233, 7438.37569100339, 7717.40407667235, 7106.27431670089, 2097.682220922, 969.14331368424, 521.146071023087, 10330.0025134336, 7092.78371210808, 7747.79188837366, 7371.73490267177, 16604.0214872067, 17909.7012330322, 3410.42783168138, 3593.26919047491, 67025.970008597, 82261.4382687422, 167025.923033985, 167591.415195814, 172859.102637552, 170206.309989656, 164395.805095093, 164355.618811528, 168622.165747915, 164531.112588629, 165102.276225055, 169585.568858557, 165670.346605114, 9668.39816463089, 1856.15162274216, 51312.6005545794, 51504.6834495228, 860.76976955382, 1590.64287900738, 23583.8965500295, 186446.247395347, 42020.569897451, 46333.9729054006, 34653.6250305714, 35279.889765086, 1386.30925733456, 10739.0514532087, 79244.1333150573, 137342.09450722, 88950.3673170079, 667.663331675873, 566.070592134515, 3265.38704170416, 2940.79951661399, 41006.4573164376, 46894.3861156416, 54016.1059400898, 1391.08025104526, 101627.489100994, 36070.6084492904, 41218.6129323469, 20623.4454468565, 16937.0825413522, 53628.7936819859, 19337.8582553017, 758.017247435295, 74.3657790574448, 121.620466588186, 5.78559118236115, 17017.3657687925, 5469.57680096827, 54235.6659893459, 153889.212315898, 154848.523651986, 255.167752297303, 303.185109429245, 380.817770655907, 17911.878966348, 18123.7909924198, 71182.8027936298, 69309.9625984282, 71473.4790803247, 70214.2341581977, 61823.6380122268, 80948.1330462666, 69891.9918615386, 44370.3060124456, 2329.22247578325, 121.94778797986, 3446.89767898377, 5268.37372888506, 5430.56825066798, 5992.56633450765, 5269.11069445943, 16075.2328033676, 7106.27431670089, 2097.682220922, 13812.7845027457, 52925.0539860187, 1733.09821796985, 1930.14988348519, 42645.8682736293, 6291.39924150032, 13965.3857427483, 2617.80683642859, 88525.1188681499, 49600.7868545241, 16075.2328033676, 55039.8536508236, 52938.5907226115, 6123.05338778074, 9696.51006616501, 53188.7704001565, 58522.9973977792, 53476.661844764, 398.206028873267, 100.68216531975, 12550.9093094836, 101149.866662325, 583.387753718421, 1087.89043882793, 658.254210804327, 32668.5475257474, 35167.4246470151, 31482.6120099971, 38041.8580253728, 206.761176210849, 1674.65799054909, 88258.4569980874, 65301.1617391746, 28498.8193557754, 14356.175242238, 765.224730234081, 117.357759743728, 4456.94251146803, 31789.1416899254, 168.803563060573, 64582.7281922128, 84908.2415783781, 97071.5512910139, 20627.3805903399, 28502.9484160247, 27538.760045669, 6960.40251199226, 6896.96693630203, 7553.23080419276, 17409.6173675702, 5459.53521960215, 11108.6229635431, 9168.91647052269, 119398.483531519, 105008.196995327, 4001.95870596901, 4357.62032237333, 3179.42498392968, 70.0487253550673, 48019.3662166286, 145433.809828158, 40693.8822246059, 45230.4298174844, 95425.7879333892, 115578.885529434, 106099.632639448, 22840.7143464175, 4610.9619630432, 1865.52670607002, 36443.74285581, 34272.2429150216, 33660.4629764611, 67893.1649962413, 127571.344910659, 120636.828093912, 92854.6051679841, 121172.538375154, 121326.692666946, 30806.1613215181, 30548.3462139258, 34959.9823782843, 14078.7204502843, 398.206028873267, 100.68216531975, 4263.71472038959, 153175.665720884, 238760.853705604, 222701.676367588, 269659.60766865, 92189.5250147731, 170842.743000644, 147850.722096189, 368521.879419072, 235377.253008258, 266226.609078027, 225967.756479707, 19337.8582553017, 15328.0300232362, 8041.25938153956, 11334.2450427577, 10237.9765566007, 52135.9803770694, 398.206028873267, 100.68216531975, 4211.8882470528, 4843.96383873594, 48424.868421795, 49811.1683393969, 7652.95454326893, 7457.70489262558, 12487.3443239224, 75774.5861533763, 118889.757562134, 55.8837027444483, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 28502.9484160247, 27538.760045669, 1344.91555283283, 1534.8455194277, 5149.1243976634, 52517.3689214811, 40768.8108402006, 2894.62766262561, 22598.9450131839, 1012.56210112466, 1658.13449840418, 35725.4114774796, 16457.9659544379, 34119.5732193562, 25427.4146264185, 173874.442777084, 64285.3217244765, 63750.6350620208, 64210.3059416548, 64196.1725323453, 64122.1862363721, 81973.1426992175, 11989.4625273211, 6920.66715407778, 10472.7287589941, 12021.6704965798, 4701.65481324998, 6711.74877980574, 16075.2328033676, 27035.460617007, 5700.95226171671, 121.401530999426, 285.350551274648, 2965.26303253727, 7568.63948814992, 24506.2576994228, 54307.6664177307, 63777.695819612, 80833.7427965251, 49518.8063526307, 10983.393210459, 13347.4124721324, 6603.93201132395, 6065.88242172138, 28263.2031370645, 47135.7200441963, 8442.31636767191, 31732.4838704206, 153175.665720884, 35106.7222359647, 34652.2544821641, 4456.94251146803, 31789.1416899254, 69464.3281631222, 63501.8018977801, 63789.6933423876, 69403.7266192652, 59602.3761537577, 43075.9725703753, 4620.43191662203, 4658.50539586673, 88082.9743604386, 70387.9668746152, 209213.714470638, 196245.655897606, 25084.7320010508, 12705.1326393703, 26739.1889950993, 17800.7529566801, 26913.793086354, 18784.4268030149, 49656.9661084809, 14166.6664823045, 38790.9360370772, 47002.8714476976, 163496.980067043, 46541.695306862, 165561.091548099, 46552.5189166935, 46207.5796099786, 32610.9714714097, 14583.4247833839, 12732.108362629, 20121.1147497618, 13547.682642629, 45514.8112944327, 8198.66815492132, 38914.1648793721, 27043.3178229638, 29542.1949442316, 65457.6602244695, 93823.9796754645, 12601.3815624615, 3717.78716509019, 4063.05589236591, 24271.1577820147, 11134.4722881965, 11009.9803992845, 27043.3178229638, 29542.1949442316, 28502.9484160247, 27538.760045669, 2227.8593567833, 2056.62103324051, 99.7320165798519, 139439.573140022, 180173.976103057, 154718.775789369, 179784.207033538, 180082.986267484, 10366.1409199313, 71603.3929814358, 63182.4939992891, 118392.93239799, 44530.947222382, 33324.6226895005, 34643.0454865444, 5837.54354585766, 35501.0391572029, 73754.0387953122, 5039.64509694219, 56113.3262712736, 34128.3735786443, 33164.1852082886, 4383.38525943078, 206.102244941948, 436.176840447964, 13.0210905868303, 79104.2914387608, 17144.9270619346, 14576.5792173094, 4367.31954792604, 4930.99030673717, 4620.43191662203, 4658.50539586673, 5204.11546260184, 3898.64550997686, 107020.984285254, 114099.617569792, 6141.95779044129, 3324.31407659029, 13730.8383920942, 29492.8515731591, 4708.49068369958, 1553.31085916099, 2454.47110158837, 2089.14039780931, 2625.99001958519, 1434.92859366781, 2578.04277948502, 69031.5165808322, 47568.1690686503, 50432.5379734911, 9106.56331029686, 29548.7753759837, 15455.7690999592, 5578.6744198816, 9159.88765933989, 46050.3443490919, 45206.2624375341, 45395.2402884092, 32515.1445946699, 32371.6433972976, 15027.5292174332, 12395.9855575968, 9014.84528920863, 15220.2490527175, 5220.45830769083, 50219.7320419396, 50024.747273028, 50964.4011916629, 49060.5589026723, 3972.06625673288, 134.479447583574, 259.447533525771, 93823.9796754645, 271234.632804734, 268810.684421445, 265408.404876666, 265263.077078015, 67181.2063102032, 76670.7152461985, 7479.82337965997, 4526.89222763858, 7508.54642053444, 9032.33806491232, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529484, 25460.646047685, 8467.8433742867, 97337.1893372181, 13173.9633615695, 102153.852674459, 102268.815005494, 12487.3443239224, 153175.665720884, 28016.3775294982, 16401.7213496833, 6000.12308441262, 6349.05838888595, 6001.74440011247, 6151.42391134341, 7656.55165555741, 16075.2328033676, 398.206028873267, 100.68216531975, 17261.3023646461, 18601.4148413147, 10788.4536462673, 18323.5231928272, 19181.192920255, 4001.95870596901, 4357.62032237333, 19337.8582553017, 1864.15501149668, 766.524294326975, 33762.8928258272, 12822.6288203288, 37260.9134461705, 23046.6385072794, 19014.9399931232, 18607.8321494227, 3419.78018687112, 23103.4588896023, 74468.5859618555, 152994.23615263, 147176.843175687, 46942.3380508782, 12794.0445355127, 106262.899226039, 99873.2748641811, 120155.203014464, 120161.274140481, 6008.05146073939, 3892.65485072541, 2731.52302700629, 284794.792819051, 281093.167534099, 283965.935026762, 283743.967092465, 231541.508547375, 283599.453849128, 281171.013247861, 289665.769824253, 281443.523887319, 291737.670232172, 312782.870710669, 13828.0377954511, 32478.2450540068, 6058.89922087771, 7087.49467299915, 27235.6441161705, 412.948389064467, 2001.01520321863, 46072.7513602738, 47176.1174761153, 27043.3178229638, 29542.1949442316, 74468.5859618556, 21442.8583355827, 40300.2083852868, 17301.4452729662, 307.303707156227, 626.138801443826, 74.0646474677702, 333.176284299135, 2902.67587944984, 13802.8577726755, 12721.8016078941, 1386.30925733456, 104160.939539591, 102678.646139363, 11495.4194241342, 11500.9733126347, 2903.98969908575, 74.3138641739006, 74.3138641739006, 2926.75909982747, 4936.85306638324, 59368.6002936813, 8723.10194190259, 1636.3387577496, 2555.65784578012, 43560.5192295784, 40591.9965421697, 51006.2545375135, 38914.1648793721, 1864.15501149668, 40408.6987051311, 45308.4904568902, 7508.54642053444, 19337.8582553017, 10138.9114079657, 6748.5446245151, 34553.4880542934, 35575.4702473679, 40461.3108045749, 25419.301549206, 24209.7507355763, 54287.5501287553, 25796.3605491714, 28044.2073490306, 25774.6907112549, 25663.0731195349, 3130.22172609467, 66623.3263215092, 67009.5743366391, 66911.2177661167, 66642.4934989355, 33520.3030255531, 78085.6322333073, 48401.476649033, 40542.529478714, 67947.3520522741, 65775.1526912092, 47568.1690686503, 50432.5379734911, 380.817770655907, 58645.7519752514, 16413.7758763607, 15169.8847771236, 1856.15162274216, 2427.88648596289, 1765.5138539457, 48297.1814057218, 56035.2394688549, 11892.6563771961, 2958.8898473578, 3420.99716675566, 13882.5002183534, 391.531497495759, 188.929065067072, 111.123424537144, 228.76068317307, 5127.82600211282, 168870.309634008, 93823.9796754645, 16075.2328033676, 1008.93628426974, 9179.4351480092, 5985.22660858454, 5917.59464982359, 4916.60901235016, 6407.31889845239, 6036.71585250087, 16075.2328033676, 9724.70541100056, 37304.5884083199, 95.3333664870739, 1921.39145622923, 1990.78596599304, 8908.71330783467, 3442.83969703514, 8306.74376151651, 40919.3443166264, 39006.6701059139, 10174.5402772304, 9925.35900853465, 18637.4380020987, 21001.6406567466, 76544.0777061686, 398.206028873267, 100.68216531975, 100344.646397673, 9032.33806491231, 17338.2710627073, 32468.3393483451, 66287.9648854568, 3735.49922529483, 25460.6460476849, 29683.9009883408, 64843.7139418263, 342.628915569153, 1401.43560769586, 7284.94464057689, 197435.583957957, 138545.814346194, 212129.314749779, 284276.163540239, 71848.416263965, 141072.849088707, 7727.23206442239, 27996.6067521145, 24869.3448925354, 30444.7073741381, 2730.80652245778, 8914.02906986728, 12476.8224383753, 15715.5560806915, 13.3807607432864, 7513.79324262127, 10539.8068916759, 10371.020810303, 10493.1833430231, 145221.628278939, 143739.334878711, 68659.4011119247]

sns.distplot(D)

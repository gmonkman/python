# %%
import funclib.baselib as baselib

# %%
#Concat List
s =['ABSOLUTE', 'ACTION', 'ADMIN', 'AFTER', 'AGGREGATE', 'ALIAS', 'ALLOCATE', 'ARE', 'ARRAY', 'ASENSITIVE', 'ASSERTION', 'ASYMMETRIC', 'AT', 'ATOMIC', 'BEFORE', 'BINARY', 'BIT', 'BLOB', 'BOOLEAN', 'BOTH', 'BREADTH', 'CALL', 'CALLED', 'CARDINALITY', 'CASCADED', 'CAST', 'CATALOG', 'CHAR', 'CHARACTER', 'CLASS', 'CLOB', 'COLLATION', 'COLLECT', 'COMPLETION', 'CONDITION', 'CONNECT', 'CONNECTION', 'CONSTRAINTS', 'CONSTRUCTOR', 'CORR', 'CORRESPONDING', 'COVAR_POP', 'COVAR_SAMP', 'CUBE', 'CUME_DIST', 'CURRENT_CATALOG', 'CURRENT_DEFAULT_TRANSFORM_GROUP', 'CURRENT_PATH', 'CURRENT_ROLE', 'CURRENT_SCHEMA', 'CURRENT_TRANSFORM_GROUP_FOR_TYPE', 'CYCLE', 'DATA', 'DATE', 'DAY', 'DEC', 'DECIMAL', 'DEFERRABLE', 'DEFERRED', 'DEPTH', 'DEREF', 'DESCRIBE', 'DESCRIPTOR', 'DESTROY', 'DESTRUCTOR', 'DETERMINISTIC', 'DICTIONARY', 'DIAGNOSTICS', 'DISCONNECT', 'DOMAIN', 'DYNAMIC', 'EACH', 'ELEMENT', 'END-EXEC', 'EQUALS', 'EVERY', 'EXCEPTION', 'FALSE', 'FILTER', 'FIRST', 'FLOAT', 'FOUND', 'FREE', 'FULLTEXTTABLE', 'FUSION', 'GENERAL', 'GET', 'GLOBAL', 'GO', 'GROUPING', 'HOLD', 'HOST', 'HOUR', 'IGNORE', 'IMMEDIATE', 'INDICATOR', 'INITIALIZE', 'INITIALLY', 'INOUT', 'INPUT', 'INT', 'INTEGER', 'INTERSECTION', 'INTERVAL', 'ISOLATION', 'ITERATE', 'LANGUAGE', 'LARGE', 'LAST', 'LATERAL', 'LEADING', 'LESS', 'LEVEL', 'LIKE_REGEX', 'LIMIT', 'LN', 'LOCAL', 'LOCALTIME', 'LOCALTIMESTAMP', 'LOCATOR', 'MAP', 'MATCH', 'MEMBER', 'METHOD', 'MINUTE', 'MOD', 'MODIFIES', 'MODIFY', 'MODULE', 'MONTH', 'MULTISET', 'NAMES', 'NATURAL', 'NCHAR', 'NCLOB', 'NEW', 'NEXT', 'NO', 'NONE', 'NORMALIZE', 'NUMERIC', 'OBJECT', 'OCCURRENCES_REGEX', 'OLD', 'ONLY', 'OPERATION', 'ORDINALITY', 'OUT', 'OVERLAY', 'OUTPUT', 'PAD', 'PARAMETER', 'PARAMETERS', 'PARTIAL', 'PARTITION', 'PATH', 'POSTFIX', 'PREFIX', 'PREORDER', 'PREPARE', 'PERCENT_RANK', 'PERCENTILE_CONT', 'PERCENTILE_DISC', 'POSITION_REGEX', 'PRESERVE', 'PRIOR', 'PRIVILEGES', 'RANGE', 'READS', 'REAL', 'RECURSIVE', 'REF', 'REFERENCING', 'REGR_AVGX', 'REGR_AVGY', 'REGR_COUNT', 'REGR_INTERCEPT', 'REGR_R2', 'REGR_SLOPE', 'REGR_SXX', 'REGR_SXY', 'REGR_SYY', 'RELATIVE', 'RELEASE', 'RESULT', 'RETURNS', 'ROLE', 'ROLLUP', 'ROUTINE', 'ROW', 'ROWS', 'SAVEPOINT', 'SCROLL', 'SCOPE', 'SEARCH', 'SECOND', 'SECTION', 'SENSITIVE', 'SEQUENCE', 'SESSION', 'SETS', 'SIMILAR', 'SIZE', 'SMALLINT', 'SPACE', 'SPECIFIC', 'SPECIFICTYPE', 'SQL', 'SQLEXCEPTION', 'SQLSTATE', 'SQLWARNING', 'START', 'STATE', 'STATEMENT', 'STATIC', 'STDDEV_POP', 'STDDEV_SAMP', 'STRUCTURE', 'SUBMULTISET', 'SUBSTRING_REGEX', 'SYMMETRIC', 'SYSTEM', 'TEMPORARY', 'TERMINATE', 'THAN', 'TIME', 'TIMESTAMP', 'TIMEZONE_HOUR', 'TIMEZONE_MINUTE', 'TRAILING', 'TRANSLATE_REGEX', 'TRANSLATION', 'TREAT', 'TRUE', 'UESCAPE', 'UNDER', 'UNKNOWN', 'UNNEST', 'USAGE', 'USING', 'VALUE', 'VAR_POP', 'VAR_SAMP', 'VARCHAR', 'VARIABLE', 'WHENEVER', 'WIDTH_BUCKET', 'WITHOUT', 'WINDOW', 'WITHIN', 'WORK', 'WRITE', 'XMLAGG', 'XMLATTRIBUTES', 'XMLBINARY', 'XMLCAST', 'XMLCOMMENT', 'XMLCONCAT', 'XMLDOCUMENT', 'XMLELEMENT', 'XMLEXISTS', 'XMLFOREST', 'XMLITERATE', 'XMLNAMESPACES', 'XMLPARSE', 'XMLPI', 'XMLQUERY', 'XMLSERIALIZE', 'XMLTABLE', 'XMLTEXT', 'XMLVALIDATE', 'YEAR', 'ZONE']
ss = ','.join(s)
ss

# %%
#Items not shared between two lists
list_species = ["Allis Shad", "Anchovy", "Angel Shark", "Atlantic Wolffish", "Baillon's Wrasse", "Ballan Wrasse", "Bass", "Black Bream", "Black Goby", "Black Scorpion Fish", "Black-mouthed Dogfish", "Blade Runner", "Blenny (Unspecified)", "Blue Shark", "Blue Whiting", "Bluefin Tuna", "Boar Fish", "Bogue", "Bonito", "Bream (Unspecified)", "Brill", "Bull Huss", "Butterfish", "Clingfish", "Cod", "Comber", "Common Goby", "Common Stingray", "Conger Eel", "Corkwing Wrasse", "Cornish Blackfish", "Couch's Seabream", "Cuckoo Wrasse", "Dab", "Dogfish (Lesser)", "Dover Sole", "Dragonet", "Eel (Unspecified)", "Five-bearded Rockling", "Flatfish (Unspecified)", "Flounder", "Four-bearded Rockling", "Garfish (Garpike)", "Giant Goby", "Gilthead Sea Bream", "Goby (Unspecified)", "Golden-Grey Mullet", "Goldsinny Wrasse", "Greater Forkbeard", "Greenland Shark", "Gurnard (Grey)", "Gurnard (Red)", "Gurnard (Tub)", "Gurnard (Unspecified)", "Haddock", "Hagfish", "Hake", "Herring", "John Dory", "Lemon Sole", "Leopard-spotted Goby", "Ling", "Long Rough Dab", "Lumpsucker", "Mackerel", "Mako Shark", "Marlin", "Mediterranean Scaldfish", "Megrim", "Mullet (Unspecified)", "Norway Haddock", "Norway Pout", "Opah", "Pandora Sea Bream", "Pilchard", "Pipefish (Greater)", "Pipefish (Unspecified)", "Plaice", "Pogge", "Pollack", "Poor Cod", "Porbeagle Shark", "Pouting (Bib, Pout)", "Ray (Blonde)", "Ray (Cuckoo)", "Ray (Eagle)", "Ray (Electric)", "Ray (Marbled-Electric)", "Ray (Sandy)", "Ray (Shagreen)", "Ray (Small Eyed)", "Ray (Spotted)", "Ray (Starry)", "Ray (Thornback)", "Ray (Undulate)", "Ray (Unspecified)", "Ray's Bream", "Red Band Fish", "Red Mullet", "Red Scorpion Fish", "Red Sea Bream", "Rock cook Wrasse", "Rock Goby", "Rockling (Unspecified)", "Rudderfish", "Saithe (Coley, Coalfish)", "Salmon", "Sand eel (Greater)", "Sand eel (Lesser)", "Sand eel (Unspecified)", "Sand Goby", "Sand Smelt (Silversides)", "Sand Sole", "Scad (Horse Mackerel)", "Scale-rayed Wrasse", "Sea Scorpion (Long Spined)", "Sea Scorpion (Short Spined)", "Sea Scorpion (Unspecified)", "Sea Trout (Sewin)", "Shad (Unspecified)", "Shanny", "Sharks (Great)", "Shore Rockling", "Silver Eel (European)", "Six-gilled Shark", "Skate (Common)", "Skate (Unspecified)", "Skate (White)", "Skate/Ray (Unspecified)", "Smooth Hound", "Sole (Unspecified)", "Solenette", "Spanish Mackerel", "Sprat", "Spurdog (Spiny Dogfish)", "Squid (European)", "Squid (Northern)", "Squid (Unspecified)", "Sturgeon (Unspecified)", "Sunfish", "Tadpole Fish", "Thick Lipped Grey Mullet", "Thin Lipped Grey Mullet", "Three-bearded Rockling", "Thresher Shark", "Tompot Blenny", "Tope", "Topknot", "Triggerfish", "Turbot", "Tusk", "Twaite Shad", "Vivaporous Blenny", "Weeverfish (Greater)", "Weeverfish (Lesser)", "Weeverfish (Unspecified)", "White Sea Bream", "Whiting", "Witch", "Wrasse (Unspecified)", "Wreckfish", "Yellowfin Tuna", "Couch's Goby"]
assert len(list_species) == len(list(set(list_species)))

list_species_alias = ["Allis Shad", "Allis Shad", "Allis Shad", "Anchovy", "Angel Shark", "Angel Shark", "Angel Shark", "Angel Shark", "Atlantic Wolffish", "Atlantic Wolffish", "Atlantic Wolffish", "Atlantic Wolffish", "Atlantic Wolffish", "Atlantic Wolffish", "Atlantic Wolffish", "Atlantic Wolffish", "Atlantic Wolffish", "Atlantic Wolffish", "Atlantic Wolffish", "Atlantic Wolffish", "Atlantic Wolffish", "Atlantic Wolffish", "Baillon's Wrasse", "Baillon's Wrasse", "Baillon's Wrasse", "Ballan Wrasse", "Ballan Wrasse", "Ballan Wrasse", "Bass", "Bass", "Bass", "Bass", "Black Bream", "Black Bream", "Black Bream", "Black Bream", "Black Bream", "Black Bream", "Black Bream", "Black Goby", "Black Scorpion Fish", "Black Scorpion Fish", "Black Scorpion Fish", "Black Scorpion Fish", "Black Scorpion Fish", "Black-mouthed Dogfish", "Black-mouthed Dogfish", "Black-mouthed Dogfish", "Black-mouthed Dogfish", "Black-mouthed Dogfish", "Black-mouthed Dogfish", "Black-mouthed Dogfish", "Black-mouthed Dogfish", "Black-mouthed Dogfish", "Black-mouthed Dogfish", "Black-mouthed Dogfish", "Black-mouthed Dogfish", "Black-mouthed Dogfish", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blade Runner", "Blenny (Unspecified)", "Blue Shark", "Blue Whiting", "Bluefin Tuna", "Bluefin Tuna", "Bluefin Tuna", "Bluefin Tuna", "Bluefin Tuna", "Boar Fish", "Boar Fish", "Bogue", "Bonito", "Bream (Unspecified)", "Brill", "Bull Huss", "Bull Huss", "Bull Huss", "Bull Huss", "Bull Huss", "Bull Huss", "Bull Huss", "Bull Huss", "Bull Huss", "Bull Huss", "Bull Huss", "Bull Huss", "Bull Huss", "Bull Huss", "Bull Huss", "Bull Huss", "Bull Huss", "Bull Huss", "Butterfish", "Butterfish", "Butterfish", "Butterfish", "Butterfish", "Butterfish", "Clingfish", "Clingfish", "Cod", "Cod", "Cod", "Cod", "Cod", "Cod", "Cod", "Comber", "Common Goby", "Common Stingray", "Common Stingray", "Common Stingray", "Conger Eel", "Conger Eel", "Corkwing Wrasse", "Corkwing Wrasse", "Cornish Blackfish", "Cornish Blackfish", "Cornish Blackfish", "Cornish Blackfish", "Cornish Blackfish", "Cornish Blackfish", "Cornish Blackfish", "Cornish Blackfish", "Cornish Blackfish", "Couch's Seabream", "Couch's Seabream", "Couch's Seabream", "Couch's Seabream", "Couch's Seabream", "Couch's Seabream", "Couch's Seabream", "Couch's Seabream", "Couch's Seabream", "Couch's Seabream", "Couch's Seabream", "Couch's Seabream", "Couch's Seabream", "Couch's Seabream", "Couch's Seabream", "Cuckoo Wrasse", "Cuckoo Wrasse", "Cuckoo Wrasse", "Dab", "Dogfish (Lesser)", "Dogfish (Lesser)", "Dogfish (Lesser)", "Dogfish (Lesser)", "Dogfish (Lesser)", "Dogfish (Lesser)", "Dogfish (Lesser)", "Dogfish (Lesser)", "Dogfish (Lesser)", "Dogfish (Lesser)", "Dogfish (Lesser)", "Dogfish (Lesser)", "Dogfish (Lesser)", "Dogfish (Lesser)", "Dogfish (Lesser)", "Dogfish (Lesser)", "Dogfish (Lesser)", "Dover Sole", "Dover Sole", "Dover Sole", "Dover Sole", "Dragonet", "Dragonet", "Dragonet", "Dragonet", "Eel (Unspecified)", "Five-bearded Rockling", "Five-bearded Rockling", "Five-bearded Rockling", "Five-bearded Rockling", "Five-bearded Rockling", "Five-bearded Rockling", "Five-bearded Rockling", "Flatfish (Unspecified)", "Flatfish (Unspecified)", "Flatfish (Unspecified)", "Flounder", "Flounder", "Flounder", "Flounder", "Four-bearded Rockling", "Four-bearded Rockling", "Four-bearded Rockling", "Four-bearded Rockling", "Four-bearded Rockling", "Four-bearded Rockling", "Four-bearded Rockling", "Garfish (Garpike)", "Garfish (Garpike)", "Garfish (Garpike)", "Garfish (Garpike)", "Garfish (Garpike)", "Garfish (Garpike)", "Garfish (Garpike)", "Garfish (Garpike)", "Garfish (Garpike)", "Garfish (Garpike)", "Garfish (Garpike)", "Garfish (Garpike)", "Garfish (Garpike)", "Garfish (Garpike)", "Garfish (Garpike)", "Garfish (Garpike)", "Garfish (Garpike)", "Garfish (Garpike)", "Garfish (Garpike)", "Garfish (Garpike)", "Garfish (Garpike)", "Giant Goby", "Gilthead Sea Bream", "Gilthead Sea Bream", "Gilthead Sea Bream", "Gilthead Sea Bream", "Gilthead Sea Bream", "Gilthead Sea Bream", "Gilthead Sea Bream", "Gilthead Sea Bream", "Goby (Unspecified)", "Golden-Grey Mullet", "Golden-Grey Mullet", "Golden-Grey Mullet", "Goldsinny Wrasse", "Goldsinny Wrasse", "Goldsinny Wrasse", "Goldsinny Wrasse", "Goldsinny Wrasse", "Goldsinny Wrasse", "Goldsinny Wrasse", "Goldsinny Wrasse", "Goldsinny Wrasse", "Greater Forkbeard", "Greater Forkbeard", "Greater Forkbeard", "Greater Forkbeard", "Greater Forkbeard", "Greater Forkbeard", "Greater Forkbeard", "Greater Forkbeard", "Greater Forkbeard", "Greater Forkbeard", "Greater Forkbeard", "Greenland Shark", "Greenland Shark", "Greenland Shark", "Greenland Shark", "Greenland Shark", "Gurnard (Grey)", "Gurnard (Grey)", "Gurnard (Red)", "Gurnard (Red)", "Gurnard (Tub)", "Gurnard (Tub)", "Gurnard (Tub)", "Gurnard (Tub)", "Gurnard (Tub)", "Gurnard (Unspecified)", "Haddock", "Hagfish", "Hagfish", "Hagfish", "Hagfish", "Hagfish", "Hagfish", "Hagfish", "Hagfish", "Hagfish", "Hagfish", "Hagfish", "Hagfish", "Hagfish", "Hake", "Herring", "Herring", "John Dory", "John Dory", "John Dory", "John Dory", "John Dory", "John Dory", "John Dory", "John Dory", "John Dory", "John Dory", "John Dory", "John Dory", "John Dory", "John Dory", "John Dory", "John Dory", "John Dory", "John Dory", "John Dory", "John Dory", "John Dory", "Lemon Sole", "Leopard-spotted Goby", "Leopard-spotted Goby", "Leopard-spotted Goby", "Leopard-spotted Goby", "Leopard-spotted Goby", "Leopard-spotted Goby", "Leopard-spotted Goby", "Ling", "Ling", "Long Rough Dab", "Long Rough Dab", "Long Rough Dab", "Long Rough Dab", "Long Rough Dab", "Long Rough Dab", "Long Rough Dab", "Long Rough Dab", "Long Rough Dab", "Long Rough Dab", "Long Rough Dab", "Long Rough Dab", "Long Rough Dab", "Lumpsucker", "Lumpsucker", "Lumpsucker", "Lumpsucker", "Lumpsucker", "Lumpsucker", "Lumpsucker", "Lumpsucker", "Lumpsucker", "Lumpsucker", "Mackerel", "Mackerel", "Mackerel", "Mackerel", "Mackerel", "Mackerel", "Mackerel", "Mackerel", "Mackerel", "Mackerel", "Mackerel", "Mako Shark", "Mako Shark", "Marlin", "Mediterranean Scaldfish", "Mediterranean Scaldfish", "Mediterranean Scaldfish", "Mediterranean Scaldfish", "Megrim", "Megrim", "Megrim", "Mullet (Unspecified)", "Norway Haddock", "Norway Haddock", "Norway Haddock", "Norway Haddock", "Norway Pout", "Norway Pout", "Opah", "Opah", "Opah", "Opah", "Opah", "Opah", "Pandora Sea Bream", "Pandora Sea Bream", "Pandora Sea Bream", "Pandora Sea Bream", "Pilchard", "Pipefish (Greater)", "Pipefish (Unspecified)", "Plaice", "Pogge", "Pogge", "Pogge", "Pogge", "Pogge", "Pogge", "Pollack", "Pollack", "Pollack", "Poor Cod", "Poor Cod", "Poor Cod", "Porbeagle Shark", "Porbeagle Shark", "Porbeagle Shark", "Porbeagle Shark", "Porbeagle Shark", "Porbeagle Shark", "Pouting (Bib, Pout)", "Pouting (Bib, Pout)", "Pouting (Bib, Pout)", "Pouting (Bib, Pout)", "Pouting (Bib, Pout)", "Ray (Blonde)", "Ray (Blonde)", "Ray (Blonde)", "Ray (Cuckoo)", "Ray (Cuckoo)", "Ray (Eagle)", "Ray (Eagle)", "Ray (Eagle)", "Ray (Eagle)", "Ray (Eagle)", "Ray (Electric)", "Ray (Electric)", "Ray (Electric)", "Ray (Electric)", "Ray (Electric)", "Ray (Electric)", "Ray (Electric)", "Ray (Electric)", "Ray (Marbled-Electric)", "Ray (Marbled-Electric)", "Ray (Marbled-Electric)", "Ray (Marbled-Electric)", "Ray (Marbled-Electric)", "Ray (Sandy)", "Ray (Sandy)", "Ray (Shagreen)", "Ray (Shagreen)", "Ray (Small Eyed)", "Ray (Small Eyed)", "Ray (Small Eyed)", "Ray (Small Eyed)", "Ray (Spotted)", "Ray (Spotted)", "Ray (Spotted)", "Ray (Spotted)", "Ray (Starry)", "Ray (Starry)", "Ray (Starry)", "Ray (Thornback)", "Ray (Thornback)", "Ray (Thornback)", "Ray (Thornback)", "Ray (Thornback)", "Ray (Thornback)", "Ray (Undulate)", "Ray (Undulate)", "Ray (Unspecified)", "Ray's Bream", "Ray's Bream", "Ray's Bream", "Ray's Bream", "Ray's Bream", "Ray's Bream", "Ray's Bream", "Ray's Bream", "Ray's Bream", "Red Band Fish", "Red Band Fish", "Red Band Fish", "Red Band Fish", "Red Band Fish", "Red Band Fish", "Red Band Fish", "Red Band Fish", "Red Band Fish", "Red Band Fish", "Red Band Fish", "Red Band Fish", "Red Mullet", "Red Mullet", "Red Mullet", "Red Mullet", "Red Scorpion Fish", "Red Scorpion Fish", "Red Scorpion Fish", "Red Scorpion Fish", "Red Scorpion Fish", "Red Scorpion Fish", "Red Scorpion Fish", "Red Scorpion Fish", "Red Scorpion Fish", "Red Scorpion Fish", "Red Scorpion Fish", "Red Sea Bream", "Red Sea Bream", "Red Sea Bream", "Rock cook Wrasse", "Rock cook Wrasse", "Rock cook Wrasse", "Rock cook Wrasse", "Rock cook Wrasse", "Rock Goby", "Rockling (Unspecified)", "Rockling (Unspecified)", "Rudderfish", "Rudderfish", "Rudderfish", "Rudderfish", "Rudderfish", "Rudderfish", "Rudderfish", "Rudderfish", "Rudderfish", "Rudderfish", "Rudderfish", "Rudderfish", "Rudderfish", "Rudderfish", "Rudderfish", "Rudderfish", "Rudderfish", "Saithe (Coley, Coalfish)", "Saithe (Coley, Coalfish)", "Saithe (Coley, Coalfish)", "Saithe (Coley, Coalfish)", "Saithe (Coley, Coalfish)", "Saithe (Coley, Coalfish)", "Salmon", "Sand eel (Greater)", "Sand eel (Greater)", "Sand eel (Greater)", "Sand eel (Greater)", "Sand eel (Greater)", "Sand eel (Lesser)", "Sand eel (Lesser)", "Sand eel (Unspecified)", "Sand eel (Unspecified)", "Sand eel (Unspecified)", "Sand Goby", "Sand Smelt (Silversides)", "Sand Smelt (Silversides)", "Sand Smelt (Silversides)", "Sand Smelt (Silversides)", "Sand Smelt (Silversides)", "Sand Sole", "Scad (Horse Mackerel)", "Scad (Horse Mackerel)", "Scad (Horse Mackerel)", "Scad (Horse Mackerel)", "Scad (Horse Mackerel)", "Scad (Horse Mackerel)", "Scad (Horse Mackerel)", "Scad (Horse Mackerel)", "Scad (Horse Mackerel)", "Scad (Horse Mackerel)", "Scad (Horse Mackerel)", "Scad (Horse Mackerel)", "Scale-rayed Wrasse", "Scale-rayed Wrasse", "Sea Scorpion (Long Spined)", "Sea Scorpion (Long Spined)", "Sea Scorpion (Long Spined)", "Sea Scorpion (Long Spined)", "Sea Scorpion (Long Spined)", "Sea Scorpion (Long Spined)", "Sea Scorpion (Long Spined)", "Sea Scorpion (Long Spined)", "Sea Scorpion (Short Spined)", "Sea Scorpion (Short Spined)", "Sea Scorpion (Short Spined)", "Sea Scorpion (Short Spined)", "Sea Scorpion (Unspecified)", "Sea Scorpion (Unspecified)", "Sea Scorpion (Unspecified)", "Sea Scorpion (Unspecified)", "Sea Scorpion (Unspecified)", "Sea Scorpion (Unspecified)", "Sea Scorpion (Unspecified)", "Sea Scorpion (Unspecified)", "Sea Scorpion (Unspecified)", "Sea Scorpion (Unspecified)", "Sea Scorpion (Unspecified)", "Sea Scorpion (Unspecified)", "Sea Scorpion (Unspecified)", "Sea Scorpion (Unspecified)", "Sea Scorpion (Unspecified)", "Sea Trout (Sewin)", "Sea Trout (Sewin)", "Sea Trout (Sewin)", "Sea Trout (Sewin)", "Sea Trout (Sewin)", "Sea Trout (Sewin)", "Sea Trout (Sewin)", "Sea Trout (Sewin)", "Sea Trout (Sewin)", "Shad (Unspecified)", "Shanny", "Shanny", "Shanny", "Shanny", "Shanny", "Sharks (Great)", "Shore Rockling", "Silver Eel (European)", "Silver Eel (European)", "Silver Eel (European)", "Silver Eel (European)", "Silver Eel (European)", "Silver Eel (European)", "Silver Eel (European)", "Silver Eel (European)", "Six-gilled Shark", "Six-gilled Shark", "Six-gilled Shark", "Six-gilled Shark", "Six-gilled Shark", "Six-gilled Shark", "Six-gilled Shark", "Six-gilled Shark", "Skate (Common)", "Skate (Common)", "Skate (Unspecified)", "Skate (White)", "Skate (White)", "Skate (White)", "Skate (White)", "Skate (White)", "Skate (White)", "Skate (White)", "Skate/Ray (Unspecified)", "Smooth Hound", "Smooth Hound", "Smooth Hound", "Smooth Hound", "Smooth Hound", "Smooth Hound", "Smooth Hound", "Smooth Hound", "Smooth Hound", "Smooth Hound", "Smooth Hound", "Smooth Hound", "Smooth Hound", "Smooth Hound", "Smooth Hound", "Smooth Hound", "Sole (Unspecified)", "Solenette", "Solenette", "Solenette", "Solenette", "Solenette", "Solenette", "Spanish Mackerel", "Spanish Mackerel", "Spanish Mackerel", "Spanish Mackerel", "Spanish Mackerel", "Spanish Mackerel", "Spanish Mackerel", "Spanish Mackerel", "Spanish Mackerel", "Spanish Mackerel", "Spanish Mackerel", "Spanish Mackerel", "Spanish Mackerel", "Spanish Mackerel", "Spanish Mackerel", "Spanish Mackerel", "Sprat", "Sprat", "Spurdog (Spiny Dogfish)", "Spurdog (Spiny Dogfish)", "Spurdog (Spiny Dogfish)", "Spurdog (Spiny Dogfish)", "Spurdog (Spiny Dogfish)", "Spurdog (Spiny Dogfish)", "Spurdog (Spiny Dogfish)", "Spurdog (Spiny Dogfish)", "Spurdog (Spiny Dogfish)", "Squid (European)", "Squid (European)", "Squid (Northern)", "Squid (Unspecified)", "Sturgeon (Unspecified)", "Sunfish", "Sunfish", "Sunfish", "Sunfish", "Sunfish", "Tadpole Fish", "Tadpole Fish", "Tadpole Fish", "Tadpole Fish", "Tadpole Fish", "Tadpole Fish", "Tadpole Fish", "Tadpole Fish", "Tadpole Fish", "Thick Lipped Grey Mullet", "Thick Lipped Grey Mullet", "Thick Lipped Grey Mullet", "Thick Lipped Grey Mullet", "Thick Lipped Grey Mullet", "Thick Lipped Grey Mullet", "Thin Lipped Grey Mullet", "Thin Lipped Grey Mullet", "Thin Lipped Grey Mullet", "Thin Lipped Grey Mullet", "Thin Lipped Grey Mullet", "Thin Lipped Grey Mullet", "Three-bearded Rockling", "Three-bearded Rockling", "Three-bearded Rockling", "Three-bearded Rockling", "Three-bearded Rockling", "Three-bearded Rockling", "Three-bearded Rockling", "Thresher Shark", "Thresher Shark", "Thresher Shark", "Tompot Blenny", "Tompot Blenny", "Tope", "Tope", "Tope", "Tope", "Tope", "Topknot", "Topknot", "Triggerfish", "Triggerfish", "Triggerfish", "Triggerfish", "Triggerfish", "Turbot", "Tusk", "Tusk", "Twaite Shad", "Vivaporous Blenny", "Vivaporous Blenny", "Vivaporous Blenny", "Weeverfish (Greater)", "Weeverfish (Greater)", "Weeverfish (Lesser)", "Weeverfish (Lesser)", "Weeverfish (Unspecified)", "Weeverfish (Unspecified)", "White Sea Bream", "White Sea Bream", "White Sea Bream", "Whiting", "Whiting", "Whiting", "Whiting", "Whiting", "Whiting", "Witch", "Wrasse (Unspecified)", "Wreckfish", "Wreckfish", "Wreckfish", "Wreckfish", "Wreckfish", "Wreckfish", "Wreckfish", "Wreckfish", "Wreckfish", "Wreckfish", "Wreckfish", "Wreckfish", "Wreckfish", "Wreckfish", "Wreckfish", "Wreckfish", "Yellowfin Tuna", "Yellowfin Tuna", "Yellowfin Tuna", "Yellowfin Tuna", "Couch's Goby", "Couch's Goby", "Couch's Goby", "Bass", "Bass", "Bass", "Bass", "Bass", "Bass"]
list_species_alias = list(set(list_species_alias))

#Retun all items not in both lists
diff = baselib.list_symmetric_diff(list_species, list_species_alias)
diff_lc = [x.lower() for x in diff]

# %%
if diff:
    print(diff)
else:
    print('Lists Match Exactly')
# Out:
# Lists Match Exactly

# %%
'long rough dab' in diff_lc
# Out:
# False
